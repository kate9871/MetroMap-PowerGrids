# %% [markdown]
# # Import Packages

# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from pyomo.environ import*
import math
import csv
from IPython.display import display

from pyproj import Transformer 
from itertools import combinations
from shapely.geometry import LineString

import matplotlib.lines as mlines

# %% [markdown]
# # Access Files
#
# Creating Dataframe of particular country and particular links

# %%
filename = 'PT.csv'
file_path = filename

country_df = pd.read_csv(file_path)

print(f"Shape of df is: {country_df.shape}")
#display(country_df)  




## Add scaling factor if needed to the x y positions for graphing and optimisation
# Infeasible when x y values are too large

scaling_factor = 0.1

# Scale 'src_x' and 'src_y' columns
country_df['src_x'] = country_df['src_x'] * scaling_factor
country_df['src_y'] = country_df['src_y'] * scaling_factor

# Scale 'dst_x' and 'dst_y' columns
country_df['dst_x'] = country_df['dst_x'] * scaling_factor
country_df['dst_y'] = country_df['dst_y'] * scaling_factor

display(country_df)

#country_df = country_df[country_df['voltage'] == 380]

#print(f"Shape of filtered df with voltage 380 is: {country_df.shape}")
#display(country_df)
# Out:
# Shape of df is: (127, 18)
#      link_id  src_bus_id  dst_bus_id  voltage  circuits dc underground  \
# 0       2655        1569        7889    220.0         2  f           f
# 1       2717        1531        6809    220.0         2  f           t
# 2       2723        1521        1760    220.0         1  f           f
# 3       2761        1521        7889    220.0         1  f           f
# 4       2724        1523        7551    220.0         1  f           f
# ..       ...         ...         ...      ...       ... ..         ...
# 122     9479        1530        7009    380.0         2  f           f
# 123     2559        1501        7158    380.0         2  f           f
# 124     2726        1507        7177    380.0         2  f           f
# 125     2762        1551        1559    380.0         1  f           f
# 126     2806        1503        1757    380.0         1  f           f
#
#     under_construction      length_m  \
# 0                    f  23714.822466
# 1                    f   7115.639038
# 2                    f  14003.703776
# 3                    f  20587.988389
# 4                    f  25416.175732
# ..                 ...           ...
# 122                  f  38042.875856
# 123                  f  30126.683107
# 124                  f  10399.767182
# 125                  f  88348.862413
# 126                  f  17267.361304
#
#                                                   tags  \
# 0    'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 1    'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 2    'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 3    'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 4    'text_'=>' '  'symbol'=>'220 kV Transmission L...
# ..                                                 ...
# 122  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
# 123  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
# 124  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
# 125  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
# 126  'symbol'=>'380-400 kV Transmission Line  1 Cir...
#
#                           src_coord                              dst_coord  \
# 0    (-6.71264599999999, 41.071069)                 (-6.899414, 41.203456)
# 1    (-9.04174799999999, 38.882481)  (-9.05415934312684, 38.9459238316964)
# 2            (-7.119141, 41.153842)          (-7.13012700000001, 41.26955)
# 3            (-7.119141, 41.153842)                 (-6.899414, 41.203456)
# 4            (-6.503906, 41.376809)                 (-6.767578, 41.286062)
# ..                              ...                                    ...
# 122          (-8.887939, 40.010787)  (-8.82202107352201, 39.9097359718023)
# 123   (-8.23974600000001, 41.99216)  (-8.14982698826844, 42.0303378869125)
# 124  (-8.77807599999999, 39.681826)         (-8.89892600000001, 39.664914)
# 125  (-7.78930700000001, 40.946714)         (-6.84448199999999, 41.244772)
# 126  (-7.63549799999999, 41.697526)          (-7.76733399999999, 41.58258)
#
#     src_country dst_country          src_x          src_y          dst_x  \
# 0            ES          PT  -74724.833460  502282.998336  -76803.925325
# 1            PT          PT -100652.278324  470485.193676 -100790.440764
# 2            PT          PT  -79249.915101  503505.987440  -79372.210693
# 3            PT          PT  -79249.915101  503505.987440  -76803.925325
# 4            PT          PT  -72401.150409  506808.078785  -75336.333686
# ..          ...         ...            ...            ...            ...
# 122          PT          PT  -98940.084368  486750.994078  -98206.289367
# 123          ES          PT  -91724.432899  515980.512241  -90723.459039
# 124          PT          PT  -97717.095046  481981.325397  -99062.391093
# 125          PT          PT  -86710.168887  500448.516525  -76192.425098
# 126          PT          PT  -84997.974931  511577.744238  -86465.566570
#
#              dst_y
# 0    504239.785350
# 1    471392.858284
# 2    505218.189517
# 3    504239.785350
# 4    505462.774904
# ..             ...
# 122  485283.401364
# 123  516552.499625
# 124  481736.730861
# 125  504851.279339
# 126  509865.559405
#
# [127 rows x 18 columns]

# %% [markdown]
# ## Functions
# Calculate Forward Sector : Calculates the sector of an edge starting at the positive x axis going in counterclockwise direction. Sectors are split from 0 - 7.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Function - NetworkX Implementation and Attributes

# %%
def calculate_forward_sector(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    # Angle in radians
    angle_rad = math.atan2(dy, dx)
    
    # Convert to degreees
    angle_deg = math.degrees(angle_rad)
    
    # Angle is rounded to nearest multiple of 45
    # Sector value calculated, modulo 8 used 
    sector = round(angle_deg / 45) % 8
    
    return sector





def euclidean_distance(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    return math.sqrt((dx)**2 + (dy)**2)




def get_non_incident_edge_pairs(G):
    non_incident_edge_pairs = []
    
    # combinations - generates all possible pairs of edges from graph G without repeating the same pair
    # '2' indicates we're looking for combinationes of 2 edges
    for edge1, edge2 in combinations(G.edges(), 2):
        
        # edges are sets and the '&' checks that they have no common elements (ie nodes)
        if not set(edge1) & set(edge2):
            non_incident_edge_pairs.append((edge1, edge2))
    return non_incident_edge_pairs    


def midpoint(pos1, pos2):
    """Calculate the midpoint between two positions."""
    return ((pos1[0] + pos2[0]) / 2, (pos1[1] + pos2[1]) / 2)



def calculate_distance(midpoint1, midpoint2):
    return math.sqrt((midpoint2[0] - midpoint1[0]) ** 2 + (midpoint2[1] - midpoint1[1]) ** 2)




def get_non_incident_edge_distance(G):
    non_incident_edge_distances = {}
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Calculate the midpoints for each edge
        midpoint1 = midpoint(src_pos1, tgt_pos1)
        midpoint2 = midpoint(src_pos2, tgt_pos2)

        # Calculate the distance between the midpoints of the two edges
        dist = calculate_distance(midpoint1, midpoint2)

        # Store the distance with the edge pair as the key
        non_incident_edge_distances[(edge1, edge2)] = dist

    return non_incident_edge_distances




def calculate_angle(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    angle_radians = math.atan2(dy, dx)
    angle_degrees = math.degrees(angle_radians)  # Convert the angle to degrees
    
    # Normalize the angle to be within 0 to 360 degrees
    angle_degrees = (angle_degrees + 360) % 360

    return angle_degrees







 
def get_filtered_neighbour_order(G):
    
    # Convert the directed graph to an undirected graph to consider all adjacent nodes as neighbours
    G_undirected = G.to_undirected()
    
    # Create Dictionary to story nodes neighbour orders
    neighbour_order = {}
    for node in G_undirected.nodes():
        
        # Check if the node has 2 or more neighbours
        if G_undirected.degree(node) >= 2:
        
            # Access the position of the current node
            src_pos = G_undirected.nodes[node]['pos']
            src_x, src_y = src_pos
            
            # Create list to store angle size of neighbours with src node
            angles_neighbours = []
            
            
            
            for neighbour in G_undirected.neighbors(node):
                # Access the position tuple of the neighbour node using the 'pos' attribute
                dst_pos = G_undirected.nodes[neighbour]['pos']
                dst_x, dst_y = dst_pos
                
                # Calculate the angle from the source node to the neighbour node
                angle = calculate_angle(src_x, src_y, dst_x, dst_y)
                
                # Append the angle and neighbour to the list
                angles_neighbours.append((angle, neighbour)) 
                
                
            
            # Sort the list of (angle, neighbour) pairs by angle in ascending order
            angles_neighbours.sort()
            
            # Extract the sorted neighbours from the sorted list of pairs
            sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]
            
            # Check conditions to move the last neighbour to the first position
            if angles_neighbours[-1][0] > 315 and ((360 - angles_neighbours[-1][0]) < angles_neighbours[0][0]):
                # Move the last neighbour to the first position
                sorted_neighbours.insert(0, sorted_neighbours.pop())
            
            
            # Store the sorted list of neighbours in the dictionary with the src_node as the key
            neighbour_order[node] = sorted_neighbours
    
    return neighbour_order

# %% [markdown]
# # NetworkX Implementation
# Dataframe is accessed where nodes and edges are added to graph.
# Forward and backward sector of a particular edge are found and stored as attributes along with the voltage information.

# %%
# Initialize a directed graph since we have source and destination
G = nx.DiGraph()

# Loop through the DataFrame rows to add edges and nodes to the graph
for index, row in country_df.iterrows():
    src_node = row['src_bus_id']
    dst_node = row['dst_bus_id']
    voltage = row['voltage']
    
    # Add the source and destination nodes if they don't already exist
    if src_node not in G:
        G.add_node(src_node, pos=(row['src_x'], row['src_y']))
    if dst_node not in G:
        G.add_node(dst_node, pos=(row['dst_x'], row['dst_y']))
        
        
        
    # Calculate the forward sector for edges
    forward_sector = calculate_forward_sector(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])

    # Backward sector
    backward_sector = (forward_sector + 4) % 8
    
    distance = euclidean_distance(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])
    
    # Add an edge between the source and destination nodes, voltage is attribute
    G.add_edge(src_node, dst_node, 
               voltage = voltage, 
               forward_sector = forward_sector, 
               backward_sector = backward_sector,
               distance = distance
               )


# Create list of non-incident edge pairs
non_incident_edge_pairs = get_non_incident_edge_pairs(G)

print(non_incident_edge_pairs)



# Print non-incident edge pairs
print("Non-incident edge pairs:")
for edge_pair in non_incident_edge_pairs:
    print(edge_pair)
    
ordered_neighbours_dict = get_filtered_neighbour_order(G)
print("\nNodes with more than 2 neighbours ordered:")
print(ordered_neighbours_dict)
for node, neighbours in ordered_neighbours_dict.items():
    print(len(neighbours))
    
    
 # dictionary
non_incident_edge_distances = get_non_incident_edge_distance(G)

# Find the non-incident edge pair with the maximum distance
max_distance_pair = max(non_incident_edge_distances, key=non_incident_edge_distances.get)

# Print the non-incident edge pair with the maximum distance and its value
max_distance_value = non_incident_edge_distances[max_distance_pair]
print(f"Non-incident edge pair with maximum distance: {max_distance_pair} with distance {max_distance_value}")
# Out:
# [((1569, 7889), (1531, 6809)), ((1569, 7889), (1531, 6824)), ((1569, 7889), (1521, 1760)), ((1569, 7889), (1521, 1627)), ((1569, 7889), (1521, 1551)), ((1569, 7889), (1523, 7551)), ((1569, 7889), (1523, 7799)), ((1569, 7889), (1523, 7627)), ((1569, 7889), (1533, 1756)), ((1569, 7889), (1533, 1561)), ((1569, 7889), (1533, 6825)), ((1569, 7889), (1533, 1538)), ((1569, 7889), (1559, 7551)), ((1569, 7889), (1559, 7799)), ((1569, 7889), (1559, 7627)), ((1569, 7889), (1559, 1759)), ((1569, 7889), (1492, 6810)), ((1569, 7889), (1536, 1563)), ((1569, 7889), (1557, 1561)), ((1569, 7889), (1557, 6815)), ((1569, 7889), (1549, 1559)), ((1569, 7889), (1564, 7585)), ((1569, 7889), (1522, 1551)), ((1569, 7889), (1522, 1525)), ((1569, 7889), (1551, 1559)), ((1569, 7889), (1567, 7182)), ((1569, 7889), (1519, 1551)), ((1569, 7889), (1519, 7698)), ((1569, 7889), (1540, 1563)), ((1569, 7889), (1540, 7397)), ((1569, 7889), (1494, 6811)), ((1569, 7889), (6808, 7452)), ((1569, 7889), (1761, 7187)), ((1569, 7889), (1510, 7219)), ((1569, 7889), (1510, 1517)), ((1569, 7889), (917, 7175)), ((1569, 7889), (917, 1500)), ((1569, 7889), (917, 1134)), ((1569, 7889), (917, 1533)), ((1569, 7889), (917, 1011)), ((1569, 7889), (917, 7178)), ((1569, 7889), (1508, 7174)), ((1569, 7889), (1508, 1514)), ((1569, 7889), (1508, 1512)), ((1569, 7889), (1542, 7231)), ((1569, 7889), (1498, 7008)), ((1569, 7889), (1498, 1540)), ((1569, 7889), (1490, 7007)), ((1569, 7889), (1490, 1497)), ((1569, 7889), (1550, 6812)), ((1569, 7889), (6816, 6852)), ((1569, 7889), (1513, 6851
# {7889: [1569, 1521], 1531: [6824, 6809, 796], 1521: [7889, 1760, 1551, 1493, 1627], 1523: [7799, 7627, 7551], 7551: [1523, 1559], 1533: [1561, 6825, 917, 1538, 1134, 1756], 1559: [1759, 7799, 7551, 7627, 1549, 1551], 1563: [1540, 1536], 1557: [6815, 1561], 1561: [1557, 1533], 7585: [1564, 7180, 7181], 1522: [1525, 1551], 1551: [1521, 1559, 1522, 1519, 1499], 1519: [7698, 1517, 1551], 1540: [1498, 1488, 1538, 7397, 1563], 7452: [6808, 1541, 6807], 1510: [1517, 7219], 917: [1500, 7178, 1134, 1533, 1011, 7175], 1508: [7174, 1512, 1514], 1498: [1491, 1540, 7008], 1490: [1497, 7007], 6852: [6816, 1762], 1512: [6839, 1508, 1514], 1762: [6817, 6852], 1517: [1519, 1506, 1510], 1506: [1517, 1515], 1515: [1506, 6838, 1505, 1489], 7799: [1537, 1525, 1559, 1523], 1514: [1508, 1512], 1500: [1538, 917, 1527], 1491: [1493, 1498], 1493: [1521, 1491], 1134: [1533, 917], 1525: [7799, 1522], 1538: [1528, 1540, 6813, 1533, 1500], 7627: [1526, 1559, 1523], 1528: [7844, 1507, 1538], 7844: [1673, 1535, 1528], 1535: [1496, 7844], 7480: [1078, 1554, 1544], 1544: [1722, 7480, 1504], 871: [1504, 1011, 7491, 1126], 7491: [871, 1558], 1011: [917, 871], 1504: [1544, 871], 1501: [7158, 1505], 1505: [1501, 1515], 1507: [1528, 7177], 1545: [1757, 7179], 1757: [1503, 1502, 1545]}
# 2
# 3
# 5
# 3
# 2
# 6
# 6
# 2
# 2
# 2
# 3
# 2
# 5
# 3
# 5
# 3
# 2
# 6
# 3
# 3
# 2
# 2
# 3
# 2
# 3
# 2
# 4
# 4
# 2
# 3
# 2
# 2
# 2
# 2
# 5
# 3
# 3
# 3
# 2
# 3
# 3
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# Non-incident edge pair with maximum distance: ((1558, 7491), (1501, 7158)) with distance 68286.81538532299

# %% [markdown]
# ## Drawing NetworkX Graph

# %%
pos = nx.get_node_attributes(G, 'pos')



""" def highest_voltage_color(G, node):
    # Get highest voltage of all connected edges
    highest_voltage = max((d['voltage'] for u, v, d in G.edges(node, data=True)), default=0)
    return voltage_colors.get(highest_voltage, 'grey')      #default colout """


def draw_graph(G, pos):
    plt.figure(figsize=(15, 15))
    
    # Convert to undirected graph for the purpose of finding node outline colors
    G_undirected = G.to_undirected()

    voltage_colors = {
        132: 'black',
        220: 'green',
        380: 'red',
        300: 'orange',
        500: 'yellow',
        750: 'purple'
    }

    # Determine the highest voltage color for each node
    node_outline_color = {}
    for node in G.nodes():
        connected_edges = G_undirected.edges(node, data=True)
        highest_voltage = max((data['voltage'] for _, _, data in connected_edges), default=0)
        node_outline_color[node] = voltage_colors.get(highest_voltage, 'grey')

    # Draw nodes with highest voltage outline color
    for node, color in node_outline_color.items():
        nx.draw_networkx_nodes(G, pos, nodelist=[node], node_color='skyblue',
                               edgecolors=color, node_size=500, linewidths=2)


    # Define custom lines for the legend with appropriate colors and labels for each voltage level
    legend_lines = [
        
        mlines.Line2D([], [], color='black', markersize=30, label='132 kV', linewidth=3),
        mlines.Line2D([], [], color='green', markersize=30, label='220 kV', linewidth=3),
        mlines.Line2D([], [], color='orange', markersize=30, label='300 kV', linewidth=3),
        mlines.Line2D([], [], color='red', markersize=30, label='380 kV', linewidth=3),
        mlines.Line2D([], [], color='yellow', markersize=30, label='500 kV', linewidth=3),
        mlines.Line2D([], [], color='purple', markersize=30, label='750 kV', linewidth=3)
    ]

    # Draw the graph edges with different colors based on the voltage
    for (u, v, d) in G.edges(data=True):
        if d['voltage'] == 380:
            edge_color = 'red'
        elif d['voltage'] == 220:
            edge_color = 'green'
        elif d['voltage'] == 132:
            edge_color = 'black'
        elif d['voltage'] == 300:
            edge_color = 'orange'
        elif d['voltage'] == 500:
            edge_color = 'yellow'
        elif d['voltage'] == 750:
            edge_color = 'purple'
        else:
            edge_color = 'grey'  # Default color for unspecified or unknown voltages
        nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], edge_color=edge_color, width=3, arrows=False)

    # Draw the node labels
    nx.draw_networkx_labels(G, pos, font_size=8)

    # Create edge labels for voltages, using 'link_id' or another attribute if desired
    edge_labels = nx.get_edge_attributes(G, 'link_id')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, label_pos=0.5, font_size=7)

    # Add the legend to the plot with all line types
    plt.legend(handles=legend_lines, loc='lower right', fontsize=20)
    plt.axis('equal')
    plt.grid(True)
    # Show the plot
    plt.show()
    
    
draw_graph(G, pos)

# %% [markdown]
# ## Access edge information from NetworkX Graph

# %%
def get_edge_info(G, edge):
    node1, node2 = edge
    
    # edge attributes eg voltage forward/backward sector are stored in edge data
    edge_data = G.get_edge_data(node1, node2)
    
    # Additional edge information
    edge_information = {
        'edge': edge,
        'source': node1,
        'destination': node2,
        'source_position': G.nodes[node1].get('pos'),
        'destination_position': G.nodes[node2].get('pos'),
        'source_neighbors': list(G.successors(node1)),  # or list(G.successors(u)) for DiGraph
        'destination_neighbors': list(G.predecessors(node2)),  # or list(G.predecessors(v)) for DiGraph
        'source_degree': G.degree(node1),
        'destination_degree': G.degree(node2)
    }
    
    # Merge edge_data into edge_info
    edge_information.update(edge_data)
    return edge_information

    
    
# Print Specified Edge Details
edge_details = {}
for edge in G.edges():
    edge_details[edge] = get_edge_info(G, edge)
    print(edge_details[edge])
    
    forward = edge_details[edge].get('forward_sector')
    backward = edge_details[edge].get('backward_sector')
    print(f"Forward sector for edge {edge}: {forward}")
    print(f"Backward sector for edge {edge}: {backward}\n")
# Out:
# {'edge': (1569, 7889), 'source': 1569, 'destination': 7889, 'source_position': (-74724.83345955035, 502282.99833607464), 'destination_position': (-76803.92532519827, 504239.7853501093), 'source_neighbors': [7889], 'destination_neighbors': [1569, 1521], 'source_degree': 1, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 2855.1074242658415}
# Forward sector for edge (1569, 7889): 3
# Backward sector for edge (1569, 7889): 7
#
# {'edge': (1531, 6809), 'source': 1531, 'destination': 6809, 'source_position': (-100652.27832410985, 470485.1936758575), 'destination_position': (-100790.44076380401, 471392.8582843113), 'source_neighbors': [6809, 6824], 'destination_neighbors': [1531], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 918.1197640732104}
# Forward sector for edge (1531, 6809): 2
# Backward sector for edge (1531, 6809): 6
#
# {'edge': (1531, 6824), 'source': 1531, 'destination': 6824, 'source_position': (-100652.27832410985, 470485.1936758575), 'destination_position': (-100163.08482181885, 471585.89267943485), 'source_neighbors': [6809, 6824], 'destination_neighbors': [1531], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1204.511759660281}
# Forward sector for edge (1531, 6824): 1
# Backward sector for edge (1531, 6824): 5
#
# {'edge': (1521, 1760), 'source': 1521, 'destination': 1760, 'source_position': (-79249.91510055165, 503505.98744034034), 'destination_position': (-79372.21069313725, 505218.1895169558), 'source_neighbors': [1760, 7889, 1627, 1551], 'destination_neighbors': [1521], 'source_degree': 5, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 1716.5640573926185}
# Forward sector for edge (1521, 1760): 2
# Backward sector for edge (1521, 1760): 6
#
# {'edge': (1521, 7889), 'source': 1521, 'destination': 7889, 'source_position': (-79249.91510055165, 503505.98744034034), 'destination_position': (-76803.92532519827, 504239.7853501093), 'source_neighbors': [1760, 7889, 1627, 1551], 'destination_neighbors': [1569, 1521], 'source_degree': 5, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 2553.68857802092}
# Forward sector for edge (1521, 7889): 0
# Backward sector for edge (1521, 7889): 4
#
# {'edge': (1521, 1627), 'source': 1521, 'destination': 1627, 'source_position': (-79249.91510055165, 503505.98744034034), 'destination_position': (-75458.62927896167, 500203.91006316384), 'source_neighbors': [1760, 7889, 1627, 1551], 'destination_neighbors': [1521], 'source_degree': 5, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 5027.679701994746}
# Forward sector for edge (1521, 1627): 7
# Backward sector for edge (1521, 1627): 3
#
# {'edge': (1521, 1551), 'source': 1521, 'destination': 1551, 'source_position': (-79249.91510055165, 503505.98744034034), 'destination_position': (-86710.16888724826, 500448.5165247797), 'source_neighbors': [1760, 7889, 1627, 1551], 'destination_neighbors': [1522, 1519, 1521, 1499], 'source_degree': 5, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 8062.475734005047}
# Forward sector for edge (1521, 1551): 4
# Backward sector for edge (1521, 1551): 0
#
# {'edge': (1523, 7551), 'source': 1523, 'destination': 7551, 'source_position': (-72401.15040873167, 506808.07878488547), 'destination_position': (-75336.33368637609, 505462.774903637), 'source_neighbors': [7551, 7799, 7627], 'destination_neighbors': [1523, 1559], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 3228.7990656381226}
# Forward sector for edge (1523, 7551): 5
# Backward sector for edge (1523, 7551): 1
#
# {'edge': (1523, 7799), 'source': 1523, 'destination': 7799, 'source_position': (-72401.15040873167, 506808.07878488547), 'destination_position': (-71300.45667961502, 507908.7595906377), 'source_neighbors': [7551, 7799, 7627], 'destination_neighbors': [1523, 1559, 1525, 1537], 'source_degree': 3, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1556.6068615639922}
# Forward sector for edge (1523, 7799): 1
# Backward sector for edge (1523, 7799): 5
#
# {'edge': (1523, 7627), 'source': 1523, 'destination': 7627, 'source_position': (-72401.15040873167, 506808.07878488547), 'destination_position': (-74113.34436467382, 507297.2718164784), 'source_neighbors': [7551, 7799, 7627], 'destination_neighbors': [1526, 1523, 1559], 'source_degree': 3, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1780.7071530501291}
# Forward sector for edge (1523, 7627): 4
# Backward sector for edge (1523, 7627): 0
#
# {'edge': (1533, 1756), 'source': 1533, 'destination': 1756, 'source_position': (-103342.85928463432, 469384.50010553165), 'destination_position': (-102975.96137492888, 468039.2181731444), 'source_neighbors': [1756, 1561, 6825, 1538], 'destination_neighbors': [1533], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 1394.4165639269506}
# Forward sector for edge (1533, 1756): 6
# Backward sector for edge (1533, 1756): 2
#
# {'edge': (1533, 1561), 'source': 1533, 'destination': 1561, 'source_position': (-103342.85928463432, 469384.50010553165), 'destination_position': (-101875.26764581213, 468406.1083942824), 'source_neighbors': [1756, 1561, 6825, 1538], 'destination_neighbors': [1557, 1533], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 1763.8241292663088}
# Forward sector for edge (1533, 1561): 7
# Backward sector for edge (1533, 1561): 3
#
# {'edge': (1533, 6825), 'source': 1533, 'destination': 6825, 'source_position': (-103342.85928463432, 469384.50010553165), 'destination_position': (-101013.8879260028, 471324.1046710753), 'source_neighbors': [1756, 1561, 6825, 1538], 'destination_neighbors': [1533], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 3030.870082996581}
# Forward sector for edge (1533, 6825): 1
# Backward sector for edge (1533, 6825): 5
#
# {'edge': (1533, 1538), 'source': 1533, 'destination': 1538, 'source_position': (-103342.85928463432, 469384.50010553165), 'destination_position': (-100163.08482181885, 477456.2513327105), 'source_neighbors': [1756, 1561, 6825, 1538], 'destination_neighbors': [1500, 1528, 1533], 'source_degree': 6, 'destination_degree': 5, 'voltage': 380.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 8675.490390049234}
# Forward sector for edge (1533, 1538): 2
# Backward sector for edge (1533, 1538): 6
#
# Forward sector for edge (1557, 1561): 6
# Backward sector for edge (1557, 1561): 2
#
# {'edge': (1557, 6815), 'source': 1557, 'destination': 6815, 'source_position': (-101875.26764581213, 469506.8009087929), 'destination_position': (-102166.77692814318, 470651.054550506), 'source_neighbors': [1561, 6815], 'destination_neighbors': [1557], 'source_degree': 2, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 1180.8022943147187}
# Forward sector for edge (1557, 6815): 2
# Backward sector for edge (1557, 6815): 6
#
# {'edge': (1549, 1559), 'source': 1549, 'destination': 1559, 'source_position': (-77415.42555202401, 509376.35433360667), 'destination_position': (-76192.42509837255, 504851.27933856996), 'source_neighbors': [1559], 'destination_neighbors': [1549, 1551], 'source_degree': 1, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 4687.433607032541}
# Forward sector for edge (1549, 1559): 6
# Backward sector for edge (1549, 1559): 2
#
# {'edge': (1564, 7585), 'source': 1564, 'destination': 7585, 'source_position': (-91602.13730600581, 505462.774903637), 'destination_position': (-91846.72849117668, 504606.6857026564), 'source_neighbors': [7585], 'destination_neighbors': [1564, 7181, 7180], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 890.3446343404961}
# Forward sector for edge (1564, 7585): 6
# Backward sector for edge (1564, 7585): 2
#
# {'edge': (1522, 1551), 'source': 1522, 'destination': 1551, 'source_position': (-82674.2918804871, 504484.3898649512), 'destination_position': (-86710.16888724826, 500448.5165247797), 'source_neighbors': [1551, 1525], 'destination_neighbors': [1522, 1519, 1521, 1499], 'source_degree': 2, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 5707.5894063615215}
# Forward sector for edge (1522, 1551): 5
# Backward sector for edge (1522, 1551): 1
#
# {'edge': (1522, 1525), 'source': 1522, 'destination': 1525, 'source_position': (-82674.2918804871, 504484.3898649512), 'destination_position': (-74969.43577667064, 507664.16247146105), 'source_neighbors': [1551, 1525], 'destination_neighbors': [1522], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 8335.212139449617}
# Forward sector for edge (1522, 1525): 0
# Backward sector for edge (1522, 1525): 4
#
# {'edge': (1551, 1559), 'source': 1551, 'destination': 1559, 'source_position': (-86710.16888724826, 500448.5165247797), 'destination_position': (-76192.42509837255, 504851.27933856996), 'source_neighbors': [1559], 'destination_neighbors': [1549, 1551], 'source_degree': 5, 'destination_degree': 6, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 11402.072390707215}
# Forward sector for edge (1551, 1559): 1
# Backward sector for edge (1551, 1559): 5
#
# {'edge': (1567, 7182), 'source': 1567, 'destination': 7182, 'source_position': (-85609.4751581315, 500570.80596262193), 'destination_position': (-86767.03857541335, 500364.88413961756), 'source_neighbors': [7182], 'destination_neighbors': [1567], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1175.736731678761}
# Forward sector for edge (1567, 7182): 4
# Backward sector for edge (1567, 7182): 0
#
# {'edge': (1519, 1551), 'source': 1519, 'destination': 1551, 'source_position': (-87810.8626163649, 502894.4996087302), 'destination_position': (-86710.16888724826, 500448.5165247797), 'source_neighbors': [1551, 7698], 'destination_neighbors': [1522, 1519, 1521, 1499], 'source_degree': 3, 'destination_degree': 5, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 2682.230402536023}
# Forward sector for edge (1519, 1551): 7
# Backward sector for edge (1519, 1551): 3
#
# {'edge': (1519, 7698), 'source': 1519, 'destination': 7698, 'source_position': (-87810.8626163649, 502894.4996087302), 'destination_position': (-88789.249620947, 503628.29286147107), 'source_neighbors': [1551, 7698], 'destination_neighbors': [1519], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 1222.985555312552}
# Forward sector for edge (1519, 7698): 3
# Backward sector for edge (1519, 7698): 7
#
# {'edge': (1540, 1563), 'source': 1540, 'destination': 1563, 'source_position': (-94659.61617623581, 488707.7797382354), 'destination_position': (-94415.0138591156, 484916.50485547504), 'source_neighbors': [1563, 7397], 'destination_neighbors': [1536, 1540], 'source_degree': 5, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 3799.157213144804}
# Forward sector for edge (1540, 1563): 6
# Backward sector for edge (1540, 1563): 2
#
# {'edge': (1540, 7397), 'source': 1540, 'destination': 7397, 'source_position': (-94659.61617623581, 488707.7797382354), 'destination_position': (-95760.30944440828, 485283.4016250316), 'source_neighbors': [1563, 7397], 'destination_neighbors': [1540], 'source_degree': 5, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 3596.9280132898693}
# Forward sector for edge (1540, 7397): 6
# Backward sector for edge (1540, 7397): 2
#
# {'edge': (1494, 6811), 'source': 1494, 'destination': 6811, 'source_position': (-81573.59815137033, 494333.5526103888), 'destination_position': (-81283.45289744173, 495352.4311397213), 'source_neighbors': [6811], 'destination_neighbors': [1494], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 1059.38554167597}
# Forward sector for edge (1494, 6811): 2
# Backward sector for edge (1494, 6811): 6
#
# {'edge': (6808, 7452), 'source': 6808, 'destination': 7452, 'source_position': (-92096.21737648908, 491032.48214154295), 'destination_position': (-93314.32012999884, 491153.7658998027), 'source_neighbors': [7452], 'destination_neighbors': [6808, 1541, 6807], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1224.1258383539173}
# Forward sector for edge (6808, 7452): 4
# Backward sector for edge (6808, 7452): 0
#
# {'edge': (1761, 7187), 'source': 1761, 'destination': 7187, 'source_position': (-96249.50340764348, 507052.666547304), 'destination_position': (-96983.29922705448, 505585.0759905137), 'source_neighbors': [7187], 'destination_neighbors': [1761], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 1640.8163660096473}
# Forward sector for edge (1761, 7187): 5
# Backward sector for edge (1761, 7187): 1
#
# {'edge': (1510, 7219), 'source': 1510, 'destination': 7219, 'source_position': (-96127.207815058, 497635.6341977333), 'destination_position': (-95273.99513748853, 500802.4618106389), 'source_neighbors': [7219, 1517], 'destination_neighbors': [1510], 'source_degree': 2, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 3279.7513629887535}
# Forward sector for edge (1510, 7219): 2
# Backward sector for edge (1510, 7219): 6
#
# {'edge': (1510, 1517), 'source': 1510, 'destination': 1517, 'source_position': (-96127.207815058, 497635.6341977333), 'destination_position': (-91724.43289859139, 501549.2031926717), 'source_neighbors': [7219, 1517], 'destination_neighbors': [1510, 1506], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 5890.70872164044}
# Forward sector for edge (1510, 1517): 1
# Backward sector for edge (1510, 1517): 5
#
# {'edge': (917, 7175), 'source': 917, 'destination': 7175, 'source_position': (-101752.9720532265, 471096.69205266284), 'destination_position': (-100832.37762547085, 470088.97714347235), 'source_neighbors': [7175, 1500, 1134, 1533, 1011, 7178], 'destination_neighbors': [917], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 1364.9115131097524}
# Forward sector for edge (917, 7175): 7
# Backward sector for edge (917, 7175): 3
#
# {'edge': (917, 1500), 'source': 917, 'destination': 1500, 'source_position': (-101752.9720532265, 471096.69205266284), 'destination_position': (-99918.48250469888, 472686.58349399763), 'source_neighbors': [7175, 1500, 1134, 1533, 1011, 7178], 'destination_neighbors': [917], 'source_degree': 6, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 2427.57218201369}
# Forward sector for edge (917, 1500): 1
# Backward sector for edge (917, 1500): 5
#
# {'edge': (917, 1134), 'source': 917, 'destination': 1134, 'source_position': (-101752.9720532265, 471096.69205266284), 'destination_position': (-104565.85973828545, 468161.5145129775), 'source_neighbors': [7175, 1500, 1134, 1533, 1011, 7178], 'destination_neighbors': [917], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 4065.415639049655}
# Forward sector for edge (917, 1134): 5
# Backward sector for edge (917, 1134): 1
#
# {'edge': (917, 1533), 'source': 917, 'destination': 1533, 'source_position': (-101752.9720532265, 471096.69205266284), 'destination_position': (-103342.85928463432, 469384.50010553165), 'source_neighbors': [7175, 1500, 1134, 1533, 1011, 7178], 'destination_neighbors': [917, 1134], 'source_degree': 6, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 2336.523629757357}
# Forward sector for edge (917, 1533): 5
# Backward sector for edge (917, 1533): 1
#
# {'edge': (917, 1011), 'source': 917, 'destination': 1011, 'source_position': (-101752.9720532265, 471096.69205266284), 'destination_position': (-98206.2885487565, 466204.7206476766), 'source_neighbors': [7175, 1500, 1134, 1533, 1011, 7178], 'destination_neighbors': [917, 871], 'source_degree': 6, 'destination_degree': 2, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 6042.379341623834}
# Forward sector for edge (917, 1011): 7
# Backward sector for edge (917, 1011): 3
#
# {'edge': (917, 7178), 'source': 917, 'destination': 7178, 'source_position': (-101752.9720532265, 471096.69205266284), 'destination_position': (-102757.4325681011, 471600.48764963413), 'source_neighbors': [7175, 1500, 1134, 1533, 1011, 7178], 'destination_neighbors': [917], 'source_degree': 6, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 1123.721909312882}
# Forward sector for edge (917, 7178): 3
# Backward sector for edge (917, 7178): 7
#
# {'edge': (1508, 7174), 'source': 1508, 'destination': 7174, 'source_position': (-96249.50340764348, 504973.5771384521), 'destination_position': (-96624.83688415165, 505728.46592004487), 'source_neighbors': [7174, 1514, 1512], 'destination_neighbors': [1508], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 843.0494001909552}
# Forward sector for edge (1508, 7174): 3
# Backward sector for edge (1508, 7174): 7
#
# {'edge': (1508, 1514), 'source': 1508, 'destination': 1514, 'source_position': (-96249.50340764348, 504973.5771384521), 'destination_position': (-95271.11640306117, 502282.99833607464), 'source_neighbors': [7174, 1514, 1512], 'destination_neighbors': [1512, 1508], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 2862.945235686221}
# Forward sector for edge (1508, 1514): 6
# Backward sector for edge (1508, 1514): 2
#
# {'edge': (1508, 1512), 'source': 1508, 'destination': 1512, 'source_position': (-96249.50340764348, 504973.5771384521), 'destination_position': (-96616.40131734902, 503383.6974512556), 'source_neighbors': [7174, 1514, 1512], 'destination_neighbors': [1508], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 1631.6652524051588}
# Forward sector for edge (1508, 1512): 6
# Backward sector for edge (1508, 1512): 2
#
# {'edge': (1542, 7231), 'source': 1542, 'destination': 7231, 'source_position': (-95393.41199564678, 493722.0469370892), 'destination_position': (-94415.0138591156, 494700.4484848734), 'source_neighbors': [7231], 'destination_neighbors': [1542], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1383.6663262052145}
# Forward sector for edge (1542, 7231): 1
# Backward sector for edge (1542, 7231): 5
#
# {'edge': (1498, 7008), 'source': 1498, 'destination': 7008, 'source_position': (-88789.249620947, 491398.3711823311), 'destination_position': (-92433.43346970521, 485252.0815032573), 'source_neighbors': [7008, 1540], 'destination_neighbors': [1498], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 7145.414805498691}
# Forward sector for edge (1498, 7008): 5
# Backward sector for edge (1498, 7008): 1
#
# {'edge': (1498, 1540), 'source': 1498, 'destination': 1540, 'source_position': (-88789.249620947, 491398.3711823311), 'destination_position': (-94659.61617623581, 488707.7797382354), 'source_neighbors': [7008, 1540], 'destination_neighbors': [1498, 1538, 1488], 'source_degree': 3, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 6457.591332106305}
# Forward sector for edge (1498, 1540): 5
# Backward sector for edge (1498, 1540): 1
#
# {'edge': (1490, 7007), 'source': 1490, 'destination': 7007, 'source_position': (-81573.59815137033, 488952.376975419), 'destination_position': (-82234.47920936123, 485270.3145467794), 'source_neighbors': [7007, 1497], 'destination_neighbors': [1490], 'source_degree': 2, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 3740.90196359256}
# Forward sector for edge (1490, 7007): 6
# Backward sector for edge (1490, 7007): 2
#
# {'edge': (1490, 1497), 'source': 1490, 'destination': 1497, 'source_position': (-81573.59815137033, 488952.376975419), 'destination_position': (-79739.10860284268, 488585.4892349027), 'source_neighbors': [7007, 1497], 'destination_neighbors': [1490], 'source_degree': 2, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 1870.817606769383}
# Forward sector for edge (1490, 1497): 0
# Backward sector for edge (1490, 1497): 4
#
# {'edge': (1550, 6812), 'source': 1550, 'destination': 6812, 'source_position': (-103832.06391887444, 473420.37792584946), 'destination_position': (-103077.82736978981, 473165.0549870372), 'source_neighbors': [6812], 'destination_neighbors': [1550], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 796.2804625625416}
# Forward sector for edge (1550, 6812): 0
# Backward sector for edge (1550, 6812): 4
#
# {'edge': (6816, 6852), 'source': 6816, 'destination': 6852, 'source_position': (-94522.18975421593, 505007.6212826689), 'destination_position': (-94911.84005889743, 503984.8718902115), 'source_neighbors': [6852], 'destination_neighbors': [6816, 1762], 'source_degree': 1, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 1094.4604514144935}
# Forward sector for edge (6816, 6852): 6
# Backward sector for edge (6816, 6852): 2
#
# {'edge': (1513, 6851), 'source': 1513, 'destination': 6851, 'source_position': (-93314.32012999884, 495678.8442049278), 'destination_position': (-94904.21849335577, 495801.13903696864), 'source_neighbors': [6851], 'destination_neighbors': [1513], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1594.5948801338045}
# Forward sector for edge (1513, 6851): 4
# Backward sector for edge (1513, 6851): 0
#
# {'edge': (1541, 7452), 'source': 1541, 'destination': 7452, 'source_position': (-93069.72894482798, 492132.1570292208), 'destination_position': (-93314.32012999884, 491153.7658998027), 'source_neighbors': [7452], 'destination_neighbors': [6808, 1541, 6807], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 1008.5008924077943}
# Forward sector for edge (1541, 7452): 6
# Backward sector for edge (1541, 7452): 2
#
# {'edge': (1512, 6839), 'source': 1512, 'destination': 6839, 'source_position': (-96616.40131734902, 503383.6974512556), 'destination_position': (-95760.31155107642, 503628.2922630283), 'source_neighbors': [6839, 1514], 'destination_neighbors': [1512], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 890.3461741720649}
# Forward sector for edge (1512, 6839): 0
# Backward sector for edge (1512, 6839): 4
#
# {'edge': (1512, 1514), 'source': 1512, 'destination': 1514, 'source_position': (-96616.40131734902, 503383.6974512556), 'destination_position': (-95271.11640306117, 502282.99833607464), 'source_neighbors': [6839, 1514], 'destination_neighbors': [1512, 1508], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 1738.1973543791203}
# Forward sector for edge (1512, 1514): 7
# Backward sector for edge (1512, 1514): 3
#
# {'edge': (6807, 7452), 'source': 6807, 'destination': 7452, 'source_position': (-93333.13762560804, 489592.0988070071), 'destination_position': (-93314.32012999884, 491153.7658998027), 'source_neighbors': [7452], 'destination_neighbors': [6808, 1541, 6807], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 1561.7804605198721}
# Forward sector for edge (6807, 7452): 2
# Backward sector for edge (6807, 7452): 6
#
# {'edge': (1762, 6817), 'source': 1762, 'destination': 6817, 'source_position': (-94904.21849335577, 503383.6974512556), 'destination_position': (-94695.20043045255, 503824.74734331464), 'source_neighbors': [6817, 6852], 'destination_neighbors': [1762], 'source_degree': 2, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 488.07126314210177}
# Forward sector for edge (1762, 6817): 1
# Backward sector for edge (1762, 6817): 5
#
# {'edge': (1762, 6852), 'source': 1762, 'destination': 6852, 'source_position': (-94904.21849335577, 503383.6974512556), 'destination_position': (-94911.84005889743, 503984.8718902115), 'source_neighbors': [6817, 6852], 'destination_neighbors': [6816, 1762], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 601.222749332766}
# Forward sector for edge (1762, 6852): 2
# Backward sector for edge (1762, 6852): 6
#
# {'edge': (7181, 7585), 'source': 7181, 'destination': 7585, 'source_position': (-91113.45170036636, 503380.1680097943), 'destination_position': (-91846.72849117668, 504606.6857026564), 'source_neighbors': [7585], 'destination_neighbors': [1564, 7181, 7180], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 1428.9998260478503}
# Forward sector for edge (7181, 7585): 3
# Backward sector for edge (7181, 7585): 7
#
# Backward sector for edge (1500, 1538): 6
#
# {'edge': (1500, 1527), 'source': 1500, 'destination': 1527, 'source_position': (-99918.48250469888, 472686.58349399763), 'destination_position': (-100896.88064123003, 466571.62167119724), 'source_neighbors': [1538, 1527], 'destination_neighbors': [1500], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 6192.7393783263615}
# Forward sector for edge (1500, 1527): 6
# Backward sector for edge (1500, 1527): 2
#
# {'edge': (1491, 1498), 'source': 1491, 'destination': 1498, 'source_position': (-87321.65798212479, 493232.85301515704), 'destination_position': (-88789.249620947, 491398.3711823311), 'source_neighbors': [1498, 1493], 'destination_neighbors': [1491], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 2349.2868733531113}
# Forward sector for edge (1491, 1498): 5
# Backward sector for edge (1491, 1498): 1
#
# {'edge': (1491, 1493), 'source': 1491, 'destination': 1493, 'source_position': (-87321.65798212479, 493232.85301515704), 'destination_position': (-82551.98515595241, 496779.5341042064), 'source_neighbors': [1498, 1493], 'destination_neighbors': [1491], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 5943.797238815241}
# Forward sector for edge (1491, 1493): 1
# Backward sector for edge (1491, 1493): 5
#
# {'edge': (1493, 1521), 'source': 1493, 'destination': 1521, 'source_position': (-82551.98515595241, 496779.5341042064), 'destination_position': (-79249.91510055165, 503505.98744034034), 'source_neighbors': [1521], 'destination_neighbors': [1493], 'source_degree': 2, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 7493.253040833563}
# Forward sector for edge (1493, 1521): 1
# Backward sector for edge (1493, 1521): 5
#
# {'edge': (1134, 1533), 'source': 1134, 'destination': 1533, 'source_position': (-104565.85973828545, 468161.5145129775), 'destination_position': (-103342.85928463432, 469384.50010553165), 'source_neighbors': [1533], 'destination_neighbors': [917, 1134], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1729.5733199913445}
# Forward sector for edge (1134, 1533): 1
# Backward sector for edge (1134, 1533): 5
#
# {'edge': (1525, 7799), 'source': 1525, 'destination': 7799, 'source_position': (-74969.43577667064, 507664.16247146105), 'destination_position': (-71300.45667961502, 507908.7595906377), 'source_neighbors': [7799], 'destination_neighbors': [1523, 1559, 1525, 1537], 'source_degree': 2, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 3677.1232458731365}
# Forward sector for edge (1525, 7799): 0
# Backward sector for edge (1525, 7799): 4
#
# {'edge': (1553, 7184), 'source': 1553, 'destination': 7184, 'source_position': (-89278.4542551869, 489808.4776474789), 'destination_position': (-89767.64775747815, 488830.0853605266), 'source_neighbors': [7184], 'destination_neighbors': [1553], 'source_degree': 1, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 1093.8746499722142}
# Forward sector for edge (1553, 7184): 5
# Backward sector for edge (1553, 7184): 1
#
# {'edge': (1538, 1540), 'source': 1538, 'destination': 1540, 'source_position': (-100163.08482181885, 477456.2513327105), 'destination_position': (-94659.61617623581, 488707.7797382354), 'source_neighbors': [1540, 6813], 'destination_neighbors': [1498, 1538, 1488], 'source_degree': 5, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 12525.376584887556}
# Forward sector for edge (1538, 1540): 1
# Backward sector for edge (1538, 1540): 5
#
# {'edge': (1538, 6813), 'source': 1538, 'destination': 6813, 'source_position': (-100163.08482181885, 477456.2513327105), 'destination_position': (-98328.58883916767, 485528.00076000136), 'source_neighbors': [1540, 6813], 'destination_neighbors': [1538], 'source_degree': 5, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 8277.591094475116}
# Forward sector for edge (1538, 6813): 2
# Backward sector for edge (1538, 6813): 6
#
# {'edge': (1537, 7799), 'source': 1537, 'destination': 7799, 'source_position': (-70322.06967503295, 509131.755878136), 'destination_position': (-71300.45667961502, 507908.7595906377), 'source_neighbors': [7799], 'destination_neighbors': [1523, 1559, 1525, 1537], 'source_degree': 1, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 1566.1931713456584}
# Forward sector for edge (1537, 7799): 5
# Backward sector for edge (1537, 7799): 1
#
# {'edge': (796, 1531), 'source': 796, 'destination': 1531, 'source_position': (-101263.77855093556, 469139.89973193617), 'destination_position': (-100652.27832410985, 470485.1936758575), 'source_neighbors': [1531], 'destination_neighbors': [796], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1477.7511031832519}
# Forward sector for edge (796, 1531): 1
# Backward sector for edge (796, 1531): 5
#
# {'edge': (1526, 7627), 'source': 1526, 'destination': 7627, 'source_position': (-71300.45667961502, 508031.059157421), 'destination_position': (-74113.34436467382, 507297.2718164784), 'source_neighbors': [7627], 'destination_neighbors': [1526, 1523, 1559], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 2907.022702092822}
# Forward sector for edge (1526, 7627): 4
# Backward sector for edge (1526, 7627): 0
#
# {'edge': (1488, 1540), 'source': 1488, 'destination': 1540, 'source_position': (-91969.03521571132, 491642.9641602829), 'destination_position': (-94659.61617623581, 488707.7797382354), 'source_neighbors': [1540], 'destination_neighbors': [1498, 1538, 1488], 'source_degree': 1, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 3981.7751690128475}
# Forward sector for edge (1488, 1540): 5
# Backward sector for edge (1488, 1540): 1
#
# {'edge': (1528, 7844), 'source': 1528, 'destination': 7844, 'source_position': (-91235.23939630034, 479046.1498859486), 'destination_position': (-84875.67933872051, 479657.6356586017), 'source_neighbors': [7844, 1538], 'destination_neighbors': [1528, 1535, 1673], 'source_degree': 3, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 6388.890277358188}
# Forward sector for edge (1528, 7844): 0
# Backward sector for edge (1528, 7844): 4
#
# {'edge': (1528, 1538), 'source': 1528, 'destination': 1538, 'source_position': (-91235.23939630034, 479046.1498859486), 'destination_position': (-100163.08482181885, 477456.2513327105), 'source_neighbors': [7844, 1538], 'destination_neighbors': [1500, 1528, 1533], 'source_degree': 3, 'destination_degree': 5, 'voltage': 380.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 9068.307524094022}
# Forward sector for edge (1528, 1538): 4
# Backward sector for edge (1528, 1538): 0
#
# {'edge': (1535, 7844), 'source': 1535, 'destination': 7844, 'source_position': (-85609.4751581315, 480758.3295636029), 'destination_position': (-84875.67933872051, 479657.6356586017), 'source_neighbors': [7844], 'destination_neighbors': [1528, 1535, 1673], 'source_degree': 2, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 1322.8693726486674}
# Forward sector for edge (1535, 7844): 7
# Backward sector for edge (1535, 7844): 3
#
# {'edge': (1807, 7218), 'source': 1807, 'destination': 7218, 'source_position': (-96371.81013217795, 508153.3593967491), 'destination_position': (-94170.4267929917, 505218.1812788253), 'source_neighbors': [7218], 'destination_neighbors': [1807], 'source_degree': 1, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 3668.9724978508366}
# Forward sector for edge (1807, 7218): 7
# Backward sector for edge (1807, 7218): 3
#
# {'edge': (1554, 7480), 'source': 1554, 'destination': 7480, 'source_position': (-84019.57679477462, 460578.9608342961), 'destination_position': (-83041.18979019253, 459845.1681494265), 'source_neighbors': [7480], 'destination_neighbors': [1554, 1544, 1078], 'source_degree': 1, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 1222.9852145889527}
# Forward sector for edge (1554, 7480): 7
# Backward sector for edge (1554, 7480): 3
#
# {'edge': (1544, 7480), 'source': 1544, 'destination': 7480, 'source_position': (-83530.38329248357, 458866.76323398773), 'destination_position': (-83041.18979019253, 459845.1681494265), 'source_neighbors': [7480, 1722], 'destination_neighbors': [1554, 1544, 1078], 'source_degree': 3, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1093.8859452605502}
# Forward sector for edge (1544, 7480): 1
# Backward sector for edge (1544, 7480): 5
#
# {'edge': (1544, 1722), 'source': 1544, 'destination': 1722, 'source_position': (-83530.38329248357, 458866.76323398773), 'destination_position': (-76070.12950578707, 459355.9701709567), 'source_neighbors': [7480, 1722], 'destination_neighbors': [1544], 'source_degree': 3, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 7476.276478909672}
# Forward sector for edge (1544, 1722): 0
# Backward sector for edge (1544, 1722): 4
#
# Forward sector for edge (1673, 7844): 5
# Backward sector for edge (1673, 7844): 1
#
# {'edge': (1504, 1544), 'source': 1504, 'destination': 1544, 'source_position': (-89523.04544035798, 458744.46583681257), 'destination_position': (-83530.38329248357, 458866.76323398773), 'source_neighbors': [1544], 'destination_neighbors': [1504], 'source_degree': 2, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 5993.909931916103}
# Forward sector for edge (1504, 1544): 0
# Backward sector for edge (1504, 1544): 4
#
# {'edge': (1501, 1505), 'source': 1501, 'destination': 1505, 'source_position': (-91724.43289859139, 515980.5122408207), 'destination_position': (-93558.92244711902, 508153.3593967491), 'source_neighbors': [1505, 7158], 'destination_neighbors': [1501], 'source_degree': 2, 'destination_degree': 2, 'voltage': 380.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 8039.258271016965}
# Forward sector for edge (1501, 1505): 6
# Backward sector for edge (1501, 1505): 2
#
# {'edge': (1501, 7158), 'source': 1501, 'destination': 7158, 'source_position': (-91724.43289859139, 515980.5122408207), 'destination_position': (-90723.45903873212, 516552.4996246329), 'source_neighbors': [1505, 7158], 'destination_neighbors': [1501], 'source_degree': 2, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1152.873902628507}
# Forward sector for edge (1501, 7158): 1
# Backward sector for edge (1501, 7158): 5
#
# {'edge': (1505, 1515), 'source': 1505, 'destination': 1515, 'source_position': (-93558.92244711902, 508153.3593967491), 'destination_position': (-93436.62685453352, 502894.4996087302), 'source_neighbors': [1515], 'destination_neighbors': [1489, 1506, 1505], 'source_degree': 2, 'destination_degree': 4, 'voltage': 380.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 5260.281597215897}
# Forward sector for edge (1505, 1515): 6
# Backward sector for edge (1505, 1515): 2
#
# {'edge': (1507, 1528), 'source': 1507, 'destination': 1528, 'source_position': (-97717.09504646546, 481981.3253974358), 'destination_position': (-91235.23939630034, 479046.1498859486), 'source_neighbors': [1528, 7177], 'destination_neighbors': [1507], 'source_degree': 2, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 7115.455568887478}
# Forward sector for edge (1507, 1528): 7
# Backward sector for edge (1507, 1528): 3
#
# {'edge': (1507, 7177), 'source': 1507, 'destination': 7177, 'source_position': (-97717.09504646546, 481981.3253974358), 'destination_position': (-99062.3910927024, 481736.73086063575), 'source_neighbors': [1528, 7177], 'destination_neighbors': [1507], 'source_degree': 2, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1367.3507009736634}
# Forward sector for edge (1507, 7177): 4
# Backward sector for edge (1507, 7177): 0
#
# {'edge': (1496, 1535), 'source': 1496, 'destination': 1535, 'source_position': (-82429.68956336715, 484182.71080708015), 'destination_position': (-85609.4751581315, 480758.3295636029), 'source_neighbors': [1535], 'destination_neighbors': [1496], 'source_degree': 1, 'destination_degree': 2, 'voltage': 380.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 4673.0528917774445}
# Forward sector for edge (1496, 1535): 5
# Backward sector for edge (1496, 1535): 1
#
# {'edge': (1545, 7179), 'source': 1545, 'destination': 7179, 'source_position': (-92702.83103512252, 510110.1511477454), 'destination_position': (-94048.11594941009, 510110.1511477454), 'source_neighbors': [7179, 1757], 'destination_neighbors': [1545], 'source_degree': 2, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1345.2849142875639}
# Forward sector for edge (1545, 7179): 4
# Backward sector for edge (1545, 7179): 0
#
# {'edge': (1545, 1757), 'source': 1545, 'destination': 1757, 'source_position': (-92702.83103512252, 510110.1511477454), 'destination_position': (-86465.56657012796, 509865.5594050677), 'source_neighbors': [7179, 1757], 'destination_neighbors': [1502, 1545, 1503], 'source_degree': 2, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 6242.05840463464}
# Forward sector for edge (1545, 1757): 0
# Backward sector for edge (1545, 1757): 4
#
# {'edge': (1499, 1551), 'source': 1499, 'destination': 1551, 'source_position': (-85364.87284101156, 498736.3239551661), 'destination_position': (-86710.16888724826, 500448.5165247797), 'source_neighbors': [1551], 'destination_neighbors': [1522, 1519, 1521, 1499], 'source_degree': 1, 'destination_degree': 5, 'voltage': 380.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 2177.481308177005}
# Forward sector for edge (1499, 1551): 3
# Backward sector for edge (1499, 1551): 7
#
# {'edge': (1556, 1744), 'source': 1556, 'destination': 1744, 'source_position': (-86098.66866042254, 449449.7244505773), 'destination_position': (-81451.30255878484, 451773.4126347199), 'source_neighbors': [1744], 'destination_neighbors': [1556], 'source_degree': 1, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 5195.915555489264}
# Forward sector for edge (1556, 1744): 1
# Backward sector for edge (1556, 1744): 5
#
# {'edge': (1502, 1757), 'source': 1502, 'destination': 1757, 'source_position': (-86832.46447983374, 511455.4397864039), 'destination_position': (-86465.56657012796, 509865.5594050677), 'source_neighbors': [1757], 'destination_neighbors': [1502, 1545, 1503], 'source_degree': 1, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 1631.665928768575}
# Forward sector for edge (1502, 1757): 6
# Backward sector for edge (1502, 1757): 2
#
# {'edge': (1503, 1757), 'source': 1503, 'destination': 1757, 'source_position': (-84997.97493130577, 511577.7442375086), 'destination_position': (-86465.56657012796, 509865.5594050677), 'source_neighbors': [1757], 'destination_neighbors': [1502, 1545, 1503], 'source_degree': 1, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 2255.083616804833}
# Forward sector for edge (1503, 1757): 5
# Backward sector for edge (1503, 1757): 1
#
# {'edge': (1547, 1769), 'source': 1547, 'destination': 1769, 'source_position': (-82796.58747307259, 475010.2635637114), 'destination_position': (-87443.96470665914, 471341.2915114169), 'source_neighbors': [1769], 'destination_neighbors': [1547], 'source_degree': 1, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 5921.103872740024}
# Forward sector for edge (1547, 1769): 5
# Backward sector for edge (1547, 1769): 1
#
# {'edge': (1555, 6840), 'source': 1555, 'destination': 6840, 'source_position': (-101019.17623381564, 465348.6269167224), 'destination_position': (-97839.39365387152, 467060.8202605969), 'source_neighbors': [6840], 'destination_neighbors': [1555], 'source_degree': 1, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 3611.4572270102185}
# Forward sector for edge (1555, 6840): 1
# Backward sector for edge (1555, 6840): 5
#
# {'edge': (1530, 7009), 'source': 1530, 'destination': 7009, 'source_position': (-98940.0843681677, 486750.99407847313), 'destination_position': (-98206.28936719988, 485283.40136397094), 'source_neighbors': [7009], 'destination_neighbors': [1530], 'source_degree': 1, 'destination_degree': 1, 'voltage': 380.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 1640.8179299072985}
# Forward sector for edge (1530, 7009): 7
# Backward sector for edge (1530, 7009): 3

# %%
# Debugging to check the sectors around the node 6188

# Usage example
edge_details = {}
for edge in G.edges():
    # Check if the node 6188 is part of the edge
    if 6188 in edge:
        edge_details[edge] = get_edge_info(G, edge)
        print(edge_details[edge])
        
        forward = edge_details[edge].get('forward_sector')
        backward = edge_details[edge].get('backward_sector')
        print(f"Forward sector for edge {edge}: {forward}")
        print(f"Backward sector for edge {edge}: {backward}\n")

# %% [markdown]
# Create Dictionary of initial lengths of each edge

# %%
initial_lengths = {}

for edge in G.edges():
    edge_info = get_edge_info(G, edge)  # Retrieve edge information

    # Assuming the 'get_edge_info' function returns a dictionary with the positions
    node1_pos = edge_info.get('source_position')  # Source position (x, y)
    node2_pos = edge_info.get('destination_position')  # Destination position (x, y)

    # Calculate the Euclidean distance between node1 and node2
    distance = euclidean_distance(node1_pos[0], node1_pos[1], node2_pos[0], node2_pos[1])

    # Store the distance in the initial_lengths dictionary using the edge as the key
    initial_lengths[edge] = distance

print(initial_lengths)    

# Calculate min, max, and average lengths
min_length = min(initial_lengths.values())
max_length = max(initial_lengths.values())
avg_length = sum(initial_lengths.values()) / len(initial_lengths)

print("\nMinimum Length:", min_length)
print("\nMaximum Length:", max_length)
print("\nAverage Length:", avg_length)
# Out:
# {(1569, 7889): 2855.1074242658415, (1531, 6809): 918.1197640732104, (1531, 6824): 1204.511759660281, (1521, 1760): 1716.5640573926185, (1521, 7889): 2553.68857802092, (1521, 1627): 5027.679701994746, (1521, 1551): 8062.475734005047, (1523, 7551): 3228.7990656381226, (1523, 7799): 1556.6068615639922, (1523, 7627): 1780.7071530501291, (1533, 1756): 1394.4165639269506, (1533, 1561): 1763.8241292663088, (1533, 6825): 3030.870082996581, (1533, 1538): 8675.490390049234, (1559, 7551): 1052.0548140618694, (1559, 7799): 5768.8422150293945, (1559, 7627): 3210.2111923083717, (1559, 1759): 2476.368934286315, (1492, 6
#
# Minimum Length: 488.07126314210177
#
# Maximum Length: 12525.376584887556
#
# Average Length: 3422.014176520458

# %% [markdown]
# # Functions - Optimisation

# %% [markdown]
# ### Octilinearity Constraints Functions
# - Getting Dynamic Minimum Edge Length

# %%
# to get dynamic min length 
# Minimum length percentage
def calculate_dynamic_min_lengths(G, min_length_horizontal, min_length_diagonal):
    # Dictionary to store dynamic minimum lengths for each edge
    dynamic_min_lengths = {}

    for edge in G.edges():
        edge_info = get_edge_info(G, edge)

        forward = edge_info.get('forward_sector')
        backward = edge_info.get('backward_sector')

        if forward in (1, 3, 5, 7) or backward in (1, 3, 5, 7):
            # Use the diagonal minimum length for diagonal edges
            #dynamic_min_length = edge_info['distance'] * min_length_diagonal
            dynamic_min_length = 1400
        else:
            # Use the horizontal minimum length for horizontal/vertical edges
            #dynamic_min_length = edge_info['distance'] * min_length_horizontal
            dynamic_min_length = 1400

        # Store the calculated dynamic minimum length in the dictionary
        dynamic_min_lengths[edge] = dynamic_min_length

    return dynamic_min_lengths
    
    
dynamic_min_lengths = calculate_dynamic_min_lengths(G, 0.2, 0.22)


print(dynamic_min_lengths)
# Out:
# {(1569, 7889): 1400, (1531, 6809): 1400, (1531, 6824): 1400, (1521, 1760): 1400, (1521, 7889): 1400, (1521, 1627): 1400, (1521, 1551): 1400, (1523, 7551): 1400, (1523, 7799): 1400, (1523, 7627): 1400, (1533, 1756): 1400, (1533, 1561): 1400, (1533, 6825): 1400, (1533, 1538): 1400, (1559, 7551): 1400, (1559, 7799): 1400, (1559, 7627): 1400, (1559, 1759): 1400, (1492, 6810): 1400, (1536, 1563): 1400, (1557, 1561): 1400, (1557, 6815): 1400, (1549, 1559): 1400, (1564, 7585): 1400, (1522, 1551): 1400, (1522, 1525): 1400, (1551, 1559): 1400, (1567, 7182): 1400, (1519, 1551): 1400, (1519, 7698): 1400, (1540, 1563): 1400, (1540, 7397): 1400, (1494, 6811): 1400, (6808, 7452): 1400, (1761, 7187): 1400, (1510, 7219): 1400, (1510, 1517): 1400, (917, 7175): 1400, (917, 1500): 1400, (917, 1134): 1400, (917, 1533): 1400, (917, 1011): 1400, (917, 7178): 1400, (1508, 7174): 1400, (1508, 1514): 1400, (1508, 1512): 1400, (1542, 7231): 1400, (1498, 7008): 1400, (1498, 1540): 1400, (1490, 7007): 1400, (1490, 1497): 1400, (1550, 6812): 1400, (6816, 6852): 1400, (1513, 6851): 1400, (1541, 7452): 1400, (1512, 6839): 1400, (1512, 1514): 1400, (6807, 7452): 1400, (1762, 6817): 1400, (1762, 6852): 1400, (7181, 7585): 1400, (7180, 7585): 1400, (1517, 1519): 1400, (1506, 1517): 1400, (1506, 1515): 1400, (1489, 1515): 1400, (1515, 6838): 1400, (1500, 1538): 1400, (1500, 1527): 1400, (1491, 1498): 1400, (1491, 1493): 1400, (1493, 1521): 1400, (1134, 1533): 1400, (1525, 7799): 1400, (1553, 7184): 1400, (1538, 1540): 1400, (1538, 6813): 1400, (1537, 7799): 1400, (796, 1531): 1400, (1526, 7627): 1400, (1488, 1540): 1400, (1528, 7844): 1400, (1528, 1538): 1400, (1535, 7844): 1400, (1807, 7218): 1400, (1554, 7480): 1400, (1544, 7480): 1400, (1544, 1722): 1400, (871, 7491): 1400, (871, 1011): 1400, (871, 1126): 1400, (871, 1504): 1400, (1558, 7491): 1400, (1078, 7480): 1400, (1673, 7844): 1400, (1504, 1544): 1400, (1501, 1505): 1400, (1501, 7158): 1400, (1505, 1515): 1400, (1507, 1528): 1400, (1507, 7177): 1400, (1496, 1535): 1400, (1545, 7179): 1400, (1545, 1757): 1400, (1499, 1551): 1400, (1556, 1744): 1400, (1502, 1757): 1400, (1503, 1757): 1400, (1547, 1769): 1400, (1555, 6840): 1400, (1530, 7009): 1400}

# %% [markdown]
# ### Circular Vertex Order Constraints Functions

# %%
## Function to get index of nodes in the ordered neighbours list.

# This function initializes the set of (node, index) pairs, where 'node' is a node with 2 or more neighbors,
# and 'index' is a unique integer (starting from 1) representing the position of a neighbor in the
# counterclockwise ordering of neighbors around 'node'.

def node_neighbour_index_pairs_init(model):
    node_index_pairs = []
    for node, neighbors in ordered_neighbours_dict.items():
        # Start index from 0 for each node's neighbors
        for idx in range(0, len(neighbors)):
            node_index_pairs.append((node, idx))
    return node_index_pairs



## Helper Function for the circular vertex order
## Determines if node with more than 2 neighbours is the source or destination node
## So the correct direction can be assigned to it

def directional_sector(model, node, neighbor):
    if (node, neighbor) in model.Edges:
        return model.dir_forward[node, neighbor]
    elif (neighbor, node) in model.Edges:
        return model.dir_backward[neighbor, node]
    else:
        return None  # This case should ideally never happen if the graph is well-defined

# %% [markdown]
# ### Edge Spacing Constraints Functions
# Gets list of intersecting edges and new list of non intersecting non incident edges created

# %%
def list_edge_intersections(G):
    intersecting_edge_pairs = []
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect
        if line1.intersects(line2):
            # If they intersect, add the edge pair to the list
            intersecting_edge_pairs.append((edge1, edge2))

    return intersecting_edge_pairs

# Call the function to get intersecting edge pairs
intersecting_edges = list_edge_intersections(G)

# Print the intersecting edge pairs
for edge_pair in intersecting_edges:
    print(f"Intersecting Edge Pair: {edge_pair}")
# Out:
# Intersecting Edge Pair: ((1521, 1760), (1551, 1559))
# Intersecting Edge Pair: ((1523, 7551), (1559, 7799))
# Intersecting Edge Pair: ((1523, 7627), (1559, 7799))
# Intersecting Edge Pair: ((1533, 6825), (1557, 6815))
# Intersecting Edge Pair: ((1533, 6825), (917, 7175))
# Intersecting Edge Pair: ((1533, 6825), (917, 1011))
# Intersecting Edge Pair: ((1533, 1538), (917, 1134))
# Intersecting Edge Pair: ((1533, 1538), (917, 7178))
# Intersecting Edge Pair: ((1492, 6810), (1491, 1493))
# Intersecting Edge Pair: ((1536, 1563), (1507, 1528))
# Intersecting Edge Pair: ((1557, 6815), (917, 1533))
# Intersecting Edge Pair: ((1549, 1559), (1522, 1525))
# Intersecting Edge Pair: ((1567, 7182), (1499, 1551))
# Intersecting Edge Pair: ((6808, 7452), (1488, 1540))
# Intersecting Edge Pair: ((917, 7175), (796, 1531))
# Intersecting Edge Pair: ((917, 1011), (1500, 1527))
# Intersecting Edge Pair: ((917, 1011), (796, 1531))
# Intersecting Edge Pair: ((917, 1011), (1555, 6840))
# Intersecting Edge Pair: ((6807, 7452), (1488, 1540))
# Intersecting Edge Pair: ((1525, 7799), (1526, 7627))
# Intersecting Edge Pair: ((1538, 1540), (1507, 7177))
# Intersecting Edge Pair: ((1501, 1505), (1545, 7179))

# %%
# Create a new list excluding intersecting edge pairs
non_intersecting_non_incident_edges = [edge_pair for edge_pair in non_incident_edge_pairs if edge_pair not in intersecting_edges]

# Print the new list of non-intersecting, non-incident edge pairs
for edge_pair in non_intersecting_non_incident_edges:
    print(f"Non-Intersecting Non-Incident Edge Pair: {edge_pair}")
# Out:
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1531, 6809))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1531, 6824))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1521, 1760))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1521, 1627))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1521, 1551))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1523, 7551))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1523, 7799))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1523, 7627))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1533, 1756))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1533, 1561))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1533, 6825))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1533, 1538))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1559, 7551))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1559, 7799))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1559, 7627))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1559, 1759))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1492, 6810))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1536, 1563))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1557, 1561))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1557, 6815))
# Non-Intersecting Non-Incident Edge Pair: ((1569, 7889), (1549, 1559))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 7179), (1503, 1757))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 7179), (1547, 1769))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 7179), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 7179), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 1757), (1499, 1551))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 1757), (1556, 1744))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 1757), (1547, 1769))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 1757), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1545, 1757), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1499, 1551), (1556, 1744))
# Non-Intersecting Non-Incident Edge Pair: ((1499, 1551), (1502, 1757))
# Non-Intersecting Non-Incident Edge Pair: ((1499, 1551), (1503, 1757))
# Non-Intersecting Non-Incident Edge Pair: ((1499, 1551), (1547, 1769))
# Non-Intersecting Non-Incident Edge Pair: ((1499, 1551), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1499, 1551), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1556, 1744), (1502, 1757))
# Non-Intersecting Non-Incident Edge Pair: ((1556, 1744), (1503, 1757))
# Non-Intersecting Non-Incident Edge Pair: ((1556, 1744), (1547, 1769))
# Non-Intersecting Non-Incident Edge Pair: ((1556, 1744), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1556, 1744), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1502, 1757), (1547, 1769))
# Non-Intersecting Non-Incident Edge Pair: ((1502, 1757), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1502, 1757), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1503, 1757), (1547, 1769))
# Non-Intersecting Non-Incident Edge Pair: ((1503, 1757), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1503, 1757), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1547, 1769), (1555, 6840))
# Non-Intersecting Non-Incident Edge Pair: ((1547, 1769), (1530, 7009))
# Non-Intersecting Non-Incident Edge Pair: ((1555, 6840), (1530, 7009))

# %% [markdown]
# # Optimisation

# %% [markdown]
# ## Variables and Parameters

# %%
model = ConcreteModel()



""" print(list(G.nodes()))
print(list(G.edges())) """
# Set used to index the other components eg Param and Var, and to define the scope
model.Nodes = Set(initialize = list(G.nodes()))
model.Edges = Set(initialize = list(G.edges()))

# Initialize set of non-incident edge pairs
# dimen = 4: creates a collection of edge pairs where each pair is treated as a single tuple, 2 integers per edge
model.NonIncidentEdges = Set(initialize = non_incident_edge_pairs, dimen=4)
model.NonIntersecting_NonIncidentEdges = Set(initialize = non_intersecting_non_incident_edges, dimen=4)
model.IntersectingEdgePairs = Set(initialize = intersecting_edges, dimen = 4)


# Set with 2 or more neighbours
# Storing set nodes with 2 or more neighbours that were predetermined in the dictionary
model.NodesWith2Neighbours = Set(initialize = ordered_neighbours_dict.keys())


# Initialize the set with the function that provides the (node, index) pairs
model.NodeNeighbours2IndexPairs = Set(dimen=2, initialize=node_neighbour_index_pairs_init)





### PARAM ###
## Param - fixed value in model that doesn't change during optimisation process ##
# pos defined earlier as tuple (x, y) in graph G
model.x_init = Param(model.Nodes, initialize={node: pos[node][0] for node in G.nodes()})
model.y_init = Param(model.Nodes, initialize={node: pos[node][1] for node in G.nodes()})


# Access information from dictionary of the edge info
edge_info = {edge: get_edge_info(G, edge) for edge in G.edges()}

# Initialize Params for static attributes from the edges
model.voltage = Param(model.Edges, initialize={edge: edge_info[edge]['voltage'] for edge in model.Edges})
model.sect_forward = Param(model.Edges, initialize={edge: edge_info[edge]['forward_sector'] for edge in model.Edges})
model.sect_backward = Param(model.Edges, initialize={edge: edge_info[edge]['backward_sector'] for edge in model.Edges})
model.distance = Param(model.Edges, initialize={edge: edge_info[edge]['distance'] for edge in model.Edges} )
#model.non_incident_edges = Param(model.Edges, initialize = {edge: edge_info[edge]['non_incident_edges'] for edge in model.Edges} )


# Param to store the ordered neighbors for each node in the model
model.OrderedNeighbours = Param(
    model.NodesWith2Neighbours,  # Index set for the Param, representing nodes with 2 or more neighbors
    within=Any,  # Specifies that the Param can hold any type of data, in this case, tuples of nodes
    initialize=lambda model, node: tuple(ordered_neighbours_dict[node])  # Initialization function
    # lambda function takes 2 arguments model and node (element from set Nodewith2Neigbours)
    # for each node, it gets the list or ordered neighbours from the dictionary
    # list is converted to tuple so that for Param, the contents are unchangeable
)
   





### VARIABLES ###
## Define Variables ##
model.x_pos = Var(model.Nodes, within = Reals, initialize = model.x_init)
model.y_pos = Var(model.Nodes, within = Reals, initialize = model.y_init)

model.z1_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] + model.y_pos[node])
model.z2_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] - model.y_pos[node])


model.dir_forward = Var(model.Edges, within = Integers, bounds = (0, 7))
model.dir_backward = Var(model.Edges, within = Integers, bounds = (0, 7))


# Binary variable for octilinear constraint to determine where edge is drawn
model.alpha_pred = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_orig = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_succ = Var(model.Edges, within = Binary, bounds = (0, 1))


# Binary Variable for non-incident edge constraint
model.is_N = Var(model.NonIncidentEdges, within=Binary)
model.is_S = Var(model.NonIncidentEdges, within=Binary)
model.is_E = Var(model.NonIncidentEdges, within=Binary)
model.is_W = Var(model.NonIncidentEdges, within=Binary)
model.is_NE = Var(model.NonIncidentEdges, within=Binary)
model.is_NW = Var(model.NonIncidentEdges, within=Binary)
model.is_SE = Var(model.NonIncidentEdges, within=Binary)
model.is_SW = Var(model.NonIncidentEdges, within=Binary)

model.delta_pred = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_orig = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_succ = Var(model.Edges, within = Integers, bounds = (0, 7))


max_degree = max(len(neighbors) for neighbors in ordered_neighbours_dict.values())


# Define Beta as a binary variable indexed by the (node, index) pairs
# Beta[node, idx] will be used in the constraints to identify the "wrap-around" point
# in the counterclockwise ordering of neighbors around each node
model.Beta = Var(model.NodeNeighbours2IndexPairs, within=Binary)




# Redefine rpos as a continuous variable representing the deviation magnitude
model.rpos = Var(model.Edges, within=NonNegativeReals)


model.dev_pos = Var(model.Edges, within=NonNegativeReals)
model.dev_neg = Var(model.Edges, within=NonNegativeReals)

tolerance = 0.01






model.min_dist_x_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_x_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_y_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_y_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)










# Lower and upper bound factors
lower_bound_factor = 0.5  # e.g., 50% of the initial length
upper_bound_factor = 5  # e.g., 150% of the initial length

# Lower absolute threshold for very short edges
absolute_lower_threshold = 500  # Some unit length that makes sense for your graph's scale

# Define min_length as a variable for each edge
model.min_length = Var(model.Edges, within=NonNegativeReals, initialize=initial_lengths,
                       bounds=lambda model, u, v: (
                           max(absolute_lower_threshold, initial_lengths[u, v] * lower_bound_factor),
                           initial_lengths[u, v] * upper_bound_factor))
# Out:
# WARNING (W1002): Setting Var 'min_length[1762,6817]' to a numeric value
# `488.07126314210177` outside the bounds (500, 2440.356315710509).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002

# %%
""" # Define a ConstraintList for spacing constraints
model.EdgeSpacingConstraints = ConstraintList()

dmin = 50  # Minimum spacing distance, as an example

# Define the constraints
def enforce_minimum_spacing(model, u1, v1, u2, v2):
    # Constraints for node u2 to be at least dmin away from nodes u1 and v1
    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[u2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[u2] >= dmin)

    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[u2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[u2] >= dmin) 

    # Constraints for node v2 to be at least dmin away from nodes u1 and v1
    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[v2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[v2] >= dmin)

    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[v2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[v2] >= dmin) 

# Adding the constraints to the model for each pair of intersecting edges
for (u1, v1, u2, v2) in model.IntersectingEdgePairs:
    enforce_minimum_spacing(model, u1, v1, u2, v2)
 """
# Out:
# ' # Define a ConstraintList for spacing constraints\nmodel.EdgeSpacingConstraints = ConstraintList()\n\ndmin = 50  # Minimum spacing distance, as an example\n\n# Define the constraints\ndef enforce_minimum_spacing(model, u1, v1, u2, v2):\n    # Constraints for node u2 to be at least dmin away from nodes u1 and v1\n    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[u2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[u2] >= dmin)\n\n    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[u2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[u2] >= dmin) \n\n    # Constraints for node v2 to be at least dmin away from nodes u1 and v1\n    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[v2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[v2] >= dmin)\n\n    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[v2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[v2] >= dmin) \n\n# Adding the constraints to the model for each pair of intersecting edges\nfor (u1, v1, u2, v2) in model.IntersectingEdgePairs:\n    enforce_minimum_spacing(model, u1, v1, u2, v2)\n '

# %% [markdown]
# ## Octilinearity Constraint

# %%
# Sum of Binary variables is equal to 1
# node1 and node2 are the src and dst nodes defined in model.Edges
def alpha_direction_constraint(model, node1, node2):
    return model.alpha_pred[node1, node2] + model.alpha_orig[node1, node2] + model.alpha_succ[node1, node2] == 1
model.alpha_direction_constraint = Constraint(model.Edges, rule = alpha_direction_constraint)


 
 # for each edge in tuple (node1, node2) in model.Edges, dir constraint is called and formed
def dir_forward_constraint(model, node1, node2):
    
    
    sect_forward_pred = (model.sect_forward[node1, node2] - 1) % 8
    sect_forward_orig = model.sect_forward[node1, node2]
    sect_forward_succ = (model.sect_forward[node1, node2] + 1) % 8
    
     # Debugging: Print the values of sectors and binary variables
    """ print(f"Edge: {(node1, node2)}")
    print(f"sect_forward_pred: {sect_forward_pred}, sect_forward_orig: {sect_forward_orig}, sect_forward_succ: {sect_forward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}") """
    
    
    
    return model.dir_forward[node1, node2] == ((sect_forward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_forward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_forward_succ * model.alpha_succ[node1, node2])
                                        )

model.DirForwardConstraint = Constraint(model.Edges, rule=dir_forward_constraint)
 

def dir_backward_constraint(model, node1, node2):
    sect_backward_pred = (model.sect_backward[node1, node2] - 1) % 8
    sect_backward_orig = model.sect_backward[node1, node2]
    sect_backward_succ = (model.sect_backward[node1, node2] + 1) % 8
    
      # Debugging: Print the values of sectors and binary variables
    """ print(f"Edge: {(node1, node2)}")
    print(f"sect_backward_pred: {sect_backward_pred}, sect_backward_orig: {sect_backward_orig}, sect_backward_succ: {sect_backward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}")  """
    
    return model.dir_backward[node1, node2] == ((sect_backward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_backward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_backward_succ * model.alpha_succ[node1, node2])
                                        )
    
model.DirBackwardConstraint = Constraint(model.Edges, rule = dir_backward_constraint) 




 
def sector_constraints_rule(model, node1, node2):

    # Retrieve original sector and minimum edge length
    sect_orig = model.sect_forward[node1, node2]
    min_length = 1500 #dynamic_min_lengths[(node1, node2)] #(model.distance[node1, node2])*0.1  #1000
    #min_length = model.min_length[node1, node2]
    
    
    # Define a large constant M for making constraints trivial when not active
    M = 30000  # Adjust as needed

    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_adjusted = (sect_orig + adjustment) % 8

        # Conditions based on adjusted sector
        if sect_adjusted in [0, 4]:  # Horizontal
            model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.y_pos[node1] + model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            
            if sect_adjusted == 0:
                # For sector 0, node1 should be to the left of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node2] - model.x_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
                
                """ model.sector_constraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance) """
                
                
                
                
                
            elif sect_adjusted == 4:
                # For sector 4, node1 should be to the right of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))
                
                """ model.sector_constraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
         """
        
        elif sect_adjusted in [2, 6]:  # Vertical
            # Add corresponding constraints for this sector
            model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.x_pos[node1] + model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            
            if sect_adjusted == 2:  # Upwards
                # Node2's y_pos should be at least min_length above Node1's y_pos
                model.sector_constraints.add(model.y_pos[node2] - model.y_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
                """ 
                model.sector_constraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
                """
            
            
            
            
            elif sect_adjusted == 6:  # Downwards
                # Node2's y_pos should be at least min_length below Node1's y_pos
                model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))

                """ model.sector_constraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance) """
        





        elif sect_adjusted == 1:         #upright diagonal /
            # dx = dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) - (model.x_pos[node2] - model.x_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # dx + dy >= min length of diagonal
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))
            
            """ model.sector_constraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance) """
        
            
        elif sect_adjusted == 5:        # Diagonal downwards /
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # -dx - dy >= min length
            # negative diagonal
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))


            """ model.sector_constraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance) """
        
            


            
        ## Diagonal \
            
        elif sect_adjusted == 3:    # Up left diagonal \
            # -dx = dy
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dx is negative
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) <= 0)
            
            # -dx + dy >= min length (dx is negative value)
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            
            
            """ model.sector_constraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
         """
            
            
        elif sect_adjusted == 7:    # Down right Diagonal \
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dy is negative
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) <= 0)
        
            # dx - dy >= min length (since dy is negative, we use -dy)
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            """ 
            model.sector_constraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            """




       



       
            # Fill in your constraints similar to above
    return Constraint.Skip 

# Initialize the constraint list on your model if not already done
model.sector_constraints = ConstraintList()

# Apply the rule to each edge
model.SectorConstraint = Constraint(model.Edges, rule=sector_constraints_rule)

# %% [markdown]
# ## Circular Vertex Order
# The initial circular ordering of neighbour nodes (counterclockwise) should be the same after optimisation.
#
# For each node in the map, the sequence in which the neighbouring nodes are arranged around a particular node should match the order in which the neighbouring nodes are arranged in the final layout.

# %%
# Beta Binary Sum Constraint


def beta_sum_constraint_rule(model, node):
    # Ensure we use 0-based indexing to match the updated indexing in Beta
    # Note that RangeSet in Pyomo starts from 1, so we adjust the range accordingly
    return sum(model.Beta[node, index] for index in range(0, len(model.OrderedNeighbours[node]) )) == 1

model.BetaSumConstraint = Constraint(model.NodesWith2Neighbours, rule=beta_sum_constraint_rule)




# Define the ConstraintList in your Pyomo model
model.OrderMaintenanceConstraints = ConstraintList()


def add_order_maintenance_constraints(model):
    for node, neighbours in ordered_neighbours_dict.items():
        num_neighbours = len(neighbours)
        
        
        for index in range(num_neighbours):
            print(index)
            # Handle all neighbor pairs except the last pair (which wraps around)
            if index < num_neighbours - 1:
                next_index = index + 1
            else:
                next_index = 0      # wrap around case
                
                
            # Use the helper function to dynamically select dir_forward or dir_backward
            dir_sect = directional_sector(model, node, neighbours[index])
            next_dir_sect = directional_sector(model, node, neighbours[next_index])
            
            # Debugging prints before adding the constraint
            print(f"Node: {node}, Neighbour: {neighbours[index]}, Directional Sector: {dir_sect}")
            print(f"Node: {node}, Next Neighbour: {neighbours[next_index]}, Next Directional Sector: {next_dir_sect}")
            if index == num_neighbours - 1:  # For wrap-around case
                print(f"\nNode: {node}, Index: {index}, Beta: {model.Beta[node, index].value if model.Beta[node, index].value is not None else 'Not solved yet'}")

            
            
            if dir_sect is not None and next_dir_sect is not None:
                    model.OrderMaintenanceConstraints.add(dir_sect <= next_dir_sect - 1 + 8*model.Beta[node, index])

                

            
           
# Call the function to add the constraints to the ConstraintList
add_order_maintenance_constraints(model)
# Out:
# 0
# Node: 7889, Neighbour: 1569, Directional Sector: dir_backward[1569,7889]
# Node: 7889, Next Neighbour: 1521, Next Directional Sector: dir_backward[1521,7889]
# 1
# Node: 7889, Neighbour: 1521, Directional Sector: dir_backward[1521,7889]
# Node: 7889, Next Neighbour: 1569, Next Directional Sector: dir_backward[1569,7889]
#
# Node: 7889, Index: 1, Beta: Not solved yet
# 0
# Node: 1531, Neighbour: 6824, Directional Sector: dir_forward[1531,6824]
# Node: 1531, Next Neighbour: 6809, Next Directional Sector: dir_forward[1531,6809]
# 1
# Node: 1531, Neighbour: 6809, Directional Sector: dir_forward[1531,6809]
# Node: 1531, Next Neighbour: 796, Next Directional Sector: dir_backward[796,1531]
# 2
# Node: 1531, Neighbour: 796, Directional Sector: dir_backward[796,1531]
# Node: 1531, Next Neighbour: 6824, Next Directional Sector: dir_forward[1531,6824]
#
# Node: 1531, Index: 2, Beta: Not solved yet
# 0
# Node: 1521, Neighbour: 7889, Directional Sector: dir_forward[1521,7889]
# Node: 1521, Next Neighbour: 1760, Next Directional Sector: dir_forward[1521,1760]
# 1
# Node: 1521, Neighbour: 1760, Directional Sector: dir_forward[1521,1760]
# Node: 1521, Next Neighbour: 1551, Next Directional Sector: dir_forward[1521,1551]
# 2
# Node: 1521, Neighbour: 1551, Directional Sector: dir_forward[1521,1551]
# Node: 1521, Next Neighbour: 1493, Next Directional Sector: dir_backward[1493,1521]
# 3
# Node: 1521, Neighbour: 1493, Directional Sector: dir_backward[1493,1521]
# Node: 1521, Next Neighbour: 1627, Next Directional Sector: dir_forward[1521,1627]
# 4
# Node: 1521, Neighbour: 1627, Directional Sector: dir_forward[1521,1627]
# Node: 1521, Next Neighbour: 7889, Next Directional Sector: dir_forward[1521,7889]
#
# Node: 1521, Index: 4, Beta: Not solved yet
# 0
# Node: 1523, Neighbour: 7799, Directional Sector: dir_forward[1523,7799]
# Node: 1523, Next Neighbour: 7627, Next Directional Sector: dir_forward[1523,7627]
# 1
# Node: 1523, Neighbour: 7627, Directional Sector: dir_forward[1523,7627]
# Node: 1523, Next Neighbour: 7551, Next Directional Sector: dir_forward[1523,7551]
# 2
# Node: 1523, Neighbour: 7551, Directional Sector: dir_forward[1523,7551]
# Node: 1523, Next Neighbour: 7799, Next Directional Sector: dir_forward[1523,7799]
#
# Node: 1523, Index: 2, Beta: Not solved yet
# 0
# Node: 7551, Neighbour: 1523, Directional Sector: dir_backward[1523,7551]
# Node: 7551, Next Neighbour: 1559, Next Directional Sector: dir_backward[1559,7551]
# 1
# Node: 7551, Neighbour: 1559, Directional Sector: dir_backward[1559,7551]
# Node: 7551, Next Neighbour: 1523, Next Directional Sector: dir_backward[1523,7551]
#
# Node: 7551, Index: 1, Beta: Not solved yet
# 0
# Node: 1533, Neighbour: 1561, Directional Sector: dir_forward[1533,1561]
# Node: 1533, Next Neighbour: 6825, Next Directional Sector: dir_forward[1533,6825]
# 1
# Node: 1533, Neighbour: 6825, Directional Sector: dir_forward[1533,6825]
# Node: 1533, Next Neighbour: 917, Next Directional Sector: dir_backward[917,1533]
# 2
# Node: 1533, Neighbour: 917, Directional Sector: dir_backward[917,1533]
# Node: 1533, Next Neighbour: 1538, Next Directional Sector: dir_forward[1533,1538]
# 3
# Node: 1533, Neighbour: 1538, Directional Sector: dir_forward[1533,1538]
# Node: 1533, Next Neighbour: 1134, Next Directional Sector: dir_backward[1134,1533]
# 4
# Node: 1533, Neighbour: 1134, Directional Sector: dir_backward[1134,1533]
# Node: 1533, Next Neighbour: 1756, Next Directional Sector: dir_forward[1533,1756]
# 5
# Node: 1533, Neighbour: 1756, Directional Sector: dir_forward[1533,1756]
# Node: 1533, Next Neighbour: 1561, Next Directional Sector: dir_forward[1533,1561]
#
# Node: 1533, Index: 5, Beta: Not solved yet
# 0
# Node: 1559, Neighbour: 1759, Directional Sector: dir_forward[1559,1759]
# Node: 1559, Next Neighbour: 7799, Next Directional Sector: dir_forward[1559,7799]
# 1
# Node: 1559, Neighbour: 7799, Directional Sector: dir_forward[1559,7799]
# Node: 1559, Next Neighbour: 7551, Next Directional Sector: dir_forward[1559,7551]
# 2
# Node: 1559, Neighbour: 7551, Directional Sector: dir_forward[1559,7551]
# Node: 1559, Next Neighbour: 7627, Next Directional Sector: dir_forward[1559,7627]
# 3
# Node: 1559, Neighbour: 7627, Directional Sector: dir_forward[1559,7627]
# Node: 1559, Next Neighbour: 1549, Next Directional Sector: dir_backward[1549,1559]
# 4
# Node: 1559, Neighbour: 1549, Directional Sector: dir_backward[1549,1559]
# Node: 1559, Next Neighbour: 1551, Next Directional Sector: dir_backward[1551,1559]
# 5
# Node: 1559, Neighbour: 1551, Directional Sector: dir_backward[1551,1559]
# Node: 1559, Next Neighbour: 1759, Next Directional Sector: dir_forward[1559,1759]
#
# Node: 1559, Index: 5, Beta: Not solved yet
# 0
# Node: 1563, Neighbour: 1540, Directional Sector: dir_backward[1540,1563]
# Node: 1563, Next Neighbour: 1536, Next Directional Sector: dir_backward[1536,1563]
# 1
# Node: 1563, Neighbour: 1536, Directional Sector: dir_backward[1536,1563]
# Node: 1563, Next Neighbour: 1540, Next Directional Sector: dir_backward[1540,1563]
#
# Node: 1563, Index: 1, Beta: Not solved yet
# 0
# Node: 1557, Neighbour: 6815, Directional Sector: dir_forward[1557,6815]
# Node: 1557, Next Neighbour: 1561, Next Directional Sector: dir_forward[1557,1561]
# 1
# Node: 1557, Neighbour: 1561, Directional Sector: dir_forward[1557,1561]
# Node: 1557, Next Neighbour: 6815, Next Directional Sector: dir_forward[1557,6815]
#
# Node: 1557, Index: 1, Beta: Not solved yet
# 0
# Node: 1561, Neighbour: 1557, Directional Sector: dir_backward[1557,1561]
# Node: 1561, Next Neighbour: 1533, Next Directional Sector: dir_backward[1533,1561]
# 1
# Node: 1561, Neighbour: 1533, Directional Sector: dir_backward[1533,1561]
# Node: 1561, Next Neighbour: 1557, Next Directional Sector: dir_backward[1557,1561]
#
# Node: 1561, Index: 1, Beta: Not solved yet
# 0
# Node: 7585, Neighbour: 1564, Directional Sector: dir_backward[1564,7585]
# Node: 7585, Next Neighbour: 7180, Next Directional Sector: dir_backward[7180,7585]
# 1
# Node: 7585, Neighbour: 7180, Directional Sector: dir_backward[7180,7585]
# Node: 7585, Next Neighbour: 7181, Next Directional Sector: dir_backward[7181,7585]
# 2
# Node: 7585, Neighbour: 7181, Directional Sector: dir_backward[7181,7585]
# Node: 7585, Next Neighbour: 1564, Next Directional Sector: dir_backward[1564,7585]
#
# Node: 7585, Index: 2, Beta: Not solved yet
# 0
# Node: 1522, Neighbour: 1525, Directional Sector: dir_forward[1522,1525]
# Node: 1522, Next Neighbour: 1551, Next Directional Sector: dir_forward[1522,1551]
# 1
# Node: 1522, Neighbour: 1551, Directional Sector: dir_forward[1522,1551]
# Node: 1522, Next Neighbour: 1525, Next Directional Sector: dir_forward[1522,1525]
#
# Node: 1522, Index: 1, Beta: Not solved yet
# 0
# Node: 1551, Neighbour: 1521, Directional Sector: dir_backward[1521,1551]
# Node: 1551, Next Neighbour: 1559, Next Directional Sector: dir_forward[1551,1559]
# 1
# Node: 1551, Neighbour: 1559, Directional Sector: dir_forward[1551,1559]
# Node: 1551, Next Neighbour: 1522, Next Directional Sector: dir_backward[1522,1551]
# 2
# Node: 1551, Neighbour: 1522, Directional Sector: dir_backward[1522,1551]
# Node: 1551, Next Neighbour: 1519, Next Directional Sector: dir_backward[1519,1551]
# 3
# Node: 1551, Neighbour: 1519, Directional Sector: dir_backward[1519,1551]
# Node: 1551, Next Neighbour: 1499, Next Directional Sector: dir_backward[1499,1551]
# 4
# Node: 1551, Neighbour: 1499, Directional Sector: dir_backward[1499,1551]
# Node: 1551, Next Neighbour: 1521, Next Directional Sector: dir_backward[1521,1551]
#
# Node: 1551, Index: 4, Beta: Not solved yet
# 0
# Node: 1519, Neighbour: 7698, Directional Sector: dir_forward[1519,7698]
# Node: 1519, Next Neighbour: 1517, Next Directional Sector: dir_backward[1517,1519]
# 1
# Node: 1519, Neighbour: 1517, Directional Sector: dir_backward[1517,1519]
# Node: 1519, Next Neighbour: 1551, Next Directional Sector: dir_forward[1519,1551]
# 2
# Node: 1519, Neighbour: 1551, Directional Sector: dir_forward[1519,1551]
# Node: 1519, Next Neighbour: 7698, Next Directional Sector: dir_forward[1519,7698]
#
# Node: 1519, Index: 2, Beta: Not solved yet
# 0
# Node: 1540, Neighbour: 1498, Directional Sector: dir_backward[1498,1540]
# Node: 1540, Next Neighbour: 1488, Next Directional Sector: dir_backward[1488,1540]
# 1
# Node: 1540, Neighbour: 1488, Directional Sector: dir_backward[1488,1540]
# Node: 1540, Next Neighbour: 1538, Next Directional Sector: dir_backward[1538,1540]
# 2
# Node: 1540, Neighbour: 1538, Directional Sector: dir_backward[1538,1540]
# Node: 1540, Next Neighbour: 7397, Next Directional Sector: dir_forward[1540,7397]
# 3
# Node: 1540, Neighbour: 7397, Directional Sector: dir_forward[1540,7397]
# Node: 1540, Next Neighbour: 1563, Next Directional Sector: dir_forward[1540,1563]
# 4
# Node: 1540, Neighbour: 1563, Directional Sector: dir_forward[1540,1563]
# Node: 1540, Next Neighbour: 1498, Next Directional Sector: dir_backward[1498,1540]
#
# Node: 1540, Index: 4, Beta: Not solved yet
# 0
# Node: 7452, Neighbour: 6808, Directional Sector: dir_backward[6808,7452]
# Node: 7452, Next Neighbour: 1541, Next Directional Sector: dir_backward[1541,7452]
# 1
# Node: 7452, Neighbour: 1541, Directional Sector: dir_backward[1541,7452]
# Node: 7452, Next Neighbour: 6807, Next Directional Sector: dir_backward[6807,7452]
# 2
# Node: 7452, Neighbour: 6807, Directional Sector: dir_backward[6807,7452]
# Node: 7452, Next Neighbour: 6808, Next Directional Sector: dir_backward[6808,7452]
#
# Node: 7452, Index: 2, Beta: Not solved yet
# 0
# Node: 1510, Neighbour: 1517, Directional Sector: dir_forward[1510,1517]
# Node: 1510, Next Neighbour: 7219, Next Directional Sector: dir_forward[1510,7219]
# 1
# Node: 1510, Neighbour: 7219, Directional Sector: dir_forward[1510,7219]
# Node: 1510, Next Neighbour: 1517, Next Directional Sector: dir_forward[1510,1517]
#
# Node: 1510, Index: 1, Beta: Not solved yet
# 0
# Node: 917, Neighbour: 1500, Directional Sector: dir_forward[917,1500]
# Node: 917, Next Neighbour: 7178, Next Directional Sector: dir_forward[917,7178]
# 1
# Node: 917, Neighbour: 7178, Directional Sector: dir_forward[917,7178]
# Node: 917, Next Neighbour: 1134, Next Directional Sector: dir_forward[917,1134]
# 2
# Node: 917, Neighbour: 1134, Directional Sector: dir_forward[917,1134]
# Node: 917, Next Neighbour: 1533, Next Directional Sector: dir_forward[917,1533]
# 3
# Node: 917, Neighbour: 1533, Directional Sector: dir_forward[917,1533]
# Node: 917, Next Neighbour: 1011, Next Directional Sector: dir_forward[917,1011]
# 4
# Node: 917, Neighbour: 1011, Directional Sector: dir_forward[917,1011]
# Node: 917, Next Neighbour: 7175, Next Directional Sector: dir_forward[917,7175]
# 5
# Node: 917, Neighbour: 7175, Directional Sector: dir_forward[917,7175]
# Node: 917, Next Neighbour: 1500, Next Directional Sector: dir_forward[917,1500]
#
# Node: 917, Index: 5, Beta: Not solved yet
# 0
# Node: 1508, Neighbour: 7174, Directional Sector: dir_forward[1508,7174]
# Node: 1508, Next Neighbour: 1512, Next Directional Sector: dir_forward[1508,1512]
# 1
# Node: 1508, Neighbour: 1512, Directional Sector: dir_forward[1508,1512]
# Node: 1508, Next Neighbour: 1514, Next Directional Sector: dir_forward[1508,1514]
# 2
# Node: 1508, Neighbour: 1514, Directional Sector: dir_forward[1508,1514]
# Node: 1508, Next Neighbour: 7174, Next Directional Sector: dir_forward[1508,7174]
#
# Node: 1508, Index: 2, Beta: Not solved yet
# 0
# Node: 1498, Neighbour: 1491, Directional Sector: dir_backward[1491,1498]
# Node: 1498, Next Neighbour: 1540, Next Directional Sector: dir_forward[1498,1540]
# 1
# Node: 1498, Neighbour: 1540, Directional Sector: dir_forward[1498,1540]
# Node: 1498, Next Neighbour: 7008, Next Directional Sector: dir_forward[1498,7008]
# 2
# Node: 1498, Neighbour: 7008, Directional Sector: dir_forward[1498,7008]
# Node: 1498, Next Neighbour: 1491, Next Directional Sector: dir_backward[1491,1498]
#
# Node: 1498, Index: 2, Beta: Not solved yet
# 0
# Node: 1490, Neighbour: 1497, Directional Sector: dir_forward[1490,1497]
# Node: 1490, Next Neighbour: 7007, Next Directional Sector: dir_forward[1490,7007]
# 1
# Node: 1490, Neighbour: 7007, Directional Sector: dir_forward[1490,7007]
# Node: 1490, Next Neighbour: 1497, Next Directional Sector: dir_forward[1490,1497]
#
# Node: 1490, Index: 1, Beta: Not solved yet
# 0
# Node: 6852, Neighbour: 6816, Directional Sector: dir_backward[6816,6852]
# Node: 6852, Next Neighbour: 1762, Next Directional Sector: dir_backward[1762,6852]
# 1
# Node: 6852, Neighbour: 1762, Directional Sector: dir_backward[1762,6852]
# Node: 6852, Next Neighbour: 6816, Next Directional Sector: dir_backward[6816,6852]
#
# Node: 6852, Index: 1, Beta: Not solved yet
# 0
# Node: 1512, Neighbour: 6839, Directional Sector: dir_forward[1512,6839]
# Node: 1512, Next Neighbour: 1508, Next Directional Sector: dir_backward[1508,1512]
# 1
# Node: 1512, Neighbour: 1508, Directional Sector: dir_backward[1508,1512]
# Node: 1512, Next Neighbour: 1514, Next Directional Sector: dir_forward[1512,1514]
# 2
# Node: 1512, Neighbour: 1514, Directional Sector: dir_forward[1512,1514]
# Node: 1512, Next Neighbour: 6839, Next Directional Sector: dir_forward[1512,6839]
#
# Node: 1512, Index: 2, Beta: Not solved yet
# 0
# Node: 1762, Neighbour: 6817, Directional Sector: dir_forward[1762,6817]
# Node: 1762, Next Neighbour: 6852, Next Directional Sector: dir_forward[1762,6852]
# 1
# Node: 1762, Neighbour: 6852, Directional Sector: dir_forward[1762,6852]
# Node: 1762, Next Neighbour: 6817, Next Directional Sector: dir_forward[1762,6817]
#
# Node: 1762, Index: 1, Beta: Not solved yet
# 0
# Node: 1517, Neighbour: 1519, Directional Sector: dir_forward[1517,1519]
# Node: 1517, Next Neighbour: 1506, Next Directional Sector: dir_backward[1506,1517]
# 1
# Node: 1517, Neighbour: 1506, Directional Sector: dir_backward[1506,1517]
# Node: 1517, Next Neighbour: 1510, Next Directional Sector: dir_backward[1510,1517]
# 2
# Node: 1517, Neighbour: 1510, Directional Sector: dir_backward[1510,1517]
# Node: 1517, Next Neighbour: 1519, Next Directional Sector: dir_forward[1517,1519]
#
# Node: 1517, Index: 2, Beta: Not solved yet
# 0
# Node: 1506, Neighbour: 1517, Directional Sector: dir_forward[1506,1517]
# Node: 1506, Next Neighbour: 1515, Next Directional Sector: dir_forward[1506,1515]
# 1
# Node: 1506, Neighbour: 1515, Directional Sector: dir_forward[1506,1515]
# Node: 1506, Next Neighbour: 1517, Next Directional Sector: dir_forward[1506,1517]
#
# Node: 1506, Index: 1, Beta: Not solved yet
# 0
# Node: 1515, Neighbour: 1506, Directional Sector: dir_backward[1506,1515]
# Node: 1515, Next Neighbour: 6838, Next Directional Sector: dir_forward[1515,6838]
# 1
# Node: 1515, Neighbour: 6838, Directional Sector: dir_forward[1515,6838]
# Node: 1515, Next Neighbour: 1505, Next Directional Sector: dir_backward[1505,1515]
# 2
# Node: 1515, Neighbour: 1505, Directional Sector: dir_backward[1505,1515]
# Node: 1515, Next Neighbour: 1489, Next Directional Sector: dir_backward[1489,1515]
# 3
# Node: 1515, Neighbour: 1489, Directional Sector: dir_backward[1489,1515]
# Node: 1515, Next Neighbour: 1506, Next Directional Sector: dir_backward[1506,1515]
#
# Node: 1515, Index: 3, Beta: Not solved yet
# 0
# Node: 7799, Neighbour: 1537, Directional Sector: dir_backward[1537,7799]
# Node: 7799, Next Neighbour: 1525, Next Directional Sector: dir_backward[1525,7799]
# 1
# Node: 7799, Neighbour: 1525, Directional Sector: dir_backward[1525,7799]
# Node: 7799, Next Neighbour: 1559, Next Directional Sector: dir_backward[1559,7799]
# 2
# Node: 7799, Neighbour: 1559, Directional Sector: dir_backward[1559,7799]
# Node: 7799, Next Neighbour: 1523, Next Directional Sector: dir_backward[1523,7799]
# 3
# Node: 7799, Neighbour: 1523, Directional Sector: dir_backward[1523,7799]
# Node: 7799, Next Neighbour: 1537, Next Directional Sector: dir_backward[1537,7799]
#
# Node: 7799, Index: 3, Beta: Not solved yet
# 0
# Node: 1514, Neighbour: 1508, Directional Sector: dir_backward[1508,1514]
# Node: 1514, Next Neighbour: 1512, Next Directional Sector: dir_backward[1512,1514]
# 1
# Node: 1514, Neighbour: 1512, Directional Sector: dir_backward[1512,1514]
# Node: 1514, Next Neighbour: 1508, Next Directional Sector: dir_backward[1508,1514]
#
# Node: 1514, Index: 1, Beta: Not solved yet
# 0
# Node: 1500, Neighbour: 1538, Directional Sector: dir_forward[1500,1538]
# Node: 1500, Next Neighbour: 917, Next Directional Sector: dir_backward[917,1500]
# 1
# Node: 1500, Neighbour: 917, Directional Sector: dir_backward[917,1500]
# Node: 1500, Next Neighbour: 1527, Next Directional Sector: dir_forward[1500,1527]
# 2
# Node: 1500, Neighbour: 1527, Directional Sector: dir_forward[1500,1527]
# Node: 1500, Next Neighbour: 1538, Next Directional Sector: dir_forward[1500,1538]
#
# Node: 1500, Index: 2, Beta: Not solved yet
# 0
# Node: 1491, Neighbour: 1493, Directional Sector: dir_forward[1491,1493]
# Node: 1491, Next Neighbour: 1498, Next Directional Sector: dir_forward[1491,1498]
# 1
# Node: 1491, Neighbour: 1498, Directional Sector: dir_forward[1491,1498]
# Node: 1491, Next Neighbour: 1493, Next Directional Sector: dir_forward[1491,1493]
#
# Node: 1491, Index: 1, Beta: Not solved yet
# 0
# Node: 1493, Neighbour: 1521, Directional Sector: dir_forward[1493,1521]
# Node: 1493, Next Neighbour: 1491, Next Directional Sector: dir_backward[1491,1493]
# 1
# Node: 1493, Neighbour: 1491, Directional Sector: dir_backward[1491,1493]
# Node: 1493, Next Neighbour: 1521, Next Directional Sector: dir_forward[1493,1521]
#
# Node: 1493, Index: 1, Beta: Not solved yet
# 0
# Node: 1134, Neighbour: 1533, Directional Sector: dir_forward[1134,1533]
# Node: 1134, Next Neighbour: 917, Next Directional Sector: dir_backward[917,1134]
# 1
# Node: 1134, Neighbour: 917, Directional Sector: dir_backward[917,1134]
# Node: 1134, Next Neighbour: 1533, Next Directional Sector: dir_forward[1134,1533]
#
# Node: 1134, Index: 1, Beta: Not solved yet
# 0
# Node: 1525, Neighbour: 7799, Directional Sector: dir_forward[1525,7799]
# Node: 1525, Next Neighbour: 1522, Next Directional Sector: dir_backward[1522,1525]
# 1
# Node: 1525, Neighbour: 1522, Directional Sector: dir_backward[1522,1525]
# Node: 1525, Next Neighbour: 7799, Next Directional Sector: dir_forward[1525,7799]
#
# Node: 1525, Index: 1, Beta: Not solved yet
# 0
# Node: 1538, Neighbour: 1528, Directional Sector: dir_backward[1528,1538]
# Node: 1538, Next Neighbour: 1540, Next Directional Sector: dir_forward[1538,1540]
# 1
# Node: 1538, Neighbour: 1540, Directional Sector: dir_forward[1538,1540]
# Node: 1538, Next Neighbour: 6813, Next Directional Sector: dir_forward[1538,6813]
# 2
# Node: 1538, Neighbour: 6813, Directional Sector: dir_forward[1538,6813]
# Node: 1538, Next Neighbour: 1533, Next Directional Sector: dir_backward[1533,1538]
# 3
# Node: 1538, Neighbour: 1533, Directional Sector: dir_backward[1533,1538]
# Node: 1538, Next Neighbour: 1500, Next Directional Sector: dir_backward[1500,1538]
# 4
# Node: 1538, Neighbour: 1500, Directional Sector: dir_backward[1500,1538]
# Node: 1538, Next Neighbour: 1528, Next Directional Sector: dir_backward[1528,1538]
#
# Node: 1538, Index: 4, Beta: Not solved yet
# 0
# Node: 7627, Neighbour: 1526, Directional Sector: dir_backward[1526,7627]
# Node: 7627, Next Neighbour: 1559, Next Directional Sector: dir_backward[1559,7627]
# 1
# Node: 7627, Neighbour: 1559, Directional Sector: dir_backward[1559,7627]
# Node: 7627, Next Neighbour: 1523, Next Directional Sector: dir_backward[1523,7627]
# 2
# Node: 7627, Neighbour: 1523, Directional Sector: dir_backward[1523,7627]
# Node: 7627, Next Neighbour: 1526, Next Directional Sector: dir_backward[1526,7627]
#
# Node: 7627, Index: 2, Beta: Not solved yet
# 0
# Node: 1528, Neighbour: 7844, Directional Sector: dir_forward[1528,7844]
# Node: 1528, Next Neighbour: 1507, Next Directional Sector: dir_backward[1507,1528]
# 1
# Node: 1528, Neighbour: 1507, Directional Sector: dir_backward[1507,1528]
# Node: 1528, Next Neighbour: 1538, Next Directional Sector: dir_forward[1528,1538]
# 2
# Node: 1528, Neighbour: 1538, Directional Sector: dir_forward[1528,1538]
# Node: 1528, Next Neighbour: 7844, Next Directional Sector: dir_forward[1528,7844]
#
# Node: 1528, Index: 2, Beta: Not solved yet
# 0
# Node: 7844, Neighbour: 1673, Directional Sector: dir_backward[1673,7844]
# Node: 7844, Next Neighbour: 1535, Next Directional Sector: dir_backward[1535,7844]
# 1
# Node: 7844, Neighbour: 1535, Directional Sector: dir_backward[1535,7844]
# Node: 7844, Next Neighbour: 1528, Next Directional Sector: dir_backward[1528,7844]
# 2
# Node: 7844, Neighbour: 1528, Directional Sector: dir_backward[1528,7844]
# Node: 7844, Next Neighbour: 1673, Next Directional Sector: dir_backward[1673,7844]
#
# Node: 7844, Index: 2, Beta: Not solved yet
# 0
# Node: 1535, Neighbour: 1496, Directional Sector: dir_backward[1496,1535]
# Node: 1535, Next Neighbour: 7844, Next Directional Sector: dir_forward[1535,7844]
# 1
# Node: 1535, Neighbour: 7844, Directional Sector: dir_forward[1535,7844]
# Node: 1535, Next Neighbour: 1496, Next Directional Sector: dir_backward[1496,1535]
#
# Node: 1535, Index: 1, Beta: Not solved yet
# 0
# Node: 7480, Neighbour: 1078, Directional Sector: dir_backward[1078,7480]
# Node: 7480, Next Neighbour: 1554, Next Directional Sector: dir_backward[1554,7480]
# 1
# Node: 7480, Neighbour: 1554, Directional Sector: dir_backward[1554,7480]
# Node: 7480, Next Neighbour: 1544, Next Directional Sector: dir_backward[1544,7480]
# 2
# Node: 7480, Neighbour: 1544, Directional Sector: dir_backward[1544,7480]
# Node: 7480, Next Neighbour: 1078, Next Directional Sector: dir_backward[1078,7480]
#
# Node: 7480, Index: 2, Beta: Not solved yet
# 0
# Node: 1544, Neighbour: 1722, Directional Sector: dir_forward[1544,1722]
# Node: 1544, Next Neighbour: 7480, Next Directional Sector: dir_forward[1544,7480]
# 1
# Node: 1544, Neighbour: 7480, Directional Sector: dir_forward[1544,7480]
# Node: 1544, Next Neighbour: 1504, Next Directional Sector: dir_backward[1504,1544]
# 2
# Node: 1544, Neighbour: 1504, Directional Sector: dir_backward[1504,1544]
# Node: 1544, Next Neighbour: 1722, Next Directional Sector: dir_forward[1544,1722]
#
# Node: 1544, Index: 2, Beta: Not solved yet
# 0
# Node: 871, Neighbour: 1504, Directional Sector: dir_forward[871,1504]
# Node: 871, Next Neighbour: 1011, Next Directional Sector: dir_forward[871,1011]
# 1
# Node: 871, Neighbour: 1011, Directional Sector: dir_forward[871,1011]
# Node: 871, Next Neighbour: 7491, Next Directional Sector: dir_forward[871,7491]
# 2
# Node: 871, Neighbour: 7491, Directional Sector: dir_forward[871,7491]
# Node: 871, Next Neighbour: 1126, Next Directional Sector: dir_forward[871,1126]
# 3
# Node: 871, Neighbour: 1126, Directional Sector: dir_forward[871,1126]
# Node: 871, Next Neighbour: 1504, Next Directional Sector: dir_forward[871,1504]
#
# Node: 871, Index: 3, Beta: Not solved yet
# 0
# Node: 7491, Neighbour: 871, Directional Sector: dir_backward[871,7491]
# Node: 7491, Next Neighbour: 1558, Next Directional Sector: dir_backward[1558,7491]
# 1
# Node: 7491, Neighbour: 1558, Directional Sector: dir_backward[1558,7491]
# Node: 7491, Next Neighbour: 871, Next Directional Sector: dir_backward[871,7491]
#
# Node: 7491, Index: 1, Beta: Not solved yet
# 0
# Node: 1011, Neighbour: 917, Directional Sector: dir_backward[917,1011]
# Node: 1011, Next Neighbour: 871, Next Directional Sector: dir_backward[871,1011]
# 1
# Node: 1011, Neighbour: 871, Directional Sector: dir_backward[871,1011]
# Node: 1011, Next Neighbour: 917, Next Directional Sector: dir_backward[917,1011]
#
# Node: 1011, Index: 1, Beta: Not solved yet
# 0
# Node: 1504, Neighbour: 1544, Directional Sector: dir_forward[1504,1544]
# Node: 1504, Next Neighbour: 871, Next Directional Sector: dir_backward[871,1504]
# 1
# Node: 1504, Neighbour: 871, Directional Sector: dir_backward[871,1504]
# Node: 1504, Next Neighbour: 1544, Next Directional Sector: dir_forward[1504,1544]
#
# Node: 1504, Index: 1, Beta: Not solved yet
# 0
# Node: 1501, Neighbour: 7158, Directional Sector: dir_forward[1501,7158]
# Node: 1501, Next Neighbour: 1505, Next Directional Sector: dir_forward[1501,1505]
# 1
# Node: 1501, Neighbour: 1505, Directional Sector: dir_forward[1501,1505]
# Node: 1501, Next Neighbour: 7158, Next Directional Sector: dir_forward[1501,7158]
#
# Node: 1501, Index: 1, Beta: Not solved yet
# 0
# Node: 1505, Neighbour: 1501, Directional Sector: dir_backward[1501,1505]
# Node: 1505, Next Neighbour: 1515, Next Directional Sector: dir_forward[1505,1515]
# 1
# Node: 1505, Neighbour: 1515, Directional Sector: dir_forward[1505,1515]
# Node: 1505, Next Neighbour: 1501, Next Directional Sector: dir_backward[1501,1505]
#
# Node: 1505, Index: 1, Beta: Not solved yet
# 0
# Node: 1507, Neighbour: 1528, Directional Sector: dir_forward[1507,1528]
# Node: 1507, Next Neighbour: 7177, Next Directional Sector: dir_forward[1507,7177]
# 1
# Node: 1507, Neighbour: 7177, Directional Sector: dir_forward[1507,7177]
# Node: 1507, Next Neighbour: 1528, Next Directional Sector: dir_forward[1507,1528]
#
# Node: 1507, Index: 1, Beta: Not solved yet
# 0
# Node: 1545, Neighbour: 1757, Directional Sector: dir_forward[1545,1757]
# Node: 1545, Next Neighbour: 7179, Next Directional Sector: dir_forward[1545,7179]
# 1
# Node: 1545, Neighbour: 7179, Directional Sector: dir_forward[1545,7179]
# Node: 1545, Next Neighbour: 1757, Next Directional Sector: dir_forward[1545,1757]
#
# Node: 1545, Index: 1, Beta: Not solved yet
# 0
# Node: 1757, Neighbour: 1503, Directional Sector: dir_backward[1503,1757]
# Node: 1757, Next Neighbour: 1502, Next Directional Sector: dir_backward[1502,1757]
# 1
# Node: 1757, Neighbour: 1502, Directional Sector: dir_backward[1502,1757]
# Node: 1757, Next Neighbour: 1545, Next Directional Sector: dir_backward[1545,1757]
# 2
# Node: 1757, Neighbour: 1545, Directional Sector: dir_backward[1545,1757]
# Node: 1757, Next Neighbour: 1503, Next Directional Sector: dir_backward[1503,1757]
#
# Node: 1757, Index: 2, Beta: Not solved yet

# %% [markdown]
# ## Edge Spacing
# Each edge must have a distance of at least dmin > 0 from each non incident edge.
#
# - Prevents edge crossings
# - maintains planarity (edges have minimum separation in at least 1 octilinear direction)
# - enhances visualisation
# - preserves topology structure

# %%
def non_incident_edge_direction_constraint_rule(model, u1, v1, u2, v2):
    
    e1 = (u1, v1)
    e2 = (u2, v2)
        
    return (model.is_N[e1, e2] + model.is_S[e1, e2] + model.is_E[e1, e2] + model.is_W[e1, e2] +
            model.is_NE[e1, e2] + model.is_NW[e1, e2] + model.is_SE[e1, e2] + model.is_SW[e1, e2] >= 1)
    
model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)
#model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIntersecting_NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)







# Initialize ConstraintList outside of function
# Adds new constraints to list in model without reinitializing it
model.edgeSpacingConstraints = ConstraintList()

def edge_spacing_constraint(model, u1, v1, u2, v2):
    dmin =1500
    
    ## infeasibility coming from too small M value due to large distances between
    M = 30000
    
    
    e1 = (u1, v1)
    e2 = (u2, v2)
    
    # is_N[e1, e2] means that e1 is north of e1
    
    ## North Constraint
    c1 = model.y_pos[u2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c2 = model.y_pos[v2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c3 = model.y_pos[u2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c4 = model.y_pos[v2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin

    
    # South
    c5 = model.y_pos[u1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c6 = model.y_pos[v1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c7 = model.y_pos[u1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c8 = model.y_pos[v1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin

    
    # is_E[e1, e2] = 1 means that e1 is East of e2
    ## East
    c9 = model.x_pos[u2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c10 = model.x_pos[v2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c11 = model.x_pos[u2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c12 = model.x_pos[v2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin

    
    
    
    ## West
    c13 = model.x_pos[u1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c14 = model.x_pos[v1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c15 = model.x_pos[u1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c16 = model.x_pos[v1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin

    
    
    ## NE
    c17 = model.z1_pos[u2] - model.z1_pos[u1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c18 = model.z1_pos[v2] - model.z1_pos[u1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c19 = model.z1_pos[u2] - model.z1_pos[v1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c20 = model.z1_pos[v2] - model.z1_pos[v1] <= M * (1 - model.is_NE[e1, e2]) - dmin

    
    
    ## NW
    c21 = model.z2_pos[u1] - model.z2_pos[u2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c22 = model.z2_pos[u1] - model.z2_pos[v2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c23 = model.z2_pos[v1] - model.z2_pos[u2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c24 = model.z2_pos[v1] - model.z2_pos[v2] <= M * (1 - model.is_NW[e1, e2]) - dmin

    
    
    # SE
    c25 = model.z2_pos[u2] - model.z2_pos[u1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c26 = model.z2_pos[v2] - model.z2_pos[u1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c27 = model.z2_pos[u2] - model.z2_pos[v1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c28 = model.z2_pos[v2] - model.z2_pos[v1] <= M * (1 - model.is_SE[e1, e2]) - dmin

    
    
    
    
    ## SW
    c29 = model.z1_pos[u1] - model.z1_pos[u2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c30 = model.z1_pos[u1] - model.z1_pos[v2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c31 = model.z1_pos[v1] - model.z1_pos[u2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c32 = model.z1_pos[v1] - model.z1_pos[v2] <= M * (1 - model.is_SW[e1, e2]) - dmin

    
    constraint_list = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32]

    # Add all constraints to the constraint list
    for constraint in constraint_list:
        model.edgeSpacingConstraints.add(constraint)
 
 
 
""" # Call edge_spacing_constraint for each non-incident edge pair
for u1, v1, u2, v2 in model.NonIncidentEdges :
    edge_spacing_constraint(model, u1, v1, u2, v2)
     """
           
# Call edge_spacing_constraint for each non-incident edge pair
for u1, v1, u2, v2 in model.NonIntersecting_NonIncidentEdges :
    edge_spacing_constraint(model, u1, v1, u2, v2)

# %% [markdown]
# ## Deviation Constraints

# %%
model.dev_pos = Var(model.Edges, within=NonNegativeReals)
model.dev_neg = Var(model.Edges, within=NonNegativeReals)

tolerance = 0.01


model.DeviationConstraints = ConstraintList()


def dev_constraints_rule(model, node1, node2):
    
    sect_orig = model.sect_forward[node1, node2]
    
    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_chosen = (sect_orig + adjustment) % 8
        
        
        if sect_chosen == 0:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
            
            
        elif sect_chosen == 1:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
        
        elif sect_chosen == 2:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
                
                
        elif sect_chosen == 3:   
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
            
        elif sect_chosen == 4:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
            
            
        elif sect_chosen == 5:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
            
        elif sect_chosen == 6:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
            
            
        elif sect_chosen == 7:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
        
    return Constraint.Skip



model.DevConstraint = Constraint(model.Edges, rule = dev_constraints_rule)
""" 
for edge in model.Edges:
    node1, node2 = edge
    dev_constraints_rule(model, node1, node2)  """
# Out:
# WARNING: Implicitly replacing the Component attribute dev_pos (type=<class
# 'pyomo.core.base.var.IndexedVar'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.var.IndexedVar'>). This is usually indicative of
# a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().
# WARNING: Implicitly replacing the Component attribute dev_neg (type=<class
# 'pyomo.core.base.var.IndexedVar'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.var.IndexedVar'>). This is usually indicative of
# a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().
# ' \nfor edge in model.Edges:\n    node1, node2 = edge\n    dev_constraints_rule(model, node1, node2)  '

# %% [markdown]
# ## Relative Position Constraint and Objective Function

# %%
# Updated constraint without Big M
def rpos_constraint_upper(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= model.dir_forward[u, v] - model.sect_forward[u, v]

model.RposConstraintUpper = Constraint(model.Edges, rule=rpos_constraint_upper)

# Updated constraint without Big M
def rpos_constraint_lower(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= -model.dir_forward[u, v] + model.sect_forward[u, v]

model.RposConstraintLower = Constraint(model.Edges, rule=rpos_constraint_lower)






penalty_per_unit_deviation = 10  # This value can be adjusted based on how strict the octilinearity needs to be enforced

def total_cost(model):
    # Sum existing costs (if any other costs are involved)
    rpos_costs = sum(model.rpos[edge] for edge in model.Edges)

    # Cost for deviations from octilinearity beyond the tolerance
    deviation_costs = sum(
        (model.dev_pos[edge] + model.dev_neg[edge])
        for edge in model.Edges
    )

    # Combine the costs
    return 0.00001*deviation_costs + 10*rpos_costs

model.TotalCost = Objective(rule=total_cost, sense=minimize)
"""
 
# Objective function to minimize the sum of the deviations
def relative_position_cost(model):
    OF = sum(model.rpos[edge] for edge in model.Edges)
    print(f"cost is: {OF}")
    return OF

model.TotalCost = Objective(rule=relative_position_cost, sense=minimize) 
"""
# Out:
# '\n \n# Objective function to minimize the sum of the deviations\ndef relative_position_cost(model):\n    OF = sum(model.rpos[edge] for edge in model.Edges)\n    print(f"cost is: {OF}")\n    return OF\n\nmodel.TotalCost = Objective(rule=relative_position_cost, sense=minimize) \n'

# %% [markdown]
# # Solver

# %%
#solver.solve(model, tee=True)  # 'tee=True' enables solver output
#Solve the model
solver = SolverFactory('gurobi')
results = solver.solve(model, tee = True)

# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)


def extract_solver_stats(results, df):
    stats = {
        'Solver Status': str(results.solver.status),
        'Termination Condition': str(results.solver.termination_condition),
        'Solve Time (s)': results.solver.time,
        'Number of Constraints': results.problem.number_of_constraints,
        'Number of Variables': results.problem.number_of_variables,
        'Number of Nonzeros': results.problem.number_of_nonzeros
    }
    if results.solver.status == 'ok' and results.solver.termination_condition == 'optimal':
        stats['Objective Value'] = int(value(model.TotalCost.expr))
    else:
        stats['Objective Value'] = 'N/A'
        
    all_nodes = pd.concat([df['src_bus_id'], df['dst_bus_id']]).unique()
    stats['Total Number of Nodes'] = len(all_nodes)
    
    stats['Total Number of Edges'] = len(df)
    
    
    return stats
stats = extract_solver_stats(results, country_df)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmp2q7gq6ud.pyomo.lp
# Reading time = 0.92 seconds
# x1: 197402 rows, 48726 columns, 812227 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 197402 rows, 48726 columns and 812227 nonzeros
# Model fingerprint: 0xa96aa101
# Variable types: 585 continuous, 48141 integer (47919 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e-05, 1e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 3e+04]
# Presolve removed 2260 rows and 936 columns
# Presolve time: 4.38s
#
# Explored 0 nodes (0 simplex iterations) in 4.52 seconds (2.65 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Model was proven to be infeasible.
# warning
# infeasible

# %% [markdown]
# # Results

# %% [markdown]
# ## NetworkX Graph

# %%
# Update positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}




draw_graph(G, updated_pos)

# %%
# Assuming 'G' is your graph and 'model' is your Pyomo model
# Updated positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}

# Initialize a list to store edge information along with the calculated angles
opt_edges_info = []

# Iterate through each edge in your graph
for edge in G.edges():
    node1, node2 = edge

    # Retrieve the updated positions for source and destination nodes
    new_src_x, new_src_y = updated_pos[node1]
    new_dst_x, new_dst_y = updated_pos[node2]

    # Calculate the angle using the updated positions
    angle = calculate_angle(new_src_x, new_src_y, new_dst_x, new_dst_y)

    formatted_angle = round(angle, 2)

    # Append the edge information and formatted angle to the list
    opt_edges_info.append({
        'Edge': edge,
        'Source': node1,
        'Destination': node2,
        'Angle (degrees)': formatted_angle  # Use the formatted angle
    })

# Convert the list of dictionaries to a pandas DataFrame for easy tabular display
opt_edges_info_df = pd.DataFrame(opt_edges_info)

# Print the DataFrame
#print(edges_info_df)
display(opt_edges_info_df)
# Out:
#              Edge  Source  Destination  Angle (degrees)
# 0    (1569, 7889)    1569         7889           136.74
# 1    (1531, 6809)    1531         6809            98.65
# 2    (1531, 6824)    1531         6824            66.04
# 3    (1521, 1760)    1521         1760            94.09
# 4    (1521, 7889)    1521         7889            16.70
# ..            ...     ...          ...              ...
# 106  (1502, 1757)    1502         1757           282.99
# 107  (1503, 1757)    1503         1757           229.40
# 108  (1547, 1769)    1547         1769           218.29
# 109  (1555, 6840)    1555         6840            28.30
# 110  (1530, 7009)    1530         7009           296.57
#
# [111 rows x 4 columns]

# %% [markdown]
# ## Functions - Results

# %%
def count_octilinearity_violations(opt_edges_info):
    violations = 0
    for edge_info in opt_edges_info:
        edge = edge_info['Edge']
        angle = edge_info['Angle (degrees)']
        # Check if the angle is not an exact multiple of 45 (including 0)
        if angle % 45 != 0:
            print(f"Violation found: {edge} with angle {angle}°")
            violations += 1
            
    if violations == 0:
        print("No violations found.")
    else:
        print(f"Total Octilinear Violations: {violations}")
        
    return violations



octilinearity_violations = count_octilinearity_violations(opt_edges_info)
# Out:
# Violation found: (1569, 7889) with angle 136.74°
# Violation found: (1531, 6809) with angle 98.65°
# Violation found: (1531, 6824) with angle 66.04°
# Violation found: (1521, 1760) with angle 94.09°
# Violation found: (1521, 7889) with angle 16.7°
# Violation found: (1521, 1627) with angle 318.95°
# Violation found: (1521, 1551) with angle 202.29°
# Violation found: (1523, 7551) with angle 204.62°
# Violation found: (1523, 7627) with angle 164.05°
# Violation found: (1533, 1756) with angle 285.26°
# Violation found: (1533, 1561) with angle 326.31°
# Violation found: (1533, 6825) with angle 39.79°
# Violation found: (1533, 1538) with angle 68.5°
# Violation found: (1559, 7551) with angle 35.54°
# Violation found: (1559, 7799) with angle 32.01°
# Violation found: (1559, 7627) with angle 49.64°
# Violation found: (1559, 1759) with angle 339.78°
# Violation found: (1492, 6810) with angle 300.66°
# Violation found: (1536, 1563) with angle 100.3°
# Violation found: (1557, 6815) with angle 104.29°
# Violation found: (1549, 1559) with angle 285.12°
# Violation found: (1564, 7585) with angle 254.05°
# Violation found: (1522, 1525) with angle 22.43°
# Violation found: (1551, 1559) with angle 22.71°
# Violation found: (1567, 7182) with angle 190.09°
# Violation found: (1519, 1551) with angle 294.23°
# Violation found: (1519, 7698) with angle 143.13°
# Violation found: (1540, 1563) with angle 273.69°
# Violation found: (1540, 7397) with angle 252.18°
# Violation found: (1494, 6811) with angle 74.1°
# Violation found: (6808, 7452) with angle 174.31°
# Violation found: (1761, 7187) with angle 243.43°
# Violation found: (1510, 7219) with angle 74.92°
# Violation found: (1510, 1517) with angle 41.63°
# Violation found: (917, 7175) with angle 312.41°
# Violation found: (917, 1500) with angle 40.91°
# Violation found: (917, 1134) with angle 226.22°
# Violation found: (917, 1533) with angle 227.12°
# Violation found: (917, 1011) with angle 305.94°
# Violation found: (917, 7178) with angle 153.36°
# Violation found: (1508, 7174) with angle 116.44°
# Violation found: (1508, 1514) with angle 289.98°
# Violation found: (1508, 1512) with angle 257.01°
# Violation found: (1498, 7008) with angle 239.34°
# Violation found: (1498, 1540) with angle 204.62°
# Violation found: (1490, 7007) with angle 259.82°
# Violation found: (1490, 1497) with angle 348.69°
# Violation found: (1550, 6812) with angle 341.3°
# Violation found: (6816, 6852) with angle 249.14°
# Violation found: (1513, 6851) with angle 175.6°
# Violation found: (1541, 7452) with angle 255.96°
# Violation found: (1512, 6839) with angle 15.95°
# Violation found: (1512, 1514) with angle 320.71°
# Violation found: (6807, 7452) with angle 89.31°
# Violation found: (1762, 6817) with angle 64.64°
# Violation found: (1762, 6852) with angle 90.73°
# Violation found: (7181, 7585) with angle 120.87°
# Violation found: (7180, 7585) with angle 83.66°
# Violation found: (1517, 1519) with angle 18.97°
# Violation found: (1506, 1515) with angle 147.99°
# Violation found: (1489, 1515) with angle 38.66°
# Violation found: (1515, 6838) with angle 51.1°
# Violation found: (1500, 1538) with angle 92.94°
# Violation found: (1500, 1527) with angle 260.91°
# Violation found: (1491, 1498) with angle 231.34°
# Violation found: (1491, 1493) with angle 36.63°
# Violation found: (1493, 1521) with angle 63.85°
# Violation found: (1525, 7799) with angle 3.81°
# Violation found: (1553, 7184) with angle 243.44°
# Violation found: (1538, 1540) with angle 63.94°
# Violation found: (1538, 6813) with angle 77.2°
# Violation found: (1537, 7799) with angle 231.34°
# Violation found: (796, 1531) with angle 65.56°
# Violation found: (1526, 7627) with angle 194.62°
# Violation found: (1488, 1540) with angle 227.49°
# Violation found: (1528, 7844) with angle 5.49°
# Violation found: (1528, 1538) with angle 190.1°
# Violation found: (1535, 7844) with angle 303.69°
# Violation found: (1807, 7218) with angle 306.87°
# Violation found: (1554, 7480) with angle 323.13°
# Violation found: (1544, 7480) with angle 63.44°
# Violation found: (1544, 1722) with angle 3.75°
# Violation found: (871, 7491) with angle 288.87°
# Violation found: (871, 1011) with angle 93.47°
# Violation found: (871, 1126) with angle 292.83°
# Violation found: (871, 1504) with angle 4.27°
# Violation found: (1558, 7491) with angle 119.74°
# Violation found: (1078, 7480) with angle 246.8°
# Violation found: (1504, 1544) with angle 1.17°
# Violation found: (1501, 1505) with angle 256.81°
# Violation found: (1501, 7158) with angle 29.74°
# Violation found: (1505, 1515) with angle 271.33°
# Violation found: (1507, 1528) with angle 335.64°
# Violation found: (1507, 7177) with angle 190.3°
# Violation found: (1496, 1535) with angle 227.12°
# Violation found: (1545, 1757) with angle 357.75°
# Violation found: (1499, 1551) with angle 128.16°
# Violation found: (1556, 1744) with angle 26.57°
# Violation found: (1502, 1757) with angle 282.99°
# Violation found: (1503, 1757) with angle 229.4°
# Violation found: (1547, 1769) with angle 218.29°
# Violation found: (1555, 6840) with angle 28.3°
# Violation found: (1530, 7009) with angle 296.57°
# Total Octilinear Violations: 103

# %% [markdown]
# ## Debugging

# %%
""" # Print initial positions
print("Initial Positions:")
#for node in model.Nodes:
print(f"Node {6193}: x = {model.x_init[6193]}, y = {model.y_init[6193]}")
print(f"Node {6398}: x = {model.x_init[6398]}, y = {model.y_init[6398]}\n\n")

# After solving the model

# Print final positions
print("\nFinal Positions:")
#for node in model.Nodes:
print(f"Node {6193}: x = {value(model.x_pos[6193])}, y = {value(model.y_pos[6193])}")
print(f"Node {6398}: x = {value(model.x_pos[6398])}, y = {value(model.y_pos[6398])}") """
# Out:
# ' # Print initial positions\nprint("Initial Positions:")\n#for node in model.Nodes:\nprint(f"Node {6193}: x = {model.x_init[6193]}, y = {model.y_init[6193]}")\nprint(f"Node {6398}: x = {model.x_init[6398]}, y = {model.y_init[6398]}\n\n")\n\n# After solving the model\n\n# Print final positions\nprint("\nFinal Positions:")\n#for node in model.Nodes:\nprint(f"Node {6193}: x = {value(model.x_pos[6193])}, y = {value(model.y_pos[6193])}")\nprint(f"Node {6398}: x = {value(model.x_pos[6398])}, y = {value(model.y_pos[6398])}") '

# %%
def get_sorted_neighbours(G, node, pos, initial_neighbour):
    angles_neighbours = []
    src_x, src_y = pos[node]

    # Convert G to an undirected graph to consider all adjacent nodes
    G_undirected = G.to_undirected()

    # Calculate angles and sort neighbours
    for neighbour in G_undirected.neighbors(node):
        dst_x, dst_y = pos[neighbour]
        angle = calculate_angle(src_x, src_y, dst_x, dst_y)
        angles_neighbours.append((angle, neighbour))

    angles_neighbours.sort()
    sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]

    # Start the sorted list with the initial neighbour
    if initial_neighbour in sorted_neighbours:
        start_index = sorted_neighbours.index(initial_neighbour)
        sorted_neighbours = sorted_neighbours[start_index:] + sorted_neighbours[:start_index]

    return sorted_neighbours

def check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict):
    violations_count = 0
    
    for node, initial_neighbours in ordered_neighbours_dict.items():
        if initial_neighbours:  # Make sure there is at least one neighbour
            initial_first_neighbour = initial_neighbours[0]
            optimized_neighbours = get_sorted_neighbours(G, node, updated_pos, initial_first_neighbour)
            
            # Check for order violations
            if initial_neighbours != optimized_neighbours:
                print(f"Order violation at node {node}. Initial order: {initial_neighbours}, Optimized order: {optimized_neighbours}")
                violations_count += 1
            
            # Check for sector violations
            angles = [round(calculate_angle(updated_pos[node][0], updated_pos[node][1],
                                            updated_pos[neighbour][0], updated_pos[neighbour][1]), 1)
                      for neighbour in optimized_neighbours]
            sectors = [int(angle // 45) for angle in angles]
            for i in range(len(sectors) - 1):
                if sectors[i] == sectors[i + 1] and angles[i] != angles[i + 1]:
                    print(f"Sector violation between nodes {optimized_neighbours[i]} and {optimized_neighbours[i + 1]} "
                          f"at node {node} in sector {sectors[i]}. Rounded angles: {angles[i]}, {angles[i + 1]}")
                    violations_count += 1
                    break  # Stop at the first violation for this node

    if violations_count == 0:
        print("No circular order violations found.")
    else:
        print(f"Total circular order violations: {violations_count}")
    
    return violations_count

# Example usage
circular_order_violations = check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict)
# Out:
# Sector violation between nodes 917 and 1538 at node 1533 in sector 1. Rounded angles: 47.1, 68.5
# Sector violation between nodes 7799 and 7551 at node 1559 in sector 0. Rounded angles: 32.0, 35.5
# Sector violation between nodes 1521 and 1559 at node 1551 in sector 0. Rounded angles: 22.3, 22.7
# Sector violation between nodes 1538 and 7397 at node 1540 in sector 5. Rounded angles: 243.9, 252.2
# Sector violation between nodes 1134 and 1533 at node 917 in sector 5. Rounded angles: 226.2, 227.1
# Sector violation between nodes 1525 and 1559 at node 7799 in sector 4. Rounded angles: 183.8, 212.0
# Sector violation between nodes 1533 and 917 at node 1134 in sector 1. Rounded angles: 45.0, 46.2
# Sector violation between nodes 1540 and 6813 at node 1538 in sector 1. Rounded angles: 63.9, 77.2
# Sector violation between nodes 7491 and 1126 at node 871 in sector 6. Rounded angles: 288.9, 292.8
# Total circular order violations: 9

# %%
def check_edge_spacing_violations(specified_edge_pairs, pos):
    intersecting_edge_pairs = []
    violations_count = 0

    for edge1, edge2 in specified_edge_pairs:
        # Get the positions for the source and target nodes of each edge from the 'pos' argument
        src_pos1, tgt_pos1 = pos[edge1[0]], pos[edge1[1]]
        src_pos2, tgt_pos2 = pos[edge2[0]], pos[edge2[1]]
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect and are not merely touching at endpoints
        if line1.intersects(line2) and not line1.touches(line2):
            print(f"Violation found between edge {edge1} and edge {edge2}")
            intersecting_edge_pairs.append((edge1, edge2))
            violations_count += 1

    if violations_count == 0:
        print("No edge spacing violations found.")
    else:
        print(f"Total edge spacing violations: {violations_count}")

    return violations_count


edge_cross_violations = check_edge_spacing_violations(non_intersecting_non_incident_edges, updated_pos)
# Out:
# No edge spacing violations found.

# %%
def display_results(stats, octilinearity_violations, circular_order_violations, edge_crossing_violations):
    # Construct the results DataFrame with the specified metrics
    results_df = pd.DataFrame([
        ['Solver Status', stats.get('Solver Status', 'N/A')],
        ['Objective Function Value', stats.get('Objective Value', 'N/A')],
        ['Computation Time (s)', stats.get('Solve Time (s)', 'N/A')],
        
        ['Number of Constraints', stats.get('Number of Constraints', 'N/A')],
        ['Number of Variables', stats.get('Number of Variables', 'N/A')],
        
        ['Total Number of Nodes', stats.get('Total Number of Nodes', 'N/A')],
        ['Total Number of Edges', stats.get('Total Number of Edges', 'N/A')],
        
        ['Octilinearity Violations', octilinearity_violations],
        ['Circular Order Violations', circular_order_violations],
        ['Edge Crossing Violations', edge_crossing_violations]
    ], columns=['Metric', 'Value'])
    
    # Display the DataFrame
    # If using a Jupyter Notebook, 'display()' will work directly.
    # In other environments, you might need to print the DataFrame or use another method to visualize it.
    display(results_df)

# %%
stats = extract_solver_stats(results, country_df)


display_results(stats, octilinearity_violations, circular_order_violations, edge_cross_violations)
# Out:
#                       Metric     Value
# 0              Solver Status   warning
# 1   Objective Function Value       N/A
# 2       Computation Time (s)  7.060376
# 3      Number of Constraints    197402
# 4        Number of Variables     48726
# 5      Total Number of Nodes       126
# 6      Total Number of Edges       127
# 7   Octilinearity Violations       103
# 8  Circular Order Violations         9
# 9   Edge Crossing Violations         0
