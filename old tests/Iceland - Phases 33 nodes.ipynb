# %% [markdown]
# # Import Packages

# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from pyomo.environ import*
import math
import csv
from IPython.display import display

from pyproj import Transformer 
from itertools import combinations
from shapely.geometry import LineString

import matplotlib.lines as mlines

# %% [markdown]
# # Access Files
#
# Creating Dataframe of particular country and particular links

# %%
filename = 'IS.csv'
file_path = filename

country_df = pd.read_csv(file_path)

print(f"Shape of df is: {country_df.shape}")
#display(country_df)  




## Add scaling factor if needed to the x y positions for graphing and optimisation
# Infeasible when x y values are too large

scaling_factor = 0.001

# Scale 'src_x' and 'src_y' columns
country_df['src_x'] = country_df['src_x'] * scaling_factor
country_df['src_y'] = country_df['src_y'] * scaling_factor

# Scale 'dst_x' and 'dst_y' columns
country_df['dst_x'] = country_df['dst_x'] * scaling_factor
country_df['dst_y'] = country_df['dst_y'] * scaling_factor

display(country_df)
# Out:
# Shape of df is: (39, 18)
#     link_id  src_bus_id  dst_bus_id  voltage  circuits dc underground  \
# 0      9014        6093        6094    132.0         1  f           f
# 1      9015        6107        6127    132.0         1  f           f
# 2      9008        6089        6126    132.0         1  f           f
# 3      9009        6124        6126    132.0         1  f           f
# 4      9013        6098        6124    132.0         1  f           f
# 5      9012        6102        6120    132.0         1  f           f
# 6      9033        6103        6116    132.0         1  f           f
# 7      9034        6127        6128    132.0         1  f           f
# 8      9020        6103        6115    132.0         1  f           f
# 9      9032        6103        6114    132.0         1  f           f
# 10     9005        6097        6112    132.0         1  f           f
# 11     9006        6095        6112    132.0         1  f           f
# 12     9002        6096        6110    132.0         1  f           f
# 13     9030        6114        6115    132.0         1  f           f
# 14     9035        6127        6129    132.0         1  f           f
# 15     9000        6105        6107    132.0         1  f           f
# 16     9004        6092        6094    132.0         1  f           f
# 17     8999        6095        6096    132.0         1  f           f
# 18     8998        6101        6102    132.0         1  f           f
# 19     9011        6100        6101    132.0         1  f           f
# 20     9010        6098        6100    132.0         1  f           f
# 21     9003        6092        6096    132.0         1  f           f
# 22     9007        6089        6097    132.0         1  f           f
# 23     9665        6098        6099    132.0         1  f           f
# 24     9001        6108        6110    132.0         1  f           f
# 25     9028        6111        6124    220.0         1  f           f
# 26     9026        6111        6124    220.0         1  f           f
# 27     9021        6105        6123    220.0         1  f           f
# 28     9023        6122        6123    220.0         1  f           f
# 29     9016        6103        6108    220.0         1  f           f
# 30     9022        6116        6123    220.0         1  f           f
# 31     9017        6119        6122    220.0         1  f           f
# 32     9018        6119        6120    220.0         1  f           f
# 33     9024        6118        6120    220.0         1  f           f
# 34     9664        6103        6116    220.0         1  f           f
# 35     8997        6103        6105    220.0         2  f           f
# 36     9029        6105        6113    220.0         1  f           f
# 37     9019        6120        6123    220.0         1  f           f
# 38     9027        6108        6122    220.0         2  f           f
#
#    under_construction       length_m  \
# 0                   f   85606.056856
# 1                   f    8526.255555
# 2                   f   84167.700312
# 3                   f  137912.853760
# 4                   f   26730.997512
# 5                   f   74921.825029
# 6                   f   40026.269114
# 7                   f    9487.765121
# 8                   f   26071.470229
# 9                   f   10353.579975
# 10                  f   34945.787918
# 11                  f   24144.662922
# 12                  f   63672.328034
# 13                  f   22738.058925
# 14                  f    8777.904066
# 15                  f   34475.242215
# 16                  f   50348.096659
# 17                  f   64281.827847
# 18                  f  175701.329128
# 19                  f   60292.067427
# 20                  f   45224.851524
# 21                  f   26321.650617
# 22                  f   92467.258898
# 23                  f   36216.000074
# 24                  f   29363.735240
# 25                  f   43599.356234
# 26                  f   47318.464041
# 27                  f  105759.477517
# 28                  f   15713.288870
# 29                  f   62527.422916
# 30                  f   58992.965910
# 31                  f   22736.612565
# 32                  f    9611.899413
# 33                  f   17863.110891
# 34                  f   34291.671594
# 35                  f   10373.355547
# 36                  f    7606.456062
# 37                  f   32110.402246
# 38                  f  107211.251555
#
#                                                  tags  \
# 0   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 1   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 2   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 3   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 4   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 5   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 6   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 7   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 8   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 9   'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 10  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 11  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 12  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 13  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 14  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 15  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 16  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 17  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 18  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 19  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 20  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 21  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 22  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 23  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 24  'text_'=>' '  'symbol'=>'132-150 kV Transmissi...
# 25  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 26  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 27  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 28  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 29  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 30  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 31  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 32  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 33  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 34  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 35  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 36  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 37  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 38  'text_'=>' '  'symbol'=>'220 kV Transmission L...
#
#                   src_coord                dst_coord src_country dst_country  \
# 0   (-23.148193, 65.789264)  (-21.851807, 65.467386)          IS          IS
# 1   (-22.554932, 63.980781)       (-22.5, 63.908396)          IS          IS
# 2    (-18.182373, 65.68543)  (-16.896973, 65.703518)          IS          IS
# 3   (-15.172119, 64.914228)  (-16.896973, 65.703518)          IS          IS
# 4   (-14.688721, 65.030423)  (-15.172119, 64.914228)          IS          IS
# 5    (-18.083496, 63.81644)  (-19.248047, 64.177679)          IS          IS
# 6   (-21.719971, 64.086607)  (-21.049805, 64.081805)          IS          IS
# 7        (-22.5, 63.908396)  (-22.302246, 63.903564)          IS          IS
# 8   (-21.719971, 64.086607)  (-21.236572, 64.187249)          IS          IS
# 9   (-21.719971, 64.086607)  (-21.708984, 64.177679)          IS          IS
# 10  (-19.489746, 65.544819)  (-20.028076, 65.353096)          IS          IS
# 11  (-20.368652, 65.512963)  (-20.028076, 65.353096)          IS          IS
# 12   (-21.137695, 65.07676)  (-21.687012, 64.609749)          IS          IS
# 13  (-21.708984, 64.177679)  (-21.236572, 64.187249)          IS          IS
# 14       (-22.5, 63.908396)  (-22.576904, 63.835824)          IS          IS
# 15  (-21.851807, 64.014496)  (-22.554932, 63.980781)          IS          IS
# 16  (-21.643066, 65.141497)  (-21.851807, 65.467386)          IS          IS
# 17  (-20.368652, 65.512963)   (-21.137695, 65.07676)          IS          IS
# 18  (-15.007324, 64.344665)   (-18.083496, 63.81644)          IS          IS
# 19   (-14.370117, 64.69441)  (-15.007324, 64.344665)          IS          IS
# 20  (-14.688721, 65.030423)   (-14.370117, 64.69441)          IS          IS
# 21  (-21.643066, 65.141497)   (-21.137695, 65.07676)          IS          IS
# 22   (-18.182373, 65.68543)  (-19.489746, 65.544819)          IS          IS
# 23  (-14.688721, 65.030423)  (-14.523926, 65.348514)          IS          IS
# 31 -2153.689728  9414.595925 -2205.055435  9410.926804
# 32 -2153.689728  9414.595925 -2142.682791  9395.027908
# 33 -2112.108002  9423.156740 -2142.682791  9395.027908
# 34 -2417.856112  9371.791220 -2343.253574  9370.568119
# 35 -2417.856112  9371.791220 -2432.532028  9353.446228
# 36 -2432.532028  9353.446228 -2439.869986  9369.345228
# 37 -2142.682791  9395.027908 -2208.724415  9374.237037
# 38 -2419.079068  9448.839686 -2205.055435  9410.926804

# %% [markdown]
# ## Functions
# Calculate Forward Sector : Calculates the sector of an edge starting at the positive x axis going in counterclockwise direction. Sectors are split from 0 - 7.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Function - NetworkX Implementation and Attributes

# %%
def calculate_forward_sector(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    # Angle in radians
    angle_rad = math.atan2(dy, dx)
    
    # Convert to degreees
    angle_deg = math.degrees(angle_rad)
    
    # Angle is rounded to nearest multiple of 45
    # Sector value calculated, modulo 8 used 
    sector = round(angle_deg / 45) % 8
    
    return sector





def euclidean_distance(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    return math.sqrt((dx)**2 + (dy)**2)




def get_non_incident_edge_pairs(G):
    non_incident_edge_pairs = []
    
    # combinations - generates all possible pairs of edges from graph G without repeating the same pair
    # '2' indicates we're looking for combinationes of 2 edges
    for edge1, edge2 in combinations(G.edges(), 2):
        
        # edges are sets and the '&' checks that they have no common elements (ie nodes)
        if not set(edge1) & set(edge2):
            non_incident_edge_pairs.append((edge1, edge2))
    return non_incident_edge_pairs    


def midpoint(pos1, pos2):
    """Calculate the midpoint between two positions."""
    return ((pos1[0] + pos2[0]) / 2, (pos1[1] + pos2[1]) / 2)



def calculate_distance(midpoint1, midpoint2):
    return math.sqrt((midpoint2[0] - midpoint1[0]) ** 2 + (midpoint2[1] - midpoint1[1]) ** 2)




def get_non_incident_edge_distance(G):
    non_incident_edge_distances = {}
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Calculate the midpoints for each edge
        midpoint1 = midpoint(src_pos1, tgt_pos1)
        midpoint2 = midpoint(src_pos2, tgt_pos2)

        # Calculate the distance between the midpoints of the two edges
        dist = calculate_distance(midpoint1, midpoint2)

        # Store the distance with the edge pair as the key
        non_incident_edge_distances[(edge1, edge2)] = dist

    return non_incident_edge_distances




def calculate_angle(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    angle_radians = math.atan2(dy, dx)
    angle_degrees = math.degrees(angle_radians)  # Convert the angle to degrees
    
    # Normalize the angle to be within 0 to 360 degrees
    angle_degrees = (angle_degrees + 360) % 360

    return angle_degrees







 
def get_filtered_neighbour_order(G):
    
    # Convert the directed graph to an undirected graph to consider all adjacent nodes as neighbours
    G_undirected = G.to_undirected()
    
    # Create Dictionary to story nodes neighbour orders
    neighbour_order = {}
    for node in G_undirected.nodes():
        
        # Check if the node has 2 or more neighbours
        if G_undirected.degree(node) >= 2:
        
            # Access the position of the current node
            src_pos = G_undirected.nodes[node]['pos']
            src_x, src_y = src_pos
            
            # Create list to store angle size of neighbours with src node
            angles_neighbours = []
            
            
            
            for neighbour in G_undirected.neighbors(node):
                # Access the position tuple of the neighbour node using the 'pos' attribute
                dst_pos = G_undirected.nodes[neighbour]['pos']
                dst_x, dst_y = dst_pos
                
                # Calculate the angle from the source node to the neighbour node
                angle = calculate_angle(src_x, src_y, dst_x, dst_y)
                
                # Append the angle and neighbour to the list
                angles_neighbours.append((angle, neighbour)) 
                
                
            
            # Sort the list of (angle, neighbour) pairs by angle in ascending order
            angles_neighbours.sort()
            
            # Extract the sorted neighbours from the sorted list of pairs
            sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]
            
            # Check conditions to move the last neighbour to the first position
            if angles_neighbours[-1][0] > 315 and ((360 - angles_neighbours[-1][0]) < angles_neighbours[0][0]):
                # Move the last neighbour to the first position
                sorted_neighbours.insert(0, sorted_neighbours.pop())
            
            
            # Store the sorted list of neighbours in the dictionary with the src_node as the key
            neighbour_order[node] = sorted_neighbours
    
    return neighbour_order
neighbour_order = get_filtered_neighbour_order(G)
print(neighbour_order)
# Out:
# {6094: [6093, 6092], 6107: [6105, 6127], 6127: [6128, 6107, 6129], 6089: [6126, 6097], 6126: [6089, 6124], 6124: [6111, 6098, 6126], 6098: [6099, 6124, 6100], 6102: [6101, 6120], 6120: [6102, 6118, 6119, 6123], 6103: [6116, 6115, 6114, 6108, 6105], 6116: [6123, 6103], 6115: [6114, 6103], 6114: [6115, 6103], 6097: [6089, 6112], 6112: [6097, 6095], 6095: [6096, 6112], 6096: [6095, 6092, 6110], 6110: [6096, 6108], 6105: [6123, 6103, 6113, 6107], 6092: [6096, 6094], 6101: [6100, 6102], 6100: [6098, 6101], 6108: [6122, 6110, 6103], 6123: [6120, 6122, 6116, 6105], 6122: [6119, 6108, 6123], 6119: [6122, 6120]}

# %% [markdown]
# # NetworkX Implementation
# Dataframe is accessed where nodes and edges are added to graph.
# Forward and backward sector of a particular edge are found and stored as attributes along with the voltage information.

# %%
# Initialize a directed graph since we have source and destination
G = nx.DiGraph()

# Loop through the DataFrame rows to add edges and nodes to the graph
for index, row in country_df.iterrows():
    src_node = row['src_bus_id']
    dst_node = row['dst_bus_id']
    voltage = row['voltage']
    
    # Add the source and destination nodes if they don't already exist
    if src_node not in G:
        G.add_node(src_node, pos=(row['src_x'], row['src_y']))
    if dst_node not in G:
        G.add_node(dst_node, pos=(row['dst_x'], row['dst_y']))
        
        
        
    # Calculate the forward sector for edges
    forward_sector = calculate_forward_sector(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])

    # Backward sector
    backward_sector = (forward_sector + 4) % 8
    
    distance = euclidean_distance(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])
    
    # Add an edge between the source and destination nodes, voltage is attribute
    G.add_edge(src_node, dst_node, 
               voltage = voltage, 
               forward_sector = forward_sector, 
               backward_sector = backward_sector,
               distance = distance
               )


# Create list of non-incident edge pairs
non_incident_edge_pairs = get_non_incident_edge_pairs(G)

print(non_incident_edge_pairs)



# Print non-incident edge pairs
print("Non-incident edge pairs:")
for edge_pair in non_incident_edge_pairs:
    print(edge_pair)
    
ordered_neighbours_dict = get_filtered_neighbour_order(G)
print("\nNodes with more than 2 neighbours ordered:")
print(ordered_neighbours_dict)
# ((6100, 6101), (6108, 6110))
# ((6100, 6101), (6108, 6122))
# ((6100, 6101), (6111, 6124))
# ((6100, 6101), (6122, 6123))
# ((6100, 6101), (6119, 6122))
# ((6100, 6101), (6119, 6120))
# ((6100, 6101), (6118, 6120))
# ((6108, 6110), (6111, 6124))
# ((6108, 6110), (6122, 6123))
# ((6108, 6110), (6119, 6122))
# ((6108, 6110), (6119, 6120))
# ((6108, 6110), (6118, 6120))
# ((6108, 6122), (6111, 6124))
# ((6108, 6122), (6119, 6120))
# ((6108, 6122), (6118, 6120))
# ((6111, 6124), (6122, 6123))
# ((6111, 6124), (6119, 6122))
# ((6111, 6124), (6119, 6120))
# ((6111, 6124), (6118, 6120))
# ((6122, 6123), (6119, 6120))
# ((6122, 6123), (6118, 6120))
# ((6119, 6122), (6118, 6120))
#
# Nodes with more than 2 neighbours ordered:
# {6094: [6093, 6092], 6107: [6105, 6127], 6127: [6128, 6107, 6129], 6089: [6126, 6097], 6126: [6089, 6124], 6124: [6111, 6098, 6126], 6098: [6099, 6124, 6100], 6102: [6101, 6120], 6120: [6102, 6118, 6119, 6123], 6103: [6116, 6115, 6114, 6108, 6105], 6116: [6123, 6103], 6115: [6114, 6103], 6114: [6115, 6103], 6097: [6089, 6112], 6112: [6097, 6095], 6095: [6096, 6112], 6096: [6095, 6092, 6110], 6110: [6096, 6108], 6105: [6123, 6103, 6113, 6107], 6092: [6096, 6094], 6101: [6100, 6102], 6100: [6098, 6101], 6108: [6122, 6110, 6103], 6123: [6120, 6122, 6116, 6105], 6122: [6119, 6108, 6123], 6119: [6122, 6120]}
# 2
# 2
# 3
# 2
# 2
# 3
# 3
# 2
# 4
# 5
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 4
# 2
# 2
# 2
# 3
# 4
# 3
# 2
# Non-incident edge pair with maximum distance: ((6127, 6129), (6098, 6099)) with distance 946.6348652291265

# %% [markdown]
# ## Drawing NetworkX Graph

# %%
pos = nx.get_node_attributes(G, 'pos')

 
 
def draw_graph(G, pos, ax=None, title="Network Layout"):
    if ax is None:
        # Creating a new figure if no axis is provided
        fig, ax = plt.subplots(figsize=(15, 15))
    
    ax.set_title(title)
    
    # Convert to undirected graph for the purpose of finding node outline colors
    G_undirected = G.to_undirected()

    voltage_colors = {
        132: 'black',
        220: 'green',
        380: 'red',
        300: 'orange',
        500: 'yellow',
        750: 'purple'
    }

    # Determine the highest voltage color for each node
    node_outline_color = {}
    for node in G.nodes():
        connected_edges = G_undirected.edges(node, data=True)
        highest_voltage = max((data['voltage'] for _, _, data in connected_edges), default=0)
        node_outline_color[node] = voltage_colors.get(highest_voltage, 'grey')

    # Draw nodes with highest voltage outline color
    for node, color in node_outline_color.items():
        nx.draw_networkx_nodes(G, pos, nodelist=[node], node_color='skyblue',
                               edgecolors=color, node_size=500, linewidths=2, ax=ax)

    # Draw the graph edges with different colors based on the voltage
    for (u, v, d) in G.edges(data=True):
        if d['voltage'] == 380:
            edge_color = 'red'
        elif d['voltage'] == 220:
            edge_color = 'green'
        elif d['voltage'] == 132:
            edge_color = 'black'
        elif d['voltage'] == 300:
            edge_color = 'orange'
        elif d['voltage'] == 500:
            edge_color = 'yellow'
        elif d['voltage'] == 750:
            edge_color = 'purple'
        else:
            edge_color = 'grey'  # Default color for unspecified or unknown voltages
        nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], edge_color=edge_color, width=3, arrows=True, ax=ax)

    # Draw the node labels
    nx.draw_networkx_labels(G, pos, font_size=8, ax=ax)

    # Create edge labels for voltages, using 'link_id' or another attribute if desired
    edge_labels = nx.get_edge_attributes(G, 'link_id')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, label_pos=0.5, font_size=7, ax=ax)

    # Define custom lines for the legend with appropriate colors and labels for each voltage level
    legend_lines = [
        mlines.Line2D([], [], color='black', markersize=30, label='132 kV', linewidth=3),
        mlines.Line2D([], [], color='green', markersize=30, label='220 kV', linewidth=3),
        mlines.Line2D([], [], color='orange', markersize=30, label='300 kV', linewidth=3),
        mlines.Line2D([], [], color='red', markersize=30, label='380 kV', linewidth=3),
        mlines.Line2D([], [], color='yellow', markersize=30, label='500 kV', linewidth=3),
        mlines.Line2D([], [], color='purple', markersize=30, label='750 kV', linewidth=3)
    ]

    # Add the legend to the plot with all line types
    ax.legend(handles=legend_lines, loc='lower right', fontsize=20)
    ax.axis('equal')
    ax.grid(True)

    # Show the plot if ax was not provided
    if ax is None:
        plt.show()
        
draw_graph(G, pos, title="Original Network Layout")

# %% [markdown]
# ## Access edge information from NetworkX Graph

# %%
def get_edge_info(G, edge):
    node1, node2 = edge
    
    # edge attributes eg voltage forward/backward sector are stored in edge data
    edge_data = G.get_edge_data(node1, node2)
    
    # Additional edge information
    edge_information = {
        'edge': edge,
        'source': node1,
        'destination': node2,
        'source_position': G.nodes[node1].get('pos'),
        'destination_position': G.nodes[node2].get('pos'),
        'source_neighbors': list(G.successors(node1)),  # or list(G.successors(u)) for DiGraph
        'destination_neighbors': list(G.predecessors(node2)),  # or list(G.predecessors(v)) for DiGraph
        'source_degree': G.degree(node1),
        'destination_degree': G.degree(node2)
    }
    
    # Merge edge_data into edge_info
    edge_information.update(edge_data)
    return edge_information

    
    
# Print Specified Edge Details
edge_details = {}
for edge in G.edges():
    edge_details[edge] = get_edge_info(G, edge)
    print(edge_details[edge])
    
    forward = edge_details[edge].get('forward_sector')
    backward = edge_details[edge].get('backward_sector')
    print(f"Forward sector for edge {edge}: {forward}")
    print(f"Backward sector for edge {edge}: {backward}\n")
# Out:
# {'edge': (6093, 6094), 'source': 6093, 'destination': 6094, 'source_position': (-2576.8450575444194, 9819.406494284744), 'destination_position': (-2432.532028152891, 9732.573974479512), 'source_neighbors': [6094], 'destination_neighbors': [6093, 6092], 'source_degree': 1, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 168.4224953736467}
# Forward sector for edge (6093, 6094): 7
# Backward sector for edge (6093, 6094): 3
#
# {'edge': (6107, 6127), 'source': 6107, 'destination': 6127, 'source_position': (-2510.803545116912, 9344.88539964164), 'destination_position': (-2504.6885428486557, 9326.540387552075), 'source_neighbors': [6127], 'destination_neighbors': [6107], 'source_degree': 2, 'destination_degree': 3, 'voltage': 132.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 19.337340078383743}
# Forward sector for edge (6107, 6127): 6
# Backward sector for edge (6107, 6127): 2
#
# {'edge': (6127, 6128), 'source': 6127, 'destination': 6128, 'source_position': (-2504.6885428486557, 9326.540387552075), 'destination_position': (-2482.6746682663224, 9325.317467561443), 'source_neighbors': [6128, 6129], 'destination_neighbors': [6127], 'source_degree': 3, 'destination_degree': 1, 'voltage': 132.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 22.047816386893928}
# Forward sector for edge (6127, 6128): 0
# Backward sector for edge (6127, 6128): 4
#
# {'edge': (6127, 6129), 'source': 6127, 'destination': 6129, 'source_position': (-2504.6885428486557, 9326.540387552075), 'destination_position': (-2513.249456968621, 9308.195431243028), 'source_neighbors': [6128, 6129], 'destination_neighbors': [6127], 'source_degree': 3, 'destination_degree': 1, 'voltage': 132.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 20.244176262576545}
# Forward sector for edge (6127, 6129): 5
# Backward sector for edge (6127, 6129): 1
#
# {'edge': (6089, 6126), 'source': 6089, 'destination': 6126, 'source_position': (-2024.0525037733657, 9791.277516058364), 'destination_position': (-1880.9624303076919, 9796.16948882388), 'source_neighbors': [6126, 6097], 'destination_neighbors': [6089, 6124], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 143.17367258665433}
# Forward sector for edge (6089, 6126): 0
# Backward sector for edge (6089, 6126): 4
#
# {'edge': (6089, 6097), 'source': 6089, 'destination': 6097, 'source_position': (-2024.0525037733657, 9791.277516058364), 'destination_position': (-2169.58860041024, 9753.364822493084), 'source_neighbors': [6126, 6097], 'destination_neighbors': [6089], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 150.39324372348787}
# Forward sector for edge (6089, 6097): 4
# Backward sector for edge (6089, 6097): 0
#
# {'edge': (6124, 6126), 'source': 6124, 'destination': 6126, 'source_position': (-1688.9525613349513, 9585.814970830292), 'destination_position': (-1880.9624303076919, 9796.16948882388), 'source_neighbors': [6126], 'destination_neighbors': [6089, 6124], 'source_degree': 3, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 284.81013504305605}
# Forward sector for edge (6124, 6126): 3
# Backward sector for edge (6124, 6126): 7
#
# {'edge': (6098, 6124), 'source': 6098, 'destination': 6124, 'source_position': (-1635.1409421244641, 9616.389626969278), 'destination_position': (-1688.9525613349513, 9585.814970830292), 'source_neighbors': [6124, 6100, 6099], 'destination_neighbors': [6098, 6111], 'source_degree': 3, 'destination_degree': 3, 'voltage': 132.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 61.89103295366548}
# Forward sector for edge (6098, 6124): 5
# Backward sector for edge (6098, 6124): 1
#
# {'edge': (6098, 6100), 'source': 6098, 'destination': 6100, 'source_position': (-1635.1409421244641, 9616.389626969278), 'destination_position': (-1599.6741070797639, 9528.33425357892), 'source_neighbors': [6124, 6100, 6099], 'destination_neighbors': [6098], 'source_degree': 3, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 94.92968540453163}
# Forward sector for edge (6098, 6100): 6
# Backward sector for edge (6098, 6100): 2
#
# {'edge': (6098, 6099), 'source': 6098, 'destination': 6099, 'source_position': (-1635.1409421244641, 9616.389626969278), 'destination_position': (-1616.7960466391867, 9700.776189134733), 'source_neighbors': [6124, 6100, 6099], 'destination_neighbors': [6098], 'source_degree': 3, 'destination_degree': 1, 'voltage': 132.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 86.35755360401282}
# Forward sector for edge (6098, 6099): 2
# Backward sector for edge (6098, 6099): 6
#
# {'edge': (6102, 6120), 'source': 6102, 'destination': 6120, 'source_position': (-2013.0455664822, 9303.303493244795), 'destination_position': (-2142.682790804997, 9395.027908325523), 'source_neighbors': [6120], 'destination_neighbors': [6102, 6119, 6118], 'source_degree': 2, 'destination_degree': 4, 'voltage': 132.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 158.80547299139502}
# Forward sector for edge (6102, 6120): 3
# Backward sector for edge (6102, 6120): 7
#
# {'edge': (6120, 6123), 'source': 6120, 'destination': 6123, 'source_position': (-2142.682790804997, 9395.027908325523), 'destination_position': (-2208.7244145519962, 9374.23703715954), 'source_neighbors': [6123], 'destination_neighbors': [6105, 6122, 6116, 6120], 'source_degree': 4, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 69.23695827360343}
# Forward sector for edge (6120, 6123): 4
# Backward sector for edge (6120, 6123): 0
#
# {'edge': (6103, 6116), 'source': 6103, 'destination': 6116, 'source_position': (-2417.856111764669, 9371.79122033052), 'destination_position': (-2343.253573897704, 9370.56811882608), 'source_neighbors': [6116, 6115, 6114, 6108, 6105], 'destination_neighbors': [6103], 'source_degree': 5, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 74.61256350965384}
# Forward sector for edge (6103, 6116): 0
# Backward sector for edge (6103, 6116): 4
#
# {'edge': (6103, 6115), 'source': 6103, 'destination': 6115, 'source_position': (-2417.856111764669, 9371.79122033052), 'destination_position': (-2364.0443812346916, 9397.474088158217), 'source_neighbors': [6116, 6115, 6114, 6108, 6105], 'destination_neighbors': [6103, 6114], 'source_degree': 5, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 59.62643744586638}
# Forward sector for edge (6103, 6115): 1
# Backward sector for edge (6103, 6115): 5
#
# {'edge': (6103, 6114), 'source': 6103, 'destination': 6114, 'source_position': (-2417.856111764669, 9371.79122033052), 'destination_position': (-2416.6330445193234, 9395.027908325523), 'source_neighbors': [6116, 6115, 6114, 6108, 6105], 'destination_neighbors': [6103], 'source_degree': 5, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 23.268853913842012}
# Forward sector for edge (6103, 6114): 2
# Backward sector for edge (6103, 6114): 6
#
# {'edge': (6103, 6108), 'source': 6103, 'destination': 6108, 'source_position': (-2417.856111764669, 9371.79122033052), 'destination_position': (-2419.079067690524, 9448.839686283745), 'source_neighbors': [6116, 6115, 6114, 6108, 6105], 'destination_neighbors': [6103], 'source_degree': 5, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 77.05817105889444}
# Forward sector for edge (6103, 6108): 2
# Backward sector for edge (6103, 6108): 6
#
# {'edge': (6103, 6105), 'source': 6103, 'destination': 6105, 'source_position': (-2417.856111764669, 9371.79122033052), 'destination_position': (-2432.532028152891, 9353.446227696108), 'source_neighbors': [6116, 6115, 6114, 6108, 6105], 'destination_neighbors': [6103], 'source_degree': 5, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 23.493004843798637}
# Forward sector for edge (6103, 6105): 5
# Backward sector for edge (6103, 6105): 1
#
# {'edge': (6116, 6123), 'source': 6116, 'destination': 6123, 'source_position': (-2343.253573897704, 9370.56811882608), 'destination_position': (-2208.7244145519962, 9374.23703715954), 'source_neighbors': [6123], 'destination_neighbors': [6105, 6122, 6116, 6120], 'source_degree': 2, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 134.5791799499478}
# Forward sector for edge (6116, 6123): 0
# Backward sector for edge (6116, 6123): 4
#
# {'edge': (6114, 6115), 'source': 6114, 'destination': 6115, 'source_position': (-2416.6330445193234, 9395.027908325523), 'destination_position': (-2364.0443812346916, 9397.474088158217), 'source_neighbors': [6115], 'destination_neighbors': [6103, 6114], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 52.64552499347177}
# Forward sector for edge (6114, 6115): 0
# Backward sector for edge (6114, 6115): 4
#
# {'edge': (6097, 6112), 'source': 6097, 'destination': 6112, 'source_position': (-2169.58860041024, 9753.364822493084), 'destination_position': (-2229.515221888983, 9701.9991889217), 'source_neighbors': [6112], 'destination_neighbors': [6097, 6095], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 78.92799423554511}
# Forward sector for edge (6097, 6112): 5
# Backward sector for edge (6097, 6112): 1
#
# {'edge': (6095, 6112), 'source': 6095, 'destination': 6112, 'source_position': (-2267.427968785393, 9744.803981992804), 'destination_position': (-2229.515221888983, 9701.9991889217), 'source_neighbors': [6112, 6096], 'destination_neighbors': [6097, 6095], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 57.18064958612541}
# Forward sector for edge (6095, 6112): 7
# Backward sector for edge (6095, 6112): 3
#
# {'edge': (6095, 6096), 'source': 6095, 'destination': 6096, 'source_position': (-2267.427968785393, 9744.803981992804), 'destination_position': (-2353.037443943525, 9628.619534825873), 'source_neighbors': [6112, 6096], 'destination_neighbors': [6095, 6092], 'source_degree': 2, 'destination_degree': 3, 'voltage': 132.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 144.31842571319837}
# Forward sector for edge (6095, 6096): 5
# Backward sector for edge (6095, 6096): 1
#
# {'edge': (6096, 6110), 'source': 6096, 'destination': 6110, 'source_position': (-2353.037443943525, 9628.619534825873), 'destination_position': (-2414.1871326676137, 9506.320418594316), 'source_neighbors': [6110], 'destination_neighbors': [6096, 6108], 'source_degree': 3, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 136.73462715081703}
# Forward sector for edge (6096, 6110): 5
# Backward sector for edge (6096, 6110): 1
#
# {'edge': (6105, 6107), 'source': 6105, 'destination': 6107, 'source_position': (-2432.532028152891, 9353.446227696108), 'destination_position': (-2510.803545116912, 9344.88539964164), 'source_neighbors': [6107, 6123, 6113], 'destination_neighbors': [6105], 'source_degree': 4, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 78.73828893763937}
# Forward sector for edge (6105, 6107): 4
# Backward sector for edge (6105, 6107): 0
#
# {'edge': (6105, 6123), 'source': 6105, 'destination': 6123, 'source_position': (-2432.532028152891, 9353.446227696108), 'destination_position': (-2208.7244145519962, 9374.23703715954), 'source_neighbors': [6107, 6123, 6113], 'destination_neighbors': [6105, 6122, 6116, 6120], 'source_degree': 4, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 224.77122961774324}
# Forward sector for edge (6105, 6123): 0
# Backward sector for edge (6105, 6123): 4
#
# {'edge': (6105, 6113), 'source': 6105, 'destination': 6113, 'source_position': (-2432.532028152891, 9353.446227696108), 'destination_position': (-2439.869986347002, 9369.345228241911), 'source_neighbors': [6107, 6123, 6113], 'destination_neighbors': [6105], 'source_degree': 4, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 17.51067813689636}
# Forward sector for edge (6105, 6113): 3
# Backward sector for edge (6105, 6113): 7
#
# {'edge': (6092, 6094), 'source': 6092, 'destination': 6094, 'source_position': (-2409.2950863252127, 9645.74151832858), 'destination_position': (-2432.532028152891, 9732.573974479512), 'source_neighbors': [6094, 6096], 'destination_neighbors': [6093, 6092], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 89.88787964295598}
# Forward sector for edge (6092, 6094): 2
# Backward sector for edge (6092, 6094): 6
#
# {'edge': (6092, 6096), 'source': 6092, 'destination': 6096, 'source_position': (-2409.2950863252127, 9645.74151832858), 'destination_position': (-2353.037443943525, 9628.619534825873), 'source_neighbors': [6094, 6096], 'destination_neighbors': [6095, 6092], 'source_degree': 2, 'destination_degree': 3, 'voltage': 132.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 58.805481423187025}
# Forward sector for edge (6092, 6096): 0
# Backward sector for edge (6092, 6096): 4
#
# {'edge': (6101, 6102), 'source': 6101, 'destination': 6102, 'source_position': (-1670.6076658496738, 9437.832789599852), 'destination_position': (-2013.0455664822, 9303.303493244795), 'source_neighbors': [6102], 'destination_neighbors': [6101], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 367.91554379694054}
# Forward sector for edge (6101, 6102): 4
# Backward sector for edge (6101, 6102): 0
#
# {'edge': (6100, 6101), 'source': 6100, 'destination': 6101, 'source_position': (-1599.6741070797639, 9528.33425357892), 'destination_position': (-1670.6076658496738, 9437.832789599852), 'source_neighbors': [6101], 'destination_neighbors': [6100], 'source_degree': 2, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 114.98732426715041}
# Forward sector for edge (6100, 6101): 5
# Backward sector for edge (6100, 6101): 1
#
# {'edge': (6108, 6110), 'source': 6108, 'destination': 6110, 'source_position': (-2419.079067690524, 9448.839686283745), 'destination_position': (-2414.1871326676137, 9506.320418594316), 'source_neighbors': [6110, 6122], 'destination_neighbors': [6096, 6108], 'source_degree': 3, 'destination_degree': 2, 'voltage': 132.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 57.68852238728126}
# Forward sector for edge (6108, 6110): 2
# Backward sector for edge (6108, 6110): 6
#
# {'edge': (6108, 6122), 'source': 6108, 'destination': 6122, 'source_position': (-2419.079067690524, 9448.839686283745), 'destination_position': (-2205.0554354549404, 9410.926803598699), 'source_neighbors': [6110, 6122], 'destination_neighbors': [6119, 6108], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 217.35570346508607}
# Forward sector for edge (6108, 6122): 0
# Backward sector for edge (6108, 6122): 4
#
# {'edge': (6111, 6124), 'source': 6111, 'destination': 6124, 'source_position': (-1591.113192959798, 9615.166670995737), 'destination_position': (-1688.9525613349513, 9585.814970830292), 'source_neighbors': [6124], 'destination_neighbors': [6098, 6111], 'source_degree': 1, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 102.14726773952967}
# Forward sector for edge (6111, 6124): 4
# Backward sector for edge (6111, 6124): 0
#
# {'edge': (6122, 6123), 'source': 6122, 'destination': 6123, 'source_position': (-2205.0554354549404, 9410.926803598699), 'destination_position': (-2208.7244145519962, 9374.23703715954), 'source_neighbors': [6123], 'destination_neighbors': [6105, 6122, 6116, 6120], 'source_degree': 3, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 36.8727591722481}
# Forward sector for edge (6122, 6123): 6
# Backward sector for edge (6122, 6123): 2
#
# {'edge': (6119, 6122), 'source': 6119, 'destination': 6122, 'source_position': (-2153.689728096164, 9414.595924806405), 'destination_position': (-2205.0554354549404, 9410.926803598699), 'source_neighbors': [6122, 6120], 'destination_neighbors': [6119, 6108], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 51.49658574026342}
# Forward sector for edge (6119, 6122): 4
# Backward sector for edge (6119, 6122): 0
#
# {'edge': (6119, 6120), 'source': 6119, 'destination': 6120, 'source_position': (-2153.689728096164, 9414.595924806405), 'destination_position': (-2142.682790804997, 9395.027908325523), 'source_neighbors': [6122, 6120], 'destination_neighbors': [6102, 6119, 6118], 'source_degree': 2, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 22.451279195799707}
# Forward sector for edge (6119, 6120): 7
# Backward sector for edge (6119, 6120): 3
#
# {'edge': (6118, 6120), 'source': 6118, 'destination': 6120, 'source_position': (-2112.1080021026983, 9423.156740246603), 'destination_position': (-2142.682790804997, 9395.027908325523), 'source_neighbors': [6120], 'destination_neighbors': [6102, 6119, 6118], 'source_degree': 1, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 41.54574454062126}
# Forward sector for edge (6118, 6120): 5
# Backward sector for edge (6118, 6120): 1

# %%
def get_neighbors_for_node(node_id, neighbors_dict):
    """
    Retrieves the ordered neighbors for a specific node from a dictionary.

    Args:
    node_id (int): The node identifier for which neighbors are required.
    neighbors_dict (dict): A dictionary mapping nodes to their ordered list of neighbors.

    Returns:
    list or None: A list of neighbors for the specified node, or None if the node isn't in the dictionary.
    """
    return neighbors_dict.get(node_id)

# Example of how to use this function:
node_id = 6120  # Specify the node ID for which you want to access neighbors
neighbors = get_neighbors_for_node(node_id, ordered_neighbours_dict)  # Assuming ordered_neighbours_dict is already defined

if neighbors is not None:
    print(f"Neighbors of node {node_id}: {neighbors}")
else:
    print(f"No neighbors listed for node {node_id}.")
# Out:
# Neighbors of node 6120: [6102, 6118, 6119, 6123]

# %% [markdown]
# Create Dictionary of initial lengths of each edge

# %%
initial_lengths = {}

for edge in G.edges():
    edge_info = get_edge_info(G, edge)  # Retrieve edge information

    # Assuming the 'get_edge_info' function returns a dictionary with the positions
    node1_pos = edge_info.get('source_position')  # Source position (x, y)
    node2_pos = edge_info.get('destination_position')  # Destination position (x, y)

    # Calculate the Euclidean distance between node1 and node2
    distance = euclidean_distance(node1_pos[0], node1_pos[1], node2_pos[0], node2_pos[1])

    # Store the distance in the initial_lengths dictionary using the edge as the key
    initial_lengths[edge] = distance

print(initial_lengths)    

# Calculate min, max, and average lengths
min_length = min(initial_lengths.values())
max_length = max(initial_lengths.values())
avg_length = sum(initial_lengths.values()) / len(initial_lengths)

print("\nMinimum Length:", min_length)
print("\nMaximum Length:", max_length)
print("\nAverage Length:", avg_length)
# Out:
# {(6093, 6094): 168.4224953736467, (6107, 6127): 19.337340078383743, (6127, 6128): 22.047816386893928, (6127, 6129): 20.244176262576545, (6089, 6126): 143.17367258665433, (6089, 6097): 150.39324372348787, (6124, 6126): 284.81013504305605, (6098, 6124): 61.89103295366548, (6098, 6100): 94.92968540453163, (6098, 6099): 86.35755360401282, (6102, 6120): 158.80547299139502, (6120, 6123): 69.23695827360343, (6103, 6116): 74.61256350965384, (6103, 6115): 59.62643744586638, (6103, 6114): 23.268853913842012, (6103, 6108): 77.05817105889444, (6103, 6105): 23.493004843798637, (6116, 6123): 134.5791799499478, (6114, 6115): 52.64552499347177, (6097, 6112): 78.92799423554511, (6095, 6112): 57.18064958612541, (6095, 6096): 144.31842571319837, (6096, 6110): 136.73462715081703, (6105, 6107): 78.73828893763937, (6105, 6123): 224.77122961774324, (6105, 6113): 17.51067813689636, (6092, 6094): 89.88787964295598, (6092, 6096): 58.805481423187025, (6101, 6102): 367.91554379694054, (6100, 6101): 114.98732426715041, (6108, 6110): 57.68852238728126, (6108, 6122): 217.35570346508607, (6111, 6124): 102.14726773952967, (6122, 6123): 36.8727591722481, (6119, 6122): 51.49658574026342, (6119, 6120): 22.451279195799707, (6118, 6120): 41.54574454062126}
#
# Minimum Length: 17.51067813689636
#
# Maximum Length: 367.91554379694054
#
# Average Length: 97.95322440936248

# %% [markdown]
# ## Dynamic Min Length and Edge Spacing

# %%
def calculate_dynamic_min_lengths(G, avg_length, std_length):
    dynamic_min_lengths = {}
    
    # Get the maximum degree in the graph to normalize the local density
    max_degree = max(deg for node, deg in G.degree())

    # Iterate through each edge in the graph G
    for edge in G.edges():
        # Get the detailed information for the current edge
        edge_info = get_edge_info(G, edge)

        # Use the degree of nodes as a proxy for local density
        local_density = edge_info['source_degree'] + edge_info['destination_degree']
        
        # Scale the density factor non-linearly to increase variability
        # We subtract from 1 to ensure that higher density leads to shorter lengths
        density_factor = 1 - math.sqrt(local_density / (2 * max_degree))
        
        # Apply the adjustment based on local density and standard deviation
        adjusted_length = avg_length + std_length * density_factor
        
        # Ensure that the adjusted length is not below some minimum threshold if necessary
        min_threshold = avg_length * 0.5  # for example, at least 50% of the average length
        adjusted_length = max(adjusted_length, min_threshold)
        
        # Store the adjusted length
        dynamic_min_lengths[edge] = adjusted_length

    return dynamic_min_lengths

# Calculate the average and standard deviation of the initial edge lengths
lengths = [euclidean_distance(*G.nodes[edge[0]]['pos'], *G.nodes[edge[1]]['pos']) for edge in G.edges()]
avg_length = np.mean(lengths)
std_length = np.std(lengths)

# Use the function with the graph G
dynamic_min_edge_length_dict = calculate_dynamic_min_lengths(G, avg_length, std_length)
print(dynamic_min_edge_length_dict )








def calculate_dynamic_min_spacings(G):
    dynamic_min_spacings = {}
    spacings = []

    # Calculate initial spacings using the euclidean_distance function
    for edge in G.edges():
        edge_info = get_edge_info(G, edge)
        src_x, src_y = edge_info['source_position']
        dst_x, dst_y = edge_info['destination_position']
        spacing = euclidean_distance(src_x, src_y, dst_x, dst_y)
        spacings.append(spacing)
    
    # Calculate average and standard deviation of spacings
    avg_spacing = sum(spacings) / len(spacings)
    std_spacing = math.sqrt(sum((x - avg_spacing)**2 for x in spacings) / len(spacings))

    # Get the maximum degree in the graph to normalize the local density
    max_degree = max(deg for node, deg in G.degree())

# %% [markdown]
# ## Details for networkX area - to get parameters for dmin

# %%
# Extract the x and y coordinates separately
x_values = [position[0] for position in pos.values()]
y_values = [position[1] for position in pos.values()]

# Calculate the bounding box
min_x = min(x_values)
max_x = max(x_values)
min_y = min(y_values)
max_y = max(y_values)

# The bounding box is defined by the minimum and maximum x and y
bounding_box = (min_x, min_y, max_x, max_y)

print("Bounding box:", bounding_box)


# Calculate the area of the bounding box
area = (max_x - min_x) * (max_y - min_y)

# Determine the average area per node
average_area_per_node = area / len(pos)

# Estimate the minimum edge distance
minimum_edge_distance = average_area_per_node**0.5

print("Estimated minimum edge distance:", minimum_edge_distance)

# Assuming minimum_edge_distance is already calculated
factor = 0.2  # Starting with 10% of the edge length
minimum_edge_spacing = minimum_edge_distance * factor
# Out:
# Bounding box: (-2576.8450575444194, 9303.303493244795, -1591.113192959798, 9819.406494284744)
# Estimated minimum edge distance: 124.16254907138402

# %% [markdown]
# # Functions - Optimisation

# %% [markdown]
# ### Octilinearity Constraints Functions
# - Getting Dynamic Minimum Edge Length

# %%
""" # to get dynamic min length 
# Minimum length percentage
def calculate_dynamic_min_lengths(G, min_length_horizontal, min_length_diagonal):
    # Dictionary to store dynamic minimum lengths for each edge
    dynamic_min_lengths = {}

    for edge in G.edges():
        edge_info = get_edge_info(G, edge)

        forward = edge_info.get('forward_sector')
        backward = edge_info.get('backward_sector')

        if forward in (1, 3, 5, 7) or backward in (1, 3, 5, 7):
            # Use the diagonal minimum length for diagonal edges
            #dynamic_min_length = edge_info['distance'] * min_length_diagonal
            dynamic_min_length = 1400
        else:
            # Use the horizontal minimum length for horizontal/vertical edges
            #dynamic_min_length = edge_info['distance'] * min_length_horizontal
            dynamic_min_length = 1400

        # Store the calculated dynamic minimum length in the dictionary
        dynamic_min_lengths[edge] = dynamic_min_length

    return dynamic_min_lengths
    
    
dynamic_min_lengths = calculate_dynamic_min_lengths(G, 0.2, 0.22)


print(dynamic_min_lengths)  """
# Out:
# " # to get dynamic min length \n# Minimum length percentage\ndef calculate_dynamic_min_lengths(G, min_length_horizontal, min_length_diagonal):\n    # Dictionary to store dynamic minimum lengths for each edge\n    dynamic_min_lengths = {}\n\n    for edge in G.edges():\n        edge_info = get_edge_info(G, edge)\n\n        forward = edge_info.get('forward_sector')\n        backward = edge_info.get('backward_sector')\n\n        if forward in (1, 3, 5, 7) or backward in (1, 3, 5, 7):\n            # Use the diagonal minimum length for diagonal edges\n            #dynamic_min_length = edge_info['distance'] * min_length_diagonal\n            dynamic_min_length = 1400\n        else:\n            # Use the horizontal minimum length for horizontal/vertical edges\n            #dynamic_min_length = edge_info['distance'] * min_length_horizontal\n            dynamic_min_length = 1400\n\n        # Store the calculated dynamic minimum length in the dictionary\n        dynamic_min_lengths[edge] = dynamic_min_length\n\n    return dynamic_min_lengths\n    \n    \ndynamic_min_lengths = calculate_dynamic_min_lengths(G, 0.2, 0.22)\n\n\nprint(dynamic_min_lengths)  "

# %% [markdown]
# ### Circular Vertex Order Constraints Functions

# %%
## Function to get index of nodes in the ordered neighbours list.

# This function initializes the set of (node, index) pairs, where 'node' is a node with 2 or more neighbors,
# and 'index' is a unique integer (starting from 1) representing the position of a neighbor in the
# counterclockwise ordering of neighbors around 'node'.

def node_neighbour_index_pairs_init(model):
    node_index_pairs = []
    for node, neighbors in ordered_neighbours_dict.items():
        # Start index from 0 for each node's neighbors
        for idx in range(0, len(neighbors)):
            node_index_pairs.append((node, idx))
    return node_index_pairs



## Helper Function for the circular vertex order
## Determines if node with more than 2 neighbours is the source or destination node
## So the correct direction can be assigned to it
def orig_sector(model, node, neighbor):
    if (node, neighbor) in model.Edges:
        return model.sect_forward[node, neighbor]
    elif (neighbor, node) in model.Edges:
        return model.sect_backward[neighbor, node]
    else:
        return None  # This case should ideally never happen if the graph is well-defined

def directional_sector(model, node, neighbor):
    if (node, neighbor) in model.Edges:
        return model.dir_forward[node, neighbor]
    elif (neighbor, node) in model.Edges:
        return model.dir_backward[neighbor, node]
    else:
        return None  # This case should ideally never happen if the graph is well-defined

# %% [markdown]
# ### Edge Spacing Constraints Functions
# Gets list of intersecting edges and new list of non intersecting non incident edges created

# %%
def list_edge_intersections(G):
    intersecting_edge_pairs = []
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect
        if line1.intersects(line2):
            # If they intersect, add the edge pair to the list
            intersecting_edge_pairs.append((edge1, edge2))

    return intersecting_edge_pairs

# Call the function to get intersecting edge pairs
intersecting_edges = list_edge_intersections(G)

# Print the intersecting edge pairs
for edge_pair in intersecting_edges:
    print(f"Intersecting Edge Pair: {edge_pair}")
# Out:
# Intersecting Edge Pair: ((6098, 6100), (6111, 6124))

# %%
# Create a new list excluding intersecting edge pairs
non_intersecting_non_incident_edges = [edge_pair for edge_pair in non_incident_edge_pairs if edge_pair not in intersecting_edges]

# Print the new list of non-intersecting, non-incident edge pairs
for edge_pair in non_intersecting_non_incident_edges:
    print(f"Non-Intersecting Non-Incident Edge Pair: {edge_pair}")
# Out:
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6107, 6127))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6127, 6128))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6127, 6129))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6089, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6089, 6097))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6124, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6098, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6093, 6094), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6089, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6089, 6097))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6124, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6098, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6107, 6127), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6089, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6089, 6097))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6124, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6098, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6128), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6089, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6089, 6097))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6124, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6098, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6127, 6129), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6098, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6126), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6124, 6126))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6098, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6089, 6097), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6098, 6100))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6098, 6099))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6124, 6126), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6124), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6100), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6102, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6120, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6098, 6099), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6102, 6120), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6103, 6116))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6103, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6103, 6114))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6103, 6108))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6103, 6105))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6120, 6123), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6116), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6115), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6114), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6108), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6116, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6103, 6105), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6114, 6115))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6116, 6123), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6097, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6095, 6112))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6114, 6115), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6095, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6097, 6112), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6096, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6112), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6095, 6096), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6105, 6107))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6105, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6105, 6113))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6096, 6110), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6107), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6123), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6092, 6094))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6092, 6096))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6105, 6113), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6094), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6101, 6102))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6100, 6101))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6092, 6096), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6101, 6102), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6108, 6110))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6108, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6100, 6101), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6110), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6110), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6110), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6110), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6110), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6122), (6111, 6124))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6122), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6108, 6122), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6111, 6124), (6122, 6123))
# Non-Intersecting Non-Incident Edge Pair: ((6111, 6124), (6119, 6122))
# Non-Intersecting Non-Incident Edge Pair: ((6111, 6124), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6111, 6124), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6122, 6123), (6119, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6122, 6123), (6118, 6120))
# Non-Intersecting Non-Incident Edge Pair: ((6119, 6122), (6118, 6120))

# %% [markdown]
# # Optimisation

# %% [markdown]
# ## Variables and Parameters

# %%
model = ConcreteModel()



#print(list(G.nodes()))
print(list(G.edges())) 
# Set used to index the other components eg Param and Var, and to define the scope
model.Nodes = Set(initialize = list(G.nodes()))
model.Edges = Set(initialize = list(G.edges()))

# Initialize set of non-incident edge pairs
# dimen = 4: creates a collection of edge pairs where each pair is treated as a single tuple, 2 integers per edge
model.NonIncidentEdges = Set(initialize = non_incident_edge_pairs, dimen=4)
model.NonIntersecting_NonIncidentEdges = Set(initialize = non_intersecting_non_incident_edges, dimen=4)
model.IntersectingEdgePairs = Set(initialize = intersecting_edges, dimen = 4)


# Set with 2 or more neighbours
# Storing set nodes with 2 or more neighbours that were predetermined in the dictionary
model.NodesWith2Neighbours = Set(initialize = ordered_neighbours_dict.keys())


# Initialize the set with the function that provides the (node, index) pairs
model.NodeNeighbours2IndexPairs = Set(dimen=2, initialize=node_neighbour_index_pairs_init)





### PARAM ###
## Param - fixed value in model that doesn't change during optimisation process ##
# pos defined earlier as tuple (x, y) in graph G
model.x_init = Param(model.Nodes, initialize={node: pos[node][0] for node in G.nodes()})
model.y_init = Param(model.Nodes, initialize={node: pos[node][1] for node in G.nodes()})


# Access information from dictionary of the edge info
edge_info = {edge: get_edge_info(G, edge) for edge in G.edges()}

# Initialize Params for static attributes from the edges
model.voltage = Param(model.Edges, initialize={edge: edge_info[edge]['voltage'] for edge in model.Edges})
model.sect_forward = Param(model.Edges, initialize={edge: edge_info[edge]['forward_sector'] for edge in model.Edges})
model.sect_backward = Param(model.Edges, initialize={edge: edge_info[edge]['backward_sector'] for edge in model.Edges})
model.distance = Param(model.Edges, initialize={edge: edge_info[edge]['distance'] for edge in model.Edges} )
#model.non_incident_edges = Param(model.Edges, initialize = {edge: edge_info[edge]['non_incident_edges'] for edge in model.Edges} )


# Param to store the ordered neighbors for each node in the model
model.OrderedNeighbours = Param(
    model.NodesWith2Neighbours,  # Index set for the Param, representing nodes with 2 or more neighbors
    within=Any,  # Specifies that the Param can hold any type of data, in this case, tuples of nodes
    initialize=lambda model, node: tuple(ordered_neighbours_dict[node])  # Initialization function
    # lambda function takes 2 arguments model and node (element from set Nodewith2Neigbours)
    # for each node, it gets the list or ordered neighbours from the dictionary
    # list is converted to tuple so that for Param, the contents are unchangeable
)
   
model.dynamicMinLengths = Param(model.Edges, within=NonNegativeReals, initialize=dynamic_min_edge_length_dict)
model.dynamicMinSpacings = Param(model.Edges, within=NonNegativeReals, initialize=dynamic_min_spacings)




### VARIABLES ###
## Define Variables ##
model.x_pos = Var(model.Nodes, within = Reals, initialize = model.x_init)
model.y_pos = Var(model.Nodes, within = Reals, initialize = model.y_init)

model.z1_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] + model.y_pos[node])
model.z2_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] - model.y_pos[node])


model.dir_forward = Var(model.Edges, within = Integers, bounds = (0, 7))
model.dir_backward = Var(model.Edges, within = Integers, bounds = (0, 7))


# Binary variable for octilinear constraint to determine where edge is drawn
model.alpha_pred = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_orig = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_succ = Var(model.Edges, within = Binary, bounds = (0, 1))


# Binary Variable for non-incident edge constraint
model.is_N = Var(model.NonIncidentEdges, within=Binary)
model.is_S = Var(model.NonIncidentEdges, within=Binary)
model.is_E = Var(model.NonIncidentEdges, within=Binary)
model.is_W = Var(model.NonIncidentEdges, within=Binary)
model.is_NE = Var(model.NonIncidentEdges, within=Binary)
model.is_NW = Var(model.NonIncidentEdges, within=Binary)
model.is_SE = Var(model.NonIncidentEdges, within=Binary)
model.is_SW = Var(model.NonIncidentEdges, within=Binary)

model.delta_pred = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_orig = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_succ = Var(model.Edges, within = Integers, bounds = (0, 7))


max_degree = max(len(neighbors) for neighbors in ordered_neighbours_dict.values())


# Define Beta as a binary variable indexed by the (node, index) pairs
# Beta[node, idx] will be used in the constraints to identify the "wrap-around" point
# in the counterclockwise ordering of neighbors around each node
#model.Beta = Var(model.NodeNeighbours2IndexPairs, within=Binary)
model.Beta = Var(model.NodesWith2Neighbours, RangeSet(0, 7), within=Binary)




# Redefine rpos as a continuous variable representing the deviation magnitude
model.rpos = Var(model.Edges, within=NonNegativeReals)


model.dev_pos = Var(model.Edges, within=NonNegativeReals)
model.dev_neg = Var(model.Edges, within=NonNegativeReals)

tolerance = 0.01



""" 


model.min_dist_x_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_x_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_y_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_y_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)

 """
# Out:
# [(6093, 6094), (6107, 6127), (6127, 6128), (6127, 6129), (6089, 6126), (6089, 6097), (6124, 6126), (6098, 6124), (6098, 6100), (6098, 6099), (6102, 6120), (6120, 6123), (6103, 6116), (6103, 6115), (6103, 6114), (6103, 6108), (6103, 6105), (6116, 6123), (6114, 6115), (6097, 6112), (6095, 6112), (6095, 6096), (6096, 6110), (6105, 6107), (6105, 6123), (6105, 6113), (6092, 6094), (6092, 6096), (6101, 6102), (6100, 6101), (6108, 6110), (6108, 6122), (6111, 6124), (6122, 6123), (6119, 6122), (6119, 6120), (6118, 6120)]
# ' \n\n\nmodel.min_dist_x_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)\nmodel.min_dist_x_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)\nmodel.min_dist_y_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)\nmodel.min_dist_y_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)\n\n '

# %%
""" # Define a ConstraintList for spacing constraints
model.EdgeSpacingConstraints = ConstraintList()

dmin = 50  # Minimum spacing distance, as an example

# Define the constraints
def enforce_minimum_spacing(model, u1, v1, u2, v2):
    # Constraints for node u2 to be at least dmin away from nodes u1 and v1
    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[u2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[u2] >= dmin)

    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[u2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[u2] >= dmin) 

    # Constraints for node v2 to be at least dmin away from nodes u1 and v1
    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[v2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[v2] >= dmin)

    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[v2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[v2] >= dmin) 

# Adding the constraints to the model for each pair of intersecting edges
for (u1, v1, u2, v2) in model.IntersectingEdgePairs:
    enforce_minimum_spacing(model, u1, v1, u2, v2)
 """
# Out:
# ' # Define a ConstraintList for spacing constraints\nmodel.EdgeSpacingConstraints = ConstraintList()\n\ndmin = 50  # Minimum spacing distance, as an example\n\n# Define the constraints\ndef enforce_minimum_spacing(model, u1, v1, u2, v2):\n    # Constraints for node u2 to be at least dmin away from nodes u1 and v1\n    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[u2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[u2] >= dmin)\n\n    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[u2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[u2] >= dmin) \n\n    # Constraints for node v2 to be at least dmin away from nodes u1 and v1\n    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[v2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[v2] >= dmin)\n\n    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[v2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[v2] >= dmin) \n\n# Adding the constraints to the model for each pair of intersecting edges\nfor (u1, v1, u2, v2) in model.IntersectingEdgePairs:\n    enforce_minimum_spacing(model, u1, v1, u2, v2)\n '

# %% [markdown]
# ## Octilinearity Constraint

# %%
# Sum of Binary variables is equal to 1
# node1 and node2 are the src and dst nodes defined in model.Edges
def alpha_direction_constraint(model, node1, node2):
    return model.alpha_pred[node1, node2] + model.alpha_orig[node1, node2] + model.alpha_succ[node1, node2] == 1
model.alpha_direction_constraint = Constraint(model.Edges, rule = alpha_direction_constraint, doc = "Alpha Binary Constraint")


 
 # for each edge in tuple (node1, node2) in model.Edges, dir constraint is called and formed
def dir_forward_constraint(model, node1, node2):
    
    
    sect_forward_pred = (model.sect_forward[node1, node2] - 1) % 8
    sect_forward_orig = model.sect_forward[node1, node2]
    sect_forward_succ = (model.sect_forward[node1, node2] + 1) % 8
    
     # Debugging: Print the values of sectors and binary variables
    """ print(f"Edge: {(node1, node2)}")
    print(f"sect_forward_pred: {sect_forward_pred}, sect_forward_orig: {sect_forward_orig}, sect_forward_succ: {sect_forward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}") """
    
    
    
    return model.dir_forward[node1, node2] == ((sect_forward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_forward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_forward_succ * model.alpha_succ[node1, node2])
                                        )

model.DirForwardConstraint = Constraint(model.Edges, rule=dir_forward_constraint, doc = "Dir forward constraint")
 

def dir_backward_constraint(model, node1, node2):
    sect_backward_pred = (model.sect_backward[node1, node2] - 1) % 8
    sect_backward_orig = model.sect_backward[node1, node2]
    sect_backward_succ = (model.sect_backward[node1, node2] + 1) % 8
    
      # Debugging: Print the values of sectors and binary variables
    """ print(f"Edge: {(node1, node2)}")
    print(f"sect_backward_pred: {sect_backward_pred}, sect_backward_orig: {sect_backward_orig}, sect_backward_succ: {sect_backward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}")  """
    
    return model.dir_backward[node1, node2] == ((sect_backward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_backward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_backward_succ * model.alpha_succ[node1, node2])
                                        )
    
model.DirBackwardConstraint = Constraint(model.Edges, rule = dir_backward_constraint, doc = "Dir back Constraint") 



#tolerance_factor = 0.25
 
def sector_constraints_rule(model, node1, node2):

    # Retrieve original sector and minimum edge length
    sect_orig = model.sect_forward[node1, node2]
    #min_length = 1500 #dynamic_min_lengths[(node1, node2)] #(model.distance[node1, node2])*0.1  #1000
    #min_length = model.min_length[node1, node2]
    #min_length = minimum_edge_distance
    min_length = model.dynamicMinLengths[node1, node2]  
    #min_length = 980
    
    # Define a large constant M for making constraints trivial when not active
    M = 50000  # Adjust as needed

    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_adjusted = (sect_orig + adjustment) % 8

        # Conditions based on adjusted sector
        if sect_adjusted in [0, 4]:  # Horizontal
            model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.y_pos[node1] + model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            
            if sect_adjusted == 0:
                # For sector 0, node1 should be to the left of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node2] - model.x_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
                
                
                
                
                
                
            elif sect_adjusted == 4:
                # For sector 4, node1 should be to the right of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))
                
                
        
        elif sect_adjusted in [2, 6]:  # Vertical
            # Add corresponding constraints for this sector
            model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.x_pos[node1] + model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            
            if sect_adjusted == 2:  # Upwards
                # Node2's y_pos should be at least min_length above Node1's y_pos
                model.sector_constraints.add(model.y_pos[node2] - model.y_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
                
            
            
            
            elif sect_adjusted == 6:  # Downwards
                # Node2's y_pos should be at least min_length below Node1's y_pos
                model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))

                





        elif sect_adjusted == 1:         #upright diagonal /
            # dx = dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) - (model.x_pos[node2] - model.x_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # dx + dy >= min length of diagonal
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))
            
           
            
        elif sect_adjusted == 5:        # Diagonal downwards /
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # -dx - dy >= min length
            # negative diagonal
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))


            
            


            
        ## Diagonal \
            
        elif sect_adjusted == 3:    # Up left diagonal \
            # -dx = dy
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dx is negative
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) <= 0)
            
            # -dx + dy >= min length (dx is negative value)
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            
           
            
            
        elif sect_adjusted == 7:    # Down right Diagonal \
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dy is negative
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) <= 0)
        
            # dx - dy >= min length (since dy is negative, we use -dy)
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            




       



       
            # Fill in your constraints similar to above
    return Constraint.Skip 

# Initialize the constraint list on your model if not already done
model.sector_constraints = ConstraintList(doc = "Oct sector constraints")

# Apply the rule to each edge
model.SectorConstraint = Constraint(model.Edges, rule=sector_constraints_rule)

# %% [markdown]
# ## Deviation Constraints

# %%
model.dev_pos = Var(model.Edges, within=NonNegativeReals)
model.dev_neg = Var(model.Edges, within=NonNegativeReals)

tolerance = 0.001


model.DeviationConstraints = ConstraintList(doc = "Deviation Constraints")


def dev_constraints_rule(model, node1, node2):
    
    sect_orig = model.sect_forward[node1, node2]
    
    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_chosen = (sect_orig + adjustment) % 8
        
        
        if sect_chosen == 0:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
            
            
        elif sect_chosen == 1:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
        
        elif sect_chosen == 2:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
                
                
        elif sect_chosen == 3:   
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
            
        elif sect_chosen == 4:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
            
            
        elif sect_chosen == 5:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
            
        elif sect_chosen == 6:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
            
            
        elif sect_chosen == 7:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
        
    return Constraint.Skip



model.DevConstraint = Constraint(model.Edges, rule = dev_constraints_rule)
"""  
for edge in model.Edges:
    node1, node2 = edge
    dev_constraints_rule(model, node1, node2)  """
# Out:
# WARNING: Implicitly replacing the Component attribute dev_pos (type=<class
# 'pyomo.core.base.var.IndexedVar'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.var.IndexedVar'>). This is usually indicative of
# a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().
# WARNING: Implicitly replacing the Component attribute dev_neg (type=<class
# 'pyomo.core.base.var.IndexedVar'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.var.IndexedVar'>). This is usually indicative of
# a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().
# '  \nfor edge in model.Edges:\n    node1, node2 = edge\n    dev_constraints_rule(model, node1, node2)  '

# %% [markdown]
# ## Relative Position Constraint and Objective Function

# %%
# Updated constraint without Big M
def rpos_constraint_upper(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= model.dir_forward[u, v] - model.sect_forward[u, v]

model.RposConstraintUpper = Constraint(model.Edges, rule=rpos_constraint_upper, doc = "RPOS upper constraint")

# Updated constraint without Big M
def rpos_constraint_lower(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= -model.dir_forward[u, v] + model.sect_forward[u, v]

model.RposConstraintLower = Constraint(model.Edges, rule=rpos_constraint_lower, doc = "RPOS lower constraint")

""" 
model.activate_rpos = Var(model.Edges, within=Binary)

# Big-M approach
M = 1000  # Large constant

def rpos_activation_rule(model, u, v):
    return model.rpos[u, v] <= (model.dir_forward[u, v] - model.sect_forward[u, v]) + M * (1 - model.activate_rpos[u, v])

def rpos_zero_rule(model, u, v):
    return model.rpos[u, v] >= (model.dir_forward[u, v] - model.sect_forward[u, v] - 2) * model.activate_rpos[u, v]

def activation_condition_rule(model, u, v):
    # Ensures that activate_rpos is 1 if the difference is >= 2
    return model.activate_rpos[u, v] * 2 <= model.dir_forward[u, v] - model.sect_forward[u, v]

model.RposActivationConstraint = Constraint(model.Edges, rule=rpos_activation_rule)
model.RposZeroConstraint = Constraint(model.Edges, rule=rpos_zero_rule)
model.ActivationCondition = Constraint(model.Edges, rule=activation_condition_rule)

 """

"""
 
# Objective function to minimize the sum of the deviations
def relative_position_cost(model):
    OF = sum(model.rpos[edge] for edge in model.Edges)
    print(f"cost is: {OF}")
    return OF

model.TotalCost = Objective(rule=relative_position_cost, sense=minimize) 
"""
# Out:
# '\n \n# Objective function to minimize the sum of the deviations\ndef relative_position_cost(model):\n    OF = sum(model.rpos[edge] for edge in model.Edges)\n    print(f"cost is: {OF}")\n    return OF\n\nmodel.TotalCost = Objective(rule=relative_position_cost, sense=minimize) \n'

# %%
penalty_per_unit_deviation = 10  # This value can be adjusted based on how strict the octilinearity needs to be enforced

def total_cost(model):
    # Sum existing costs (if any other costs are involved)
    rpos_costs = sum(model.rpos[edge] for edge in model.Edges)

    # Cost for deviations from octilinearity beyond the tolerance
    deviation_costs = sum(
        (model.dev_pos[edge] + model.dev_neg[edge])
        for edge in model.Edges
    )

    # Combine the costs
    return  100*rpos_costs #+ 0.0001*deviation_costs #10*rpos_costs #+ 0.0001

model.TotalCost = Objective(rule=total_cost, sense=minimize)

# %%
solver = SolverFactory('gurobi')
results = solver.solve(model, tee = True)

# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmpauek9i6g.pyomo.lp
# Reading time = 0.01 seconds
# x1: 740 rows, 362 columns, 2697 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 740 rows, 362 columns and 2697 nonzeros
# Model fingerprint: 0x139ba867
# Variable types: 177 continuous, 185 integer (111 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-03, 5e+04]
# Presolve removed 439 rows and 197 columns
# Presolve time: 0.01s
# Presolved: 301 rows, 165 columns, 1081 nonzeros
# Variable types: 60 continuous, 105 integer (105 binary)
#
# Root relaxation: objective 8.000000e+02, 137 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     800.0000000  800.00000  0.00%     -    0s
#
# Explored 1 nodes (137 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 800
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+02, best bound 8.000000000000e+02, gap 0.0000%
# ok
# optimal

# %%
# Update positions based on optimized x and y coordinates
updated_pos1 = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}




#draw_graph(G, updated_pos)

draw_graph(G, updated_pos1, title="Optimized Network Layout 1")

# %%
opt_edges_info = []

# Iterate through each edge in your graph
for edge in G.edges():
    node1, node2 = edge

    # Retrieve the updated positions for source and destination nodes
    new_src_x, new_src_y = updated_pos1[node1]
    new_dst_x, new_dst_y = updated_pos1[node2]

    # Calculate the angle using the updated positions
    angle = calculate_angle(new_src_x, new_src_y, new_dst_x, new_dst_y)

    formatted_angle = round(angle, 2)

    # Append the edge information and formatted angle to the list
    opt_edges_info.append({
        'Edge': edge,
        'Source': node1,
        'Destination': node2,
        'Angle (degrees)': formatted_angle  # Use the formatted angle
    })

# Convert the list of dictionaries to a pandas DataFrame for easy tabular display
opt_edges_info_df = pd.DataFrame(opt_edges_info)

# Print the DataFrame
#print(edges_info_df)
display(opt_edges_info_df)
# Out:
#             Edge  Source  Destination  Angle (degrees)
# 0   (6093, 6094)    6093         6094           315.00
# 1   (6107, 6127)    6107         6127           270.00
# 2   (6127, 6128)    6127         6128             0.00
# 3   (6127, 6129)    6127         6129           180.00
# 4   (6089, 6126)    6089         6126             0.00
# 5   (6089, 6097)    6089         6097           180.00
# 6   (6124, 6126)    6124         6126            90.00
# 7   (6098, 6124)    6098         6124           180.00
# 8   (6098, 6100)    6098         6100           270.00
# 9   (6098, 6099)    6098         6099            90.00
# 10  (6102, 6120)    6102         6120           135.00
# 11  (6120, 6123)    6120         6123           180.00
# 12  (6103, 6116)    6103         6116             0.00
# 13  (6103, 6115)    6103         6115            45.00
# 14  (6103, 6114)    6103         6114            90.00
# 15  (6103, 6108)    6103         6108            90.00
# 16  (6103, 6105)    6103         6105           180.00
# 17  (6116, 6123)    6116         6123             0.00
# 18  (6114, 6115)    6114         6115             0.00
# 19  (6097, 6112)    6097         6112           180.00
# 20  (6095, 6112)    6095         6112           314.84
# 21  (6095, 6096)    6095         6096           270.00
# 22  (6096, 6110)    6096         6110           270.00
# 23  (6105, 6107)    6105         6107           180.00
# 24  (6105, 6123)    6105         6123             0.00
# 25  (6105, 6113)    6105         6113            90.00
# 26  (6092, 6094)    6092         6094            90.00
# 27  (6092, 6096)    6092         6096             0.00
# 28  (6101, 6102)    6101         6102           180.00
# 29  (6100, 6101)    6100         6101           270.00
# 30  (6108, 6110)    6108         6110            90.00
# 31  (6108, 6122)    6108         6122             0.00
# 32  (6111, 6124)    6111         6124           180.00
# 33  (6122, 6123)    6122         6123           270.00
# 34  (6119, 6122)    6119         6122           180.00
# 35  (6119, 6120)    6119         6120           314.93
# 36  (6118, 6120)    6118         6120           180.00

# %% [markdown]
# ## Circular Vertex Order
# The initial circular ordering of neighbour nodes (counterclockwise) should be the same after optimisation.
#
# For each node in the map, the sequence in which the neighbouring nodes are arranged around a particular node should match the order in which the neighbouring nodes are arranged in the final layout.

# %%
# Beta Binary Sum Constraint


def beta_sum_constraint_rule(model, node):
    # Ensure we use 0-based indexing to match the updated indexing in Beta
    # Note that RangeSet in Pyomo starts from 1, so we adjust the range accordingly
    return sum(model.Beta[node, index] for index in range(0, len(model.OrderedNeighbours[node]) )) == 1

model.BetaSumConstraint = Constraint(model.NodesWith2Neighbours, rule=beta_sum_constraint_rule, doc = "Circle Binary Constraint")




# Define the ConstraintList in your Pyomo model
model.OrderMaintenanceConstraints = ConstraintList(doc = "Circle Order Constraints")


def add_order_maintenance_constraints(model):
    for node, neighbours in ordered_neighbours_dict.items():
        num_neighbours = len(neighbours)
        
        
        for index in range(num_neighbours):
            print(index)
            # Handle all neighbor pairs except the last pair (which wraps around)
            if index < num_neighbours - 1:
                next_index = index + 1
            else:
                next_index = 0      # wrap around case
                
                
            # Use the helper function to dynamically select dir_forward or dir_backward
            dir_sect = directional_sector(model, node, neighbours[index])
            next_dir_sect = directional_sector(model, node, neighbours[next_index])
            
            # Debugging prints before adding the constraint
            print(f"Node: {node}, Neighbour: {neighbours[index]}, Directional Sector: {dir_sect}")
            print(f"Node: {node}, Next Neighbour: {neighbours[next_index]}, Next Directional Sector: {next_dir_sect}")
            if index == num_neighbours - 1:  # For wrap-around case
                print(f"\nNode: {node}, Index: {index}, Beta: {model.Beta[node, index].value if model.Beta[node, index].value is not None else 'Not solved yet'}")

            
            
            if dir_sect is not None and next_dir_sect is not None:
                    model.OrderMaintenanceConstraints.add(dir_sect <= next_dir_sect - 1 + 8*model.Beta[node, index])

                

            
           
# Call the function to add the constraints to the ConstraintList
add_order_maintenance_constraints(model)   

""" 
# Now use this helper function in the circular order constraint
def circular_order_with_wrap(model):
    model.CircularOrderWithWrap = ConstraintList()

    # Define beta_test as a binary variable for each node and each of its neighbors
    model.beta_test = Var([(node, i) for node in model.NodesWith2Neighbours for i in range(len(model.OrderedNeighbours[node]))], within=Binary)

    for node, neighbours in ordered_neighbours_dict.items():
        num_neighbours = len(neighbours)
        
        # Ensure beta_test sum is exactly one
        model.CircularOrderWithWrap.add(
            sum(model.beta_test[node, i] for i in range(num_neighbours)) == 1
        )

        for i in range(num_neighbours):
            # Use the helper function to get the correct direction variable
            dir_current = directional_sector(model, node, neighbours[i])
            dir_next = directional_sector(model, node, neighbours[(i + 1) % num_neighbours])

            # Assuming the function ensures edges are directed and exist in the edge set
            # Add the constraint with wrap-around using the directional variables
            model.CircularOrderWithWrap.add(
                dir_current <= dir_next + 8 * model.beta_test[node, i] - (1 - model.beta_test[node, i])
            )

# Apply the function to add constraints to the model
circular_order_with_wrap(model)
 """
 
""" model.wrap_around = Var(
    model.NodesWith2Neighbours,  # Using the nodes that have 2 or more neighbors
    within=Binary,  # Binary variables
    initialize=0  # Initializing to 0
)

def circular_order_constraints(model):
    model.CircularOrder = ConstraintList()
    
    for node in model.NodesWith2Neighbours:
        neighbors = list(model.OrderedNeighbours[node])  # Assuming OrderedNeighbours is correctly initialized
        n = len(neighbors)
        for i in range(n):
            current_neighbor = neighbors[i]
            next_neighbor = neighbors[(i + 1) % n]
            
            current_dir = directional_sector(model, node, current_neighbor)
            next_dir = directional_sector(model, node, next_neighbor)

            if i < n - 1:  # Standard order constraint for non-wrap-around cases
                model.CircularOrder.add(current_dir <= next_dir)
            else:  # Handle the wrap-around from the last to the first neighbor
                wrap_var = model.wrap_around[node]
                # Constraint to handle wrapping without modulus
                model.CircularOrder.add(current_dir - next_dir <= -1 + 8 * wrap_var)
                model.CircularOrder.add(next_dir - current_dir <= 7 * (1 - wrap_var))

# Apply the constraints to the model
circular_order_constraints(model) """
# Out:
# 0
# Node: 6094, Neighbour: 6093, Directional Sector: dir_backward[6093,6094]
# Node: 6094, Next Neighbour: 6092, Next Directional Sector: dir_backward[6092,6094]
# 1
# Node: 6094, Neighbour: 6092, Directional Sector: dir_backward[6092,6094]
# Node: 6094, Next Neighbour: 6093, Next Directional Sector: dir_backward[6093,6094]
#
# Node: 6094, Index: 1, Beta: Not solved yet
# 0
# Node: 6107, Neighbour: 6105, Directional Sector: dir_backward[6105,6107]
# Node: 6107, Next Neighbour: 6127, Next Directional Sector: dir_forward[6107,6127]
# 1
# Node: 6107, Neighbour: 6127, Directional Sector: dir_forward[6107,6127]
# Node: 6107, Next Neighbour: 6105, Next Directional Sector: dir_backward[6105,6107]
#
# Node: 6107, Index: 1, Beta: Not solved yet
# 0
# Node: 6127, Neighbour: 6128, Directional Sector: dir_forward[6127,6128]
# Node: 6127, Next Neighbour: 6107, Next Directional Sector: dir_backward[6107,6127]
# 1
# Node: 6127, Neighbour: 6107, Directional Sector: dir_backward[6107,6127]
# Node: 6127, Next Neighbour: 6129, Next Directional Sector: dir_forward[6127,6129]
# 2
# Node: 6127, Neighbour: 6129, Directional Sector: dir_forward[6127,6129]
# Node: 6127, Next Neighbour: 6128, Next Directional Sector: dir_forward[6127,6128]
#
# Node: 6127, Index: 2, Beta: Not solved yet
# 0
# Node: 6089, Neighbour: 6126, Directional Sector: dir_forward[6089,6126]
# Node: 6089, Next Neighbour: 6097, Next Directional Sector: dir_forward[6089,6097]
# 1
# Node: 6089, Neighbour: 6097, Directional Sector: dir_forward[6089,6097]
# Node: 6089, Next Neighbour: 6126, Next Directional Sector: dir_forward[6089,6126]
#
# Node: 6089, Index: 1, Beta: Not solved yet
# 0
# Node: 6126, Neighbour: 6089, Directional Sector: dir_backward[6089,6126]
# Node: 6126, Next Neighbour: 6124, Next Directional Sector: dir_backward[6124,6126]
# 1
# Node: 6126, Neighbour: 6124, Directional Sector: dir_backward[6124,6126]
# Node: 6126, Next Neighbour: 6089, Next Directional Sector: dir_backward[6089,6126]
#
# Node: 6126, Index: 1, Beta: Not solved yet
# 0
# Node: 6124, Neighbour: 6111, Directional Sector: dir_backward[6111,6124]
# Node: 6124, Next Neighbour: 6098, Next Directional Sector: dir_backward[6098,6124]
# 1
# Node: 6124, Neighbour: 6098, Directional Sector: dir_backward[6098,6124]
# Node: 6124, Next Neighbour: 6126, Next Directional Sector: dir_forward[6124,6126]
# 2
# Node: 6124, Neighbour: 6126, Directional Sector: dir_forward[6124,6126]
# Node: 6124, Next Neighbour: 6111, Next Directional Sector: dir_backward[6111,6124]
#
# Node: 6124, Index: 2, Beta: Not solved yet
# 0
# Node: 6098, Neighbour: 6099, Directional Sector: dir_forward[6098,6099]
# Node: 6098, Next Neighbour: 6124, Next Directional Sector: dir_forward[6098,6124]
# 1
# Node: 6098, Neighbour: 6124, Directional Sector: dir_forward[6098,6124]
# Node: 6098, Next Neighbour: 6100, Next Directional Sector: dir_forward[6098,6100]
# 2
# Node: 6098, Neighbour: 6100, Directional Sector: dir_forward[6098,6100]
# Node: 6098, Next Neighbour: 6099, Next Directional Sector: dir_forward[6098,6099]
#
# Node: 6098, Index: 2, Beta: Not solved yet
# 0
# Node: 6102, Neighbour: 6101, Directional Sector: dir_backward[6101,6102]
# Node: 6102, Next Neighbour: 6120, Next Directional Sector: dir_forward[6102,6120]
# 1
# Node: 6102, Neighbour: 6120, Directional Sector: dir_forward[6102,6120]
# Node: 6102, Next Neighbour: 6101, Next Directional Sector: dir_backward[6101,6102]
#
# Node: 6102, Index: 1, Beta: Not solved yet
# 0
# Node: 6120, Neighbour: 6102, Directional Sector: dir_backward[6102,6120]
# Node: 6120, Next Neighbour: 6118, Next Directional Sector: dir_backward[6118,6120]
# 1
# Node: 6120, Neighbour: 6118, Directional Sector: dir_backward[6118,6120]
# Node: 6120, Next Neighbour: 6119, Next Directional Sector: dir_backward[6119,6120]
# 2
# Node: 6120, Neighbour: 6119, Directional Sector: dir_backward[6119,6120]
# Node: 6120, Next Neighbour: 6123, Next Directional Sector: dir_forward[6120,6123]
# 3
# Node: 6120, Neighbour: 6123, Directional Sector: dir_forward[6120,6123]
# Node: 6120, Next Neighbour: 6102, Next Directional Sector: dir_backward[6102,6120]
#
# Node: 6120, Index: 3, Beta: Not solved yet
# 0
# Node: 6103, Neighbour: 6116, Directional Sector: dir_forward[6103,6116]
# Node: 6103, Next Neighbour: 6115, Next Directional Sector: dir_forward[6103,6115]
# 1
# Node: 6103, Neighbour: 6115, Directional Sector: dir_forward[6103,6115]
# Node: 6103, Next Neighbour: 6114, Next Directional Sector: dir_forward[6103,6114]
# 2
# Node: 6103, Neighbour: 6114, Directional Sector: dir_forward[6103,6114]
# Node: 6103, Next Neighbour: 6108, Next Directional Sector: dir_forward[6103,6108]
# 3
# Node: 6103, Neighbour: 6108, Directional Sector: dir_forward[6103,6108]
# Node: 6103, Next Neighbour: 6105, Next Directional Sector: dir_forward[6103,6105]
# 4
# Node: 6103, Neighbour: 6105, Directional Sector: dir_forward[6103,6105]
# Node: 6103, Next Neighbour: 6116, Next Directional Sector: dir_forward[6103,6116]
#
# Node: 6103, Index: 4, Beta: Not solved yet
# 0
# Node: 6116, Neighbour: 6123, Directional Sector: dir_forward[6116,6123]
# Node: 6116, Next Neighbour: 6103, Next Directional Sector: dir_backward[6103,6116]
# 1
# Node: 6116, Neighbour: 6103, Directional Sector: dir_backward[6103,6116]
# Node: 6116, Next Neighbour: 6123, Next Directional Sector: dir_forward[6116,6123]
#
# Node: 6116, Index: 1, Beta: Not solved yet
# 0
# Node: 6115, Neighbour: 6114, Directional Sector: dir_backward[6114,6115]
# Node: 6115, Next Neighbour: 6103, Next Directional Sector: dir_backward[6103,6115]
# 1
# Node: 6115, Neighbour: 6103, Directional Sector: dir_backward[6103,6115]
# Node: 6115, Next Neighbour: 6114, Next Directional Sector: dir_backward[6114,6115]
#
# Node: 6115, Index: 1, Beta: Not solved yet
# 0
# Node: 6114, Neighbour: 6115, Directional Sector: dir_forward[6114,6115]
# Node: 6114, Next Neighbour: 6103, Next Directional Sector: dir_backward[6103,6114]
# 1
# Node: 6114, Neighbour: 6103, Directional Sector: dir_backward[6103,6114]
# Node: 6114, Next Neighbour: 6115, Next Directional Sector: dir_forward[6114,6115]
#
# Node: 6114, Index: 1, Beta: Not solved yet
# 0
# Node: 6097, Neighbour: 6089, Directional Sector: dir_backward[6089,6097]
# Node: 6097, Next Neighbour: 6112, Next Directional Sector: dir_forward[6097,6112]
# 1
# Node: 6097, Neighbour: 6112, Directional Sector: dir_forward[6097,6112]
# Node: 6097, Next Neighbour: 6089, Next Directional Sector: dir_backward[6089,6097]
#
# Node: 6097, Index: 1, Beta: Not solved yet
# 0
# Node: 6112, Neighbour: 6097, Directional Sector: dir_backward[6097,6112]
# Node: 6112, Next Neighbour: 6095, Next Directional Sector: dir_backward[6095,6112]
# 1
# Node: 6112, Neighbour: 6095, Directional Sector: dir_backward[6095,6112]
# Node: 6112, Next Neighbour: 6097, Next Directional Sector: dir_backward[6097,6112]
#
# Node: 6112, Index: 1, Beta: Not solved yet
# 0
# Node: 6095, Neighbour: 6096, Directional Sector: dir_forward[6095,6096]
# Node: 6095, Next Neighbour: 6112, Next Directional Sector: dir_forward[6095,6112]
# 1
# Node: 6095, Neighbour: 6112, Directional Sector: dir_forward[6095,6112]
# Node: 6095, Next Neighbour: 6096, Next Directional Sector: dir_forward[6095,6096]
#
# Node: 6095, Index: 1, Beta: Not solved yet
# 0
# Node: 6096, Neighbour: 6095, Directional Sector: dir_backward[6095,6096]
# Node: 6096, Next Neighbour: 6092, Next Directional Sector: dir_backward[6092,6096]
# 1
# Node: 6096, Neighbour: 6092, Directional Sector: dir_backward[6092,6096]
# Node: 6096, Next Neighbour: 6110, Next Directional Sector: dir_forward[6096,6110]
# 2
# Node: 6096, Neighbour: 6110, Directional Sector: dir_forward[6096,6110]
# Node: 6096, Next Neighbour: 6095, Next Directional Sector: dir_backward[6095,6096]
#
# Node: 6096, Index: 2, Beta: Not solved yet
# 0
# Node: 6110, Neighbour: 6096, Directional Sector: dir_backward[6096,6110]
# Node: 6110, Next Neighbour: 6108, Next Directional Sector: dir_backward[6108,6110]
# 1
# Node: 6110, Neighbour: 6108, Directional Sector: dir_backward[6108,6110]
# Node: 6110, Next Neighbour: 6096, Next Directional Sector: dir_backward[6096,6110]
#
# Node: 6110, Index: 1, Beta: Not solved yet
# 0
# Node: 6105, Neighbour: 6123, Directional Sector: dir_forward[6105,6123]
# Node: 6105, Next Neighbour: 6103, Next Directional Sector: dir_backward[6103,6105]
# 1
# Node: 6105, Neighbour: 6103, Directional Sector: dir_backward[6103,6105]
# Node: 6105, Next Neighbour: 6113, Next Directional Sector: dir_forward[6105,6113]
# 2
# Node: 6105, Neighbour: 6113, Directional Sector: dir_forward[6105,6113]
# Node: 6105, Next Neighbour: 6107, Next Directional Sector: dir_forward[6105,6107]
# 3
# Node: 6105, Neighbour: 6107, Directional Sector: dir_forward[6105,6107]
# Node: 6105, Next Neighbour: 6123, Next Directional Sector: dir_forward[6105,6123]
#
# Node: 6105, Index: 3, Beta: Not solved yet
# 0
# Node: 6092, Neighbour: 6096, Directional Sector: dir_forward[6092,6096]
# Node: 6092, Next Neighbour: 6094, Next Directional Sector: dir_forward[6092,6094]
# 1
# Node: 6092, Neighbour: 6094, Directional Sector: dir_forward[6092,6094]
# Node: 6092, Next Neighbour: 6096, Next Directional Sector: dir_forward[6092,6096]
#
# Node: 6092, Index: 1, Beta: Not solved yet
# 0
# Node: 6101, Neighbour: 6100, Directional Sector: dir_backward[6100,6101]
# Node: 6101, Next Neighbour: 6102, Next Directional Sector: dir_forward[6101,6102]
# 1
# Node: 6101, Neighbour: 6102, Directional Sector: dir_forward[6101,6102]
# Node: 6101, Next Neighbour: 6100, Next Directional Sector: dir_backward[6100,6101]
#
# Node: 6101, Index: 1, Beta: Not solved yet
# 0
# Node: 6100, Neighbour: 6098, Directional Sector: dir_backward[6098,6100]
# Node: 6100, Next Neighbour: 6101, Next Directional Sector: dir_forward[6100,6101]
# 1
# Node: 6100, Neighbour: 6101, Directional Sector: dir_forward[6100,6101]
# Node: 6100, Next Neighbour: 6098, Next Directional Sector: dir_backward[6098,6100]
#
# Node: 6100, Index: 1, Beta: Not solved yet
# 0
# Node: 6108, Neighbour: 6122, Directional Sector: dir_forward[6108,6122]
# Node: 6108, Next Neighbour: 6110, Next Directional Sector: dir_forward[6108,6110]
# 1
# Node: 6108, Neighbour: 6110, Directional Sector: dir_forward[6108,6110]
# Node: 6108, Next Neighbour: 6103, Next Directional Sector: dir_backward[6103,6108]
# 2
# Node: 6108, Neighbour: 6103, Directional Sector: dir_backward[6103,6108]
# Node: 6108, Next Neighbour: 6122, Next Directional Sector: dir_forward[6108,6122]
#
# Node: 6108, Index: 2, Beta: Not solved yet
# 0
# Node: 6123, Neighbour: 6120, Directional Sector: dir_backward[6120,6123]
# Node: 6123, Next Neighbour: 6122, Next Directional Sector: dir_backward[6122,6123]
# 1
# Node: 6123, Neighbour: 6122, Directional Sector: dir_backward[6122,6123]
# Node: 6123, Next Neighbour: 6116, Next Directional Sector: dir_backward[6116,6123]
# 2
# Node: 6123, Neighbour: 6116, Directional Sector: dir_backward[6116,6123]
# Node: 6123, Next Neighbour: 6105, Next Directional Sector: dir_backward[6105,6123]
# 3
# Node: 6123, Neighbour: 6105, Directional Sector: dir_backward[6105,6123]
# Node: 6123, Next Neighbour: 6120, Next Directional Sector: dir_backward[6120,6123]
#
# Node: 6123, Index: 3, Beta: Not solved yet
# 0
# Node: 6122, Neighbour: 6119, Directional Sector: dir_backward[6119,6122]
# Node: 6122, Next Neighbour: 6108, Next Directional Sector: dir_backward[6108,6122]
# 1
# Node: 6122, Neighbour: 6108, Directional Sector: dir_backward[6108,6122]
# Node: 6122, Next Neighbour: 6123, Next Directional Sector: dir_forward[6122,6123]
# 2
# Node: 6122, Neighbour: 6123, Directional Sector: dir_forward[6122,6123]
# Node: 6122, Next Neighbour: 6119, Next Directional Sector: dir_backward[6119,6122]
#
# Node: 6122, Index: 2, Beta: Not solved yet
# 0
# Node: 6119, Neighbour: 6122, Directional Sector: dir_forward[6119,6122]
# Node: 6119, Next Neighbour: 6120, Next Directional Sector: dir_forward[6119,6120]
# 1
# Node: 6119, Neighbour: 6120, Directional Sector: dir_forward[6119,6120]
# Node: 6119, Next Neighbour: 6122, Next Directional Sector: dir_forward[6119,6122]
#
# Node: 6119, Index: 1, Beta: Not solved yet
# ' model.wrap_around = Var(\n    model.NodesWith2Neighbours,  # Using the nodes that have 2 or more neighbors\n    within=Binary,  # Binary variables\n    initialize=0  # Initializing to 0\n)\n\ndef circular_order_constraints(model):\n    model.CircularOrder = ConstraintList()\n    \n    for node in model.NodesWith2Neighbours:\n        neighbors = list(model.OrderedNeighbours[node])  # Assuming OrderedNeighbours is correctly initialized\n        n = len(neighbors)\n        for i in range(n):\n            current_neighbor = neighbors[i]\n            next_neighbor = neighbors[(i + 1) % n]\n            \n            current_dir = directional_sector(model, node, current_neighbor)\n            next_dir = directional_sector(model, node, next_neighbor)\n\n            if i < n - 1:  # Standard order constraint for non-wrap-around cases\n                model.CircularOrder.add(current_dir <= next_dir)\n            else:  # Handle the wrap-around from the last to the first neighbor\n                wrap_var = model.wrap_around[node]\n                # Constraint to handle wrapping without modulus\n                model.CircularOrder.add(current_dir - next_dir <= -1 + 8 * wrap_var)\n                model.CircularOrder.add(next_dir - current_dir <= 7 * (1 - wrap_var))\n\n# Apply the constraints to the model\ncircular_order_constraints(model) '

# %%
solver.solve(model, tee=True, warmstart=True)
# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmppcilvn4f.pyomo.lp
# Reading time = 0.01 seconds
# x1: 833 rows, 429 columns, 2965 nonzeros
# Read MIP start from file C:\Users\katec\AppData\Local\Temp\tmpyp5tngxu.gurobi.mst
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 833 rows, 429 columns and 2965 nonzeros
# Model fingerprint: 0x13c33529
# Variable types: 177 continuous, 252 integer (178 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-03, 5e+04]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 489 rows and 255 columns
# Presolve time: 0.01s
# Presolved: 344 rows, 174 columns, 1222 nonzeros
# Variable types: 59 continuous, 115 integer (96 binary)
#
# Root relaxation: objective 1.500000e+03, 157 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1500.00000    0    2          - 1500.00000      -     -    0s
#      0     0 1600.00000    0    4          - 1600.00000      -     -    0s
# Another try with MIP start
# H    0     0                    1700.0000000 1600.00000  5.88%     -    0s
#
# Explored 1 nodes (176 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1700
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+03, best bound 1.700000000000e+03, gap 0.0000%
# ok
# optimal

# %%
# Update positions based on optimized x and y coordinates
updated_pos2 = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}




#draw_graph(G, updated_pos)

draw_graph(G, updated_pos2, title="Optimized Network Layout2")

# %%
node_id = 6120  # Specify the node ID for which you want to access neighbors
neighbors = get_neighbors_for_node(node_id, ordered_neighbours_dict)  # Assuming ordered_neighbours_dict is already defined

if neighbors is not None:
    print(f"Neighbors of node {node_id}: {neighbors}")
else:
    print(f"No neighbors listed for node {node_id}.")
    
    
for x in neighbors:
    direction_sector = directional_sector(model, node_id, x)
    print(f"\ndirection sector: edge {node_id} to {x} is : {direction_sector}: {direction_sector.value} ")
    
    original_sector = orig_sector(model, node_id, x)
    print(f"original sector: edge {node_id} to {x} is : {original_sector}:  ")
    
print(f"\n{model.dir_forward[6119, 6120].value}")
print(f"{model.dir_backward[6119, 6120].value}")

print(f"\n{model.dir_forward[6118, 6120].value}")
print(f"{model.dir_backward[6118, 6120].value}")
# Out:
# Neighbors of node 6120: [6102, 6118, 6119, 6123]
#
# direction sector: edge 6120 to 6102 is : dir_backward[6102,6120]: 7.0
# original sector: edge 6120 to 6102 is : 7:
#
# direction sector: edge 6120 to 6118 is : dir_backward[6118,6120]: 0.0
# original sector: edge 6120 to 6118 is : 1:
#
# direction sector: edge 6120 to 6119 is : dir_backward[6119,6120]: 3.0
# original sector: edge 6120 to 6119 is : 3:
#
# direction sector: edge 6120 to 6123 is : dir_forward[6120,6123]: 4.0
# original sector: edge 6120 to 6123 is : 4:
#
# 7.0
# 3.0
#
# 4.0
# 0.0

# %%
def get_sorted_neighbours(G, node, pos, initial_neighbour):
    angles_neighbours = []
    src_x, src_y = pos[node]

    # Convert G to an undirected graph to consider all adjacent nodes
    G_undirected = G.to_undirected()

    # Calculate angles and sort neighbours
    for neighbour in G_undirected.neighbors(node):
        dst_x, dst_y = pos[neighbour]
        angle = calculate_angle(src_x, src_y, dst_x, dst_y)
        angles_neighbours.append((angle, neighbour))

    angles_neighbours.sort()
    sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]

    # Start the sorted list with the initial neighbour
    if initial_neighbour in sorted_neighbours:
        start_index = sorted_neighbours.index(initial_neighbour)
        sorted_neighbours = sorted_neighbours[start_index:] + sorted_neighbours[:start_index]

    return sorted_neighbours

def check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict):
    violations_count = 0
    
    for node, initial_neighbours in ordered_neighbours_dict.items():
        if initial_neighbours:  # Make sure there is at least one neighbour
            initial_first_neighbour = initial_neighbours[0]
            optimized_neighbours = get_sorted_neighbours(G, node, updated_pos, initial_first_neighbour)
            
            # Check for order violations
            if initial_neighbours != optimized_neighbours:
                print(f"Order violation at node {node}. Initial order: {initial_neighbours}, Optimized order: {optimized_neighbours}")
                violations_count += 1
            
            # Check for sector violations
            angles = [round(calculate_angle(updated_pos[node][0], updated_pos[node][1],
                                            updated_pos[neighbour][0], updated_pos[neighbour][1]), 1)
                      for neighbour in optimized_neighbours]
            sectors = [int(angle // 45) for angle in angles]
            for i in range(len(sectors) - 1):
                if sectors[i] == sectors[i + 1] and angles[i] != angles[i + 1]:
                    print(f"Sector violation between nodes {optimized_neighbours[i]} and {optimized_neighbours[i + 1]} "
                          f"at node {node} in sector {sectors[i]}. Rounded angles: {angles[i]}, {angles[i + 1]}")
                    violations_count += 1
                    break  # Stop at the first violation for this node

    if violations_count == 0:
        print("No circular order violations found.")
    else:
        print(f"Total circular order violations: {violations_count}")
    
    return violations_count

# Example usage
circular_order_violations = check_order_and_sector_violations(G, updated_pos2, ordered_neighbours_dict)
# Out:
# Order violation at node 6123. Initial order: [6120, 6122, 6116, 6105], Optimized order: [6120, 6116, 6122, 6105]
# Total circular order violations: 1

# %%
def directional_sector2(model, node, neighbor):
    if (node, neighbor) in model.Edges:
        return model.dir_forward[node, neighbor].value
    elif (neighbor, node) in model.Edges:
        return model.dir_backward[neighbor, node].value
    else:
        raise ValueError(f"Edge between {node} and {neighbor} is not properly defined in the graph.")


def check_constraints_post_optimization(model):
    for node, neighbours in ordered_neighbours_dict.items():
        num_neighbours = len(neighbours)
        for i in range(num_neighbours):
            current_neighbour = neighbours[i]
            next_neighbour = neighbours[(i + 1) % num_neighbours]  # Wrap index around

            # Use the helper function to get the actual values of the direction variables
            current_dir = directional_sector2(model, node, current_neighbour)
            next_dir = directional_sector2(model, node, next_neighbour)

            # Check if the current direction is not less than the next (considering wrap-around)
            if current_dir is not None and next_dir is not None:
                if not ((current_dir < next_dir) or (current_dir == 7 and next_dir == 0)):
                    print(f"Order violation found at node {node} between edges ({node}, {current_neighbour}) and ({node}, {next_neighbour}): {current_dir} !< {next_dir}")
            else:
                print(f"Could not retrieve direction value for edges ({node}, {current_neighbour}) or ({node}, {next_neighbour})")

# Assuming you have already solved the model using the solver
check_constraints_post_optimization(model)
# Out:
# Order violation found at node 6094 between edges (6094, 6092) and (6094, 6093): 6.0 !< 3.0
# Order violation found at node 6107 between edges (6107, 6127) and (6107, 6105): 6.0 !< 0.0
# Order violation found at node 6127 between edges (6127, 6129) and (6127, 6128): 4.0 !< 0.0
# Order violation found at node 6089 between edges (6089, 6097) and (6089, 6126): 4.0 !< -0.0
# Order violation found at node 6126 between edges (6126, 6124) and (6126, 6089): 7.0 !< 4.0
# Order violation found at node 6098 between edges (6098, 6100) and (6098, 6099): 6.0 !< 2.0
# Order violation found at node 6102 between edges (6102, 6120) and (6102, 6101): 3.0 !< 0.0
# Order violation found at node 6103 between edges (6103, 6105) and (6103, 6116): 6.0 !< 0.0
# Order violation found at node 6116 between edges (6116, 6123) and (6116, 6103): 7.0 !< 4.0
# Order violation found at node 6115 between edges (6115, 6103) and (6115, 6114): 5.0 !< 4.0
# Order violation found at node 6114 between edges (6114, 6103) and (6114, 6115): 6.0 !< 0.0
# Order violation found at node 6097 between edges (6097, 6112) and (6097, 6089): 4.0 !< 0.0
# Order violation found at node 6112 between edges (6112, 6095) and (6112, 6097): 3.0 !< 0.0
# Order violation found at node 6095 between edges (6095, 6112) and (6095, 6096): 7.0 !< 6.0
# Order violation found at node 6096 between edges (6096, 6110) and (6096, 6095): 6.0 !< 2.0
# Order violation found at node 6110 between edges (6110, 6108) and (6110, 6096): 6.0 !< 2.0
# Order violation found at node 6105 between edges (6105, 6107) and (6105, 6123): 4.0 !< 0.0
# Order violation found at node 6092 between edges (6092, 6094) and (6092, 6096): 2.0 !< 0.0
# Order violation found at node 6101 between edges (6101, 6102) and (6101, 6100): 4.0 !< 2.0
# Order violation found at node 6100 between edges (6100, 6101) and (6100, 6098): 6.0 !< 2.0
# Order violation found at node 6123 between edges (6123, 6105) and (6123, 6120): 4.0 !< 0.0
# Order violation found at node 6122 between edges (6122, 6123) and (6122, 6119): 6.0 !< 0.0
# Order violation found at node 6119 between edges (6119, 6120) and (6119, 6122): 7.0 !< 4.0

# %%
opt_edges_info = []

# Iterate through each edge in your graph
for edge in G.edges():
    node1, node2 = edge

    # Retrieve the updated positions for source and destination nodes
    new_src_x, new_src_y = updated_pos2[node1]
    new_dst_x, new_dst_y = updated_pos2[node2]

    # Calculate the angle using the updated positions
    angle = calculate_angle(new_src_x, new_src_y, new_dst_x, new_dst_y)

    formatted_angle = round(angle, 2)

    # Append the edge information and formatted angle to the list
    opt_edges_info.append({
        'Edge': edge,
        'Source': node1,
        'Destination': node2,
        'Angle (degrees)': formatted_angle  # Use the formatted angle
    })

# Convert the list of dictionaries to a pandas DataFrame for easy tabular display
opt_edges_info_df = pd.DataFrame(opt_edges_info)

# Print the DataFrame
#print(edges_info_df)
display(opt_edges_info_df)
# Out:
#             Edge  Source  Destination  Angle (degrees)
# 0   (6093, 6094)    6093         6094           315.00
# 1   (6107, 6127)    6107         6127           270.00
# 2   (6127, 6128)    6127         6128             0.00
# 3   (6127, 6129)    6127         6129           180.00
# 4   (6089, 6126)    6089         6126             0.00
# 5   (6089, 6097)    6089         6097           180.00
# 6   (6124, 6126)    6124         6126            90.00
# 7   (6098, 6124)    6098         6124           180.00
# 8   (6098, 6100)    6098         6100           270.00
# 9   (6098, 6099)    6098         6099            90.00
# 10  (6102, 6120)    6102         6120            90.00
# 11  (6120, 6123)    6120         6123           180.00
# 12  (6103, 6116)    6103         6116             0.00
# 13  (6103, 6115)    6103         6115            45.00
# 14  (6103, 6114)    6103         6114            90.00
# 15  (6103, 6108)    6103         6108           135.00
# 16  (6103, 6105)    6103         6105           270.00
# 17  (6116, 6123)    6116         6123           267.87
# 18  (6114, 6115)    6114         6115             0.00
# 19  (6097, 6112)    6097         6112           180.00
# 20  (6095, 6112)    6095         6112           225.07
# 21  (6095, 6096)    6095         6096           270.00
# 22  (6096, 6110)    6096         6110           270.00
# 23  (6105, 6107)    6105         6107           180.00
# 24  (6105, 6123)    6105         6123             0.00
# 25  (6105, 6113)    6105         6113            90.00
# 26  (6092, 6094)    6092         6094            90.00
# 27  (6092, 6096)    6092         6096             0.00
# 28  (6101, 6102)    6101         6102           180.00
# 29  (6100, 6101)    6100         6101           270.00
# 30  (6108, 6110)    6108         6110            90.00
# 31  (6108, 6122)    6108         6122             0.00
# 32  (6111, 6124)    6111         6124            90.00
# 33  (6122, 6123)    6122         6123           270.00
# 34  (6119, 6122)    6119         6122           180.00
# 35  (6119, 6120)    6119         6120           267.12
# 36  (6118, 6120)    6118         6120           180.00

# %% [markdown]
# ## Edge Spacing
# Each edge must have a distance of at least dmin > 0 from each non incident edge.
#
# - Prevents edge crossings
# - maintains planarity (edges have minimum separation in at least 1 octilinear direction)
# - enhances visualisation
# - preserves topology structure

# %%
def non_incident_edge_direction_constraint_rule(model, u1, v1, u2, v2):
    
    e1 = (u1, v1)
    e2 = (u2, v2)
        
    return (model.is_N[e1, e2] + model.is_S[e1, e2] + model.is_E[e1, e2] + model.is_W[e1, e2] +
            model.is_NE[e1, e2] + model.is_NW[e1, e2] + model.is_SE[e1, e2] + model.is_SW[e1, e2] >= 1)
    
#model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)
model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIntersecting_NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule, doc = "NSEW Constraint")





#tolerance_factor = 0.25  # This defines a 10% tolerance, adjust as needed


# Initialize ConstraintList outside of function
# Adds new constraints to list in model without reinitializing it
model.edgeSpacingConstraints = ConstraintList(doc = "Edge Spacing Constraint")

def edge_spacing_constraint(model, u1, v1, u2, v2):
    
    
    e1 = (u1, v1)
    e2 = (u2, v2)
    
    
    #dmin = min_edge_spacing
    #dmin = model.dynamicMinSpacings[e1]    ## infeasibility coming from too small M value due to large distances between
    dmin = model.dynamicMinSpacings[e1] 
    M = 100000
    
    
    
    
    # is_N[e1, e2] means that e1 is north of e1
    
    ## North Constraint
    c1 = model.y_pos[u2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c2 = model.y_pos[v2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c3 = model.y_pos[u2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c4 = model.y_pos[v2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin

    
    # South
    c5 = model.y_pos[u1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c6 = model.y_pos[v1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c7 = model.y_pos[u1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c8 = model.y_pos[v1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin

    
    # is_E[e1, e2] = 1 means that e1 is East of e2
    ## East
    c9 = model.x_pos[u2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c10 = model.x_pos[v2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c11 = model.x_pos[u2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c12 = model.x_pos[v2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin

    
    
    
    ## West
    c13 = model.x_pos[u1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c14 = model.x_pos[v1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c15 = model.x_pos[u1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c16 = model.x_pos[v1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin

    
    
    ## NE
    c17 = (model.x_pos[u2] + model.y_pos[u2]) - (model.x_pos[u1] + model.y_pos[u1]) <= M * (1 - model.is_NE[e1, e2]) - dmin
    c18 = (model.x_pos[v2] + model.y_pos[v2]) - (model.x_pos[u1] + model.y_pos[u1]) <= M * (1 - model.is_NE[e1, e2]) - dmin
    c19 = (model.x_pos[u2] + model.y_pos[u2]) - (model.x_pos[v1] + model.y_pos[v1]) <= M * (1 - model.is_NE[e1, e2]) - dmin
    c20 = (model.x_pos[v2] + model.y_pos[v2]) - (model.x_pos[v1] + model.y_pos[v1]) <= M * (1 - model.is_NE[e1, e2]) - dmin

    
    
    ## NW
    c21 = (model.x_pos[u1] - model.y_pos[u1]) - (model.x_pos[u2] - model.y_pos[u2]) <= M * (1 - model.is_NW[e1, e2]) - dmin
    c22 = (model.x_pos[u1] - model.y_pos[u1]) - (model.x_pos[v2] - model.y_pos[v2]) <= M * (1 - model.is_NW[e1, e2]) - dmin
    c23 = (model.x_pos[v1] - model.y_pos[v1]) - (model.x_pos[u2] - model.y_pos[u2]) <= M * (1 - model.is_NW[e1, e2]) - dmin
    c24 = (model.x_pos[v1] - model.y_pos[v1]) - (model.x_pos[v2] - model.y_pos[v2]) <= M * (1 - model.is_NW[e1, e2]) - dmin

    
    
    # SE
    c25 = (model.x_pos[u2] - model.y_pos[u2]) - (model.x_pos[u1] - model.y_pos[u1]) <= M * (1 - model.is_SE[e1, e2]) - dmin
    c26 = (model.x_pos[v2] - model.y_pos[v2]) - (model.x_pos[u1] - model.y_pos[u1]) <= M * (1 - model.is_SE[e1, e2]) - dmin
    c27 = (model.x_pos[u2] - model.y_pos[u2]) - (model.x_pos[v1] - model.y_pos[v1]) <= M * (1 - model.is_SE[e1, e2]) - dmin
    c28 = (model.x_pos[v2] - model.y_pos[v2]) - (model.x_pos[v1] - model.y_pos[v1]) <= M * (1 - model.is_SE[e1, e2]) - dmin

    
    
    
    
    ## SW
    c29 = (model.x_pos[u1] + model.y_pos[u1]) - (model.x_pos[u2] + model.y_pos[u2]) <= M * (1 - model.is_SW[e1, e2]) - dmin
    c30 = (model.x_pos[u1] + model.y_pos[u1]) - (model.x_pos[v2] + model.y_pos[v2]) <= M * (1 - model.is_SW[e1, e2]) - dmin
    c31 = (model.x_pos[v1] + model.y_pos[v1]) - (model.x_pos[u2] + model.y_pos[u2]) <= M * (1 - model.is_SW[e1, e2]) - dmin
    c32 = (model.x_pos[v1] + model.y_pos[v1]) - (model.x_pos[v2] + model.y_pos[v2]) <= M * (1 - model.is_SW[e1, e2]) - dmin

    
    constraint_list = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32]

    # Add all constraints to the constraint list
    for constraint in constraint_list:
        model.edgeSpacingConstraints.add(constraint)
 
 
 

           
# Call edge_spacing_constraint for each non-incident edge pair
for u1, v1, u2, v2 in model.NonIntersecting_NonIncidentEdges :
    edge_spacing_constraint(model, u1, v1, u2, v2)

# %%
def total_cost(model):
    # Sum existing costs (if any other costs are involved)
    rpos_costs = sum(model.rpos[edge] for edge in model.Edges)

    # Cost for deviations from octilinearity beyond the tolerance
    deviation_costs = sum(
        (model.dev_pos[edge] + model.dev_neg[edge])
        for edge in model.Edges
    )

    # Combine the costs
    return  10*rpos_costs + 0.1*deviation_costs #10*rpos_costs #+ 0.0001

model.TotalCost = Objective(rule=total_cost, sense=minimize)
# Out:
# WARNING: Implicitly replacing the Component attribute TotalCost (type=<class
# 'pyomo.core.base.objective.ScalarObjective'>) on block unknown with a new
# Component (type=<class 'pyomo.core.base.objective.ScalarObjective'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().

# %%
solver.solve(model, tee=True, warmstart=True)
# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmp6q53gpl_.pyomo.lp
# Reading time = 0.08 seconds
# x1: 20732 rows, 5253 columns, 84973 nonzeros
# Read MIP start from file C:\Users\katec\AppData\Local\Temp\tmpwwk1172u.gurobi.mst
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 20732 rows, 5253 columns and 84973 nonzeros
# Model fingerprint: 0x0d1cb890
# Variable types: 177 continuous, 5076 integer (5002 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e-01, 1e+01]
#   Bounds range     [1e+00,
#      0     0  586.95081    0  298  886.33514  586.95081  33.8%     -    8s
#      0     0  586.95081    0  300  886.33514  586.95081  33.8%     -    8s
#      0     0  587.04299    0  299  886.33514  587.04299  33.8%     -    9s
#      0     0  587.04299    0  300  886.33514  587.04299  33.8%     -    9s
#      0     0  587.04299    0  300  886.33514  587.04299  33.8%     -    9s
#      0     0  588.11993    0  288  886.33514  588.11993  33.6%     -    9s
#      0     0  588.11993    0  290  886.33514  588.11993  33.6%     -    9s
#      0     0  588.41262    0  312  886.33514  588.41262  33.6%     -   10s
#      0     0  588.41262    0  312  886.33514  588.41262  33.6%     -   10s
#      0     0  588.65404    0  296  886.33514  588.65404  33.6%     -   10s
#      0     0  588.85731    0  304  886.33514  588.85731  33.6%     -   10s
#      0     0  588.85731    0  304  886.33514  588.85731  33.6%     -   10s
#      0     0  589.03813    0  293  886.33514  589.03813  33.5%     -   10s
#      0     0  589.03813    0  293  886.33514  589.03813  33.5%     -   10s
#      0     0  589.08096    0  296  886.33514  589.08096  33.5%     -   10s
#      0     0  589.16101    0  289  886.33514  589.16101  33.5%     -   11s
#      0     0  589.16101    0  289  886.33514  589.16101  33.5%     -   11s
#      0     0  589.17055    0  284  886.33514  589.17055  33.5%     -   11s
#      0     0  589.17203    0  286  886.33514  589.17203  33.5%     -   11s
#      0     0  589.18397    0  296  886.33514  589.18397  33.5%     -   11s
#      0     0  590.68912    0  299  886.33514  590.68912  33.4%     -   12s
#      0     2  590.68912    0  280  886.33514  590.68912  33.4%     -   13s
# H   31    35                     885.5139197  649.87830  26.6%   130   14s
# H   33    35                     873.6208337  649.87830  25.6%   123   14s
# H   34    35                     858.4699216  649.87830  24.3%   119   14s
#     72    69 infeasible   11       858.46992  649.87830  24.3%  77.0   15s
# H   73    69                     852.8836976  649.87830  23.8%  75.9   15s
# H   74    69                     846.4178950  649.87830  23.2%  75.2   15s
# H  214   144                     844.5248090  652.91091  22.7%  39.2   16s
# H  418   249                     815.8906743  652.91091  20.0%  30.0   18s
# H  626   295                     805.1974473  666.71339  17.2%  29.9   19s
#    729   277     cutoff   12       805.19745  671.73861  16.6%  31.7   20s
# H  947   263                     803.9189994  687.83444  14.4%  32.5   21s
# H 1226   203                     803.8386476  726.79022  9.59%  32.6   23s
#
# Cutting planes:
#   Learned: 211
#   Gomory: 46
#   Cover: 19
#   Implied bound: 77
#   Clique: 6
#   MIR: 147
#   Flow cover: 50
#   Inf proof: 1
#   Zero half: 2
#   RLT: 29
#   Relax-and-lift: 119
#
# Explored 1570 nodes (55943 simplex iterations) in 23.98 seconds (14.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 803.839 803.919 805.197 ... 885.514
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.038386476460e+02, best bound 8.038386476460e+02, gap 0.0000%
# ok
# optimal

# %%
model.write("output.lp")
# Out:
# ('output.lp', 1764348402896)

# %%
model.write("model.lp", io_options={"symbolic_solver_labels": True})
# Out:
# ('model.lp', 1764351761232)

# %%
# Update positions based on optimized x and y coordinates
updated_pos3 = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}




#draw_graph(G, updated_pos)

draw_graph(G, updated_pos3, title="Optimized Network Layout3")

# %%
node_id = 6120  # Specify the node ID for which you want to access neighbors
neighbors = get_neighbors_for_node(node_id, ordered_neighbours_dict)  # Assuming ordered_neighbours_dict is already defined

if neighbors is not None:
    print(f"Neighbors of node {node_id}: {neighbors}")
else:
    print(f"No neighbors listed for node {node_id}.")
    
    
for x in neighbors:
    direction_sector = directional_sector(model, node_id, x)
    print(f"\ndirection sector: edge {node_id} to {x} is : {direction_sector}: {direction_sector.value} ")
    
    original_sector = orig_sector(model, node_id, x)
    print(f"original sector: edge {node_id} to {x} is : {original_sector}:  ")
    
print(f"\n{model.dir_forward[6119, 6120].value}")
print(f"{model.dir_backward[6119, 6120].value}")

print(f"\n{model.dir_forward[6118, 6120].value}")
print(f"{model.dir_backward[6118, 6120].value}")
# Out:
# Neighbors of node 6120: [6102, 6118, 6119, 6123]
#
# direction sector: edge 6120 to 6102 is : dir_backward[6102,6120]: 7.0
# original sector: edge 6120 to 6102 is : 7:
#
# direction sector: edge 6120 to 6118 is : dir_backward[6118,6120]: 2.0
# original sector: edge 6120 to 6118 is : 1:
#
# direction sector: edge 6120 to 6119 is : dir_backward[6119,6120]: 3.0
# original sector: edge 6120 to 6119 is : 3:
#
# direction sector: edge 6120 to 6123 is : dir_forward[6120,6123]: 4.0
# original sector: edge 6120 to 6123 is : 4:
#
# 7.0
# 3.0
#
# 6.0
# 2.0

# %% [markdown]
# # Solver

# %%
""" 
#solver.solve(model, tee=True)  # 'tee=True' enables solver output
#Solve the model
solver = SolverFactory('gurobi')
results = solver.solve(model, tee = True)

# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)
 """

def extract_solver_stats(results, df):
    stats = {
        'Solver Status': str(results.solver.status),
        'Termination Condition': str(results.solver.termination_condition),
        'Solve Time (s)': results.solver.time,
        'Number of Constraints': results.problem.number_of_constraints,
        'Number of Variables': results.problem.number_of_variables,
        'Number of Nonzeros': results.problem.number_of_nonzeros
    }
    if results.solver.status == 'ok' and results.solver.termination_condition == 'optimal':
        stats['Objective Value'] = int(value(model.TotalCost.expr))
    else:
        stats['Objective Value'] = 'N/A'
        
    all_nodes = pd.concat([df['src_bus_id'], df['dst_bus_id']]).unique()
    stats['Total Number of Nodes'] = len(all_nodes)
    
    stats['Total Number of Edges'] = len(df)
    
    
    return stats
stats = extract_solver_stats(results, country_df)

# %% [markdown]
# # Results

# %% [markdown]
# ## NetworkX Graph

# %%
""" # Update positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}




#draw_graph(G, updated_pos)

draw_graph(G, updated_pos, title="Optimized Network Layout") """
# Out:
# ' # Update positions based on optimized x and y coordinates\nupdated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}\n\n\n\n\n#draw_graph(G, updated_pos)\n\ndraw_graph(G, updated_pos, title="Optimized Network Layout") '

# %%
# Assuming 'G' is your graph and 'model' is your Pyomo model
# Updated positions based on optimized x and y coordinates
#updated_pos3 = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}

# Initialize a list to store edge information along with the calculated angles
opt_edges_info = []

# Iterate through each edge in your graph
for edge in G.edges():
    node1, node2 = edge

    # Retrieve the updated positions for source and destination nodes
    new_src_x, new_src_y = updated_pos3[node1]
    new_dst_x, new_dst_y = updated_pos3[node2]

    # Calculate the angle using the updated positions
    angle = calculate_angle(new_src_x, new_src_y, new_dst_x, new_dst_y)

    formatted_angle = round(angle, 2)

    # Append the edge information and formatted angle to the list
    opt_edges_info.append({
        'Edge': edge,
        'Source': node1,
        'Destination': node2,
        'Angle (degrees)': formatted_angle  # Use the formatted angle
    })

# Convert the list of dictionaries to a pandas DataFrame for easy tabular display
opt_edges_info_df = pd.DataFrame(opt_edges_info)

# Print the DataFrame
#print(edges_info_df)
display(opt_edges_info_df)
# Out:
#             Edge  Source  Destination  Angle (degrees)
# 0   (6093, 6094)    6093         6094           270.00
# 1   (6107, 6127)    6107         6127           270.00
# 2   (6127, 6128)    6127         6128             0.00
# 3   (6127, 6129)    6127         6129           270.00
# 4   (6089, 6126)    6089         6126             0.00
# 5   (6089, 6097)    6089         6097           180.00
# 6   (6124, 6126)    6124         6126           116.57
# 7   (6098, 6124)    6098         6124           180.00
# 8   (6098, 6100)    6098         6100           270.00
# 9   (6098, 6099)    6098         6099            90.00
# 10  (6102, 6120)    6102         6120           135.00
# 11  (6120, 6123)    6120         6123           180.00
# 12  (6103, 6116)    6103         6116           360.00
# 13  (6103, 6115)    6103         6115            45.00
# 14  (6103, 6114)    6103         6114            90.00
# 15  (6103, 6108)    6103         6108           130.58
# 16  (6103, 6105)    6103         6105           270.00
# 17  (6116, 6123)    6116         6123           312.22
# 18  (6114, 6115)    6114         6115             0.00
# 19  (6097, 6112)    6097         6112           180.00
# 20  (6095, 6112)    6095         6112           294.82
# 21  (6095, 6096)    6095         6096           180.00
# 22  (6096, 6110)    6096         6110           270.00
# 23  (6105, 6107)    6105         6107           180.00
# 24  (6105, 6123)    6105         6123             0.00
# 25  (6105, 6113)    6105         6113           135.00
# 26  (6092, 6094)    6092         6094            90.00
# 27  (6092, 6096)    6092         6096             0.00
# 28  (6101, 6102)    6101         6102           180.00
# 29  (6100, 6101)    6100         6101           270.00
# 30  (6108, 6110)    6108         6110            90.00
# 31  (6108, 6122)    6108         6122             0.00
# 32  (6111, 6124)    6111         6124           135.00
# 33  (6122, 6123)    6122         6123           270.00
# 34  (6119, 6122)    6119         6122           180.00
# 35  (6119, 6120)    6119         6120           267.42
# 36  (6118, 6120)    6118         6120           270.00

# %% [markdown]
# ## Functions - Results

# %%
def count_octilinearity_violations(opt_edges_info):
    violations = 0
    for edge_info in opt_edges_info:
        edge = edge_info['Edge']
        angle = edge_info['Angle (degrees)']
        # Check if the angle is not an exact multiple of 45 (including 0)
        if angle % 45 != 0:
            print(f"Violation found: {edge} with angle {angle}°")
            violations += 1
            
    if violations == 0:
        print("No violations found.")
    else:
        print(f"Total Octilinear Violations: {violations}")
        
    return violations



octilinearity_violations = count_octilinearity_violations(opt_edges_info)
# Out:
# Violation found: (6124, 6126) with angle 116.57°
# Violation found: (6103, 6108) with angle 130.58°
# Violation found: (6116, 6123) with angle 312.22°
# Violation found: (6095, 6112) with angle 294.82°
# Violation found: (6119, 6120) with angle 267.42°
# Total Octilinear Violations: 5

# %% [markdown]
# ## Debugging

# %%
""" # Print initial positions
print("Initial Positions:")
#for node in model.Nodes:
print(f"Node {6193}: x = {model.x_init[6193]}, y = {model.y_init[6193]}")
print(f"Node {6398}: x = {model.x_init[6398]}, y = {model.y_init[6398]}\n\n")

# After solving the model

# Print final positions
print("\nFinal Positions:")
#for node in model.Nodes:
print(f"Node {6193}: x = {value(model.x_pos[6193])}, y = {value(model.y_pos[6193])}")
print(f"Node {6398}: x = {value(model.x_pos[6398])}, y = {value(model.y_pos[6398])}") """
# Out:
# ' # Print initial positions\nprint("Initial Positions:")\n#for node in model.Nodes:\nprint(f"Node {6193}: x = {model.x_init[6193]}, y = {model.y_init[6193]}")\nprint(f"Node {6398}: x = {model.x_init[6398]}, y = {model.y_init[6398]}\n\n")\n\n# After solving the model\n\n# Print final positions\nprint("\nFinal Positions:")\n#for node in model.Nodes:\nprint(f"Node {6193}: x = {value(model.x_pos[6193])}, y = {value(model.y_pos[6193])}")\nprint(f"Node {6398}: x = {value(model.x_pos[6398])}, y = {value(model.y_pos[6398])}") '

# %%
def get_sorted_neighbours(G, node, pos, initial_neighbour):
    angles_neighbours = []
    src_x, src_y = pos[node]

    # Convert G to an undirected graph to consider all adjacent nodes
    G_undirected = G.to_undirected()

    # Calculate angles and sort neighbours
    for neighbour in G_undirected.neighbors(node):
        dst_x, dst_y = pos[neighbour]
        angle = calculate_angle(src_x, src_y, dst_x, dst_y)
        angles_neighbours.append((angle, neighbour))

    angles_neighbours.sort()
    sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]

    # Start the sorted list with the initial neighbour
    if initial_neighbour in sorted_neighbours:
        start_index = sorted_neighbours.index(initial_neighbour)
        sorted_neighbours = sorted_neighbours[start_index:] + sorted_neighbours[:start_index]

    return sorted_neighbours

def check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict):
    violations_count = 0
    
    for node, initial_neighbours in ordered_neighbours_dict.items():
        if initial_neighbours:  # Make sure there is at least one neighbour
            initial_first_neighbour = initial_neighbours[0]
            optimized_neighbours = get_sorted_neighbours(G, node, updated_pos, initial_first_neighbour)
            
            # Check for order violations
            if initial_neighbours != optimized_neighbours:
                print(f"Order violation at node {node}. Initial order: {initial_neighbours}, Optimized order: {optimized_neighbours}")
                violations_count += 1
            
            # Check for sector violations
            angles = [round(calculate_angle(updated_pos[node][0], updated_pos[node][1],
                                            updated_pos[neighbour][0], updated_pos[neighbour][1]), 1)
                      for neighbour in optimized_neighbours]
            sectors = [int(angle // 45) for angle in angles]
            for i in range(len(sectors) - 1):
                if sectors[i] == sectors[i + 1] and angles[i] != angles[i + 1]:
                    print(f"Sector violation between nodes {optimized_neighbours[i]} and {optimized_neighbours[i + 1]} "
                          f"at node {node} in sector {sectors[i]}. Rounded angles: {angles[i]}, {angles[i + 1]}")
                    violations_count += 1
                    break  # Stop at the first violation for this node

    if violations_count == 0:
        print("No circular order violations found.")
    else:
        print(f"Total circular order violations: {violations_count}")
    
    return violations_count

# Example usage
circular_order_violations = check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2114], line 57
#      54     return violations_count
#      56 # Example usage
# ---> 57 circular_order_violations = check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict)
#
# NameError: name 'updated_pos' is not defined

# %%
def check_edge_spacing_violations(specified_edge_pairs, pos):
    intersecting_edge_pairs = []
    violations_count = 0

    for edge1, edge2 in specified_edge_pairs:
        # Get the positions for the source and target nodes of each edge from the 'pos' argument
        src_pos1, tgt_pos1 = pos[edge1[0]], pos[edge1[1]]
        src_pos2, tgt_pos2 = pos[edge2[0]], pos[edge2[1]]
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect and are not merely touching at endpoints
        if line1.intersects(line2) and not line1.touches(line2):
            print(f"Violation found between edge {edge1} and edge {edge2}")
            intersecting_edge_pairs.append((edge1, edge2))
            violations_count += 1

    if violations_count == 0:
        print("No edge spacing violations found.")
    else:
        print(f"Total edge spacing violations: {violations_count}")

    return violations_count


edge_cross_violations = check_edge_spacing_violations(non_intersecting_non_incident_edges, updated_pos)
# Out:
# No edge spacing violations found.

# %%
def display_results(stats, octilinearity_violations, circular_order_violations, edge_crossing_violations):
    # Construct the results DataFrame with the specified metrics
    results_df = pd.DataFrame([
        ['Solver Status', stats.get('Solver Status', 'N/A')],
        ['Objective Function Value', stats.get('Objective Value', 'N/A')],
        ['Computation Time (s)', stats.get('Solve Time (s)', 'N/A')],
        
        ['Number of Constraints', stats.get('Number of Constraints', 'N/A')],
        ['Number of Variables', stats.get('Number of Variables', 'N/A')],
        
        ['Total Number of Nodes', stats.get('Total Number of Nodes', 'N/A')],
        ['Total Number of Edges', stats.get('Total Number of Edges', 'N/A')],
        
        ['Octilinearity Violations', octilinearity_violations],
        ['Circular Order Violations', circular_order_violations],
        ['Edge Crossing Violations', edge_crossing_violations]
    ], columns=['Metric', 'Value'])
    
    # Display the DataFrame
    # If using a Jupyter Notebook, 'display()' will work directly.
    # In other environments, you might need to print the DataFrame or use another method to visualize it.
    display(results_df)

# %%
stats = extract_solver_stats(results, country_df)


display_results(stats, octilinearity_violations, circular_order_violations, edge_cross_violations)
# Out:
#                       Metric     Value
# 0              Solver Status        ok
# 1   Objective Function Value      1704
# 2       Computation Time (s)  8.896518
# 3      Number of Constraints     20733
# 4        Number of Variables      5261
# 5      Total Number of Nodes        33
# 6      Total Number of Edges        39
# 7   Octilinearity Violations         4
# 8  Circular Order Violations         2
# 9   Edge Crossing Violations         0

# %%
# Now create a subplot with both the original and optimized graphs side by side
fig, axs = plt.subplots(1, 2, figsize=(30, 15))  # 1 row, 2 columns for the subplots

# Draw the original graph on the first subplot
draw_graph(G, pos, ax=axs[0], title="Original Network Layout")

# Draw the optimized graph on the second subplot
draw_graph(G, updated_pos, ax=axs[1], title="Optimized Network Layout")

# Adjust layout to prevent overlapping
plt.tight_layout()

# Display the combined plot
plt.show()
