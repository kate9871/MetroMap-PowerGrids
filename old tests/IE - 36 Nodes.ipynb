# %% [markdown]
# # Import Packages

# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from pyomo.environ import*
import math
import csv
from IPython.display import display

from pyproj import Transformer 
from itertools import combinations
from shapely.geometry import LineString

import matplotlib.lines as mlines

# %% [markdown]
# # Access Files
#
# Creating Dataframe of particular country and particular links

# %%
filename = 'IE.csv'
file_path = filename

country_df = pd.read_csv(file_path)

print(f"Shape of df is: {country_df.shape}")
#display(country_df)  




## Add scaling factor if needed to the x y positions for graphing and optimisation
# Infeasible when x y values are too large

scaling_factor = 0.1

# Scale 'src_x' and 'src_y' columns
country_df['src_x'] = country_df['src_x'] * scaling_factor
country_df['src_y'] = country_df['src_y'] * scaling_factor

# Scale 'dst_x' and 'dst_y' columns
country_df['dst_x'] = country_df['dst_x'] * scaling_factor
country_df['dst_y'] = country_df['dst_y'] * scaling_factor

display(country_df)
# Out:
# Shape of df is: (48, 18)
#     link_id  src_bus_id  dst_bus_id  voltage  circuits dc underground  \
# 0      9727        6172        6173    220.0         1  f           t
# 1      9519        6188        6198    220.0         1  f           f
# 2      9500        6193        6198    220.0         1  f           f
# 3      9520        6194        6199    220.0         1  f           f
# 4      9514        6174        6199    220.0         1  f           f
# 5      9505        6191        6200    220.0         2  f           t
# 6      9511        6170        6200    220.0         1  f           t
# 7      9523        6172        6201    220.0         1  f           f
# 8      9726        6171        6201    220.0         2  f           f
# 9      9748        6170        6202    220.0         1  f           t
# 10     9488        6183        6197    220.0         1  f           f
# 11     9751        6190        6202    220.0         1  f           t
# 12     9510        6193        6398    220.0         2  f           f
# 13     9639        6184        6549    220.0         1  f           f
# 14     9640        6183        6549    220.0         1  f           f
# 15     9655        6192        6556    220.0         1  f           f
# 16     9750        6202        6585    220.0         1  f           t
# 17     9512        6190        6585    220.0         1  f           t
# 18     9725        6189        6585    220.0         1  f           t
# 19     9507        6186        7011    220.0         2  f           f
# 20     9643        6173        7705    220.0         2  f           f
# 21     9749        6200        6202    220.0         1  f           t
# 22     9516        6171        6197    220.0         1  f           f
# 23     9515        6176        6196    220.0         1  f           f
# 24     9483        6171        6196    220.0         1  f           f
# 25     9485        6175        6177    220.0         1  f           f
# 26     9490        6176        6177    220.0         1  f           f
# 27     9486        6171        6177    220.0         1  f           f
# 28     9489        6178        6180    220.0         1  f           f
# 29     9492        6174        6180    220.0         1  f           f
# 30     9491        6176        6180    220.0         1  f           f
# 31     9522        6182        6183    220.0         1  f           f
# 32     9493        6182        6186    220.0         1  f           f
# 33     9495        6181        6186    220.0         1  f           f
# 34     9728        6201        7705    220.0         1  f           t
# 35     9498        6175        6188    220.0         1  f           f
# 36     9496        6186        6188    220.0         1  f           f
# 37     9508        6188        6189    220.0         2  f           f
# 38     9504        6184        6190    220.0         1  f           f
# 39     9499        6188        6191    220.0         1  f           f
# 40     9501        6174        6192    220.0         1  f           f
# 41     9521        6192        6193    220.0         1  f           f
# 42     9497        6191        6193    220.0         1  f           f
# 43     9494        6181        6188    220.0         1  f           f
# 44     9487        6171        7705    220.0         1  f           f
# 45     9502        6178        6186    380.0         1  f           f
# 46     9513        6178        6194    380.0         1  f           f
# 47     9503        6185        6194    380.0         1  f           f
#
#    under_construction       length_m  \
# 15          IE          IE  -92825.126628  715572.885110  -93681.218040
# 16          IE          IE  -68976.773629  703832.164368  -70199.762950
# 17          IE          IE  -69221.375946  701019.267668  -70199.762950
# 18          IE          IE  -71300.456680  703342.950548  -70199.762950
# 19          IE          IE  -74724.833460  700530.071577  -73134.946228
# 20          IE         NaN  -93925.820357  676559.429223  -93069.728945
# 21          IE          IE  -69710.569448  705666.642756  -68976.773629
# 22          IE          IE  -93314.320130  680717.606642  -81818.200468
# 23          IE          IE -105055.053241  689890.041275  -98450.890866
# 24          IE          IE  -93314.320130  680717.606642  -98450.890866
# 25          IE          IE  -89523.045440  703220.661503  -95515.707588
# 26          IE          IE -105055.053241  689890.041275  -95515.707588
# 27          IE          IE  -93314.320130  680717.606642  -95515.707588
# 28          IE          IE -104810.450923  691969.130725 -102731.370190
# 29          IE          IE  -99429.289002  703342.950548 -102731.370190
# 30          IE          IE -105055.053241  689890.041275 -102731.370190
# 31          IE          IE  -78638.414874  693314.419559  -77537.721145
# 32          IE          IE  -78638.414874  693314.419559  -74724.833460
# 33          IE          IE  -71667.354589  698450.984729  -74724.833460
# 34          IE         NaN  -90012.250075  678271.617658  -93069.728945
# 35          IE          IE  -89523.045440  703220.661503  -73746.446455
# 36          IE          IE  -74724.833460  700530.071577  -73746.446455
# 37          IE          IE  -73746.446455  703709.855989  -71300.456680
# 38          IE          IE  -69465.967131  694904.308018  -69221.375946
# 39          IE          IE  -73746.446455  703709.855989  -71667.354589
# 40          IE          IE  -99429.289002  703342.950548  -92825.126628
# 41          IE          IE  -92825.126628  715572.885110  -73624.150862
# 42          IE          IE  -71667.354589  705544.350521  -73624.150862
# 43          IE          IE  -71667.354589  698450.984729  -73746.446455
# 44          IE          IE  -93314.320130  680717.606642  -93069.728945
# 45          IE          IE -104810.450923  691969.130725  -74724.833460
# 46          IE          IE -104810.450923  691969.130725  -93314.320130
# 47          IE          IE  -73624.150862  706522.748723  -93314.320130
#
#             dst_y
# 0   676559.429223
# 1   711414.718443
# 2   711414.718443
# 3   702119.975351
# 4   702119.975351
# 5   705666.642756
# 6   705666.642756
# 7   678271.617658
# 8   678271.617658
# 9   703832.164368
# 10  683530.486430
# 11  703832.164368
# 12  723155.434466
# 13  690990.744244
# 14  690990.744244
# 15  720954.048504
# 16  703465.258388
# 17  703465.258388
# 18  703465.258388
# 19  701875.363999
# 20  678027.016869
# 21  703832.164368
# 22  683530.486430
# 23  678149.317057
# 24  678149.317057
# 25  690501.539862
# 26  690501.539862
# 27  690501.539862
# 28  691969.130725
# 29  691969.130725
# 30  691969.130725
# 31  684998.070303
# 32  700530.071577
# 33  700530.071577
# 34  678027.016869
# 35  703709.855989
# 36  703709.855989
# 37  703342.950548
# 38  701019.267668
# 39  705544.350521
# 40  715572.885110
# 41  716918.176343
# 42  716918.176343
# 43  703709.855989
# 44  678027.016869
# 45  700530.071577
# 46  700530.071577
# 47  700530.071577

# %% [markdown]
# ## Functions
# Calculate Forward Sector : Calculates the sector of an edge starting at the positive x axis going in counterclockwise direction. Sectors are split from 0 - 7.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Function - NetworkX Implementation and Attributes

# %%
def calculate_forward_sector(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    # Angle in radians
    angle_rad = math.atan2(dy, dx)
    
    # Convert to degreees
    angle_deg = math.degrees(angle_rad)
    
    # Angle is rounded to nearest multiple of 45
    # Sector value calculated, modulo 8 used 
    sector = round(angle_deg / 45) % 8
    
    return sector





def euclidean_distance(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    return math.sqrt((dx)**2 + (dy)**2)




def get_non_incident_edge_pairs(G):
    non_incident_edge_pairs = []
    
    # combinations - generates all possible pairs of edges from graph G without repeating the same pair
    # '2' indicates we're looking for combinationes of 2 edges
    for edge1, edge2 in combinations(G.edges(), 2):
        
        # edges are sets and the '&' checks that they have no common elements (ie nodes)
        if not set(edge1) & set(edge2):
            non_incident_edge_pairs.append((edge1, edge2))
    return non_incident_edge_pairs    


def midpoint(pos1, pos2):
    """Calculate the midpoint between two positions."""
    return ((pos1[0] + pos2[0]) / 2, (pos1[1] + pos2[1]) / 2)



def calculate_distance(midpoint1, midpoint2):
    return math.sqrt((midpoint2[0] - midpoint1[0]) ** 2 + (midpoint2[1] - midpoint1[1]) ** 2)




def get_non_incident_edge_distance(G):
    non_incident_edge_distances = {}
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Calculate the midpoints for each edge
        midpoint1 = midpoint(src_pos1, tgt_pos1)
        midpoint2 = midpoint(src_pos2, tgt_pos2)

        # Calculate the distance between the midpoints of the two edges
        dist = calculate_distance(midpoint1, midpoint2)

        # Store the distance with the edge pair as the key
        non_incident_edge_distances[(edge1, edge2)] = dist

    return non_incident_edge_distances




def calculate_angle(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    angle_radians = math.atan2(dy, dx)
    angle_degrees = math.degrees(angle_radians)  # Convert the angle to degrees
    
    # Normalize the angle to be within 0 to 360 degrees
    angle_degrees = (angle_degrees + 360) % 360

    return angle_degrees







 
def get_filtered_neighbour_order(G):
    
    # Convert the directed graph to an undirected graph to consider all adjacent nodes as neighbours
    G_undirected = G.to_undirected()
    
    # Create Dictionary to story nodes neighbour orders
    neighbour_order = {}
    for node in G_undirected.nodes():
        
        # Check if the node has 2 or more neighbours
        if G_undirected.degree(node) >= 2:
        
            # Access the position of the current node
            src_pos = G_undirected.nodes[node]['pos']
            src_x, src_y = src_pos
            
            # Create list to store angle size of neighbours with src node
            angles_neighbours = []
            
            
            
            for neighbour in G_undirected.neighbors(node):
                # Access the position tuple of the neighbour node using the 'pos' attribute
                dst_pos = G_undirected.nodes[neighbour]['pos']
                dst_x, dst_y = dst_pos
                
                # Calculate the angle from the source node to the neighbour node
                angle = calculate_angle(src_x, src_y, dst_x, dst_y)
                
                # Append the angle and neighbour to the list
                angles_neighbours.append((angle, neighbour)) 
                
                
            
            # Sort the list of (angle, neighbour) pairs by angle in ascending order
            angles_neighbours.sort()
            
            # Extract the sorted neighbours from the sorted list of pairs
            sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]
            
            # Check conditions to move the last neighbour to the first position
            if angles_neighbours[-1][0] > 315 and ((360 - angles_neighbours[-1][0]) < angles_neighbours[0][0]):
                # Move the last neighbour to the first position
                sorted_neighbours.insert(0, sorted_neighbours.pop())
            
            
            # Store the sorted list of neighbours in the dictionary with the src_node as the key
            neighbour_order[node] = sorted_neighbours
    
    return neighbour_order

# %% [markdown]
# # NetworkX Implementation
# Dataframe is accessed where nodes and edges are added to graph.
# Forward and backward sector of a particular edge are found and stored as attributes along with the voltage information.

# %%
# Initialize a directed graph since we have source and destination
G = nx.DiGraph()

# Loop through the DataFrame rows to add edges and nodes to the graph
for index, row in country_df.iterrows():
    src_node = row['src_bus_id']
    dst_node = row['dst_bus_id']
    voltage = row['voltage']
    
    # Add the source and destination nodes if they don't already exist
    if src_node not in G:
        G.add_node(src_node, pos=(row['src_x'], row['src_y']))
    if dst_node not in G:
        G.add_node(dst_node, pos=(row['dst_x'], row['dst_y']))
        
        
        
    # Calculate the forward sector for edges
    forward_sector = calculate_forward_sector(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])

    # Backward sector
    backward_sector = (forward_sector + 4) % 8
    
    distance = euclidean_distance(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])
    
    # Add an edge between the source and destination nodes, voltage is attribute
    G.add_edge(src_node, dst_node, 
               voltage = voltage, 
               forward_sector = forward_sector, 
               backward_sector = backward_sector,
               distance = distance
               )


# Create list of non-incident edge pairs
non_incident_edge_pairs = get_non_incident_edge_pairs(G)

print(non_incident_edge_pairs)



# Print non-incident edge pairs
print("Non-incident edge pairs:")
for edge_pair in non_incident_edge_pairs:
    print(edge_pair)
    
ordered_neighbours_dict = get_filtered_neighbour_order(G)
print("\nNodes with more than 2 neighbours ordered:")
print(ordered_neighbours_dict)
for node, neighbours in ordered_neighbours_dict.items():
    print(len(neighbours))
    
    
 # dictionary
non_incident_edge_distances = get_non_incident_edge_distance(G)

# Find the non-incident edge pair with the maximum distance
max_distance_pair = max(non_incident_edge_distances, key=non_incident_edge_distances.get)

# Print the non-incident edge pair with the maximum distance and its value
max_distance_value = non_incident_edge_distances[max_distance_pair]
print(f"Non-incident edge pair with maximum distance: {max_distance_pair} with distance {max_distance_value}")
# Out:
# [((6172, 6173), (6188, 6198)), ((6172, 6173), (6188, 6189)), ((6172, 6173), (6188, 6191)), ((6172, 6173), (6193, 6198)), ((6172, 6173), (6193, 6398)), ((6172, 6173), (6194, 6199)), ((6172, 6173), (6174, 6199)), ((6172, 6173), (6174, 6180)), ((6172, 6173), (6174, 6192)), ((6172, 6173), (6191, 6200)), ((6172, 6173), (6191, 6193)), ((6172, 6173), (6200, 6202)), ((6172, 6173), (6170, 6200)), ((6172, 6173), (6170, 6202)), ((6172, 6173), (6201, 7705)), ((6172, 6173), (6171, 6201)), ((6172, 6173), (6171, 6197)), ((6172, 6173), (6171, 6196)), ((6172, 6173), (6171, 6177)), ((6172, 6173), (6171, 7705)), ((6172, 6173), (6202, 6585)), ((6172, 6173), (6183, 6197)), ((6172, 6173), (6183, 6549)), ((6172, 6173), (6190, 6202)), ((6172, 6173), (6190, 6585)), ((6172, 6173), (6184, 6549)), ((6172, 6173), (6184, 6190)), ((6172, 6173), (6192, 6556)), ((6172, 6173), (6192, 6193)), ((6172, 6173), (6189, 6585)), ((6172, 6173), (6186, 7011)), ((6172, 6173), (6186, 6188)), ((6172, 6173), (6176, 6196)), ((6172, 6173), (6176, 6177)), ((6172, 6173), (6176, 6180)), ((6172, 6173), (6175, 6177)), ((6172, 6173), (6175, 6188)
6549, 6182, 6197], 6197: [6183, 6171], 6190: [6202, 6585, 6184], 6184: [6190, 6549], 6549: [6184, 6183], 6192: [6193, 6556, 6174], 6585: [6202, 6189, 6190], 6189: [6585, 6188], 6186: [6181, 7011, 6188, 6178, 6182], 7705: [6201, 6171, 6173], 6176: [6177, 6180, 6196], 6196: [6171, 6176], 6175: [6188, 6177], 6177: [6175, 6176, 6171], 6178: [6180, 6186, 6194], 6180: [6174, 6178, 6176], 6182: [6186, 6183], 6181: [6188, 6186]}
# 2
# 2
# 6
# 2
# 4
# 3
# 2
# 3
# 3
# 3
# 2
# 3
# 5
# 4
# 3
# 2
# 3
# 2
# 2
# 3
# 3
# 2
# 5
# 3
# 3
# 2
# 2
# 3
# 3
# 3
# 2
# 2
# Non-incident edge pair with maximum distance: ((6173, 7705), (6193, 6398)) with distance 47531.82142960742

# %% [markdown]
# ## Drawing NetworkX Graph

# %%
pos = nx.get_node_attributes(G, 'pos')



""" def highest_voltage_color(G, node):
    # Get highest voltage of all connected edges
    highest_voltage = max((d['voltage'] for u, v, d in G.edges(node, data=True)), default=0)
    return voltage_colors.get(highest_voltage, 'grey')      #default colout """


def draw_graph(G, pos):
    plt.figure(figsize=(15, 15))
    
    # Convert to undirected graph for the purpose of finding node outline colors
    G_undirected = G.to_undirected()

    voltage_colors = {
        132: 'black',
        220: 'green',
        380: 'red',
        300: 'orange',
        500: 'yellow',
        750: 'purple'
    }

    # Determine the highest voltage color for each node
    node_outline_color = {}
    for node in G.nodes():
        connected_edges = G_undirected.edges(node, data=True)
        highest_voltage = max((data['voltage'] for _, _, data in connected_edges), default=0)
        node_outline_color[node] = voltage_colors.get(highest_voltage, 'grey')

    # Draw nodes with highest voltage outline color
    for node, color in node_outline_color.items():
        nx.draw_networkx_nodes(G, pos, nodelist=[node], node_color='skyblue',
                               edgecolors=color, node_size=500, linewidths=2)


    # Define custom lines for the legend with appropriate colors and labels for each voltage level
    legend_lines = [
        
        mlines.Line2D([], [], color='black', markersize=30, label='132 kV', linewidth=3),
        mlines.Line2D([], [], color='green', markersize=30, label='220 kV', linewidth=3),
        mlines.Line2D([], [], color='orange', markersize=30, label='300 kV', linewidth=3),
        mlines.Line2D([], [], color='red', markersize=30, label='380 kV', linewidth=3),
        mlines.Line2D([], [], color='yellow', markersize=30, label='500 kV', linewidth=3),
        mlines.Line2D([], [], color='purple', markersize=30, label='750 kV', linewidth=3)
    ]

    # Draw the graph edges with different colors based on the voltage
    for (u, v, d) in G.edges(data=True):
        if d['voltage'] == 380:
            edge_color = 'red'
        elif d['voltage'] == 220:
            edge_color = 'green'
        elif d['voltage'] == 132:
            edge_color = 'black'
        elif d['voltage'] == 300:
            edge_color = 'orange'
        elif d['voltage'] == 500:
            edge_color = 'yellow'
        elif d['voltage'] == 750:
            edge_color = 'purple'
        else:
            edge_color = 'grey'  # Default color for unspecified or unknown voltages
        nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], edge_color=edge_color, width=3, arrows=False)

    # Draw the node labels
    nx.draw_networkx_labels(G, pos, font_size=8)

    # Create edge labels for voltages, using 'link_id' or another attribute if desired
    edge_labels = nx.get_edge_attributes(G, 'link_id')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, label_pos=0.5, font_size=7)

    # Add the legend to the plot with all line types
    plt.legend(handles=legend_lines, loc='lower right', fontsize=20)
    plt.axis('equal')
    plt.grid(True)
    # Show the plot
    plt.show()
    
    
draw_graph(G, pos)

# %% [markdown]
# ## Access edge information from NetworkX Graph

# %%
def get_edge_info(G, edge):
    node1, node2 = edge
    
    # edge attributes eg voltage forward/backward sector are stored in edge data
    edge_data = G.get_edge_data(node1, node2)
    
    # Additional edge information
    edge_information = {
        'edge': edge,
        'source': node1,
        'destination': node2,
        'source_position': G.nodes[node1].get('pos'),
        'destination_position': G.nodes[node2].get('pos'),
        'source_neighbors': list(G.successors(node1)),  # or list(G.successors(u)) for DiGraph
        'destination_neighbors': list(G.predecessors(node2)),  # or list(G.predecessors(v)) for DiGraph
        'source_degree': G.degree(node1),
        'destination_degree': G.degree(node2)
    }
    
    # Merge edge_data into edge_info
    edge_information.update(edge_data)
    return edge_information

    
    
# Print Specified Edge Details
edge_details = {}
for edge in G.edges():
    edge_details[edge] = get_edge_info(G, edge)
    print(edge_details[edge])
    
    forward = edge_details[edge].get('forward_sector')
    backward = edge_details[edge].get('backward_sector')
    print(f"Forward sector for edge {edge}: {forward}")
    print(f"Backward sector for edge {edge}: {backward}\n")
# Out:
# {'edge': (6172, 6173), 'source': 6172, 'destination': 6173, 'source_position': (-90990.63707918006, 677170.9272222472), 'destination_position': (-93925.82035682457, 676559.4292231115), 'source_neighbors': [6173, 6201], 'destination_neighbors': [6172], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 2998.204575460285}
# Forward sector for edge (6172, 6173): 4
# Backward sector for edge (6172, 6173): 0
#
# {'edge': (6172, 6201), 'source': 6172, 'destination': 6201, 'source_position': (-90990.63707918006, 677170.9272222472), 'destination_position': (-90012.2500745981, 678271.617657593), 'source_neighbors': [6173, 6201], 'destination_neighbors': [6172, 6171], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1472.6712345925976}
# Forward sector for edge (6172, 6201): 1
# Backward sector for edge (6172, 6201): 5
#
# {'edge': (6173, 7705), 'source': 6173, 'destination': 7705, 'source_position': (-93925.82035682457, 676559.4292231115), 'destination_position': (-93069.72894482798, 678027.0168693209), 'source_neighbors': [7705], 'destination_neighbors': [6173, 6201, 6171], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 1699.0309017203797}
# Forward sector for edge (6173, 7705): 1
# Backward sector for edge (6173, 7705): 5
#
# {'edge': (6188, 6198), 'source': 6188, 'destination': 6198, 'source_position': (-73746.44645496838, 703709.8559885431), 'destination_position': (-74357.946681794, 711414.718442685), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188, 6193], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 7729.090371101402}
# Forward sector for edge (6188, 6198): 2
# Backward sector for edge (6188, 6198): 6
#
# {'edge': (6188, 6189), 'source': 6188, 'destination': 6189, 'source_position': (-73746.44645496838, 703709.8559885431), 'destination_position': (-71300.45667961502, 703342.9505480125), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 2473.355126831597}
# Forward sector for edge (6188, 6189): 0
# Backward sector for edge (6188, 6189): 4
#
# {'edge': (6188, 6191), 'source': 6188, 'destination': 6191, 'source_position': (-73746.44645496838, 703709.8559885431), 'destination_position': (-71667.35458932047, 705544.3505209369), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 2772.7230613939564}
# Forward sector for edge (6188, 6191): 1
# Backward sector for edge (6188, 6191): 5
#
# {'edge': (6193, 6198), 'source': 6193, 'destination': 6198, 'source_position': (-73624.15086238278, 716918.1763432152), 'destination_position': (-74357.946681794, 711414.718442685), 'source_neighbors': [6198, 6398], 'destination_neighbors': [6188, 6193], 'source_degree': 4, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 5552.1622065186075}
# Forward sector for edge (6193, 6198): 6
# Backward sector for edge (6193, 6198): 2
#
# {'edge': (6193, 6398), 'source': 6193, 'destination': 6398, 'source_position': (-73624.15086238278, 716918.1763432152), 'destination_position': (-71789.66131385515, 723155.4344659001), 'source_neighbors': [6198, 6398], 'destination_neighbors': [6193], 'source_degree': 4, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 6501.441439608288}
# Forward sector for edge (6193, 6398): 2
# Backward sector for edge (6193, 6398): 6
#
# {'edge': (6194, 6199), 'source': 6194, 'destination': 6199, 'source_position': (-93314.32012999884, 700530.0715766218), 'destination_position': (-95638.01431276693, 702119.9753507258), 'source_neighbors': [6199], 'destination_neighbors': [6194, 6174], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 2815.554770545278}
# Forward sector for edge (6194, 6199): 3
# Backward sector for edge (6194, 6199): 7
#
# {'edge': (6174, 6199), 'source': 6174, 'destination': 6199, 'source_position': (-99429.28900240782, 703342.9505480125), 'destination_position': (-95638.01431276693, 702119.9753507258), 'source_neighbors': [6199, 6180, 6192], 'destination_neighbors': [6194, 6174], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 3983.645579803766}
# Forward sector for edge (6174, 6199): 0
# Backward sector for edge (6174, 6199): 4
#
# {'edge': (6174, 6180), 'source': 6174, 'destination': 6180, 'source_position': (-99429.28900240782, 703342.9505480125), 'destination_position': (-102731.37018975778, 691969.1307246548), 'source_neighbors': [6199, 6180, 6192], 'destination_neighbors': [6178, 6174, 6176], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 11843.4588504396}
# Forward sector for edge (6174, 6180): 6
# Backward sector for edge (6174, 6180): 2
#
# {'edge': (6174, 6192), 'source': 6174, 'destination': 6192, 'source_position': (-99429.28900240782, 703342.9505480125), 'destination_position': (-92825.1266277078, 715572.885109591), 'source_neighbors': [6199, 6180, 6192], 'destination_neighbors': [6174], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 13899.146018798936}
# Forward sector for edge (6174, 6192): 1
# Backward sector for edge (6174, 6192): 5
#
# {'edge': (6191, 6200), 'source': 6191, 'destination': 6200, 'source_position': (-71667.35458932047, 705544.3505209369), 'destination_position': (-69710.56944820723, 705666.6427559726), 'source_neighbors': [6200, 6193], 'destination_neighbors': [6191, 6170], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 1960.60283566856}
# Forward sector for edge (6191, 6200): 0
# Backward sector for edge (6191, 6200): 4
#
# {'edge': (6191, 6193), 'source': 6191, 'destination': 6193, 'source_position': (-71667.35458932047, 705544.3505209369), 'destination_position': (-73624.15086238278, 716918.1763432152), 'source_neighbors': [6200, 6193], 'destination_neighbors': [6192, 6191], 'source_degree': 3, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 11540.925677336052}
# Forward sector for edge (6191, 6193): 2
# Backward sector for edge (6191, 6193): 6
#
# {'edge': (6200, 6202), 'source': 6200, 'destination': 6202, 'source_position': (-69710.56944820723, 705666.6427559726), 'destination_position': (-68976.77362879623, 703832.1643676325), 'source_neighbors': [6202], 'destination_neighbors': [6170, 6190, 6200], 'source_degree': 3, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 1975.795349187747}
# Forward sector for edge (6200, 6202): 6
# Backward sector for edge (6200, 6202): 2
#
# {'edge': (6170, 6200), 'source': 6170, 'destination': 6200, 'source_position': (-68120.68221679975, 705544.3505209369), 'destination_position': (-69710.56944820723, 705666.6427559726), 'source_neighbors': [6200, 6202], 'destination_neighbors': [6191, 6170], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1594.5835817988893}
# Forward sector for edge (6170, 6200): 4
# Backward sector for edge (6170, 6200): 0
#
# {'edge': (6170, 6202), 'source': 6170, 'destination': 6202, 'source_position': (-68120.68221679975, 705544.3505209369), 'destination_position': (-68976.77362879623, 703832.1643676325), 'source_neighbors': [6200, 6202], 'destination_neighbors': [6170, 6190, 6200], 'source_degree': 2, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 1914.2815700051822}
# Forward sector for edge (6170, 6202): 5
# Backward sector for edge (6170, 6202): 1
#
# {'edge': (6201, 7705), 'source': 6201, 'destination': 7705, 'source_position': (-90012.2500745981, 678271.617657593), 'destination_position': (-93069.72894482798, 678027.0168693209), 'source_neighbors': [7705], 'destination_neighbors': [6173, 6201, 6171], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 3067.2473958788414}
# Forward sector for edge (6201, 7705): 4
# Backward sector for edge (6201, 7705): 0
#
# {'edge': (6171, 6201), 'source': 6171, 'destination': 6201, 'source_position': (-93314.32012999884, 680717.6066415538), 'destination_position': (-90012.2500745981, 678271.617657593), 'source_neighbors': [6201, 6197, 6196, 6177, 7705], 'destination_neighbors': [6172, 6171], 'source_degree': 5, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 4109.322177735886}
# Forward sector for edge (6171, 6201): 7
# Backward sector for edge (6171, 6201): 3
#
# {'edge': (6171, 6197), 'source': 6171, 'destination': 6197, 'source_position': (-93314.32012999884, 680717.6066415538), 'destination_position': (-81818.20046849061, 683530.4864299865), 'source_neighbors': [6201, 6197, 6196, 6177, 7705], 'destination_neighbors': [6183, 6171], 'source_degree': 5, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 11835.246510989517}
# Forward sector for edge (6171, 6197): 0
# Backward sector for edge (6171, 6197): 4
#
# {'edge': (6171, 6196), 'source': 6171, 'destination': 6196, 'source_position': (-93314.32012999884, 680717.6066415538), 'destination_position': (-98450.89086587669, 678149.3170565078), 'source_neighbors': [6201, 6197, 6196, 6177, 7705], 'destination_neighbors': [6176, 6171], 'source_degree': 5, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 5742.862554278349}
# Forward sector for edge (6171, 6196): 5
# Backward sector for edge (6171, 6196): 1
#
# {'edge': (6171, 6177), 'source': 6171, 'destination': 6177, 'source_position': (-93314.32012999884, 680717.6066415538), 'destination_position': (-95515.7075882323, 690501.5398618673), 'source_neighbors': [6201, 6197, 6196, 6177, 7705], 'destination_neighbors': [6175, 6176, 6171], 'source_degree': 5, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 10028.53209601594}
# Forward sector for edge (6171, 6177): 2
# Backward sector for edge (6171, 6177): 6
#
# {'edge': (6171, 7705), 'source': 6171, 'destination': 7705, 'source_position': (-93314.32012999884, 680717.6066415538), 'destination_position': (-93069.72894482798, 678027.0168693209), 'source_neighbors': [6201, 6197, 6196, 6177, 7705], 'destination_neighbors': [6173, 6201, 6171], 'source_degree': 5, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 2701.6843209945364}
# Forward sector for edge (6171, 7705): 6
# Backward sector for edge (6171, 7705): 2
#
# {'edge': (6202, 6585), 'source': 6202, 'destination': 6585, 'source_position': (-68976.77362879623, 703832.1643676325), 'destination_position': (-70199.76295049826, 703465.2583877346), 'source_neighbors': [6585], 'destination_neighbors': [6202, 6190, 6189], 'source_degree': 4, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 1276.8409764265766}
# Forward sector for edge (6202, 6585): 4
# Backward sector for edge (6202, 6585): 0
#
# {'edge': (6183, 6197), 'source': 6183, 'destination': 6197, 'source_position': (-77537.72114460927, 684998.0703029373), 'destination_position': (-81818.20046849061, 683530.4864299865), 'source_neighbors': [6197, 6549], 'destination_neighbors': [6183, 6171], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 4525.075211123105}
# Forward sector for edge (6183, 6197): 4
# Backward sector for edge (6183, 6197): 0
#
# {'edge': (6183, 6549), 'source': 6183, 'destination': 6549, 'source_position': (-77537.72114460927, 684998.0703029373), 'destination_position': (-72890.3550429718, 690990.7442443849), 'source_neighbors': [6197, 6549], 'destination_neighbors': [6184, 6183], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 7583.54486049595}
# Forward sector for edge (6183, 6549): 1
# Backward sector for edge (6183, 6549): 5
#
# {'edge': (6190, 6202), 'source': 6190, 'destination': 6202, 'source_position': (-69221.37594591618, 701019.2676682686), 'destination_position': (-68976.77362879623, 703832.1643676325), 'source_neighbors': [6202, 6585], 'destination_neighbors': [6170, 6190, 6200], 'source_degree': 3, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 2823.511667203163}
# Forward sector for edge (6190, 6202): 2
# Backward sector for edge (6190, 6202): 6
#
# {'edge': (6190, 6585), 'source': 6190, 'destination': 6585, 'source_position': (-69221.37594591618, 701019.2676682686), 'destination_position': (-70199.76295049826, 703465.2583877346), 'source_neighbors': [6202, 6585], 'destination_neighbors': [6202, 6190, 6189], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 2634.4091805277553}
# Forward sector for edge (6190, 6585): 2
# Backward sector for edge (6190, 6585): 6
#
# {'edge': (6184, 6549), 'source': 6184, 'destination': 6549, 'source_position': (-69465.96713108728, 694904.3080180641), 'destination_position': (-72890.3550429718, 690990.7442443849), 'source_neighbors': [6549, 6190], 'destination_neighbors': [6184, 6183], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 5200.232108446218}
# Forward sector for edge (6184, 6549): 5
# Backward sector for edge (6184, 6549): 1
#
# {'edge': (6184, 6190), 'source': 6184, 'destination': 6190, 'source_position': (-69465.96713108728, 694904.3080180641), 'destination_position': (-69221.37594591618, 701019.2676682686), 'source_neighbors': [6549, 6190], 'destination_neighbors': [6184], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 6119.8493749023555}
# Forward sector for edge (6184, 6190): 2
# Backward sector for edge (6184, 6190): 6
#
# {'edge': (6192, 6556), 'source': 6192, 'destination': 6556, 'source_position': (-92825.1266277078, 715572.885109591), 'destination_position': (-93681.21803970465, 720954.0485041132), 'source_neighbors': [6556, 6193], 'destination_neighbors': [6192], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 5448.835837519902}
# Forward sector for edge (6192, 6556): 2
# Backward sector for edge (6192, 6556): 6
#
# {'edge': (6192, 6193), 'source': 6192, 'destination': 6193, 'source_position': (-92825.1266277078, 715572.885109591), 'destination_position': (-73624.15086238278, 716918.1763432152), 'source_neighbors': [6556, 6193], 'destination_neighbors': [6192, 6191], 'source_degree': 3, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 19248.046104575515}
# Forward sector for edge (6192, 6193): 0
# Backward sector for edge (6192, 6193): 4
#
# {'edge': (6189, 6585), 'source': 6189, 'destination': 6585, 'source_position': (-71300.45667961502, 703342.9505480125), 'destination_position': (-70199.76295049826, 703465.2583877346), 'source_neighbors': [6585], 'destination_neighbors': [6202, 6190, 6189], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 1107.4682356503265}
# Forward sector for edge (6189, 6585): 0
# Backward sector for edge (6189, 6585): 4
#
# {'edge': (6186, 7011), 'source': 6186, 'destination': 7011, 'source_position': (-74724.83345955035, 700530.0715766218), 'destination_position': (-73134.94622814267, 701875.3639990112), 'source_neighbors': [7011, 6188], 'destination_neighbors': [6186], 'source_degree': 5, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 2082.679310487211}
# Forward sector for edge (6186, 7011): 1
# Backward sector for edge (6186, 7011): 5
#
# {'edge': (6186, 6188), 'source': 6186, 'destination': 6188, 'source_position': (-74724.83345955035, 700530.0715766218), 'destination_position': (-73746.44645496838, 703709.8559885431), 'source_neighbors': [7011, 6188], 'destination_neighbors': [6175, 6186, 6181], 'source_degree': 5, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 3326.9009659189546}
# Forward sector for edge (6186, 6188): 2
# Backward sector for edge (6186, 6188): 6
#
# {'edge': (6176, 6196), 'source': 6176, 'destination': 6196, 'source_position': (-105055.0532405767, 689890.0412749045), 'destination_position': (-98450.89086587669, 678149.3170565078), 'source_neighbors': [6196, 6177, 6180], 'destination_neighbors': [6176, 6171], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 7, 'backward_sector': 3, 'distance': 13470.69284943615}
# Forward sector for edge (6176, 6196): 7
# Backward sector for edge (6176, 6196): 3
#
# {'edge': (6176, 6177), 'source': 6176, 'destination': 6177, 'source_position': (-105055.0532405767, 689890.0412749045), 'destination_position': (-95515.7075882323, 690501.5398618673), 'source_neighbors': [6196, 6177, 6180], 'destination_neighbors': [6175, 6176, 6171], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 9558.924939383069}
# Forward sector for edge (6176, 6177): 0
# Backward sector for edge (6176, 6177): 4
#
# {'edge': (6176, 6180), 'source': 6176, 'destination': 6180, 'source_position': (-105055.0532405767, 689890.0412749045), 'destination_position': (-102731.37018975778, 691969.1307246548), 'source_neighbors': [6196, 6177, 6180], 'destination_neighbors': [6178, 6174, 6176], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 3118.0307664816173}
# Forward sector for edge (6176, 6180): 1
# Backward sector for edge (6176, 6180): 5
#
# {'edge': (6175, 6177), 'source': 6175, 'destination': 6177, 'source_position': (-89523.04544035798, 703220.6615032485), 'destination_position': (-95515.7075882323, 690501.5398618673), 'source_neighbors': [6177, 6188], 'destination_neighbors': [6175, 6176, 6171], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 14060.158425381154}
# Forward sector for edge (6175, 6177): 5
# Backward sector for edge (6175, 6177): 1
#
# {'edge': (6175, 6188), 'source': 6175, 'destination': 6188, 'source_position': (-89523.04544035798, 703220.6615032485), 'destination_position': (-73746.44645496838, 703709.8559885431), 'source_neighbors': [6177, 6188], 'destination_neighbors': [6175, 6186, 6181], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 15784.181536913433}
# Forward sector for edge (6175, 6188): 0
# Backward sector for edge (6175, 6188): 4
#
# {'edge': (6178, 6180), 'source': 6178, 'destination': 6180, 'source_position': (-104810.45092345652, 691969.1307246548), 'destination_position': (-102731.37018975778, 691969.1307246548), 'source_neighbors': [6180, 6186, 6194], 'destination_neighbors': [6178, 6174, 6176], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 2079.0807336987345}
# Forward sector for edge (6178, 6180): 0
# Backward sector for edge (6178, 6180): 4
#
# {'edge': (6178, 6186), 'source': 6178, 'destination': 6186, 'source_position': (-104810.45092345652, 691969.1307246548), 'destination_position': (-74724.83345955035, 700530.0715766218), 'source_neighbors': [6180, 6186, 6194], 'destination_neighbors': [6182, 6181, 6178], 'source_degree': 3, 'destination_degree': 5, 'voltage': 380.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 31279.931049402498}
# Forward sector for edge (6178, 6186): 0
# Backward sector for edge (6178, 6186): 4
#
# {'edge': (6178, 6194), 'source': 6178, 'destination': 6194, 'source_position': (-104810.45092345652, 691969.1307246548), 'destination_position': (-93314.32012999884, 700530.0715766218), 'source_neighbors': [6180, 6186, 6194], 'destination_neighbors': [6178, 6185], 'source_degree': 3, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 14333.552647238741}
# Forward sector for edge (6178, 6194): 1
# Backward sector for edge (6178, 6194): 5
#
# {'edge': (6182, 6183), 'source': 6182, 'destination': 6183, 'source_position': (-78638.41487372603, 693314.4195593819), 'destination_position': (-77537.72114460927, 684998.0703029373), 'source_neighbors': [6183, 6186], 'destination_neighbors': [6182], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 8388.87308525309}
# Forward sector for edge (6182, 6183): 6
# Backward sector for edge (6182, 6183): 2
#
# {'edge': (6182, 6186), 'source': 6182, 'destination': 6186, 'source_position': (-78638.41487372603, 693314.4195593819), 'destination_position': (-74724.83345955035, 700530.0715766218), 'source_neighbors': [6183, 6186], 'destination_neighbors': [6182, 6181, 6178], 'source_degree': 2, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 8208.638956567656}
# Forward sector for edge (6182, 6186): 1
# Backward sector for edge (6182, 6186): 5
#
# {'edge': (6181, 6186), 'source': 6181, 'destination': 6186, 'source_position': (-71667.35458932047, 698450.9847294064), 'destination_position': (-74724.83345955035, 700530.0715766218), 'source_neighbors': [6186, 6188], 'destination_neighbors': [6182, 6181, 6178], 'source_degree': 2, 'destination_degree': 5, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 3697.401676876125}
# Forward sector for edge (6181, 6186): 3
# Backward sector for edge (6181, 6186): 7
#
# {'edge': (6181, 6188), 'source': 6181, 'destination': 6188, 'source_position': (-71667.35458932047, 698450.9847294064), 'destination_position': (-73746.44645496838, 703709.8559885431), 'source_neighbors': [6186, 6188], 'destination_neighbors': [6175, 6186, 6181], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 5654.9403096741335}
# Forward sector for edge (6181, 6188): 2
# Backward sector for edge (6181, 6188): 6
#
# {'edge': (6185, 6194), 'source': 6185, 'destination': 6194, 'source_position': (-73624.15086238278, 706522.7487227939), 'destination_position': (-93314.32012999884, 700530.0715766218), 'source_neighbors': [6194], 'destination_neighbors': [6178, 6185], 'source_degree': 1, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 20581.90820030117}
# Forward sector for edge (6185, 6194): 4
# Backward sector for edge (6185, 6194): 0

# %%
# Debugging to check the sectors around the node 6188

# Usage example
edge_details = {}
for edge in G.edges():
    # Check if the node 6188 is part of the edge
    if 6188 in edge:
        edge_details[edge] = get_edge_info(G, edge)
        print(edge_details[edge])
        
        forward = edge_details[edge].get('forward_sector')
        backward = edge_details[edge].get('backward_sector')
        print(f"Forward sector for edge {edge}: {forward}")
        print(f"Backward sector for edge {edge}: {backward}\n")
# Out:
# {'edge': (6188, 6198), 'source': 6188, 'destination': 6198, 'source_position': (-73746.44645496838, 703709.8559885431), 'destination_position': (-74357.946681794, 711414.718442685), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188, 6193], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 7729.090371101402}
# Forward sector for edge (6188, 6198): 2
# Backward sector for edge (6188, 6198): 6
#
# {'edge': (6188, 6189), 'source': 6188, 'destination': 6189, 'source_position': (-73746.44645496838, 703709.8559885431), 'destination_position': (-71300.45667961502, 703342.9505480125), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 2473.355126831597}
# Forward sector for edge (6188, 6189): 0
# Backward sector for edge (6188, 6189): 4
#
# {'edge': (6188, 6191), 'source': 6188, 'destination': 6191, 'source_position': (-73746.44645496838, 703709.8559885431), 'destination_position': (-71667.35458932047, 705544.3505209369), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 2772.7230613939564}
# Forward sector for edge (6188, 6191): 1
# Backward sector for edge (6188, 6191): 5
#
# {'edge': (6186, 6188), 'source': 6186, 'destination': 6188, 'source_position': (-74724.83345955035, 700530.0715766218), 'destination_position': (-73746.44645496838, 703709.8559885431), 'source_neighbors': [7011, 6188], 'destination_neighbors': [6175, 6186, 6181], 'source_degree': 5, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 3326.9009659189546}
# Forward sector for edge (6186, 6188): 2
# Backward sector for edge (6186, 6188): 6
#
# {'edge': (6175, 6188), 'source': 6175, 'destination': 6188, 'source_position': (-89523.04544035798, 703220.6615032485), 'destination_position': (-73746.44645496838, 703709.8559885431), 'source_neighbors': [6177, 6188], 'destination_neighbors': [6175, 6186, 6181], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 15784.181536913433}
# Forward sector for edge (6175, 6188): 0
# Backward sector for edge (6175, 6188): 4
#
# {'edge': (6181, 6188), 'source': 6181, 'destination': 6188, 'source_position': (-71667.35458932047, 698450.9847294064), 'destination_position': (-73746.44645496838, 703709.8559885431), 'source_neighbors': [6186, 6188], 'destination_neighbors': [6175, 6186, 6181], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 5654.9403096741335}
# Forward sector for edge (6181, 6188): 2
# Backward sector for edge (6181, 6188): 6

# %% [markdown]
# Create Dictionary of initial lengths of each edge

# %%
initial_lengths = {}

for edge in G.edges():
    edge_info = get_edge_info(G, edge)  # Retrieve edge information

    # Assuming the 'get_edge_info' function returns a dictionary with the positions
    node1_pos = edge_info.get('source_position')  # Source position (x, y)
    node2_pos = edge_info.get('destination_position')  # Destination position (x, y)

    # Calculate the Euclidean distance between node1 and node2
    distance = euclidean_distance(node1_pos[0], node1_pos[1], node2_pos[0], node2_pos[1])

    # Store the distance in the initial_lengths dictionary using the edge as the key
    initial_lengths[edge] = distance

print(initial_lengths)
# Out:
# {(6172, 6173): 2998.204575460285, (6172, 6201): 1472.6712345925976, (6173, 7705): 1699.0309017203797, (6188, 6198): 7729.090371101402, (6188, 6189): 2473.355126831597, (6188, 6191): 2772.7230613939564, (6193, 6198): 5552.1622065186075, (6193, 6398): 6501.441439608288, (6194, 6199): 2815.554770545278, (6174, 6199): 3983.645579803766, (6174, 6180): 11843.4588504396, (6174, 6192): 13899.146018798936, (6191, 6200): 1960.60283566856, (6191, 6193): 11540.925677336052, (6200, 6202): 1975.795349187747, (6170, 6200): 1594.5835817988893, (6170, 6202): 1914.2815700051822, (6201, 7705): 3067.2473958788414, (6171, 6201): 4109.322177735886, (6171, 6197): 11835.246510989517, (6171, 6196): 5742.862554278349, (6171, 6177): 10028.53209601594, (6171, 7705): 2701.6843209945364, (6202, 6585): 1276.8409764265766, (6183, 6197): 4525.075211123105, (6183, 6549): 7583.54486049595, (6190, 6202): 2823.511667203163, (6190, 6585): 2634.4091805277553, (6184, 6549): 5200.232108446218, (6184, 6190): 6119.8493749023555, (6192, 6556): 5448.835837519902, (6192, 6193): 19248.046104575515, (6189, 6585): 1107.4682356503265, (6186, 7011): 2082.679310487211, (6186, 6188): 3326.9009659189546, (6176, 6196): 13470.69284943615, (6176, 6177): 9558.924939383069, (6176, 6180): 3118.0307664816173, (6175, 6177): 14060.158425381154, (6175, 6188): 15784.181536913433, (6178, 6180): 2079.0807336987345, (6178, 6186): 31279.931049402498, (6178, 6194): 14333.552647238741, (6182, 6183): 8388.87308525309, (6182, 6186): 8208.638956567656, (6181, 6186): 3697.401676876125, (6181, 6188): 5654.9403096741335, (6185, 6194): 20581.90820030117}

# %% [markdown]
# # Functions - Optimisation

# %% [markdown]
# ### Octilinearity Constraints Functions
# - Getting Dynamic Minimum Edge Length

# %%
# to get dynamic min length 
# Minimum length percentage
def calculate_dynamic_min_lengths(G, min_length_horizontal, min_length_diagonal):
    # Dictionary to store dynamic minimum lengths for each edge
    dynamic_min_lengths = {}

    for edge in G.edges():
        edge_info = get_edge_info(G, edge)

        forward = edge_info.get('forward_sector')
        backward = edge_info.get('backward_sector')

        if forward in (1, 3, 5, 7) or backward in (1, 3, 5, 7):
            # Use the diagonal minimum length for diagonal edges
            #dynamic_min_length = edge_info['distance'] * min_length_diagonal
            dynamic_min_length = 1400
        else:
            # Use the horizontal minimum length for horizontal/vertical edges
            #dynamic_min_length = edge_info['distance'] * min_length_horizontal
            dynamic_min_length = 1400

        # Store the calculated dynamic minimum length in the dictionary
        dynamic_min_lengths[edge] = dynamic_min_length

    return dynamic_min_lengths
    
    
dynamic_min_lengths = calculate_dynamic_min_lengths(G, 0.2, 0.22)


print(dynamic_min_lengths)
# Out:
# {(6172, 6173): 1400, (6172, 6201): 1400, (6173, 7705): 1400, (6188, 6198): 1400, (6188, 6189): 1400, (6188, 6191): 1400, (6193, 6198): 1400, (6193, 6398): 1400, (6194, 6199): 1400, (6174, 6199): 1400, (6174, 6180): 1400, (6174, 6192): 1400, (6191, 6200): 1400, (6191, 6193): 1400, (6200, 6202): 1400, (6170, 6200): 1400, (6170, 6202): 1400, (6201, 7705): 1400, (6171, 6201): 1400, (6171, 6197): 1400, (6171, 6196): 1400, (6171, 6177): 1400, (6171, 7705): 1400, (6202, 6585): 1400, (6183, 6197): 1400, (6183, 6549): 1400, (6190, 6202): 1400, (6190, 6585): 1400, (6184, 6549): 1400, (6184, 6190): 1400, (6192, 6556): 1400, (6192, 6193): 1400, (6189, 6585): 1400, (6186, 7011): 1400, (6186, 6188): 1400, (6176, 6196): 1400, (6176, 6177): 1400, (6176, 6180): 1400, (6175, 6177): 1400, (6175, 6188): 1400, (6178, 6180): 1400, (6178, 6186): 1400, (6178, 6194): 1400, (6182, 6183): 1400, (6182, 6186): 1400, (6181, 6186): 1400, (6181, 6188): 1400, (6185, 6194): 1400}

# %% [markdown]
# ### Circular Vertex Order Constraints Functions

# %%
## Function to get index of nodes in the ordered neighbours list.

# This function initializes the set of (node, index) pairs, where 'node' is a node with 2 or more neighbors,
# and 'index' is a unique integer (starting from 1) representing the position of a neighbor in the
# counterclockwise ordering of neighbors around 'node'.

def node_neighbour_index_pairs_init(model):
    node_index_pairs = []
    for node, neighbors in ordered_neighbours_dict.items():
        # Start index from 0 for each node's neighbors
        for idx in range(0, len(neighbors)):
            node_index_pairs.append((node, idx))
    return node_index_pairs



## Helper Function for the circular vertex order
## Determines if node with more than 2 neighbours is the source or destination node
## So the correct direction can be assigned to it

def directional_sector(model, node, neighbor):
    if (node, neighbor) in model.Edges:
        return model.dir_forward[node, neighbor]
    elif (neighbor, node) in model.Edges:
        return model.dir_backward[neighbor, node]
    else:
        return None  # This case should ideally never happen if the graph is well-defined

# %% [markdown]
# ### Edge Spacing Constraints Functions
# Gets list of intersecting edges and new list of non intersecting non incident edges created

# %%
def list_edge_intersections(G):
    intersecting_edge_pairs = []
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect
        if line1.intersects(line2):
            # If they intersect, add the edge pair to the list
            intersecting_edge_pairs.append((edge1, edge2))

    return intersecting_edge_pairs

# Call the function to get intersecting edge pairs
intersecting_edges = list_edge_intersections(G)

# Print the intersecting edge pairs
for edge_pair in intersecting_edges:
    print(f"Intersecting Edge Pair: {edge_pair}")
# Out:
# Intersecting Edge Pair: ((6188, 6198), (6185, 6194))
# Intersecting Edge Pair: ((6174, 6180), (6178, 6186))
# Intersecting Edge Pair: ((6174, 6180), (6178, 6194))
# Intersecting Edge Pair: ((6175, 6177), (6178, 6186))
# Intersecting Edge Pair: ((6175, 6177), (6185, 6194))
# Intersecting Edge Pair: ((6175, 6188), (6185, 6194))

# %%
# Create a new list excluding intersecting edge pairs
non_intersecting_non_incident_edges = [edge_pair for edge_pair in non_incident_edge_pairs if edge_pair not in intersecting_edges]

# Print the new list of non-intersecting, non-incident edge pairs
for edge_pair in non_intersecting_non_incident_edges:
    print(f"Non-Intersecting Non-Incident Edge Pair: {edge_pair}")
# Out:
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6173), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6173, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6172, 6201), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6173, 7705), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6194, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6174, 6199))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6191, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6191, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6200), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6200, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6170, 6200))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6170, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6191, 6193), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6200, 6202), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6200), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6201, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6171, 6201))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6171, 7705))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6170, 6202), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6171, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6171, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6171, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6201, 7705), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6183, 6197))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6201), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6202, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6183, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6171, 6197), (6182, 6183))
# ...
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6197), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6190, 6202))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6190, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6184, 6190))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6183, 6549), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6202), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6184, 6549))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6190, 6585), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6549), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6184, 6190), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6189, 6585))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6186, 7011))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6189, 6585), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 7011), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6176, 6196))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6196), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6186), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6186), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6186), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6182, 6183))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6183), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6183), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6183), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6186), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6186), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6181, 6186), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6181, 6188), (6185, 6194))

# %% [markdown]
# # Optimisation

# %% [markdown]
# ## Variables and Parameters

# %%
model = ConcreteModel()



""" print(list(G.nodes()))
print(list(G.edges())) """
# Set used to index the other components eg Param and Var, and to define the scope
model.Nodes = Set(initialize = list(G.nodes()))
model.Edges = Set(initialize = list(G.edges()))

# Initialize set of non-incident edge pairs
# dimen = 4: creates a collection of edge pairs where each pair is treated as a single tuple, 2 integers per edge
model.NonIncidentEdges = Set(initialize = non_incident_edge_pairs, dimen=4)
model.NonIntersecting_NonIncidentEdges = Set(initialize = non_intersecting_non_incident_edges, dimen=4)
model.IntersectingEdgePairs = Set(initialize = intersecting_edges, dimen = 4)


# Set with 2 or more neighbours
# Storing set nodes with 2 or more neighbours that were predetermined in the dictionary
model.NodesWith2Neighbours = Set(initialize = ordered_neighbours_dict.keys())


# Initialize the set with the function that provides the (node, index) pairs
model.NodeNeighbours2IndexPairs = Set(dimen=2, initialize=node_neighbour_index_pairs_init)





### PARAM ###
## Param - fixed value in model that doesn't change during optimisation process ##
# pos defined earlier as tuple (x, y) in graph G
model.x_init = Param(model.Nodes, initialize={node: pos[node][0] for node in G.nodes()})
model.y_init = Param(model.Nodes, initialize={node: pos[node][1] for node in G.nodes()})


# Access information from dictionary of the edge info
edge_info = {edge: get_edge_info(G, edge) for edge in G.edges()}

# Initialize Params for static attributes from the edges
model.voltage = Param(model.Edges, initialize={edge: edge_info[edge]['voltage'] for edge in model.Edges})
model.sect_forward = Param(model.Edges, initialize={edge: edge_info[edge]['forward_sector'] for edge in model.Edges})
model.sect_backward = Param(model.Edges, initialize={edge: edge_info[edge]['backward_sector'] for edge in model.Edges})
model.distance = Param(model.Edges, initialize={edge: edge_info[edge]['distance'] for edge in model.Edges} )
#model.non_incident_edges = Param(model.Edges, initialize = {edge: edge_info[edge]['non_incident_edges'] for edge in model.Edges} )


# Param to store the ordered neighbors for each node in the model
model.OrderedNeighbours = Param(
    model.NodesWith2Neighbours,  # Index set for the Param, representing nodes with 2 or more neighbors
    within=Any,  # Specifies that the Param can hold any type of data, in this case, tuples of nodes
    initialize=lambda model, node: tuple(ordered_neighbours_dict[node])  # Initialization function
    # lambda function takes 2 arguments model and node (element from set Nodewith2Neigbours)
    # for each node, it gets the list or ordered neighbours from the dictionary
    # list is converted to tuple so that for Param, the contents are unchangeable
)
   





### VARIABLES ###
## Define Variables ##
model.x_pos = Var(model.Nodes, within = Reals, initialize = model.x_init)
model.y_pos = Var(model.Nodes, within = Reals, initialize = model.y_init)

model.z1_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] + model.y_pos[node])
model.z2_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] - model.y_pos[node])


model.dir_forward = Var(model.Edges, within = Integers, bounds = (0, 7))
model.dir_backward = Var(model.Edges, within = Integers, bounds = (0, 7))


# Binary variable for octilinear constraint to determine where edge is drawn
model.alpha_pred = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_orig = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_succ = Var(model.Edges, within = Binary, bounds = (0, 1))


# Binary Variable for non-incident edge constraint
model.is_N = Var(model.NonIncidentEdges, within=Binary)
model.is_S = Var(model.NonIncidentEdges, within=Binary)
model.is_E = Var(model.NonIncidentEdges, within=Binary)
model.is_W = Var(model.NonIncidentEdges, within=Binary)
model.is_NE = Var(model.NonIncidentEdges, within=Binary)
model.is_NW = Var(model.NonIncidentEdges, within=Binary)
model.is_SE = Var(model.NonIncidentEdges, within=Binary)
model.is_SW = Var(model.NonIncidentEdges, within=Binary)

model.delta_pred = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_orig = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_succ = Var(model.Edges, within = Integers, bounds = (0, 7))


max_degree = max(len(neighbors) for neighbors in ordered_neighbours_dict.values())


# Define Beta as a binary variable indexed by the (node, index) pairs
# Beta[node, idx] will be used in the constraints to identify the "wrap-around" point
# in the counterclockwise ordering of neighbors around each node
model.Beta = Var(model.NodeNeighbours2IndexPairs, within=Binary)




# Redefine rpos as a continuous variable representing the deviation magnitude
model.rpos = Var(model.Edges, within=NonNegativeReals)


model.dev_pos = Var(model.Edges, within=NonNegativeReals)
model.dev_neg = Var(model.Edges, within=NonNegativeReals)

tolerance = 0.01






model.min_dist_x_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_x_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_y_pos = Var(model.IntersectingEdgePairs, within=NonNegativeReals)
model.min_dist_y_neg = Var(model.IntersectingEdgePairs, within=NonNegativeReals)










# Lower and upper bound factors
lower_bound_factor = 0.5  # e.g., 50% of the initial length
upper_bound_factor = 4  # e.g., 150% of the initial length

# Lower absolute threshold for very short edges
absolute_lower_threshold = 500  # Some unit length that makes sense for your graph's scale

# Define min_length as a variable for each edge
model.min_length = Var(model.Edges, within=NonNegativeReals, initialize=initial_lengths,
                       bounds=lambda model, u, v: (
                           max(absolute_lower_threshold, initial_lengths[u, v] * lower_bound_factor),
                           initial_lengths[u, v] * upper_bound_factor))

# %%
""" # Define a ConstraintList for spacing constraints
model.EdgeSpacingConstraints = ConstraintList()

dmin = 50  # Minimum spacing distance, as an example

# Define the constraints
def enforce_minimum_spacing(model, u1, v1, u2, v2):
    # Constraints for node u2 to be at least dmin away from nodes u1 and v1
    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[u2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[u2] >= dmin)

    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[u2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[u2] >= dmin) 

    # Constraints for node v2 to be at least dmin away from nodes u1 and v1
    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[v2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[u1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[v2] >= dmin)

    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[v2] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[v1] >= dmin)
    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[v2] >= dmin) 

# Adding the constraints to the model for each pair of intersecting edges
for (u1, v1, u2, v2) in model.IntersectingEdgePairs:
    enforce_minimum_spacing(model, u1, v1, u2, v2)
 """
# Out:
# ' # Define a ConstraintList for spacing constraints\nmodel.EdgeSpacingConstraints = ConstraintList()\n\ndmin = 50  # Minimum spacing distance, as an example\n\n# Define the constraints\ndef enforce_minimum_spacing(model, u1, v1, u2, v2):\n    # Constraints for node u2 to be at least dmin away from nodes u1 and v1\n    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[u2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[u2] >= dmin)\n\n    model.EdgeSpacingConstraints.add(model.x_pos[u2] - model.x_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[u2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u2] - model.y_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[u2] >= dmin) \n\n    # Constraints for node v2 to be at least dmin away from nodes u1 and v1\n    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[u1] - model.x_pos[v2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[u1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[u1] - model.y_pos[v2] >= dmin)\n\n    model.EdgeSpacingConstraints.add(model.x_pos[v2] - model.x_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.x_pos[v1] - model.x_pos[v2] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v2] - model.y_pos[v1] >= dmin)\n    model.EdgeSpacingConstraints.add(model.y_pos[v1] - model.y_pos[v2] >= dmin) \n\n# Adding the constraints to the model for each pair of intersecting edges\nfor (u1, v1, u2, v2) in model.IntersectingEdgePairs:\n    enforce_minimum_spacing(model, u1, v1, u2, v2)\n '

# %% [markdown]
# ## Octilinearity Constraint

# %%
# Sum of Binary variables is equal to 1
# node1 and node2 are the src and dst nodes defined in model.Edges
def alpha_direction_constraint(model, node1, node2):
    return model.alpha_pred[node1, node2] + model.alpha_orig[node1, node2] + model.alpha_succ[node1, node2] == 1
model.alpha_direction_constraint = Constraint(model.Edges, rule = alpha_direction_constraint)


 
 # for each edge in tuple (node1, node2) in model.Edges, dir constraint is called and formed
def dir_forward_constraint(model, node1, node2):
    
    
    sect_forward_pred = (model.sect_forward[node1, node2] - 1) % 8
    sect_forward_orig = model.sect_forward[node1, node2]
    sect_forward_succ = (model.sect_forward[node1, node2] + 1) % 8
    
     # Debugging: Print the values of sectors and binary variables
    """ print(f"Edge: {(node1, node2)}")
    print(f"sect_forward_pred: {sect_forward_pred}, sect_forward_orig: {sect_forward_orig}, sect_forward_succ: {sect_forward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}") """
    
    
    
    return model.dir_forward[node1, node2] == ((sect_forward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_forward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_forward_succ * model.alpha_succ[node1, node2])
                                        )

model.DirForwardConstraint = Constraint(model.Edges, rule=dir_forward_constraint)
 

def dir_backward_constraint(model, node1, node2):
    sect_backward_pred = (model.sect_backward[node1, node2] - 1) % 8
    sect_backward_orig = model.sect_backward[node1, node2]
    sect_backward_succ = (model.sect_backward[node1, node2] + 1) % 8
    
      # Debugging: Print the values of sectors and binary variables
    """ print(f"Edge: {(node1, node2)}")
    print(f"sect_backward_pred: {sect_backward_pred}, sect_backward_orig: {sect_backward_orig}, sect_backward_succ: {sect_backward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}")  """
    
    return model.dir_backward[node1, node2] == ((sect_backward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_backward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_backward_succ * model.alpha_succ[node1, node2])
                                        )
    
model.DirBackwardConstraint = Constraint(model.Edges, rule = dir_backward_constraint) 




 
def sector_constraints_rule(model, node1, node2):

    # Retrieve original sector and minimum edge length
    sect_orig = model.sect_forward[node1, node2]
    min_length = 1400 #dynamic_min_lengths[(node1, node2)] #(model.distance[node1, node2])*0.1  #1000
    #min_length = model.min_length[node1, node2]
    
    
    # Define a large constant M for making constraints trivial when not active
    M = 30000  # Adjust as needed

    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_adjusted = (sect_orig + adjustment) % 8

        # Conditions based on adjusted sector
        if sect_adjusted in [0, 4]:  # Horizontal
            model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.y_pos[node1] + model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            
            if sect_adjusted == 0:
                # For sector 0, node1 should be to the left of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node2] - model.x_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
                
                """ model.sector_constraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance) """
                
                
                
                
                
            elif sect_adjusted == 4:
                # For sector 4, node1 should be to the right of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))
                
                """ model.sector_constraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
         """
        
        elif sect_adjusted in [2, 6]:  # Vertical
            # Add corresponding constraints for this sector
            model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.x_pos[node1] + model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            
            if sect_adjusted == 2:  # Upwards
                # Node2's y_pos should be at least min_length above Node1's y_pos
                model.sector_constraints.add(model.y_pos[node2] - model.y_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
                """ 
                model.sector_constraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
                """
            
            
            
            
            elif sect_adjusted == 6:  # Downwards
                # Node2's y_pos should be at least min_length below Node1's y_pos
                model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))

                """ model.sector_constraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
                model.sector_constraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance) """
        





        elif sect_adjusted == 1:         #upright diagonal /
            # dx = dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) - (model.x_pos[node2] - model.x_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # dx + dy >= min length of diagonal
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))
            
            """ model.sector_constraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance) """
        
            
        elif sect_adjusted == 5:        # Diagonal downwards /
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # -dx - dy >= min length
            # negative diagonal
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))


            """ model.sector_constraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance) """
        
            


            
        ## Diagonal \
            
        elif sect_adjusted == 3:    # Up left diagonal \
            # -dx = dy
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dx is negative
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) <= 0)
            
            # -dx + dy >= min length (dx is negative value)
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            
            
            """ model.sector_constraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
         """
            
            
        elif sect_adjusted == 7:    # Down right Diagonal \
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dy is negative
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) <= 0)
        
            # dx - dy >= min length (since dy is negative, we use -dy)
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            """ 
            model.sector_constraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.sector_constraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            """




       



       
            # Fill in your constraints similar to above
    return Constraint.Skip 

# Initialize the constraint list on your model if not already done
model.sector_constraints = ConstraintList()

# Apply the rule to each edge
model.SectorConstraint = Constraint(model.Edges, rule=sector_constraints_rule)

# %% [markdown]
# ## Circular Vertex Order
# The initial circular ordering of neighbour nodes (counterclockwise) should be the same after optimisation.
#
# For each node in the map, the sequence in which the neighbouring nodes are arranged around a particular node should match the order in which the neighbouring nodes are arranged in the final layout.

# %%
# Beta Binary Sum Constraint


def beta_sum_constraint_rule(model, node):
    # Ensure we use 0-based indexing to match the updated indexing in Beta
    # Note that RangeSet in Pyomo starts from 1, so we adjust the range accordingly
    return sum(model.Beta[node, index] for index in range(0, len(model.OrderedNeighbours[node]) )) == 1

model.BetaSumConstraint = Constraint(model.NodesWith2Neighbours, rule=beta_sum_constraint_rule)




# Define the ConstraintList in your Pyomo model
model.OrderMaintenanceConstraints = ConstraintList()


def add_order_maintenance_constraints(model):
    for node, neighbours in ordered_neighbours_dict.items():
        num_neighbours = len(neighbours)
        
        
        for index in range(num_neighbours):
            print(index)
            # Handle all neighbor pairs except the last pair (which wraps around)
            if index < num_neighbours - 1:
                next_index = index + 1
            else:
                next_index = 0      # wrap around case
                
                
            # Use the helper function to dynamically select dir_forward or dir_backward
            dir_sect = directional_sector(model, node, neighbours[index])
            next_dir_sect = directional_sector(model, node, neighbours[next_index])
            
            # Debugging prints before adding the constraint
            print(f"Node: {node}, Neighbour: {neighbours[index]}, Directional Sector: {dir_sect}")
            print(f"Node: {node}, Next Neighbour: {neighbours[next_index]}, Next Directional Sector: {next_dir_sect}")
            if index == num_neighbours - 1:  # For wrap-around case
                print(f"\nNode: {node}, Index: {index}, Beta: {model.Beta[node, index].value if model.Beta[node, index].value is not None else 'Not solved yet'}")

            
            
            if dir_sect is not None and next_dir_sect is not None:
                    model.OrderMaintenanceConstraints.add(dir_sect <= next_dir_sect - 1 + 8*model.Beta[node, index])

                

            
           
# Call the function to add the constraints to the ConstraintList
add_order_maintenance_constraints(model)
# Out:
# 0
# Node: 6172, Neighbour: 6201, Directional Sector: dir_forward[6172,6201]
# Node: 6172, Next Neighbour: 6173, Next Directional Sector: dir_forward[6172,6173]
# 1
# Node: 6172, Neighbour: 6173, Directional Sector: dir_forward[6172,6173]
# Node: 6172, Next Neighbour: 6201, Next Directional Sector: dir_forward[6172,6201]
#
# Node: 6172, Index: 1, Beta: Not solved yet
# 0
# Node: 6173, Neighbour: 6172, Directional Sector: dir_backward[6172,6173]
# Node: 6173, Next Neighbour: 7705, Next Directional Sector: dir_forward[6173,7705]
# 1
# Node: 6173, Neighbour: 7705, Directional Sector: dir_forward[6173,7705]
# Node: 6173, Next Neighbour: 6172, Next Directional Sector: dir_backward[6172,6173]
#
# Node: 6173, Index: 1, Beta: Not solved yet
# 0
# Node: 6188, Neighbour: 6189, Directional Sector: dir_forward[6188,6189]
# Node: 6188, Next Neighbour: 6191, Next Directional Sector: dir_forward[6188,6191]
# 1
# Node: 6188, Neighbour: 6191, Directional Sector: dir_forward[6188,6191]
# Node: 6188, Next Neighbour: 6198, Next Directional Sector: dir_forward[6188,6198]
# 2
# Node: 6188, Neighbour: 6198, Directional Sector: dir_forward[6188,6198]
# Node: 6188, Next Neighbour: 6175, Next Directional Sector: dir_backward[6175,6188]
# 3
# Node: 6188, Neighbour: 6175, Directional Sector: dir_backward[6175,6188]
# Node: 6188, Next Neighbour: 6186, Next Directional Sector: dir_backward[6186,6188]
# 4
# Node: 6188, Neighbour: 6186, Directional Sector: dir_backward[6186,6188]
# Node: 6188, Next Neighbour: 6181, Next Directional Sector: dir_backward[6181,6188]
# 5
# Node: 6188, Neighbour: 6181, Directional Sector: dir_backward[6181,6188]
# Node: 6188, Next Neighbour: 6189, Next Directional Sector: dir_forward[6188,6189]
#
# Node: 6188, Index: 5, Beta: Not solved yet
# 0
# Node: 6198, Neighbour: 6193, Directional Sector: dir_backward[6193,6198]
# Node: 6198, Next Neighbour: 6188, Next Directional Sector: dir_backward[6188,6198]
# 1
# Node: 6198, Neighbour: 6188, Directional Sector: dir_backward[6188,6198]
# Node: 6198, Next Neighbour: 6193, Next Directional Sector: dir_backward[6193,6198]
#
# Node: 6198, Index: 1, Beta: Not solved yet
# 0
# Node: 6193, Neighbour: 6398, Directional Sector: dir_forward[6193,6398]
# Node: 6193, Next Neighbour: 6192, Next Directional Sector: dir_backward[6192,6193]
# 1
# Node: 6193, Neighbour: 6192, Directional Sector: dir_backward[6192,6193]
# Node: 6193, Next Neighbour: 6198, Next Directional Sector: dir_forward[6193,6198]
# 2
# Node: 6193, Neighbour: 6198, Directional Sector: dir_forward[6193,6198]
# Node: 6193, Next Neighbour: 6191, Next Directional Sector: dir_backward[6191,6193]
# 3
# Node: 6193, Neighbour: 6191, Directional Sector: dir_backward[6191,6193]
# Node: 6193, Next Neighbour: 6398, Next Directional Sector: dir_forward[6193,6398]
#
# Node: 6193, Index: 3, Beta: Not solved yet
# 0
# Node: 6194, Neighbour: 6185, Directional Sector: dir_backward[6185,6194]
# Node: 6194, Next Neighbour: 6199, Next Directional Sector: dir_forward[6194,6199]
# 1
# Node: 6194, Neighbour: 6199, Directional Sector: dir_forward[6194,6199]
# Node: 6194, Next Neighbour: 6178, Next Directional Sector: dir_backward[6178,6194]
# 2
# Node: 6194, Neighbour: 6178, Directional Sector: dir_backward[6178,6194]
# Node: 6194, Next Neighbour: 6185, Next Directional Sector: dir_backward[6185,6194]
#
# Node: 6194, Index: 2, Beta: Not solved yet
# 0
# Node: 6199, Neighbour: 6194, Directional Sector: dir_backward[6194,6199]
# Node: 6199, Next Neighbour: 6174, Next Directional Sector: dir_backward[6174,6199]
# 1
# Node: 6199, Neighbour: 6174, Directional Sector: dir_backward[6174,6199]
# Node: 6199, Next Neighbour: 6194, Next Directional Sector: dir_backward[6194,6199]
#
# Node: 6199, Index: 1, Beta: Not solved yet
# 0
# Node: 6174, Neighbour: 6199, Directional Sector: dir_forward[6174,6199]
# Node: 6174, Next Neighbour: 6192, Next Directional Sector: dir_forward[6174,6192]
# 1
# Node: 6174, Neighbour: 6192, Directional Sector: dir_forward[6174,6192]
# Node: 6174, Next Neighbour: 6180, Next Directional Sector: dir_forward[6174,6180]
# 2
# Node: 6174, Neighbour: 6180, Directional Sector: dir_forward[6174,6180]
# Node: 6174, Next Neighbour: 6199, Next Directional Sector: dir_forward[6174,6199]
#
# Node: 6174, Index: 2, Beta: Not solved yet
# 0
# Node: 6191, Neighbour: 6200, Directional Sector: dir_forward[6191,6200]
# Node: 6191, Next Neighbour: 6193, Next Directional Sector: dir_forward[6191,6193]
# 1
# Node: 6191, Neighbour: 6193, Directional Sector: dir_forward[6191,6193]
# Node: 6191, Next Neighbour: 6188, Next Directional Sector: dir_backward[6188,6191]
# 2
# Node: 6191, Neighbour: 6188, Directional Sector: dir_backward[6188,6191]
# Node: 6191, Next Neighbour: 6200, Next Directional Sector: dir_forward[6191,6200]
#
# Node: 6191, Index: 2, Beta: Not solved yet
# 0
# Node: 6200, Neighbour: 6170, Directional Sector: dir_backward[6170,6200]
# Node: 6200, Next Neighbour: 6191, Next Directional Sector: dir_backward[6191,6200]
# 1
# Node: 6200, Neighbour: 6191, Directional Sector: dir_backward[6191,6200]
# Node: 6200, Next Neighbour: 6202, Next Directional Sector: dir_forward[6200,6202]
# 2
# Node: 6200, Neighbour: 6202, Directional Sector: dir_forward[6200,6202]
# Node: 6200, Next Neighbour: 6170, Next Directional Sector: dir_backward[6170,6200]
#
# Node: 6200, Index: 2, Beta: Not solved yet
# 0
# Node: 6170, Neighbour: 6200, Directional Sector: dir_forward[6170,6200]
# Node: 6170, Next Neighbour: 6202, Next Directional Sector: dir_forward[6170,6202]
# 1
# Node: 6170, Neighbour: 6202, Directional Sector: dir_forward[6170,6202]
# Node: 6170, Next Neighbour: 6200, Next Directional Sector: dir_forward[6170,6200]
#
# Node: 6170, Index: 1, Beta: Not solved yet
# 0
# Node: 6201, Neighbour: 6171, Directional Sector: dir_backward[6171,6201]
# Node: 6201, Next Neighbour: 7705, Next Directional Sector: dir_forward[6201,7705]
# 1
# Node: 6201, Neighbour: 7705, Directional Sector: dir_forward[6201,7705]
# Node: 6201, Next Neighbour: 6172, Next Directional Sector: dir_backward[6172,6201]
# 2
# Node: 6201, Neighbour: 6172, Directional Sector: dir_backward[6172,6201]
# Node: 6201, Next Neighbour: 6171, Next Directional Sector: dir_backward[6171,6201]
#
# Node: 6201, Index: 2, Beta: Not solved yet
# 0
# Node: 6171, Neighbour: 6197, Directional Sector: dir_forward[6171,6197]
# Node: 6171, Next Neighbour: 6177, Next Directional Sector: dir_forward[6171,6177]
# 1
# Node: 6171, Neighbour: 6177, Directional Sector: dir_forward[6171,6177]
# Node: 6171, Next Neighbour: 6196, Next Directional Sector: dir_forward[6171,6196]
# 2
# Node: 6171, Neighbour: 6196, Directional Sector: dir_forward[6171,6196]
# Node: 6171, Next Neighbour: 7705, Next Directional Sector: dir_forward[6171,7705]
# 3
# Node: 6171, Neighbour: 7705, Directional Sector: dir_forward[6171,7705]
# Node: 6171, Next Neighbour: 6201, Next Directional Sector: dir_forward[6171,6201]
# 4
# Node: 6171, Neighbour: 6201, Directional Sector: dir_forward[6171,6201]
# Node: 6171, Next Neighbour: 6197, Next Directional Sector: dir_forward[6171,6197]
#
# Node: 6171, Index: 4, Beta: Not solved yet
# 0
# Node: 6202, Neighbour: 6170, Directional Sector: dir_backward[6170,6202]
# Node: 6202, Next Neighbour: 6200, Next Directional Sector: dir_backward[6200,6202]
# 1
# Node: 6202, Neighbour: 6200, Directional Sector: dir_backward[6200,6202]
# Node: 6202, Next Neighbour: 6585, Next Directional Sector: dir_forward[6202,6585]
# 2
# Node: 6202, Neighbour: 6585, Directional Sector: dir_forward[6202,6585]
# Node: 6202, Next Neighbour: 6190, Next Directional Sector: dir_backward[6190,6202]
# 3
# Node: 6202, Neighbour: 6190, Directional Sector: dir_backward[6190,6202]
# Node: 6202, Next Neighbour: 6170, Next Directional Sector: dir_backward[6170,6202]
#
# Node: 6202, Index: 3, Beta: Not solved yet
# 0
# Node: 6183, Neighbour: 6549, Directional Sector: dir_forward[6183,6549]
# Node: 6183, Next Neighbour: 6182, Next Directional Sector: dir_backward[6182,6183]
# 1
# Node: 6183, Neighbour: 6182, Directional Sector: dir_backward[6182,6183]
# Node: 6183, Next Neighbour: 6197, Next Directional Sector: dir_forward[6183,6197]
# 2
# Node: 6183, Neighbour: 6197, Directional Sector: dir_forward[6183,6197]
# Node: 6183, Next Neighbour: 6549, Next Directional Sector: dir_forward[6183,6549]
#
# Node: 6183, Index: 2, Beta: Not solved yet
# 0
# Node: 6197, Neighbour: 6183, Directional Sector: dir_backward[6183,6197]
# Node: 6197, Next Neighbour: 6171, Next Directional Sector: dir_backward[6171,6197]
# 1
# Node: 6197, Neighbour: 6171, Directional Sector: dir_backward[6171,6197]
# Node: 6197, Next Neighbour: 6183, Next Directional Sector: dir_backward[6183,6197]
#
# Node: 6197, Index: 1, Beta: Not solved yet
# 0
# Node: 6190, Neighbour: 6202, Directional Sector: dir_forward[6190,6202]
# Node: 6190, Next Neighbour: 6585, Next Directional Sector: dir_forward[6190,6585]
# 1
# Node: 6190, Neighbour: 6585, Directional Sector: dir_forward[6190,6585]
# Node: 6190, Next Neighbour: 6184, Next Directional Sector: dir_backward[6184,6190]
# 2
# Node: 6190, Neighbour: 6184, Directional Sector: dir_backward[6184,6190]
# Node: 6190, Next Neighbour: 6202, Next Directional Sector: dir_forward[6190,6202]
#
# Node: 6190, Index: 2, Beta: Not solved yet
# 0
# Node: 6184, Neighbour: 6190, Directional Sector: dir_forward[6184,6190]
# Node: 6184, Next Neighbour: 6549, Next Directional Sector: dir_forward[6184,6549]
# 1
# Node: 6184, Neighbour: 6549, Directional Sector: dir_forward[6184,6549]
# Node: 6184, Next Neighbour: 6190, Next Directional Sector: dir_forward[6184,6190]
#
# Node: 6184, Index: 1, Beta: Not solved yet
# 0
# Node: 6549, Neighbour: 6184, Directional Sector: dir_backward[6184,6549]
# Node: 6549, Next Neighbour: 6183, Next Directional Sector: dir_backward[6183,6549]
# 1
# Node: 6549, Neighbour: 6183, Directional Sector: dir_backward[6183,6549]
# Node: 6549, Next Neighbour: 6184, Next Directional Sector: dir_backward[6184,6549]
#
# Node: 6549, Index: 1, Beta: Not solved yet
# 0
# Node: 6192, Neighbour: 6193, Directional Sector: dir_forward[6192,6193]
# Node: 6192, Next Neighbour: 6556, Next Directional Sector: dir_forward[6192,6556]
# 1
# Node: 6192, Neighbour: 6556, Directional Sector: dir_forward[6192,6556]
# Node: 6192, Next Neighbour: 6174, Next Directional Sector: dir_backward[6174,6192]
# 2
# Node: 6192, Neighbour: 6174, Directional Sector: dir_backward[6174,6192]
# Node: 6192, Next Neighbour: 6193, Next Directional Sector: dir_forward[6192,6193]
#
# Node: 6192, Index: 2, Beta: Not solved yet
# 0
# Node: 6585, Neighbour: 6202, Directional Sector: dir_backward[6202,6585]
# Node: 6585, Next Neighbour: 6189, Next Directional Sector: dir_backward[6189,6585]
# 1
# Node: 6585, Neighbour: 6189, Directional Sector: dir_backward[6189,6585]
# Node: 6585, Next Neighbour: 6190, Next Directional Sector: dir_backward[6190,6585]
# 2
# Node: 6585, Neighbour: 6190, Directional Sector: dir_backward[6190,6585]
# Node: 6585, Next Neighbour: 6202, Next Directional Sector: dir_backward[6202,6585]
#
# Node: 6585, Index: 2, Beta: Not solved yet
# 0
# Node: 6189, Neighbour: 6585, Directional Sector: dir_forward[6189,6585]
# Node: 6189, Next Neighbour: 6188, Next Directional Sector: dir_backward[6188,6189]
# 1
# Node: 6189, Neighbour: 6188, Directional Sector: dir_backward[6188,6189]
# Node: 6189, Next Neighbour: 6585, Next Directional Sector: dir_forward[6189,6585]
#
# Node: 6189, Index: 1, Beta: Not solved yet
# 0
# Node: 6186, Neighbour: 6181, Directional Sector: dir_backward[6181,6186]
# Node: 6186, Next Neighbour: 7011, Next Directional Sector: dir_forward[6186,7011]
# 1
# Node: 6186, Neighbour: 7011, Directional Sector: dir_forward[6186,7011]
# Node: 6186, Next Neighbour: 6188, Next Directional Sector: dir_forward[6186,6188]
# 2
# Node: 6186, Neighbour: 6188, Directional Sector: dir_forward[6186,6188]
# Node: 6186, Next Neighbour: 6178, Next Directional Sector: dir_backward[6178,6186]
# 3
# Node: 6186, Neighbour: 6178, Directional Sector: dir_backward[6178,6186]
# Node: 6186, Next Neighbour: 6182, Next Directional Sector: dir_backward[6182,6186]
# 4
# Node: 6186, Neighbour: 6182, Directional Sector: dir_backward[6182,6186]
# Node: 6186, Next Neighbour: 6181, Next Directional Sector: dir_backward[6181,6186]
#
# Node: 6186, Index: 4, Beta: Not solved yet
# 0
# Node: 7705, Neighbour: 6201, Directional Sector: dir_backward[6201,7705]
# Node: 7705, Next Neighbour: 6171, Next Directional Sector: dir_backward[6171,7705]
# 1
# Node: 7705, Neighbour: 6171, Directional Sector: dir_backward[6171,7705]
# Node: 7705, Next Neighbour: 6173, Next Directional Sector: dir_backward[6173,7705]
# 2
# Node: 7705, Neighbour: 6173, Directional Sector: dir_backward[6173,7705]
# Node: 7705, Next Neighbour: 6201, Next Directional Sector: dir_backward[6201,7705]
#
# Node: 7705, Index: 2, Beta: Not solved yet
# 0
# Node: 6176, Neighbour: 6177, Directional Sector: dir_forward[6176,6177]
# Node: 6176, Next Neighbour: 6180, Next Directional Sector: dir_forward[6176,6180]
# 1
# Node: 6176, Neighbour: 6180, Directional Sector: dir_forward[6176,6180]
# Node: 6176, Next Neighbour: 6196, Next Directional Sector: dir_forward[6176,6196]
# 2
# Node: 6176, Neighbour: 6196, Directional Sector: dir_forward[6176,6196]
# Node: 6176, Next Neighbour: 6177, Next Directional Sector: dir_forward[6176,6177]
#
# Node: 6176, Index: 2, Beta: Not solved yet
# 0
# Node: 6196, Neighbour: 6171, Directional Sector: dir_backward[6171,6196]
# Node: 6196, Next Neighbour: 6176, Next Directional Sector: dir_backward[6176,6196]
# 1
# Node: 6196, Neighbour: 6176, Directional Sector: dir_backward[6176,6196]
# Node: 6196, Next Neighbour: 6171, Next Directional Sector: dir_backward[6171,6196]
#
# Node: 6196, Index: 1, Beta: Not solved yet
# 0
# Node: 6175, Neighbour: 6188, Directional Sector: dir_forward[6175,6188]
# Node: 6175, Next Neighbour: 6177, Next Directional Sector: dir_forward[6175,6177]
# 1
# Node: 6175, Neighbour: 6177, Directional Sector: dir_forward[6175,6177]
# Node: 6175, Next Neighbour: 6188, Next Directional Sector: dir_forward[6175,6188]
#
# Node: 6175, Index: 1, Beta: Not solved yet
# 0
# Node: 6177, Neighbour: 6175, Directional Sector: dir_backward[6175,6177]
# Node: 6177, Next Neighbour: 6176, Next Directional Sector: dir_backward[6176,6177]
# 1
# Node: 6177, Neighbour: 6176, Directional Sector: dir_backward[6176,6177]
# Node: 6177, Next Neighbour: 6171, Next Directional Sector: dir_backward[6171,6177]
# 2
# Node: 6177, Neighbour: 6171, Directional Sector: dir_backward[6171,6177]
# Node: 6177, Next Neighbour: 6175, Next Directional Sector: dir_backward[6175,6177]
#
# Node: 6177, Index: 2, Beta: Not solved yet
# 0
# Node: 6178, Neighbour: 6180, Directional Sector: dir_forward[6178,6180]
# Node: 6178, Next Neighbour: 6186, Next Directional Sector: dir_forward[6178,6186]
# 1
# Node: 6178, Neighbour: 6186, Directional Sector: dir_forward[6178,6186]
# Node: 6178, Next Neighbour: 6194, Next Directional Sector: dir_forward[6178,6194]
# 2
# Node: 6178, Neighbour: 6194, Directional Sector: dir_forward[6178,6194]
# Node: 6178, Next Neighbour: 6180, Next Directional Sector: dir_forward[6178,6180]
#
# Node: 6178, Index: 2, Beta: Not solved yet
# 0
# Node: 6180, Neighbour: 6174, Directional Sector: dir_backward[6174,6180]
# Node: 6180, Next Neighbour: 6178, Next Directional Sector: dir_backward[6178,6180]
# 1
# Node: 6180, Neighbour: 6178, Directional Sector: dir_backward[6178,6180]
# Node: 6180, Next Neighbour: 6176, Next Directional Sector: dir_backward[6176,6180]
# 2
# Node: 6180, Neighbour: 6176, Directional Sector: dir_backward[6176,6180]
# Node: 6180, Next Neighbour: 6174, Next Directional Sector: dir_backward[6174,6180]
#
# Node: 6180, Index: 2, Beta: Not solved yet
# 0
# Node: 6182, Neighbour: 6186, Directional Sector: dir_forward[6182,6186]
# Node: 6182, Next Neighbour: 6183, Next Directional Sector: dir_forward[6182,6183]
# 1
# Node: 6182, Neighbour: 6183, Directional Sector: dir_forward[6182,6183]
# Node: 6182, Next Neighbour: 6186, Next Directional Sector: dir_forward[6182,6186]
#
# Node: 6182, Index: 1, Beta: Not solved yet
# 0
# Node: 6181, Neighbour: 6188, Directional Sector: dir_forward[6181,6188]
# Node: 6181, Next Neighbour: 6186, Next Directional Sector: dir_forward[6181,6186]
# 1
# Node: 6181, Neighbour: 6186, Directional Sector: dir_forward[6181,6186]
# Node: 6181, Next Neighbour: 6188, Next Directional Sector: dir_forward[6181,6188]
#
# Node: 6181, Index: 1, Beta: Not solved yet

# %% [markdown]
# ## Edge Spacing
# Each edge must have a distance of at least dmin > 0 from each non incident edge.
#
# - Prevents edge crossings
# - maintains planarity (edges have minimum separation in at least 1 octilinear direction)
# - enhances visualisation
# - preserves topology structure

# %%
def non_incident_edge_direction_constraint_rule(model, u1, v1, u2, v2):
    
    e1 = (u1, v1)
    e2 = (u2, v2)
        
    return (model.is_N[e1, e2] + model.is_S[e1, e2] + model.is_E[e1, e2] + model.is_W[e1, e2] +
            model.is_NE[e1, e2] + model.is_NW[e1, e2] + model.is_SE[e1, e2] + model.is_SW[e1, e2] >= 1)
    
model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)
#model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIntersecting_NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)







# Initialize ConstraintList outside of function
# Adds new constraints to list in model without reinitializing it
model.edgeSpacingConstraints = ConstraintList()

def edge_spacing_constraint(model, u1, v1, u2, v2):
    dmin = 1400
    
    ## infeasibility coming from too small M value due to large distances between
    M = 30000
    
    
    e1 = (u1, v1)
    e2 = (u2, v2)
    
    # is_N[e1, e2] means that e1 is north of e1
    
    ## North Constraint
    c1 = model.y_pos[u2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c2 = model.y_pos[v2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c3 = model.y_pos[u2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c4 = model.y_pos[v2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin

    
    # South
    c5 = model.y_pos[u1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c6 = model.y_pos[v1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c7 = model.y_pos[u1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c8 = model.y_pos[v1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin

    
    # is_E[e1, e2] = 1 means that e1 is East of e2
    ## East
    c9 = model.x_pos[u2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c10 = model.x_pos[v2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c11 = model.x_pos[u2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c12 = model.x_pos[v2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin

    
    
    
    ## West
    c13 = model.x_pos[u1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c14 = model.x_pos[v1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c15 = model.x_pos[u1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c16 = model.x_pos[v1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin

    
    
    ## NE
    c17 = model.z1_pos[u2] - model.z1_pos[u1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c18 = model.z1_pos[v2] - model.z1_pos[u1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c19 = model.z1_pos[u2] - model.z1_pos[v1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c20 = model.z1_pos[v2] - model.z1_pos[v1] <= M * (1 - model.is_NE[e1, e2]) - dmin

    
    
    ## NW
    c21 = model.z2_pos[u1] - model.z2_pos[u2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c22 = model.z2_pos[u1] - model.z2_pos[v2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c23 = model.z2_pos[v1] - model.z2_pos[u2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c24 = model.z2_pos[v1] - model.z2_pos[v2] <= M * (1 - model.is_NW[e1, e2]) - dmin

    
    
    # SE
    c25 = model.z2_pos[u2] - model.z2_pos[u1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c26 = model.z2_pos[v2] - model.z2_pos[u1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c27 = model.z2_pos[u2] - model.z2_pos[v1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c28 = model.z2_pos[v2] - model.z2_pos[v1] <= M * (1 - model.is_SE[e1, e2]) - dmin

    
    
    
    
    ## SW
    c29 = model.z1_pos[u1] - model.z1_pos[u2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c30 = model.z1_pos[u1] - model.z1_pos[v2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c31 = model.z1_pos[v1] - model.z1_pos[u2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c32 = model.z1_pos[v1] - model.z1_pos[v2] <= M * (1 - model.is_SW[e1, e2]) - dmin

    
    constraint_list = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32]

    # Add all constraints to the constraint list
    for constraint in constraint_list:
        model.edgeSpacingConstraints.add(constraint)
 
 
 
""" # Call edge_spacing_constraint for each non-incident edge pair
for u1, v1, u2, v2 in model.NonIncidentEdges :
    edge_spacing_constraint(model, u1, v1, u2, v2)
     """
           
# Call edge_spacing_constraint for each non-incident edge pair
for u1, v1, u2, v2 in model.NonIntersecting_NonIncidentEdges :
    edge_spacing_constraint(model, u1, v1, u2, v2)

# %% [markdown]
# ## Deviation Constraints

# %%
model.dev_pos = Var(model.Edges, within=NonNegativeReals)
model.dev_neg = Var(model.Edges, within=NonNegativeReals)

tolerance = 0.01


model.DeviationConstraints = ConstraintList()


def dev_constraints_rule(model, node1, node2):
    
    sect_orig = model.sect_forward[node1, node2]
    
    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_chosen = (sect_orig + adjustment) % 8
        
        
        if sect_chosen == 0:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
            
            
        elif sect_chosen == 1:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
        
        elif sect_chosen == 2:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
                
                
        elif sect_chosen == 3:   
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
            
        elif sect_chosen == 4:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.y_pos[node2] - model.y_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.y_pos[node2] + model.y_pos[node1] - tolerance)
            
            
        elif sect_chosen == 5:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
            
        elif sect_chosen == 6:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= model.x_pos[node2] - model.x_pos[node1] - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -model.x_pos[node2] + model.x_pos[node1] - tolerance)
            
            
        elif sect_chosen == 7:
            model.DeviationConstraints.add(model.dev_pos[node1, node2] >= (model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            model.DeviationConstraints.add(model.dev_neg[node1, node2] >= -(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) - tolerance)
            
        
    return Constraint.Skip



model.DevConstraint = Constraint(model.Edges, rule = dev_constraints_rule)
""" 
for edge in model.Edges:
    node1, node2 = edge
    dev_constraints_rule(model, node1, node2)  """
# Out:
# WARNING: Implicitly replacing the Component attribute dev_pos (type=<class
# 'pyomo.core.base.var.IndexedVar'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.var.IndexedVar'>). This is usually indicative of
# a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().
# WARNING: Implicitly replacing the Component attribute dev_neg (type=<class
# 'pyomo.core.base.var.IndexedVar'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.var.IndexedVar'>). This is usually indicative of
# a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().
# ' \nfor edge in model.Edges:\n    node1, node2 = edge\n    dev_constraints_rule(model, node1, node2)  '

# %% [markdown]
# ## Relative Position Constraint and Objective Function

# %%
# Updated constraint without Big M
def rpos_constraint_upper(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= model.dir_forward[u, v] - model.sect_forward[u, v]

model.RposConstraintUpper = Constraint(model.Edges, rule=rpos_constraint_upper)

# Updated constraint without Big M
def rpos_constraint_lower(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= -model.dir_forward[u, v] + model.sect_forward[u, v]

model.RposConstraintLower = Constraint(model.Edges, rule=rpos_constraint_lower)






penalty_per_unit_deviation = 10  # This value can be adjusted based on how strict the octilinearity needs to be enforced

def total_cost(model):
    # Sum existing costs (if any other costs are involved)
    rpos_costs = sum(model.rpos[edge] for edge in model.Edges)

    # Cost for deviations from octilinearity beyond the tolerance
    deviation_costs = sum(
        (model.dev_pos[edge] + model.dev_neg[edge])
        for edge in model.Edges
    )

    # Combine the costs
    return 0.00001*deviation_costs + 10*rpos_costs

model.TotalCost = Objective(rule=total_cost, sense=minimize)
"""
 
# Objective function to minimize the sum of the deviations
def relative_position_cost(model):
    OF = sum(model.rpos[edge] for edge in model.Edges)
    print(f"cost is: {OF}")
    return OF

model.TotalCost = Objective(rule=relative_position_cost, sense=minimize) 
"""
# Out:
# '\n \n# Objective function to minimize the sum of the deviations\ndef relative_position_cost(model):\n    OF = sum(model.rpos[edge] for edge in model.Edges)\n    print(f"cost is: {OF}")\n    return OF\n\nmodel.TotalCost = Objective(rule=relative_position_cost, sense=minimize) \n'

# %% [markdown]
# # Solver

# %%
#solver.solve(model, tee=True)  # 'tee=True' enables solver output
#Solve the model
solver = SolverFactory('gurobi')
results = solver.solve(model, tee = True)

# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)


def extract_solver_stats(results, df):
    stats = {
        'Solver Status': str(results.solver.status),
        'Termination Condition': str(results.solver.termination_condition),
        'Solve Time (s)': results.solver.time,
        'Number of Constraints': results.problem.number_of_constraints,
        'Number of Variables': results.problem.number_of_variables,
        'Number of Nonzeros': results.problem.number_of_nonzeros
    }
    if results.solver.status == 'ok' and results.solver.termination_condition == 'optimal':
        stats['Objective Value'] = int(value(model.TotalCost.expr))
    else:
        stats['Objective Value'] = 'N/A'
        
    all_nodes = pd.concat([df['src_bus_id'], df['dst_bus_id']]).unique()
    stats['Total Number of Nodes'] = len(all_nodes)
    
    stats['Total Number of Edges'] = len(df)
    
    
    return stats
stats = extract_solver_stats(results, country_df)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmpb31t0r5b.pyomo.lp
# Reading time = 0.12 seconds
# x1: 34750 rows, 8756 columns, 142668 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 34750 rows, 8756 columns and 142668 nonzeros
# Model fingerprint: 0x51f3817a
# Variable types: 216 continuous, 8540 integer (8444 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e-05, 1e+01]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e-02, 3e+04]
# Presolve removed 558 rows and 382 columns
# Presolve time: 0.44s
# Presolved: 34192 rows, 8374 columns, 137407 nonzeros
# Variable types: 167 continuous, 8207 integer (8174 binary)
#
# Root relaxation: objective 7.217581e+01, 4036 iterations, 0.39 seconds (0.55 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.17581    0  561          -   72.17581      -     -    2s
#      0     0  112.14081    0  568          -  112.14081      -     -    2s
#      0     0  112.14081    0  564          -  112.14081      -     -    2s
#      0     0  160.78997    0  544          -  160.78997      -     -    5s
#      0     0  160.78997    0  496          -  160.78997      -     -    5s
#      0     0  160.78997    0  490          -  160.78997      -     -    5s
#      0     0  160.78997    0  488          -  160.78997      -     -    5s
#      0     0  160.81858    0  377          -  160.81858      -     -    9s
#      0     0  160.81858    0  370          -  160.81858      -     -    9s
#      0     0  160.81858    0  370          -  160.81858      -     -    9s
#      0     0  160.81858    0  368          -  160.81858      -     -    9s
#      0     0  160.87326    0  346          -  160.87326      -     -   10s
#      0     0  160.87326    0  335          -  160.87326      -     -   10s
#      0     0  160.87326    0  334          -  160.87326      -     -   10s
#      0     0  161.15266    0   72  161.22499  161.15266  0.04%     -   57s
#      0     0  161.15266    0   67  161.22499  161.15266  0.04%     -   57s
#      0     0  161.15266    0   70  161.22499  161.15266  0.04%     -   58s
#      0     0  161.15266    0   72  161.22499  161.15266  0.04%     -   58s
#      0     0  161.16856    0   64  161.22499  161.16856  0.04%     -   60s
#      0     0  161.16856    0   64  161.22499  161.16856  0.04%     -   60s
#      0     0  161.16856    0   64  161.22499  161.16856  0.04%     -   60s
#      0     2  161.16856    0   64  161.22499  161.16856  0.04%     -   61s
#
# Cutting planes:
#   Gomory: 33
#   Cover: 18
#   Implied bound: 37
#   Clique: 1
#   MIR: 109
#   RLT: 58
#   Relax-and-lift: 23
#
# Explored 327 nodes (46917 simplex iterations) in 64.23 seconds (35.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 161.225 161.272 161.374 ... 161.626
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.612249944000e+02, best bound 1.612226610667e+02, gap 0.0014%
# ok
# optimal

# %% [markdown]
# # Results

# %% [markdown]
# ## NetworkX Graph

# %%
# Update positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}




draw_graph(G, updated_pos)

# %%
# Assuming 'G' is your graph and 'model' is your Pyomo model
# Updated positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}

# Initialize a list to store edge information along with the calculated angles
opt_edges_info = []

# Iterate through each edge in your graph
for edge in G.edges():
    node1, node2 = edge

    # Retrieve the updated positions for source and destination nodes
    new_src_x, new_src_y = updated_pos[node1]
    new_dst_x, new_dst_y = updated_pos[node2]

    # Calculate the angle using the updated positions
    angle = calculate_angle(new_src_x, new_src_y, new_dst_x, new_dst_y)

    formatted_angle = round(angle, 2)

    # Append the edge information and formatted angle to the list
    opt_edges_info.append({
        'Edge': edge,
        'Source': node1,
        'Destination': node2,
        'Angle (degrees)': formatted_angle  # Use the formatted angle
    })

# Convert the list of dictionaries to a pandas DataFrame for easy tabular display
opt_edges_info_df = pd.DataFrame(opt_edges_info)

# Print the DataFrame
#print(edges_info_df)
display(opt_edges_info_df)
# Out:
#             Edge  Source  Destination  Angle (degrees)
# 0   (6172, 6173)    6172         6173            180.0
# 1   (6172, 6201)    6172         6201             45.0
# 2   (6173, 7705)    6173         7705             45.0
# 3   (6188, 6198)    6188         6198             90.0
# 4   (6188, 6189)    6188         6189              0.0
# 5   (6188, 6191)    6188         6191             45.0
# 6   (6193, 6198)    6193         6198            270.0
# 7   (6193, 6398)    6193         6398             90.0
# 8   (6194, 6199)    6194         6199             90.0
# 9   (6174, 6199)    6174         6199              0.0
# 10  (6174, 6180)    6174         6180            270.0
# 11  (6174, 6192)    6174         6192             45.0
# 12  (6191, 6200)    6191         6200              0.0
# 13  (6191, 6193)    6191         6193            135.0
# 14  (6200, 6202)    6200         6202            315.0
# 15  (6170, 6200)    6170         6200            180.0
# 16  (6170, 6202)    6170         6202            270.0
# 17  (6201, 7705)    6201         7705            180.0
# 18  (6171, 6201)    6171         6201            315.0
# 19  (6171, 6197)    6171         6197              0.0
# 20  (6171, 6196)    6171         6196            180.0
# 21  (6171, 6177)    6171         6177             90.0
# 22  (6171, 7705)    6171         7705            270.0
# 23  (6202, 6585)    6202         6585            180.0
# 24  (6183, 6197)    6183         6197            180.0
# 25  (6183, 6549)    6183         6549             45.0
# 26  (6190, 6202)    6190         6202             90.0
# 27  (6190, 6585)    6190         6585            135.0
# 28  (6184, 6549)    6184         6549            180.0
# 29  (6184, 6190)    6184         6190             90.0
# 30  (6192, 6556)    6192         6556             90.0
# 31  (6192, 6193)    6192         6193              0.0
# 32  (6189, 6585)    6189         6585              0.0
# 33  (6186, 7011)    6186         7011             45.0
# 34  (6186, 6188)    6186         6188             90.0
# 35  (6176, 6196)    6176         6196            315.0
# 36  (6176, 6177)    6176         6177              0.0
# 37  (6176, 6180)    6176         6180             45.0
# 38  (6175, 6177)    6175         6177            270.0
# 39  (6175, 6188)    6175         6188              0.0
# 40  (6178, 6180)    6178         6180            270.0
# 41  (6178, 6186)    6178         6186              0.0
# 42  (6178, 6194)    6178         6194             45.0
# 43  (6182, 6183)    6182         6183            270.0
# 44  (6182, 6186)    6182         6186             45.0
# 45  (6181, 6186)    6181         6186            180.0
# 46  (6181, 6188)    6181         6188            135.0
# 47  (6185, 6194)    6185         6194            180.0

# %% [markdown]
# ## Functions - Results

# %%
def count_octilinearity_violations(opt_edges_info):
    violations = 0
    for edge_info in opt_edges_info:
        edge = edge_info['Edge']
        angle = edge_info['Angle (degrees)']
        # Check if the angle is not an exact multiple of 45 (including 0)
        if angle % 45 != 0:
            print(f"Violation found: {edge} with angle {angle}°")
            violations += 1
            
    if violations == 0:
        print("No violations found.")
    else:
        print(f"Total Octilinear Violations: {violations}")
        
    return violations



octilinearity_violations = count_octilinearity_violations(opt_edges_info)
# Out:
# No violations found.

# %% [markdown]
# ## Debugging

# %%
""" # Print initial positions
print("Initial Positions:")
#for node in model.Nodes:
print(f"Node {6193}: x = {model.x_init[6193]}, y = {model.y_init[6193]}")
print(f"Node {6398}: x = {model.x_init[6398]}, y = {model.y_init[6398]}\n\n")

# After solving the model

# Print final positions
print("\nFinal Positions:")
#for node in model.Nodes:
print(f"Node {6193}: x = {value(model.x_pos[6193])}, y = {value(model.y_pos[6193])}")
print(f"Node {6398}: x = {value(model.x_pos[6398])}, y = {value(model.y_pos[6398])}") """
# Out:
# ' # Print initial positions\nprint("Initial Positions:")\n#for node in model.Nodes:\nprint(f"Node {6193}: x = {model.x_init[6193]}, y = {model.y_init[6193]}")\nprint(f"Node {6398}: x = {model.x_init[6398]}, y = {model.y_init[6398]}\n\n")\n\n# After solving the model\n\n# Print final positions\nprint("\nFinal Positions:")\n#for node in model.Nodes:\nprint(f"Node {6193}: x = {value(model.x_pos[6193])}, y = {value(model.y_pos[6193])}")\nprint(f"Node {6398}: x = {value(model.x_pos[6398])}, y = {value(model.y_pos[6398])}") '

# %%
def get_sorted_neighbours(G, node, pos, initial_neighbour):
    angles_neighbours = []
    src_x, src_y = pos[node]

    # Convert G to an undirected graph to consider all adjacent nodes
    G_undirected = G.to_undirected()

    # Calculate angles and sort neighbours
    for neighbour in G_undirected.neighbors(node):
        dst_x, dst_y = pos[neighbour]
        angle = calculate_angle(src_x, src_y, dst_x, dst_y)
        angles_neighbours.append((angle, neighbour))

    angles_neighbours.sort()
    sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]

    # Start the sorted list with the initial neighbour
    if initial_neighbour in sorted_neighbours:
        start_index = sorted_neighbours.index(initial_neighbour)
        sorted_neighbours = sorted_neighbours[start_index:] + sorted_neighbours[:start_index]

    return sorted_neighbours

def check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict):
    violations_count = 0
    
    for node, initial_neighbours in ordered_neighbours_dict.items():
        if initial_neighbours:  # Make sure there is at least one neighbour
            initial_first_neighbour = initial_neighbours[0]
            optimized_neighbours = get_sorted_neighbours(G, node, updated_pos, initial_first_neighbour)
            
            # Check for order violations
            if initial_neighbours != optimized_neighbours:
                print(f"Order violation at node {node}. Initial order: {initial_neighbours}, Optimized order: {optimized_neighbours}")
                violations_count += 1
            
            # Check for sector violations
            angles = [round(calculate_angle(updated_pos[node][0], updated_pos[node][1],
                                            updated_pos[neighbour][0], updated_pos[neighbour][1]), 1)
                      for neighbour in optimized_neighbours]
            sectors = [int(angle // 45) for angle in angles]
            for i in range(len(sectors) - 1):
                if sectors[i] == sectors[i + 1] and angles[i] != angles[i + 1]:
                    print(f"Sector violation between nodes {optimized_neighbours[i]} and {optimized_neighbours[i + 1]} "
                          f"at node {node} in sector {sectors[i]}. Rounded angles: {angles[i]}, {angles[i + 1]}")
                    violations_count += 1
                    break  # Stop at the first violation for this node

    if violations_count == 0:
        print("No circular order violations found.")
    else:
        print(f"Total circular order violations: {violations_count}")
    
    return violations_count

# Example usage
circular_order_violations = check_order_and_sector_violations(G, updated_pos, ordered_neighbours_dict)
# Out:
# Order violation at node 6180. Initial order: [6174, 6178, 6176], Optimized order: [6174, 6176, 6178]
# Total circular order violations: 1

# %%
def check_edge_spacing_violations(specified_edge_pairs, pos):
    intersecting_edge_pairs = []
    violations_count = 0

    for edge1, edge2 in specified_edge_pairs:
        # Get the positions for the source and target nodes of each edge from the 'pos' argument
        src_pos1, tgt_pos1 = pos[edge1[0]], pos[edge1[1]]
        src_pos2, tgt_pos2 = pos[edge2[0]], pos[edge2[1]]
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect and are not merely touching at endpoints
        if line1.intersects(line2) and not line1.touches(line2):
            print(f"Violation found between edge {edge1} and edge {edge2}")
            intersecting_edge_pairs.append((edge1, edge2))
            violations_count += 1

    if violations_count == 0:
        print("No edge spacing violations found.")
    else:
        print(f"Total edge spacing violations: {violations_count}")

    return violations_count


edge_cross_violations = check_edge_spacing_violations(non_intersecting_non_incident_edges, updated_pos)
# Out:
# No edge spacing violations found.

# %%
def display_results(stats, octilinearity_violations, circular_order_violations, edge_crossing_violations):
    # Construct the results DataFrame with the specified metrics
    results_df = pd.DataFrame([
        ['Solver Status', stats.get('Solver Status', 'N/A')],
        ['Objective Function Value', stats.get('Objective Value', 'N/A')],
        ['Computation Time (s)', stats.get('Solve Time (s)', 'N/A')],
        
        ['Number of Constraints', stats.get('Number of Constraints', 'N/A')],
        ['Number of Variables', stats.get('Number of Variables', 'N/A')],
        
        ['Total Number of Nodes', stats.get('Total Number of Nodes', 'N/A')],
        ['Total Number of Edges', stats.get('Total Number of Edges', 'N/A')],
        
        ['Octilinearity Violations', octilinearity_violations],
        ['Circular Order Violations', circular_order_violations],
        ['Edge Crossing Violations', edge_crossing_violations]
    ], columns=['Metric', 'Value'])
    
    # Display the DataFrame
    # If using a Jupyter Notebook, 'display()' will work directly.
    # In other environments, you might need to print the DataFrame or use another method to visualize it.
    display(results_df)

# %%
stats = extract_solver_stats(results, country_df)


display_results(stats, octilinearity_violations, circular_order_violations, edge_cross_violations)
# Out:
#                       Metric      Value
# 0              Solver Status         ok
# 1   Objective Function Value        161
# 2       Computation Time (s)  64.687346
# 3      Number of Constraints      34750
# 4        Number of Variables       8756
# 5      Total Number of Nodes         36
# 6      Total Number of Edges         48
# 7   Octilinearity Violations          0
# 8  Circular Order Violations          1
# 9   Edge Crossing Violations          0
