# %% [markdown]
# # Import Packages

# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from pyomo.environ import*
import math
import csv
from IPython.display import display

from pyproj import Transformer 
from itertools import combinations

# %% [markdown]
# # Access Files
#
# Creating Dataframe of particular country and particular links

# %%
#directory = r'C:\Users\katec\OneDrive - University College Dublin\Documents\5th year\Thesis\Test Data Sets\entsoe'
filename = 'filtered_links.csv'
file_path = filename
#file_path = os.path.join(directory, filename)

df = pd.read_csv(file_path)
ireland_df = df[(df['src_country'] == 'IE') | (df['dst_country'] == 'IE')].copy()
ireland_df.sort_values(by = 'voltage' , ascending = True, inplace = True)

# Duplicates in file of edges
#unique_ireland_df = ireland_df.drop_duplicates(subset=['src_bus_id', 'dst_bus_id'])

# %% [markdown]
# # Create Smaller dataframe but more meshed
#
# Testing for nodes with more than 4 edge connections to test edges at 45 degree angles

# %%
""" link_id_list = [9503, 9513, 9502, 9495, 9493, 9496, 9494, 9508, 9499, 9519]

#link_id_list = [9499, 9519, 9496, 9494, 9508]     #, 9508

filtered_df = ireland_df[ireland_df['link_id'].isin(link_id_list)]

# Then, update the src_bus_id for the link_id 9520 in the filtered dataframe
#filtered_df.loc[filtered_df['link_id'] == 9520, 'src_bus_id'] = 6195
filtered_df.loc[filtered_df['link_id'] == 9493, 'dst_bus_id'] = 6187
filtered_df.loc[filtered_df['link_id'] == 9495, 'dst_bus_id'] = 6187
filtered_df.loc[filtered_df['link_id'] == 9496, 'src_bus_id'] = 6187 

display(filtered_df) """
# Out:
# " link_id_list = [9503, 9513, 9502, 9495, 9493, 9496, 9494, 9508, 9499, 9519]\n\n#link_id_list = [9499, 9519, 9496, 9494, 9508]     #, 9508\n\nfiltered_df = ireland_df[ireland_df['link_id'].isin(link_id_list)]\n\n# Then, update the src_bus_id for the link_id 9520 in the filtered dataframe\n#filtered_df.loc[filtered_df['link_id'] == 9520, 'src_bus_id'] = 6195\nfiltered_df.loc[filtered_df['link_id'] == 9493, 'dst_bus_id'] = 6187\nfiltered_df.loc[filtered_df['link_id'] == 9495, 'dst_bus_id'] = 6187\nfiltered_df.loc[filtered_df['link_id'] == 9496, 'src_bus_id'] = 6187 \n\ndisplay(filtered_df) "

# %% [markdown]
# ## Create Medium 15 node dataframe

# %%
 #link_id_list = [9513, 9514, 9520, 9501, 9655, 9521, 9502, 9503, 9510, 9500, 9519, 9496, 9507, 9494, 9495]
## NOTE: src_bus id for two different links between red and green line have different number nodes
link_id_list = [9502, 9513, 9503, 9514, 9501, 9521, 9500, 9520, 9655, 9510, 9493, 9494, 9495, 9519, 9508, 9499, 9496, 9492, 9489, 9491,9490, 9485, 9498]


#link_id_list = [9520, 9493, 9495, 9496, 9489]
filtered_df = ireland_df[ireland_df['link_id'].isin(link_id_list)]

""" # Then, update the src_bus_id for the link_id 9520 in the filtered dataframe
filtered_df.loc[filtered_df['link_id'] == 9520, 'src_bus_id'] = 6195
filtered_df.loc[filtered_df['link_id'] == 9493, 'dst_bus_id'] = 6187
filtered_df.loc[filtered_df['link_id'] == 9495, 'dst_bus_id'] = 6187

filtered_df.loc[filtered_df['link_id'] == 9496, 'src_bus_id'] = 6187

filtered_df.loc[filtered_df['link_id'] == 9489, 'src_bus_id'] = 6179


 """


# To check the change, display the row with link_id 9520 from the filtered dataframe
#display(filtered_df[filtered_df['link_id'] == 9520])
#print(f"Shape of df is: {filtered_df.shape}")

#print(filtered_df) 

# Initialize a dictionary to hold the mapping from coordinates to bus IDs
coord_to_bus_id = {}

# Function to decide which bus ID to keep 
def decide_bus_id(existing_id, new_id):
    # Keeps the smaller bus ID
    return min(existing_id, new_id)


# Iterate through rows to populate the mappings
for index, row in filtered_df.iterrows():
    for coord_type in ['src_coord', 'dst_coord']:
        coord = row[coord_type]
        bus_id = row[coord_type.split('_')[0] + '_bus_id']  # Construct bus_id column name
        
        if coord not in coord_to_bus_id:
            coord_to_bus_id[coord] = bus_id
        else:
            coord_to_bus_id[coord] = decide_bus_id(coord_to_bus_id[coord], bus_id)

# Update the DataFrame using the mappings
filtered_df.loc[:, 'src_bus_id'] = filtered_df['src_coord'].map(coord_to_bus_id)
filtered_df.loc[:, 'dst_bus_id'] = filtered_df['dst_coord'].map(coord_to_bus_id)

print(f"Shape of df is: {filtered_df.shape}")


# Display the updated DataFrame
print(filtered_df[['link_id', 'src_bus_id', 'dst_bus_id', 'src_coord', 'dst_coord']])
# Out:
# Shape of df is: (23, 14)
#       link_id  src_bus_id  dst_bus_id                       src_coord  \
# 5611     9520        6194        6199  (-8.38256799999999, 53.120405)
# 5612     9514        6174        6199          (-8.931885, 53.271783)
# 5610     9500        6193        6198  (-6.61376999999999, 53.994854)
# 5893     9655        6192        6556  (-8.33862299999999, 53.923751)
# 5741     9510        6193        6398  (-6.61376999999999, 53.994854)
# 5609     9519        6188        6198          (-6.624756, 53.291489)
# 5584     9485        6175        6177          (-8.041992, 53.265213)
# 5585     9490        6176        6177  (-9.43725600000001, 52.542955)
# 5587     9489        6178        6180          (-9.415283, 52.656394)
# 5588     9492        6174        6180          (-8.931885, 53.271783)
# 5589     9491        6176        6180  (-9.43725600000001, 52.542955)
# 5592     9493        6182        6186          (-7.064209, 52.729639)
# 5593     9495        6181        6186  (-6.43798799999999, 53.008173)
# 5594     9498        6175        6188          (-8.041992, 53.265213)
# 5595     9494        6181        6188  (-6.43798799999999, 53.008173)
# 5597     9508        6188        6189          (-6.624756, 53.291489)
# 5599     9499        6188        6191          (-6.624756, 53.291489)
# 5600     9501        6174        6192          (-8.931885, 53.271783)
# 5601     9521        6192        6193  (-8.33862299999999, 53.923751)
# 5596     9496        6186        6188  (-6.71264599999999, 53.120405)
# 5591     9502        6178        6186          (-9.415283, 52.656394)
# 5603     9513        6178        6194          (-9.415283, 52.656394)
# 5604     9503        6185        6194  (-6.61376999999999, 53.442264)
#
#                            dst_coord
# 5611  (-8.59130900000001, 53.206033)
# 5612  (-8.59130900000001, 53.206033)
# 5610          (-6.679688, 53.703211)
# 5893  (-8.41552700000001, 54.207436)
# 5741          (-6.448975, 54.322931)
# 5609          (-6.679688, 53.703211)
# 5584           (-8.580322, 52.57635)
# 5585           (-8.580322, 52.57635)
# 5587          (-9.228516, 52.656394)
# 5588          (-9.228516, 52.656394)
# 5589          (-9.228516, 52.656394)
# 5592  (-6.71264599999999, 53.120405)
# 5593  (-6.71264599999999, 53.120405)
# 5594          (-6.624756, 53.291489)
# 5595          (-6.624756, 53.291489)
# 5597          (-6.405029, 53.271783)
# 5599  (-6.43798799999999, 53.389881)
# 5600  (-8.33862299999999, 53.923751)
# 5601  (-6.61376999999999, 53.994854)
# 5596          (-6.624756, 53.291489)
# 5591  (-6.71264599999999, 53.120405)
# 5603  (-8.38256799999999, 53.120405)
# 5604  (-8.38256799999999, 53.120405)

# %% [markdown]
# # Create Large 220 and 400 kV DataFrame
# Need to update the nodes that connect the 220 and 380 kV, some are labelled differently

# %%
""" filtered_df = ireland_df[ireland_df['voltage'].isin([220, 380])].copy()

# For the node 6178
filtered_df.loc[filtered_df['link_id'] == 9489, 'src_bus_id'] = 6178

# For the node 6195 
filtered_df.loc[filtered_df['link_id'] == 9520, 'src_bus_id'] = 6195

# Node 6187
filtered_df.loc[filtered_df['link_id'] == 9493, 'dst_bus_id'] = 6187
filtered_df.loc[filtered_df['link_id'] == 9495, 'dst_bus_id'] = 6187
filtered_df.loc[filtered_df['link_id'] == 9507, 'src_bus_id'] = 6187
filtered_df.loc[filtered_df['link_id'] == 9496, 'src_bus_id'] = 6187

print(f"Shape of df is: {filtered_df.shape}")
display(filtered_df)  """
# Out:
# ' filtered_df = ireland_df[ireland_df[\'voltage\'].isin([220, 380])].copy()\n\n# For the node 6178\nfiltered_df.loc[filtered_df[\'link_id\'] == 9489, \'src_bus_id\'] = 6178\n\n# For the node 6195 \nfiltered_df.loc[filtered_df[\'link_id\'] == 9520, \'src_bus_id\'] = 6195\n\n# Node 6187\nfiltered_df.loc[filtered_df[\'link_id\'] == 9493, \'dst_bus_id\'] = 6187\nfiltered_df.loc[filtered_df[\'link_id\'] == 9495, \'dst_bus_id\'] = 6187\nfiltered_df.loc[filtered_df[\'link_id\'] == 9507, \'src_bus_id\'] = 6187\nfiltered_df.loc[filtered_df[\'link_id\'] == 9496, \'src_bus_id\'] = 6187\n\nprint(f"Shape of df is: {filtered_df.shape}")\ndisplay(filtered_df)  '

# %% [markdown]
# ## Modify dataframe from the csv file
# Coordinates are in longitude and latitude, so equivalent cartesian xy coordinates need to be found and added to dataframe

# %%
# Create Transformer object to convert geographic (WGS84) (EPSG:4326) coordinates to Web Mercator (EPSG: 3857)
# Converts to cartesian xy coordinates
 
transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

# Function to transform a single coordinate tuple
def transform_coord(coord):
    # Check if coord is a string (e.g., "(lon, lat)") and convert it to a tuple
    if isinstance(coord, str):
        # Remove parentheses and split by comma
        coord = coord.strip("()").split(",")
        # Convert the split strings to floats and create a tuple
        coord = tuple(map(float, coord))
    
    # At this point, coord should be a tuple of floats (lon, lat)
    # Apply the transformation using the unpacked tuple
    return transformer.transform(*coord)


filtered_df[['src_x', 'src_y']] = filtered_df['src_coord'].apply(transform_coord).apply(pd.Series)
filtered_df[['dst_x', 'dst_y']] = filtered_df['dst_coord'].apply(transform_coord).apply(pd.Series)

display(filtered_df)
# Out:
# C:\Users\katec\AppData\Local\Temp\ipykernel_8712\2717354479.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['src_x', 'src_y']] = filtered_df['src_coord'].apply(transform_coord).apply(pd.Series)
# C:\Users\katec\AppData\Local\Temp\ipykernel_8712\2717354479.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['src_x', 'src_y']] = filtered_df['src_coord'].apply(transform_coord).apply(pd.Series)
# C:\Users\katec\AppData\Local\Temp\ipykernel_8712\2717354479.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['dst_x', 'dst_y']] = filtered_df['dst_coord'].apply(transform_coord).apply(pd.Series)
# C:\Users\katec\AppData\Local\Temp\ipykernel_8712\2717354479.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['dst_x', 'dst_y']] = filtered_df['dst_coord'].apply(transform_coord).apply(pd.Series)
#       link_id  src_bus_id  dst_bus_id  voltage  circuits dc underground  \
# 5611     9520        6194        6199    220.0         1  f           f
# 5612     9514        6174        6199    220.0         1  f           f
# 5610     9500        6193        6198    220.0         1  f           f
# 5893     9655        6192        6556    220.0         1  f           f
# 5741     9510        6193        6398    220.0         2  f           f
# 5609     9519        6188        6198    220.0         1  f           f
# 5584     9485        6175        6177    220.0         1  f           f
# 5585     9490        6176        6177    220.0         1  f           f
# 5587     9489        6178        6180    220.0         1  f           f
# 5588     9492        6174        6180    220.0         1  f           f
# 5589     9491        6176        6180    220.0         1  f           f
# 5592     9493        6182        6186    220.0         1  f           f
# 5593     9495        6181        6186    220.0         1  f           f
# 5594     9498        6175        6188    220.0         1  f           f
# 5595     9494        6181        6188    220.0         1  f           f
# 5597     9508        6188        6189    220.0         2  f           f
# 5599     9499        6188        6191    220.0         1  f           f
# 5600     9501        6174        6192    220.0         1  f           f
# 5601     9521        6192        6193    220.0         1  f           f
# 5596     9496        6186        6188    220.0         1  f           f
# 5591     9502        6178        6186    380.0         1  f           f
# 5603     9513        6178        6194    380.0         1  f           f
# 5604     9503        6185        6194    380.0         1  f           f
#
#      under_construction       length_m  \
# 5611                  f   17218.410675
# 5612                  f   23300.746912
# 5610                  f   31641.416533
# 5893                  f   30721.672252
# 5741                  f   37581.936235
# 5609                  f   48178.308519
# 5584                  f   84711.816123
# 5585                  f   60628.365278
# 5587                  f   11935.459729
# 5588                  f   70065.023853
# 5589                  f   17764.175107
# 5592                  f   53245.887520
# 5593                  f   24105.867989
# 5594                  f   93166.852762
# 5595                  f   36594.812265
# 5597                  f   13963.436591
# 5599                  f   16798.312122
# 5600                  f   80224.468810
# 5601                  f  111637.066432
# 5596                  f   20101.560283
# 5591                  f  183680.572423
# 5603                  f   91769.496361
# 5604                  f  120737.313111
#
#                                                    tags  \
# 5611  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5612  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5610  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5893  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5741  'text_'=>'275'  'symbol'=>'220 kV Transmission...
# 5609  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5584  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5585  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5587  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5588  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5589  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5592  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5593  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5594  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5595  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5597  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5599  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5600  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5601  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5596  'text_'=>' '  'symbol'=>'220 kV Transmission L...
# 5591  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
# 5603  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
# 5604  'text_'=>' '  'symbol'=>'380-400 kV Transmissi...
#
#                            src_coord                       dst_coord  \
# 5611  (-8.38256799999999, 53.120405)  (-8.59130900000001, 53.206033)
# 5612          (-8.931885, 53.271783)  (-8.59130900000001, 53.206033)
# 5610  (-6.61376999999999, 53.994854)          (-6.679688, 53.703211)
# 5893  (-8.33862299999999, 53.923751)  (-8.41552700000001, 54.207436)
# 5741  (-6.61376999999999, 53.994854)          (-6.448975, 54.322931)
# 5609          (-6.624756, 53.291489)          (-6.679688, 53.703211)
# 5584          (-8.041992, 53.265213)           (-8.580322, 52.57635)
# 5585  (-9.43725600000001, 52.542955)           (-8.580322, 52.57635)
# 5587          (-9.415283, 52.656394)          (-9.228516, 52.656394)
# 5588          (-8.931885, 53.271783)          (-9.228516, 52.656394)
# 5589  (-9.43725600000001, 52.542955)          (-9.228516, 52.656394)
# 5592          (-7.064209, 52.729639)  (-6.71264599999999, 53.120405)
# 5593  (-6.43798799999999, 53.008173)  (-6.71264599999999, 53.120405)
# 5594          (-8.041992, 53.265213)          (-6.624756, 53.291489)
# 5595  (-6.43798799999999, 53.008173)          (-6.624756, 53.291489)
# 5597          (-6.624756, 53.291489)          (-6.405029, 53.271783)
# 5599          (-6.624756, 53.291489)  (-6.43798799999999, 53.389881)
# 5600          (-8.931885, 53.271783)  (-8.33862299999999, 53.923751)
# 5601  (-8.33862299999999, 53.923751)  (-6.61376999999999, 53.994854)
# 5596  (-6.71264599999999, 53.120405)          (-6.624756, 53.291489)
# 5591          (-9.415283, 52.656394)  (-6.71264599999999, 53.120405)
# 5603          (-9.415283, 52.656394)  (-8.38256799999999, 53.120405)
# 5604  (-6.61376999999999, 53.442264)  (-8.38256799999999, 53.120405)
#
#      src_country dst_country         src_x         src_y         dst_x  \
# 5611          IE          IE -9.331432e+05  7.005301e+06 -9.563801e+05
# 5612          IE          IE -9.942929e+05  7.033430e+06 -9.563801e+05
# 5610          IE          IE -7.362415e+05  7.169182e+06 -7.435795e+05
# 5893          IE          IE -9.282513e+05  7.155729e+06 -9.368122e+05
# 5741          IE          NI -7.362415e+05  7.169182e+06 -7.178966e+05
# 5609          IE          IE -7.374645e+05  7.037099e+06 -7.435795e+05
# 5584          IE          IE -8.952305e+05  7.032207e+06 -9.551571e+05
# 5585          IE          IE -1.050551e+06  6.898900e+06 -9.551571e+05
# 5587          IE          IE -1.048105e+06  6.919691e+06 -1.027314e+06
# 5588          IE          IE -9.942929e+05  7.033430e+06 -1.027314e+06
# 5589          IE          IE -1.050551e+06  6.898900e+06 -1.027314e+06
# 5592          IE          IE -7.863841e+05  6.933144e+06 -7.472483e+05
# 5593          IE          IE -7.166735e+05  6.984510e+06 -7.472483e+05
# 5594          IE          IE -8.952305e+05  7.032207e+06 -7.374645e+05
# 5595          IE          IE -7.166735e+05  6.984510e+06 -7.374645e+05
# 5597          IE          IE -7.374645e+05  7.037099e+06 -7.130046e+05
# 5599          IE          IE -7.374645e+05  7.037099e+06 -7.166735e+05
# 5600          IE          IE -9.942929e+05  7.033430e+06 -9.282513e+05
# 5601          IE          IE -9.282513e+05  7.155729e+06 -7.362415e+05
# 5596          IE          IE -7.472483e+05  7.005301e+06 -7.374645e+05
# 5591          IE          IE -1.048105e+06  6.919691e+06 -7.472483e+05
# 5603          IE          IE -1.048105e+06  6.919691e+06 -9.331432e+05
# 5604          IE          IE -7.362415e+05  7.065227e+06 -9.331432e+05
#
#              dst_y
# 5611  7.021200e+06
# 5612  7.021200e+06
# 5610  7.114147e+06
# 5893  7.209540e+06
# 5741  7.231554e+06
# 5609  7.114147e+06
# 5584  6.905015e+06
# 5585  6.905015e+06
# 5587  6.919691e+06
# 5588  6.919691e+06
# 5589  6.919691e+06
# 5592  7.005301e+06
# 5593  7.005301e+06
# 5594  7.037099e+06
# 5595  7.037099e+06
# 5597  7.033430e+06
# 5599  7.055444e+06
# 5600  7.155729e+06
# 5601  7.169182e+06
# 5596  7.037099e+06
# 5591  7.005301e+06
# 5603  7.005301e+06
# 5604  7.005301e+06

# %% [markdown]
# ## Functions
# Calculate Forward Sector : Calculates the sector of an edge starting at the positive x axis going in counterclockwise direction. Sectors are split from 0 - 7.
#
# ![image.png](attachment:image.png)

# %%
def calculate_forward_sector(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    print("dx dy :")
    #print(dx)
    #print(dy)
    
    # Angle in radians
    angle_rad = math.atan2(dy, dx)
    
    # Convert to degreees
    angle_deg = math.degrees(angle_rad)
    #print("Angle deg: ")
   # print(angle_deg)
    # Angle is rounded to nearest multiple of 45
    # Sector value calculated, modulo 8 used 
    sector = round(angle_deg / 45) % 8
    
    return sector

def euclidean_distance(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    
    return math.sqrt((dx)**2 + (dy)**2)


def get_non_incident_edge_pairs(G):
    non_incident_edge_pairs = []
    
    # combinations - generates all possible pairs of edges from graph G without repeating the same pair
    # '2' indicates we're looking for combinationes of 2 edges
    for edge1, edge2 in combinations(G.edges(), 2):
        
        # edges are sets and the '&' checks that they have no common elements (ie nodes)
        if not set(edge1) & set(edge2):
            non_incident_edge_pairs.append((edge1, edge2))
    return non_incident_edge_pairs       













def midpoint(pos1, pos2):
    """Calculate the midpoint between two positions."""
    return ((pos1[0] + pos2[0]) / 2, (pos1[1] + pos2[1]) / 2)



def calculate_distance(midpoint1, midpoint2):
    return math.sqrt((midpoint2[0] - midpoint1[0]) ** 2 + (midpoint2[1] - midpoint1[1]) ** 2)

# Then use the renamed function in your code



def get_non_incident_edge_distance(G):
    non_incident_edge_distances = {}
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Calculate the midpoints for each edge
        midpoint1 = midpoint(src_pos1, tgt_pos1)
        midpoint2 = midpoint(src_pos2, tgt_pos2)

        # Calculate the distance between the midpoints of the two edges
        dist = calculate_distance(midpoint1, midpoint2)

        # Store the distance with the edge pair as the key
        non_incident_edge_distances[(edge1, edge2)] = dist

    return non_incident_edge_distances















def calculate_angle(src_x, src_y, dst_x, dst_y):
    dx = dst_x - src_x
    dy = dst_y - src_y
    angle_radians = math.atan2(dy, dx)
    angle_degrees = math.degrees(angle_radians)  # Convert the angle to degrees
    
    # Normalize the angle to be within 0 to 360 degrees
    angle_degrees = (angle_degrees + 360) % 360

    return angle_degrees


 
def get_filtered_neighbour_order(G):
    
    # Convert the directed graph to an undirected graph to consider all adjacent nodes as neighbours
    G_undirected = G.to_undirected()
    
    # Create Dictionary to story nodes neighbour orders
    neighbour_order = {}
    for node in G_undirected.nodes():
        
        # Check if the node has 2 or more neighbours
        if G_undirected.degree(node) >= 2:
        
            # Access the position of the current node
            src_pos = G_undirected.nodes[node]['pos']
            src_x, src_y = src_pos
            
            # Create list to store angle size of neighbours with src node
            angles_neighbours = []
            
            
            
            for neighbour in G_undirected.neighbors(node):
                # Access the position tuple of the neighbour node using the 'pos' attribute
                dst_pos = G_undirected.nodes[neighbour]['pos']
                dst_x, dst_y = dst_pos
                
                # Calculate the angle from the source node to the neighbour node
                angle = calculate_angle(src_x, src_y, dst_x, dst_y)
                
                # Append the angle and neighbour to the list
                angles_neighbours.append((angle, neighbour)) 
                
                """ ## TESTING USING ADJUSTED ANGLES
                angle = calculate_angle(src_x, src_y, dst_x, dst_y)
                if (360 - angle)  """
            
            # Sort the list of (angle, neighbour) pairs by angle in ascending order
            angles_neighbours.sort()
            
            # Extract the sorted neighbours from the sorted list of pairs
            sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]
            
            # Check conditions to move the last neighbour to the first position
            if angles_neighbours[-1][0] > 315 and ((360 - angles_neighbours[-1][0]) < angles_neighbours[0][0]):
                # Move the last neighbour to the first position
                sorted_neighbours.insert(0, sorted_neighbours.pop())
            
            
            # Store the sorted list of neighbours in the dictionary with the src_node as the key
            neighbour_order[node] = sorted_neighbours
    
    return neighbour_order
   
     
""" def get_filtered_neighbour_order(G):
    G_undirected = G.to_undirected()
    neighbour_order = {}

    for node in G_undirected.nodes():
        if G_undirected.degree(node) >= 2:
            src_pos = G_undirected.nodes[node]['pos']  # Access positions from the undirected graph
            src_x, src_y = src_pos

            angles_neighbours = []
            for neighbour in G_undirected.neighbors(node):
                dst_pos = G_undirected.nodes[neighbour]['pos']
                dst_x, dst_y = dst_pos
                angle = calculate_angle(src_x, src_y, dst_x, dst_y)
                
                # Debugging print statements
                print(f"Node: {node}, Neighbour: {neighbour}, Angle: {angle} degress")

                angles_neighbours.append((angle, neighbour))

            angles_neighbours.sort()
            sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]
            neighbour_order[node] = sorted_neighbours

    return neighbour_order """
# Out:
# ' def get_filtered_neighbour_order(G):\n    G_undirected = G.to_undirected()\n    neighbour_order = {}\n\n    for node in G_undirected.nodes():\n        if G_undirected.degree(node) >= 2:\n            src_pos = G_undirected.nodes[node][\'pos\']  # Access positions from the undirected graph\n            src_x, src_y = src_pos\n\n            angles_neighbours = []\n            for neighbour in G_undirected.neighbors(node):\n                dst_pos = G_undirected.nodes[neighbour][\'pos\']\n                dst_x, dst_y = dst_pos\n                angle = calculate_angle(src_x, src_y, dst_x, dst_y)\n                \n                # Debugging print statements\n                print(f"Node: {node}, Neighbour: {neighbour}, Angle: {angle} degress")\n\n                angles_neighbours.append((angle, neighbour))\n\n            angles_neighbours.sort()\n            sorted_neighbours = [neighbour for _, neighbour in angles_neighbours]\n            neighbour_order[node] = sorted_neighbours\n\n    return neighbour_order '

# %% [markdown]
# # NetworkX Implementation
# Dataframe is accessed where nodes and edges are added to graph.
# Forward and backward sector of a particular edge are found and stored as attributes along with the voltage information.

# %%
# Initialize a directed graph since we have source and destination
G = nx.DiGraph()

# Loop through the DataFrame rows to add edges and nodes to the graph
for index, row in filtered_df.iterrows():
    src_node = row['src_bus_id']
    dst_node = row['dst_bus_id']
    voltage = row['voltage']
    
    # Add the source and destination nodes if they don't already exist
    if src_node not in G:
        G.add_node(src_node, pos=(row['src_x'], row['src_y']))
    if dst_node not in G:
        G.add_node(dst_node, pos=(row['dst_x'], row['dst_y']))
        
        
        
    # Calculate the forward sector for edges
    forward_sector = calculate_forward_sector(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])

    # Backward sector
    backward_sector = (forward_sector + 4) % 8
    
    distance = euclidean_distance(row['src_x'], row['src_y'], row['dst_x'], row['dst_y'])
    
    # Add an edge between the source and destination nodes, voltage is attribute
    G.add_edge(src_node, dst_node, 
               voltage = voltage, 
               forward_sector = forward_sector, 
               backward_sector = backward_sector,
               distance = distance
               )


# Create list of non-incident edge pairs
non_incident_edge_pairs = get_non_incident_edge_pairs(G)

print(non_incident_edge_pairs)

# Find non-incident edges
#non_incident_edge_pairs = get_non_incident_edge_pairs(G)

# Print non-incident edge pairs
print("Non-incident edge pairs:")
for edge_pair in non_incident_edge_pairs:
    print(edge_pair)
    
ordered_neighbours_dict = get_filtered_neighbour_order(G)
print("\nNodes with more than 2 neighbours ordered:")
print(ordered_neighbours_dict)
for node, neighbours in ordered_neighbours_dict.items():
    print(len(neighbours))
    
    
 # dictionary
non_incident_edge_distances = get_non_incident_edge_distance(G)

# Find the non-incident edge pair with the maximum distance
max_distance_pair = max(non_incident_edge_distances, key=non_incident_edge_distances.get)

# Print the non-incident edge pair with the maximum distance and its value
max_distance_value = non_incident_edge_distances[max_distance_pair]
print(f"Non-incident edge pair with maximum distance: {max_distance_pair} with distance {max_distance_value}")
# Out:
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# dx dy :
# [((6194, 6199), (6174, 6180)), ((6194, 6199), (6174, 6192)), ((6194, 6199), (6193, 6198)), ((6194, 6199), (6193, 6398)), ((6194, 6199), (6192, 6556)), ((6194, 6199), (6192, 6193)), ((6194, 6199), (6188, 6198)), ((6194, 6199), (6188, 6189)), ((6194, 6199), (6188, 6191)), ((6194, 6199), (6175, 6177)), ((6194, 6199), (6175, 6188)), ((6194, 6199), (6176, 6177)), ((6194, 6199), (6176, 6180)), ((6194, 6199), (6178, 6180)), ((6194, 6199), (6178, 6186)), ((6194, 6199), (6182, 6186)), ((6194, 6199), (6186, 6188)), ((6194, 6199), (6181, 6186)), ((6194, 6199), (6181, 6188)), ((6174, 6199), (6193, 6198)), ((6174, 6199), (6193, 6398)), ((6174, 6199), (6192, 6556)), ((6174, 6199), (6192, 6193)), ((6174, 6199), (6188, 6198)), ((6174, 6199), (6188, 6189)), ((6174, 6199), (6188, 6191)), ((6174, 6199), (6175, 6177)), ((6174, 6199), (6175, 6188)), ((6174, 6199), (6176, 6177)), ((6174, 6199), (6176, 6180)), ((6174, 6199), (6178, 6180)), ((6174, 6199), (6178, 6186)), ((6174, 6199), (6178, 6194)), ((6174, 6199), (6182, 6186)), ((6174, 6199), (6186, 6188)), ((6174, 6199), (6181, 6186)), ((6174, 6199), (6181, 6188)), ((6174, 6199), (6185, 6194)), ((6174, 6180), (6193, 6198)), ((6174, 6180), (6193, 6398)), ((6174, 6180), (6192, 6556)), ((6174, 6180), (6192, 6193)), ((6174, 6180), (6188, 6198)), ((6174, 6180), (6188, 6189)), ((6174, 6180), (6188, 6191)), ((6174, 6180), (6175, 6177)), ((6174, 6180), (6175, 6188)), ((6174, 6180), (6176, 6177)), ((6174, 6180), (6178, 6186)), ((6174, 6180), (6178, 6194)), ((6174, 6180), (6182, 6186)), ((6174, 6180), (6186, 6188)), ((6174, 6180), (6181, 6186)), ((6174, 6180), (6181, 6188)), ((6174, 6180), (6185, 6194)), ((6174, 6192), (6193, 6198)), ((6174, 6192), (6193, 6398)), ((6174, 6192), (6188, 6198)), ((6174, 6192), (6188, 6189)), ((6174, 6192), (6188, 6191)), ((6174, 6192), (6175, 6177)), ((6174, 6192), (6175, 6188)), ((6174, 6192), (6176, 6177)), ((6174, 6192), (6176, 6180)), ((6174, 6192), (6178, 6180)), ((6174, 6192), (6178, 6186)), ((6174, 6192), (6178, 6194)), ((6174, 6192), (6182, 6186)), ((6174, 6192), (6186, 6188)), ((6174, 6192), (6181, 6186)), ((6174, 6192), (6181, 6188)), ((6174, 6192), (6185, 6194)), ((6193, 6198), (6192, 6556)), ((6193, 6198), (6188, 6189)), ((6193, 6198), (6188, 6191)), ((6193, 6198), (6175, 6177)), ((6193, 6198), (6175, 6188)), ((6193, 6198), (6176, 6177)), ((6193, 6198), (6176, 6180)), ((6193, 6198), (6178, 6180)), ((6193, 6198), (6178, 6186)), ((6193, 6198), (6178, 6194)), ((6193, 6198), (6182, 6186)), ((6193, 6198), (6186, 6188)), ((6193, 6198), (6181, 6186)), ((6193, 6198), (6181, 6188)), ((6193, 6198), (6185, 6194)), ((6193, 6398), (6192, 6556)), ((6193, 6398), (6188, 6198)), ((6193, 6398), (6188, 6189)), ((6193, 6398), (6188, 6191)), ((6193, 6398), (6175, 6177)), ((6193, 6398), (6175, 6188)), ((6193, 6398), (6176, 6177)), ((6193, 6398), (6176, 6180)), ((6193, 6398), (6178, 6180)), ((6193, 6398), (6178, 6186)), ((6193, 6398), (6178, 6194)), ((6193, 6398), (6182, 6186)), ((6193, 6398), (6186, 6188)), ((6193, 6398), (6181, 6186)), ((6193, 6398), (6181, 6188)), ((6193, 6398), (6185, 6194)), ((6192, 6556), (6188, 6198)), ((6192, 6556), (6188, 6189)), ((6192, 6556), (6188, 6191)), ((6192, 6556), (6175, 6177)), ((6192, 6556), (6175, 6188)), ((6192, 6556), (6176, 6177)), ((6192, 6556), (6176, 6180)), ((6192, 6556), (6178, 6180)), ((6192, 6556), (6178, 6186)), ((6192, 6556), (6178, 6194)), ((6192, 6556), (6182, 6186)), ((6192, 6556), (6186, 6188)), ((6192, 6556), (6181, 6186)), ((6192, 6556), (6181, 6188)), ((6192, 6556), (6185, 6194)), ((6192, 6193), (6188, 6198)), ((6192, 6193), (6188, 6189)), ((6192, 6193), (6188, 6191)), ((6192, 6193), (6175, 6177)), ((6192, 6193), (6175, 6188)), ((6192, 6193), (6176, 6177)), ((6192, 6193), (6176, 6180)), ((6192, 6193), (6178, 6180)), ((6192, 6193), (6178, 6186)), ((6192, 6193), (6178, 6194)), ((6192, 6193), (6182, 6186)), ((6192, 6193), (6186, 6188)), ((6192, 6193), (6181, 6186)), ((6192, 6193), (6181, 6188)), ((6192, 6193), (6185, 6194)), ((6188, 6 ...
# Non-incident edge pairs:
# ((6194, 6199), (6174, 6180))
# ((6194, 6199), (6174, 6192))
# ((6194, 6199), (6193, 6198))
# ((6194, 6199), (6193, 6398))
# ((6194, 6199), (6192, 6556))
# ((6194, 6199), (6192, 6193))
# ((6194, 6199), (6188, 6198))
# ((6194, 6199), (6188, 6189))
# ((6194, 6199), (6188, 6191))
# ((6194, 6199), (6175, 6177))
# ((6194, 6199), (6175, 6188))
# ((6194, 6199), (6176, 6177))
# ((6194, 6199), (6176, 6180))
# ((6194, 6199), (6178, 6180))
# ((6194, 6199), (6178, 6186))
# ((6194, 6199), (6182, 6186))
# ((6194, 6199), (6186, 6188))
# ((6194, 6199), (6181, 6186))
# ((6194, 6199), (6181, 6188))
# ((6174, 6199), (6193, 6198))
# ((6174, 6199), (6193, 6398))
# ((6174, 6199), (6192, 6556))
# ((6174, 6199), (6192, 6193))
# ((6174, 6199), (6188, 6198))
# ((6174, 6199), (6188, 6189))
# ((6174, 6199), (6188, 6191))
# ((6174, 6199), (6175, 6177))
# ((6174, 6199), (6175, 6188))
# ((6174, 6199), (6176, 6177))
# ((6174, 6199), (6176, 6180))
# ((6174, 6199), (6178, 6180))
# ((6174, 6199), (6178, 6186))
# ((6174, 6199), (6178, 6194))
# ((6174, 6199), (6182, 6186))
# ((6174, 6199), (6186, 6188))
# ((6174, 6199), (6181, 6186))
# ((6174, 6199), (6181, 6188))
# ((6174, 6199), (6185, 6194))
# ((6174, 6180), (6193, 6198))
# ((6174, 6180), (6193, 6398))
# ((6174, 6180), (6192, 6556))
# ((6174, 6180), (6192, 6193))
# ((6174, 6180), (6188, 6198))
# ((6174, 6180), (6188, 6189))
# ((6174, 6180), (6188, 6191))
# ((6174, 6180), (6175, 6177))
# ((6174, 6180), (6175, 6188))
# ((6174, 6180), (6176, 6177))
# ((6174, 6180), (6178, 6186))
# ((6174, 6180), (6178, 6194))
# ((6174, 6180), (6182, 6186))
# ((6174, 6180), (6186, 6188))
# ((6174, 6180), (6181, 6186))
# ((6174, 6180), (6181, 6188))
# ((6174, 6180), (6185, 6194))
# ((6174, 6192), (6193, 6198))
# ((6174, 6192), (6193, 6398))
# ((6174, 6192), (6188, 6198))
# ((6174, 6192), (6188, 6189))
# ((6174, 6192), (6188, 6191))
# ((6174, 6192), (6175, 6177))
# ((6174, 6192), (6175, 6188))
# ((6174, 6192), (6176, 6177))
# ((6174, 6192), (6176, 6180))
# ((6174, 6192), (6178, 6180))
# ((6174, 6192), (6178, 6186))
# ((6174, 6192), (6178, 6194))
# ((6174, 6192), (6182, 6186))
# ((6174, 6192), (6186, 6188))
# ((6174, 6192), (6181, 6186))
# ((6174, 6192), (6181, 6188))
# ((6174, 6192), (6185, 6194))
# ((6193, 6198), (6192, 6556))
# ((6193, 6198), (6188, 6189))
# ((6193, 6198), (6188, 6191))
# ((6193, 6198), (6175, 6177))
# ((6193, 6198), (6175, 6188))
# ((6193, 6198), (6176, 6177))
# ((6193, 6198), (6176, 6180))
# ((6193, 6198), (6178, 6180))
# ((6193, 6198), (6178, 6186))
# ((6193, 6198), (6178, 6194))
# ((6193, 6198), (6182, 6186))
# ((6193, 6198), (6186, 6188))
# ((6193, 6198), (6181, 6186))
# ((6193, 6198), (6181, 6188))
# ((6193, 6198), (6185, 6194))
# ((6193, 6398), (6192, 6556))
# ((6193, 6398), (6188, 6198))
# ((6193, 6398), (6188, 6189))
# ((6193, 6398), (6188, 6191))
# ((6193, 6398), (6175, 6177))
# ((6193, 6398), (6175, 6188))
# ((6193, 6398), (6176, 6177))
# ((6193, 6398), (6176, 6180))
# ((6193, 6398), (6178, 6180))
# ((6193, 6398), (6178, 6186))
# ((6193, 6398), (6178, 6194))
# ((6193, 6398), (6182, 6186))
# ((6193, 6398), (6186, 6188))
# ((6193, 6398), (6181, 6186))
# ((6193, 6398), (6181, 6188))
# ((6193, 6398), (6185, 6194))
# ((6192, 6556), (6188, 6198))
# ((6192, 6556), (6188, 6189))
# ((6192, 6556), (6188, 6191))
# ((6192, 6556), (6175, 6177))
# ((6192, 6556), (6175, 6188))
# ((6192, 6556), (6176, 6177))
# ((6192, 6556), (6176, 6180))
# ((6192, 6556), (6178, 6180))
# ((6192, 6556), (6178, 6186))
# ((6192, 6556), (6178, 6194))
# ((6192, 6556), (6182, 6186))
# ((6192, 6556), (6186, 6188))
# ((6192, 6556), (6181, 6186))
# ((6192, 6556), (6181, 6188))
# ((6192, 6556), (6185, 6194))
# ((6192, 6193), (6188, 6198))
# ((6192, 6193), (6188, 6189))
# ((6192, 6193), (6188, 6191))
# ((6192, 6193), (6175, 6177))
# ((6192, 6193), (6175, 6188))
# ((6192, 6193), (6176, 6177))
# ((6192, 6193), (6176, 6180))
# ((6192, 6193), (6178, 6180))
# ((6192, 6193), (6178, 6186))
# ((6192, 6193), (6178, 6194))
# ((6192, 6193), (6182, 6186))
# ((6192, 6193), (6186, 6188))
# ((6192, 6193), (6181, 6186))
# ((6192, 6193), (6181, 6188))
# ((6192, 6193), (6185, 6194))
# ((6188, 6198), (6175, 6177))
# ((6188, 6198), (6176, 6177))
# ((6188, 6198), (6176, 6180))
# ((6188, 6198), (6178, 6180))
# ((6188, 6198), (6178, 6186))
# ((6188, 6198), (6178, 6194))
# ((6188, 6198), (6182, 6186))
# ((6188, 6198), (6181, 6186))
# ((6188, 6198), (6185, 6194))
# ((6188, 6189), (6175, 6177))
# ((6188, 6189), (6176, 6177))
# ((6188, 6189), (6176, 6180))
# ((6188, 6189), (6178, 6180))
# ((6188, 6189), (6178, 6186))
# ((6188, 6189), (6178, 6194))
# ((6188, 6189), (6182, 6186))
# ((6188, 6189), (6181, 6186))
# ((6188, 6189), (6185, 6194))
# ((6188, 6191), (6175, 6177))
# ((6188, 6191), (6176, 6177))
# ((6188, 6191), (6176, 6180))
# ((6188, 6191), (6178, 6180))
# ((6188, 6191), (6178, 6186))
# ((6188, 6191), (6178, 6194))
# ((6188, 6191), (6182, 6186))
# ((6188, 6191), (6181, 6186))
# ((6188, 6191), (6185, 6194))
# ((6175, 6177), (6176, 6180))
# ((6175, 6177), (6178, 6180))
# ((6175, 6177), (6178, 6186))
# ((6175, 6177), (6178, 6194))
# ((6175, 6177), (6182, 6186))
# ((6175, 6177), (6186, 6188))
# ((6175, 6177), (6181, 6186))
# ((6175, 6177), (6181, 6188))
# ((6175, 6177), (6185, 6194))
# ((6175, 6188), (6176, 6177))
# ((6175, 6188), (6176, 6180))
# ((6175, 6188), (6178, 6180))
# ((6175, 6188), (6178, 6186))
# ((6175, 6188), (6178, 6194))
# ((6175, 6188), (6182, 6186))
# ((6175, 6188), (6181, 6186))
# ((6175, 6188), (6185, 6194))
# ((6176, 6177), (6178, 6180))
# ((6176, 6177), (6178, 6186))
# ((6176, 6177), (6178, 6194))
# ((6176, 6177), (6182, 6186))
# ((6176, 6177), (6186, 6188))
# ((6176, 6177), (6181, 6186))
# ((6176, 6177), (6181, 6188))
# ((6176, 6177), (6185, 6194))
# ((6176, 6180), (6178, 6186))
# ((6176, 6180), (6178, 6194))
# ((6176, 6180), (6182, 6186))
# ((6176, 6180), (6186, 6188))
# ((6176, 6180), (6181, 6186))
# ((6176, 6180), (6181, 6188))
# ((6176, 6180), (6185, 6194))
# ((6178, 6180), (6182, 6186))
# ((6178, 6180), (6186, 6188))
# ((6178, 6180), (6181, 6186))
# ((6178, 6180), (6181, 6188))
# ((6178, 6180), (6185, 6194))
# ((6178, 6186), (6181, 6188))
# ((6178, 6186), (6185, 6194))
# ((6178, 6194), (6182, 6186))
# ((6178, 6194), (6186, 6188))
# ((6178, 6194), (6181, 6186))
# ((6178, 6194), (6181, 6188))
# ((6182, 6186), (6181, 6188))
# ((6182, 6186), (6185, 6194))
# ((6186, 6188), (6185, 6194))
# ((6181, 6186), (6185, 6194))
# ((6181, 6188), (6185, 6194))
#
# Nodes with more than 2 neighbours ordered:
# {6194: [6185, 6199, 6178], 6199: [6194, 6174], 6174: [6199, 6192, 6180], 6193: [6398, 6192, 6198], 6198: [6193, 6188], 6192: [6193, 6556, 6174], 6188: [6189, 6191, 6198, 6175, 6186, 6181], 6175: [6188, 6177], 6177: [6175, 6176], 6176: [6177, 6180], 6178: [6180, 6186, 6194], 6180: [6174, 6178, 6176], 6186: [6181, 6188, 6178, 6182], 6181: [6188, 6186]}
# 3
# 2
# 3
# 3
# 2
# 3
# 6
# 2
# 2
# 2
# 3
# 3
# 4
# 2
# Non-incident edge pair with maximum distance: ((6193, 6398), (6176, 6180)) with distance 426593.00042798946

# %% [markdown]
# ## Drawing NetworkX Graph

# %%
import matplotlib.lines as mlines

pos = nx.get_node_attributes(G, 'pos')

plt.figure(figsize = (15, 15))
# Draw nodes
nx.draw_networkx_nodes(G, pos, node_color='skyblue', node_size=500)

# Create custom lines for the legend
red_line = mlines.Line2D([], [], color='red', markersize=30, label='380 kV', linewidth = 3)
green_line = mlines.Line2D([], [], color='green', markersize=30, label='220 kV', linewidth = 3)



# Draw the graph edges with different colors based on the voltage
for (u, v, d) in G.edges(data=True):
    edge_color = 'r' if d['voltage'] == 380.0 else 'g' if d['voltage'] == 220.0 else 'k'
    nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], edge_color=edge_color, width = 3, arrows = False)

# Draw the node labels
nx.draw_networkx_labels(G, pos, font_size=10)

# Create edge labels for voltages
edge_labels = nx.get_edge_attributes(G, 'link_id')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, label_pos=0.5, font_size=7)
#nx.draw_networkx_edge_labels(G, pos, label_pos=0.5, font_size=7)


# Add the legend to the plot
plt.legend(handles=[red_line, green_line], loc='lower right', fontsize = 20)

plt.grid(True)
# Show the plot
plt.show()
# Out:
# C:\Users\katec\AppData\Local\Temp\ipykernel_8712\4114552692.py:18: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], edge_color=edge_color, width = 3, arrows = False)

# %% [markdown]
# ## Create Dictionary to access edge information

# %%
def get_edge_info(G, edge):
    node1, node2 = edge
    
    # edge attributes eg voltage forward/backward sector are stored in edge data
    edge_data = G.get_edge_data(node1, node2)
    
    # Additional edge information
    edge_information = {
        'edge': edge,
        'source': node1,
        'destination': node2,
        'source_position': G.nodes[node1].get('pos'),
        'destination_position': G.nodes[node2].get('pos'),
        'source_neighbors': list(G.successors(node1)),  # or list(G.successors(u)) for DiGraph
        'destination_neighbors': list(G.predecessors(node2)),  # or list(G.predecessors(v)) for DiGraph
        'source_degree': G.degree(node1),
        'destination_degree': G.degree(node2)
    }
    
    # Merge edge_data into edge_info
    edge_information.update(edge_data)
    return edge_information

    
    
# Usage example
edge_details = {}
for edge in G.edges():
    edge_details[edge] = get_edge_info(G, edge)
    print(edge_details[edge])
    
    forward = edge_details[edge].get('forward_sector')
    backward = edge_details[edge].get('backward_sector')
    print(f"Forward sector for edge {edge}: {forward}")
    print(f"Backward sector for edge {edge}: {backward}\n")
# Out:
# {'edge': (6194, 6199), 'source': 6194, 'destination': 6199, 'source_position': (-933143.2012999885, 7005300.7157662185), 'destination_position': (-956380.1431276693, 7021199.753507257), 'source_neighbors': [6199], 'destination_neighbors': [6194, 6174], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 28155.547705452336}
# Forward sector for edge (6194, 6199): 3
# Backward sector for edge (6194, 6199): 7
#
# {'edge': (6174, 6199), 'source': 6174, 'destination': 6199, 'source_position': (-994292.8900240782, 7033429.505480125), 'destination_position': (-956380.1431276693, 7021199.753507257), 'source_neighbors': [6199, 6180, 6192], 'destination_neighbors': [6194, 6174], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 39836.45579803765}
# Forward sector for edge (6174, 6199): 0
# Backward sector for edge (6174, 6199): 4
#
# {'edge': (6174, 6180), 'source': 6174, 'destination': 6180, 'source_position': (-994292.8900240782, 7033429.505480125), 'destination_position': (-1027313.7018975778, 6919691.307246547), 'source_neighbors': [6199, 6180, 6192], 'destination_neighbors': [6178, 6174, 6176], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 118434.588504396}
# Forward sector for edge (6174, 6180): 6
# Backward sector for edge (6174, 6180): 2
#
# {'edge': (6174, 6192), 'source': 6174, 'destination': 6192, 'source_position': (-994292.8900240782, 7033429.505480125), 'destination_position': (-928251.266277078, 7155728.851095909), 'source_neighbors': [6199, 6180, 6192], 'destination_neighbors': [6174], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 138991.46018798955}
# Forward sector for edge (6174, 6192): 1
# Backward sector for edge (6174, 6192): 5
#
# {'edge': (6193, 6198), 'source': 6193, 'destination': 6198, 'source_position': (-736241.5086238278, 7169181.763432151), 'destination_position': (-743579.4668179399, 7114147.184426849), 'source_neighbors': [6198, 6398], 'destination_neighbors': [6193, 6188], 'source_degree': 3, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 6, 'backward_sector': 2, 'distance': 55521.622065186064}
# Forward sector for edge (6193, 6198): 6
# Backward sector for edge (6193, 6198): 2
#
# {'edge': (6193, 6398), 'source': 6193, 'destination': 6398, 'source_position': (-736241.5086238278, 7169181.763432151), 'destination_position': (-717896.6131385515, 7231554.344659001), 'source_neighbors': [6198, 6398], 'destination_neighbors': [6193], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 65014.41439608377}
# Forward sector for edge (6193, 6398): 2
# Backward sector for edge (6193, 6398): 6
#
# {'edge': (6192, 6556), 'source': 6192, 'destination': 6556, 'source_position': (-928251.266277078, 7155728.851095909), 'destination_position': (-936812.1803970463, 7209540.485041131), 'source_neighbors': [6556, 6193], 'destination_neighbors': [6192], 'source_degree': 3, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 54488.3583751983}
# Forward sector for edge (6192, 6556): 2
# Backward sector for edge (6192, 6556): 6
#
# {'edge': (6192, 6193), 'source': 6192, 'destination': 6193, 'source_position': (-928251.266277078, 7155728.851095909), 'destination_position': (-736241.5086238278, 7169181.763432151), 'source_neighbors': [6556, 6193], 'destination_neighbors': [6192], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 192480.4610457551}
# Forward sector for edge (6192, 6193): 0
# Backward sector for edge (6192, 6193): 4
#
# {'edge': (6188, 6198), 'source': 6188, 'destination': 6198, 'source_position': (-737464.4645496837, 7037098.559885431), 'destination_position': (-743579.4668179399, 7114147.184426849), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6193, 6188], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 77290.9037110133}
# Forward sector for edge (6188, 6198): 2
# Backward sector for edge (6188, 6198): 6
#
# {'edge': (6188, 6189), 'source': 6188, 'destination': 6189, 'source_position': (-737464.4645496837, 7037098.559885431), 'destination_position': (-713004.5667961502, 7033429.505480125), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 24733.551268315976}
# Forward sector for edge (6188, 6189): 0
# Backward sector for edge (6188, 6189): 4
#
# {'edge': (6188, 6191), 'source': 6188, 'destination': 6191, 'source_position': (-737464.4645496837, 7037098.559885431), 'destination_position': (-716673.5458932046, 7055443.505209369), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 27727.230613939606}
# Forward sector for edge (6188, 6191): 1
# Backward sector for edge (6188, 6191): 5
#
# {'edge': (6175, 6177), 'source': 6175, 'destination': 6177, 'source_position': (-895230.4544035797, 7032206.615032485), 'destination_position': (-955157.0758823229, 6905015.398618673), 'source_neighbors': [6177, 6188], 'destination_neighbors': [6175, 6176], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 5, 'backward_sector': 1, 'distance': 140601.58425381154}
# Forward sector for edge (6175, 6177): 5
# Backward sector for edge (6175, 6177): 1
#
# {'edge': (6175, 6188), 'source': 6175, 'destination': 6188, 'source_position': (-895230.4544035797, 7032206.615032485), 'destination_position': (-737464.4645496837, 7037098.559885431), 'source_neighbors': [6177, 6188], 'destination_neighbors': [6175, 6181, 6186], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 157841.81536913427}
# Forward sector for edge (6175, 6188): 0
# Backward sector for edge (6175, 6188): 4
#
# {'edge': (6176, 6177), 'source': 6176, 'destination': 6177, 'source_position': (-1050550.532405767, 6898900.412749045), 'destination_position': (-955157.0758823229, 6905015.398618673), 'source_neighbors': [6177, 6180], 'destination_neighbors': [6175, 6176], 'source_degree': 2, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 95589.2493938307}
# Forward sector for edge (6176, 6177): 0
# Backward sector for edge (6176, 6177): 4
#
# {'edge': (6176, 6180), 'source': 6176, 'destination': 6180, 'source_position': (-1050550.532405767, 6898900.412749045), 'destination_position': (-1027313.7018975778, 6919691.307246547), 'source_neighbors': [6177, 6180], 'destination_neighbors': [6178, 6174, 6176], 'source_degree': 2, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 31180.307664816086}
# Forward sector for edge (6176, 6180): 1
# Backward sector for edge (6176, 6180): 5
#
# {'edge': (6178, 6180), 'source': 6178, 'destination': 6180, 'source_position': (-1048104.5092345652, 6919691.307246547), 'destination_position': (-1027313.7018975778, 6919691.307246547), 'source_neighbors': [6180, 6186, 6194], 'destination_neighbors': [6178, 6174, 6176], 'source_degree': 3, 'destination_degree': 3, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 20790.807336987345}
# Forward sector for edge (6178, 6180): 0
# Backward sector for edge (6178, 6180): 4
#
# {'edge': (6178, 6186), 'source': 6178, 'destination': 6186, 'source_position': (-1048104.5092345652, 6919691.307246547), 'destination_position': (-747248.3345955035, 7005300.7157662185), 'source_neighbors': [6180, 6186, 6194], 'destination_neighbors': [6182, 6181, 6178], 'source_degree': 3, 'destination_degree': 4, 'voltage': 380.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 312799.3104940251}
# Forward sector for edge (6178, 6186): 0
# Backward sector for edge (6178, 6186): 4
#
# {'edge': (6178, 6194), 'source': 6178, 'destination': 6194, 'source_position': (-1048104.5092345652, 6919691.307246547), 'destination_position': (-933143.2012999885, 7005300.7157662185), 'source_neighbors': [6180, 6186, 6194], 'destination_neighbors': [6178, 6185], 'source_degree': 3, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 143335.5264723876}
# Forward sector for edge (6178, 6194): 1
# Backward sector for edge (6178, 6194): 5
#
# {'edge': (6182, 6186), 'source': 6182, 'destination': 6186, 'source_position': (-786384.1487372603, 6933144.195593818), 'destination_position': (-747248.3345955035, 7005300.7157662185), 'source_neighbors': [6186], 'destination_neighbors': [6182, 6181, 6178], 'source_degree': 1, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 82086.38956567741}
# Forward sector for edge (6182, 6186): 1
# Backward sector for edge (6182, 6186): 5
#
# {'edge': (6186, 6188), 'source': 6186, 'destination': 6188, 'source_position': (-747248.3345955035, 7005300.7157662185), 'destination_position': (-737464.4645496837, 7037098.559885431), 'source_neighbors': [6188], 'destination_neighbors': [6175, 6181, 6186], 'source_degree': 4, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 33269.00965918932}
# Forward sector for edge (6186, 6188): 2
# Backward sector for edge (6186, 6188): 6
#
# {'edge': (6181, 6186), 'source': 6181, 'destination': 6186, 'source_position': (-716673.5458932046, 6984509.847294063), 'destination_position': (-747248.3345955035, 7005300.7157662185), 'source_neighbors': [6186, 6188], 'destination_neighbors': [6182, 6181, 6178], 'source_degree': 2, 'destination_degree': 4, 'voltage': 220.0, 'forward_sector': 3, 'backward_sector': 7, 'distance': 36974.01676876182}
# Forward sector for edge (6181, 6186): 3
# Backward sector for edge (6181, 6186): 7
#
# {'edge': (6181, 6188), 'source': 6181, 'destination': 6188, 'source_position': (-716673.5458932046, 6984509.847294063), 'destination_position': (-737464.4645496837, 7037098.559885431), 'source_neighbors': [6186, 6188], 'destination_neighbors': [6175, 6181, 6186], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 56549.403096742004}
# Forward sector for edge (6181, 6188): 2
# Backward sector for edge (6181, 6188): 6
#
# {'edge': (6185, 6194), 'source': 6185, 'destination': 6194, 'source_position': (-736241.5086238278, 7065227.487227938), 'destination_position': (-933143.2012999885, 7005300.7157662185), 'source_neighbors': [6194], 'destination_neighbors': [6178, 6185], 'source_degree': 1, 'destination_degree': 3, 'voltage': 380.0, 'forward_sector': 4, 'backward_sector': 0, 'distance': 205819.08200301163}
# Forward sector for edge (6185, 6194): 4
# Backward sector for edge (6185, 6194): 0

# %%
# Debugging to check the sectors around the node 6188

# Usage example
edge_details = {}
for edge in G.edges():
    # Check if the node 6188 is part of the edge
    if 6188 in edge:
        edge_details[edge] = get_edge_info(G, edge)
        print(edge_details[edge])
        
        forward = edge_details[edge].get('forward_sector')
        backward = edge_details[edge].get('backward_sector')
        print(f"Forward sector for edge {edge}: {forward}")
        print(f"Backward sector for edge {edge}: {backward}\n")
# Out:
# {'edge': (6188, 6198), 'source': 6188, 'destination': 6198, 'source_position': (-737464.4645496837, 7037098.559885431), 'destination_position': (-743579.4668179399, 7114147.184426849), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6193, 6188], 'source_degree': 6, 'destination_degree': 2, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 77290.9037110133}
# Forward sector for edge (6188, 6198): 2
# Backward sector for edge (6188, 6198): 6
#
# {'edge': (6188, 6189), 'source': 6188, 'destination': 6189, 'source_position': (-737464.4645496837, 7037098.559885431), 'destination_position': (-713004.5667961502, 7033429.505480125), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 24733.551268315976}
# Forward sector for edge (6188, 6189): 0
# Backward sector for edge (6188, 6189): 4
#
# {'edge': (6188, 6191), 'source': 6188, 'destination': 6191, 'source_position': (-737464.4645496837, 7037098.559885431), 'destination_position': (-716673.5458932046, 7055443.505209369), 'source_neighbors': [6198, 6189, 6191], 'destination_neighbors': [6188], 'source_degree': 6, 'destination_degree': 1, 'voltage': 220.0, 'forward_sector': 1, 'backward_sector': 5, 'distance': 27727.230613939606}
# Forward sector for edge (6188, 6191): 1
# Backward sector for edge (6188, 6191): 5
#
# {'edge': (6175, 6188), 'source': 6175, 'destination': 6188, 'source_position': (-895230.4544035797, 7032206.615032485), 'destination_position': (-737464.4645496837, 7037098.559885431), 'source_neighbors': [6177, 6188], 'destination_neighbors': [6175, 6181, 6186], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 0, 'backward_sector': 4, 'distance': 157841.81536913427}
# Forward sector for edge (6175, 6188): 0
# Backward sector for edge (6175, 6188): 4
#
# {'edge': (6186, 6188), 'source': 6186, 'destination': 6188, 'source_position': (-747248.3345955035, 7005300.7157662185), 'destination_position': (-737464.4645496837, 7037098.559885431), 'source_neighbors': [6188], 'destination_neighbors': [6175, 6181, 6186], 'source_degree': 4, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 33269.00965918932}
# Forward sector for edge (6186, 6188): 2
# Backward sector for edge (6186, 6188): 6
#
# {'edge': (6181, 6188), 'source': 6181, 'destination': 6188, 'source_position': (-716673.5458932046, 6984509.847294063), 'destination_position': (-737464.4645496837, 7037098.559885431), 'source_neighbors': [6186, 6188], 'destination_neighbors': [6175, 6181, 6186], 'source_degree': 2, 'destination_degree': 6, 'voltage': 220.0, 'forward_sector': 2, 'backward_sector': 6, 'distance': 56549.403096742004}
# Forward sector for edge (6181, 6188): 2
# Backward sector for edge (6181, 6188): 6

# %%
## Function to get index of nodes in the ordered neighbours list.

# This function initializes the set of (node, index) pairs, where 'node' is a node with 2 or more neighbors,
# and 'index' is a unique integer (starting from 1) representing the position of a neighbor in the
# counterclockwise ordering of neighbors around 'node'.

def node_neighbour_index_pairs_init(model):
    node_index_pairs = []
    for node, neighbors in ordered_neighbours_dict.items():
        # Start index from 0 for each node's neighbors
        for idx in range(0, len(neighbors)):
            node_index_pairs.append((node, idx))
    return node_index_pairs

# %%
# to get dynamic min length 
# Minimum length percentage
min_length_percentage = 0.05  # Adjust as needed

# Dictionary to store dynamic minimum lengths for each edge
dynamic_min_lengths = {}

for edge in G.edges():
    edge_info = get_edge_info(G, edge)
    
    forward = edge_info.get('forward_sector')
    backward = edge_info.get('backward_sector')
    
    if forward in (1, 3, 5, 7) or backward in (1, 3, 5, 7):
        dynamic_min_length = edge_info['distance'] *0.0705
    else:
        # Assuming 'distance' is an attribute in edge_info; if not, calculate it from positions
        dynamic_min_length = edge_info['distance'] * min_length_percentage
    
    # Store the calculated dynamic minimum length in the dictionary
    dynamic_min_lengths[edge] = dynamic_min_length
    
print(dynamic_min_lengths)


# before implementing adjusted percentage lengths:
# 
# 
# {(6188, 6198): 3864.5451855506653, 
# (6188, 6189): 1236.6775634157989, 
# (6188, 6191): 1386.3615306969805,  sector 1
# (6181, 6188): 2827.4701548371004, 
# (6186, 6188): 1663.4504829594662}
# Out:
# {(6194, 6199): 1984.9661132343895, (6174, 6199): 1991.8227899018825, (6174, 6180): 5921.729425219801, (6174, 6192): 9798.897943253261, (6193, 6198): 2776.0811032593033, (6193, 6398): 3250.720719804189, (6192, 6556): 2724.417918759915, (6192, 6193): 9624.023052287755, (6188, 6198): 3864.5451855506653, (6188, 6189): 1236.6775634157989, (6188, 6191): 1954.769758282742, (6175, 6177): 9912.411689893712, (6175, 6188): 7892.090768456714, (6176, 6177): 4779.462469691535, (6176, 6180): 2198.2116903695337, (6178, 6180): 1039.5403668493673, (6178, 6186): 15639.965524701256, (6178, 6194): 10105.154616303325, (6182, 6186): 5787.090464380257, (6186, 6188): 1663.4504829594662, (6181, 6186): 2606.668182197708, (6181, 6188): 2827.4701548371004, (6185, 6194): 10290.954100150582}

# %% [markdown]
# ## Check for intersecting edges

# %%
from shapely.geometry import LineString

def list_edge_intersections(G):
    intersecting_edge_pairs = []
    non_incident_edge_pairs = get_non_incident_edge_pairs(G)

    for edge1, edge2 in non_incident_edge_pairs:
        # Get the positions for the source and target nodes of each edge
        src_pos1, tgt_pos1 = G.nodes[edge1[0]]['pos'], G.nodes[edge1[1]]['pos']
        src_pos2, tgt_pos2 = G.nodes[edge2[0]]['pos'], G.nodes[edge2[1]]['pos']
        
        # Create LineString objects for each edge
        line1 = LineString([src_pos1, tgt_pos1])
        line2 = LineString([src_pos2, tgt_pos2])

        # Check if the two edges intersect
        if line1.intersects(line2):
            # If they intersect, add the edge pair to the list
            intersecting_edge_pairs.append((edge1, edge2))

    return intersecting_edge_pairs

# Call the function to get intersecting edge pairs
intersecting_edges = list_edge_intersections(G)

# Print the intersecting edge pairs
for edge_pair in intersecting_edges:
    print(f"Intersecting Edge Pair: {edge_pair}")
# Out:
# Intersecting Edge Pair: ((6174, 6180), (6178, 6186))
# Intersecting Edge Pair: ((6174, 6180), (6178, 6194))
# Intersecting Edge Pair: ((6188, 6198), (6185, 6194))
# Intersecting Edge Pair: ((6175, 6177), (6178, 6186))
# Intersecting Edge Pair: ((6175, 6177), (6185, 6194))
# Intersecting Edge Pair: ((6175, 6188), (6185, 6194))

# %% [markdown]
# ### Create new list of non intersecting non incident edges

# %%
# Create a new list excluding intersecting edge pairs
non_intersecting_non_incident_edges = [edge_pair for edge_pair in non_incident_edge_pairs if edge_pair not in intersecting_edges]

# Print the new list of non-intersecting, non-incident edge pairs
for edge_pair in non_intersecting_non_incident_edges:
    print(f"Non-Intersecting Non-Incident Edge Pair: {edge_pair}")
# Out:
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6174, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6174, 6192))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6194, 6199), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6199), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6192, 6193))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6180), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6193, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6193, 6398))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6174, 6192), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6198), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6192, 6556))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6193, 6398), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6556), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6188, 6198))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6188, 6189))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6188, 6191))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6175, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6192, 6193), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6198), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6189), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6175, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6188, 6191), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6177), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6176, 6177))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6176, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6175, 6188), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6178, 6180))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6177), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6178, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6178, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6176, 6180), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6180), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6186), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6186), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6182, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6186, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6181, 6186))
# Non-Intersecting Non-Incident Edge Pair: ((6178, 6194), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6186), (6181, 6188))
# Non-Intersecting Non-Incident Edge Pair: ((6182, 6186), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6186, 6188), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6181, 6186), (6185, 6194))
# Non-Intersecting Non-Incident Edge Pair: ((6181, 6188), (6185, 6194))

# %% [markdown]
# # Optimisation

# %%
model = ConcreteModel()



print(list(G.nodes()))
print(list(G.edges()))
# Set used to index the other components eg Param and Var, and to define the scope
model.Nodes = Set(initialize = list(G.nodes()))
model.Edges = Set(initialize = list(G.edges()))

# Initialize set of non-incident edge pairs
# dimen = 4: creates a collection of edge pairs where each pair is treated as a single tuple, 2 integers per edge
model.NonIncidentEdges = Set(initialize = non_incident_edge_pairs, dimen=4)
model.NonIntersecting_NonIncidentEdges = Set(initialize = non_intersecting_non_incident_edges, dimen=4)

# Set with 2 or more neighbours
# Storing set nodes with 2 or more neighbours that were predetermined in the dictionary
model.NodesWith2Neighbours = Set(initialize = ordered_neighbours_dict.keys())


# Initialize the set with the function that provides the (node, index) pairs
model.NodeNeighbours2IndexPairs = Set(dimen=2, initialize=node_neighbour_index_pairs_init)





### PARAM ###
## Param - fixed value in model that doesn't change during optimisation process ##
# pos defined earlier as tuple (x, y) in graph G
model.x_init = Param(model.Nodes, initialize={node: pos[node][0] for node in G.nodes()})
model.y_init = Param(model.Nodes, initialize={node: pos[node][1] for node in G.nodes()})


# Access information from dictionary of the edge info
edge_info = {edge: get_edge_info(G, edge) for edge in G.edges()}

# Initialize Params for static attributes from the edges
model.voltage = Param(model.Edges, initialize={edge: edge_info[edge]['voltage'] for edge in model.Edges})
model.sect_forward = Param(model.Edges, initialize={edge: edge_info[edge]['forward_sector'] for edge in model.Edges})
model.sect_backward = Param(model.Edges, initialize={edge: edge_info[edge]['backward_sector'] for edge in model.Edges})
model.distance = Param(model.Edges, initialize={edge: edge_info[edge]['distance'] for edge in model.Edges} )
#model.non_incident_edges = Param(model.Edges, initialize = {edge: edge_info[edge]['non_incident_edges'] for edge in model.Edges} )


# Param to store the ordered neighbors for each node in the model
model.OrderedNeighbours = Param(
    model.NodesWith2Neighbours,  # Index set for the Param, representing nodes with 2 or more neighbors
    within=Any,  # Specifies that the Param can hold any type of data, in this case, tuples of nodes
    initialize=lambda model, node: tuple(ordered_neighbours_dict[node])  # Initialization function
    # lambda function takes 2 arguments model and node (element from set Nodewith2Neigbours)
    # for each node, it gets the list or ordered neighbours from the dictionary
    # list is converted to tuple so that for Param, the contents are unchangeable
)
   





### VARIABLES ###
## Define Variables ##
model.x_pos = Var(model.Nodes, within = Reals, initialize = model.x_init)
model.y_pos = Var(model.Nodes, within = Reals, initialize = model.y_init)

model.z1_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] + model.y_pos[node])
model.z2_pos = Expression(model.Nodes, rule = lambda model, node: model.x_pos[node] - model.y_pos[node])


model.dir_forward = Var(model.Edges, within = Integers, bounds = (0, 7))
model.dir_backward = Var(model.Edges, within = Integers, bounds = (0, 7))


# Binary variable for octilinear constraint to determine where edge is drawn
model.alpha_pred = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_orig = Var(model.Edges, within = Binary, bounds = (0, 1))
model.alpha_succ = Var(model.Edges, within = Binary, bounds = (0, 1))


# Binary Variable for non-incident edge constraint
model.is_N = Var(model.NonIncidentEdges, within=Binary)
model.is_S = Var(model.NonIncidentEdges, within=Binary)
model.is_E = Var(model.NonIncidentEdges, within=Binary)
model.is_W = Var(model.NonIncidentEdges, within=Binary)
model.is_NE = Var(model.NonIncidentEdges, within=Binary)
model.is_NW = Var(model.NonIncidentEdges, within=Binary)
model.is_SE = Var(model.NonIncidentEdges, within=Binary)
model.is_SW = Var(model.NonIncidentEdges, within=Binary)

model.delta_pred = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_orig = Var(model.Edges, within = Integers, bounds = (0, 7))
model.delta_succ = Var(model.Edges, within = Integers, bounds = (0, 7))


max_degree = max(len(neighbors) for neighbors in ordered_neighbours_dict.values())


# Define Beta as a binary variable indexed by the (node, index) pairs
# Beta[node, idx] will be used in the constraints to identify the "wrap-around" point
# in the counterclockwise ordering of neighbors around each node
model.Beta = Var(model.NodeNeighbours2IndexPairs, within=Binary)




# Redefine rpos as a continuous variable representing the deviation magnitude
model.rpos = Var(model.Edges, within=NonNegativeReals)





#model.rpos = Var(model.Edges, within=Binary)
# Out:
# [6194, 6199, 6174, 6193, 6198, 6192, 6556, 6398, 6188, 6175, 6177, 6176, 6178, 6180, 6182, 6186, 6181, 6189, 6191, 6185]
# [(6194, 6199), (6174, 6199), (6174, 6180), (6174, 6192), (6193, 6198), (6193, 6398), (6192, 6556), (6192, 6193), (6188, 6198), (6188, 6189), (6188, 6191), (6175, 6177), (6175, 6188), (6176, 6177), (6176, 6180), (6178, 6180), (6178, 6186), (6178, 6194), (6182, 6186), (6186, 6188), (6181, 6186), (6181, 6188), (6185, 6194)]

# %% [markdown]
# ### Debugging

# %%
## DEBUGGING
for pair in model.NodeNeighbours2IndexPairs:
    print(pair)


for node in model.NodesWith2Neighbours:
    print(f"Node: {node}, Ordered Neighbours: {model.OrderedNeighbours[node]}")
    print(len(model.OrderedNeighbours[node]) - 1)

for node, index in model.NodeNeighbours2IndexPairs:
    print(f"Beta[{node}, {index}]: {model.Beta[node, index]}")
    
print(len(model.OrderedNeighbours[node]) - 1)
# Out:
# (6194, 0)
# (6194, 1)
# (6194, 2)
# (6199, 0)
# (6199, 1)
# (6174, 0)
# (6174, 1)
# (6174, 2)
# (6193, 0)
# (6193, 1)
# (6193, 2)
# (6198, 0)
# (6198, 1)
# (6192, 0)
# (6192, 1)
# (6192, 2)
# (6188, 0)
# (6188, 1)
# (6188, 2)
# (6188, 3)
# (6188, 4)
# (6188, 5)
# (6175, 0)
# (6175, 1)
# (6177, 0)
# (6177, 1)
# (6176, 0)
# (6176, 1)
# (6178, 0)
# (6178, 1)
# (6178, 2)
# (6180, 0)
# (6180, 1)
# (6180, 2)
# (6186, 0)
# (6186, 1)
# (6186, 2)
# (6186, 3)
# (6181, 0)
# (6181, 1)
# Node: 6194, Ordered Neighbours: (6185, 6199, 6178)
# 2
# Node: 6199, Ordered Neighbours: (6194, 6174)
# 1
# Node: 6174, Ordered Neighbours: (6199, 6192, 6180)
# 2
# Node: 6193, Ordered Neighbours: (6398, 6192, 6198)
# 2
# Node: 6198, Ordered Neighbours: (6193, 6188)
# 1
# Node: 6192, Ordered Neighbours: (6193, 6556, 6174)
# 2
# Node: 6188, Ordered Neighbours: (6189, 6191, 6198, 6175, 6186, 6181)
# 5
# Node: 6175, Ordered Neighbours: (6188, 6177)
# 1
# Node: 6177, Ordered Neighbours: (6175, 6176)
# 1
# Node: 6176, Ordered Neighbours: (6177, 6180)
# 1
# Node: 6178, Ordered Neighbours: (6180, 6186, 6194)
# 2
# Node: 6180, Ordered Neighbours: (6174, 6178, 6176)
# 2
# Node: 6186, Ordered Neighbours: (6181, 6188, 6178, 6182)
# 3
# Node: 6181, Ordered Neighbours: (6188, 6186)
# 1
# Beta[6194, 0]: Beta[6194,0]
# Beta[6194, 1]: Beta[6194,1]
# Beta[6194, 2]: Beta[6194,2]
# Beta[6199, 0]: Beta[6199,0]
# Beta[6199, 1]: Beta[6199,1]
# Beta[6174, 0]: Beta[6174,0]
# Beta[6174, 1]: Beta[6174,1]
# Beta[6174, 2]: Beta[6174,2]
# Beta[6193, 0]: Beta[6193,0]
# Beta[6193, 1]: Beta[6193,1]
# Beta[6193, 2]: Beta[6193,2]
# Beta[6198, 0]: Beta[6198,0]
# Beta[6198, 1]: Beta[6198,1]
# Beta[6192, 0]: Beta[6192,0]
# Beta[6192, 1]: Beta[6192,1]
# Beta[6192, 2]: Beta[6192,2]
# Beta[6188, 0]: Beta[6188,0]
# Beta[6188, 1]: Beta[6188,1]
# Beta[6188, 2]: Beta[6188,2]
# Beta[6188, 3]: Beta[6188,3]
# Beta[6188, 4]: Beta[6188,4]
# Beta[6188, 5]: Beta[6188,5]
# Beta[6175, 0]: Beta[6175,0]
# Beta[6175, 1]: Beta[6175,1]
# Beta[6177, 0]: Beta[6177,0]
# Beta[6177, 1]: Beta[6177,1]
# Beta[6176, 0]: Beta[6176,0]
# Beta[6176, 1]: Beta[6176,1]
# Beta[6178, 0]: Beta[6178,0]
# Beta[6178, 1]: Beta[6178,1]
# Beta[6178, 2]: Beta[6178,2]
# Beta[6180, 0]: Beta[6180,0]
# Beta[6180, 1]: Beta[6180,1]
# Beta[6180, 2]: Beta[6180,2]
# Beta[6186, 0]: Beta[6186,0]
# Beta[6186, 1]: Beta[6186,1]
# Beta[6186, 2]: Beta[6186,2]
# Beta[6186, 3]: Beta[6186,3]
# Beta[6181, 0]: Beta[6181,0]
# Beta[6181, 1]: Beta[6181,1]
# 1

# %% [markdown]
# # Octilinearity Constraint

# %%
#M= 10000

# Sum of Binary variables is equal to 1
# node1 and node2 are the src and dst nodes defined in model.Edges
def alpha_direction_constraint(model, node1, node2):
    return model.alpha_pred[node1, node2] + model.alpha_orig[node1, node2] + model.alpha_succ[node1, node2] == 1
model.alpha_direction_constraint = Constraint(model.Edges, rule = alpha_direction_constraint)


 
 # for each edge in tuple (node1, node2) in model.Edges, dir constraint is called and formed
def dir_forward_constraint(model, node1, node2):
    
    
    sect_forward_pred = (model.sect_forward[node1, node2] - 1) % 8
    sect_forward_orig = model.sect_forward[node1, node2]
    sect_forward_succ = (model.sect_forward[node1, node2] + 1) % 8
    
     # Debugging: Print the values of sectors and binary variables
    print(f"Edge: {(node1, node2)}")
    print(f"sect_forward_pred: {sect_forward_pred}, sect_forward_orig: {sect_forward_orig}, sect_forward_succ: {sect_forward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}")
    
    
    
    return model.dir_forward[node1, node2] == ((sect_forward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_forward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_forward_succ * model.alpha_succ[node1, node2])
                                        )

model.DirForwardConstraint = Constraint(model.Edges, rule=dir_forward_constraint)
 

def dir_backward_constraint(model, node1, node2):
    sect_backward_pred = (model.sect_backward[node1, node2] - 1) % 8
    sect_backward_orig = model.sect_backward[node1, node2]
    sect_backward_succ = (model.sect_backward[node1, node2] + 1) % 8
    
      # Debugging: Print the values of sectors and binary variables
    print(f"Edge: {(node1, node2)}")
    print(f"sect_backward_pred: {sect_backward_pred}, sect_backward_orig: {sect_backward_orig}, sect_backward_succ: {sect_backward_succ}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}") 
    
    return model.dir_backward[node1, node2] == ((sect_backward_pred * model.alpha_pred[node1, node2]) +
                                        (sect_backward_orig * model.alpha_orig[node1, node2]) +
                                        (sect_backward_succ * model.alpha_succ[node1, node2])
                                        )
    
model.DirBackwardConstraint = Constraint(model.Edges, rule = dir_backward_constraint) 




 
def sector_constraints_rule(model, node1, node2):

    # Retrieve original sector and minimum edge length
    sect_orig = model.sect_forward[node1, node2]
    min_length = dynamic_min_lengths[(node1, node2)] #(model.distance[node1, node2])*0.1  #1000

    # Define a large constant M for making constraints trivial when not active
    M = 30000  # Adjust as needed

    # Iterate over each alpha variable and its corresponding sector adjustment
    for alpha, adjustment in zip([model.alpha_pred, model.alpha_orig, model.alpha_succ], [-1, 0, 1]):
        # Adjusted sector based on alpha variable
        sect_adjusted = (sect_orig + adjustment) % 8

        # Conditions based on adjusted sector
        if sect_adjusted in [0, 4]:  # Horizontal
            model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.y_pos[node1] + model.y_pos[node2] <= M * (1 - alpha[node1, node2]))
            
            if sect_adjusted == 0:
                # For sector 0, node1 should be to the left of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node2] - model.x_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
            elif sect_adjusted == 4:
                # For sector 4, node1 should be to the right of node2 by at least min_length if this direction is selected
                model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))
                
        
        elif sect_adjusted in [2, 6]:  # Vertical
            # Add corresponding constraints for this sector
            model.sector_constraints.add(model.x_pos[node1] - model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-model.x_pos[node1] + model.x_pos[node2] <= M*(1 - alpha[node1, node2]))
            if sect_adjusted == 2:  # Upwards
                # Node2's y_pos should be at least min_length above Node1's y_pos
                model.sector_constraints.add(model.y_pos[node2] - model.y_pos[node1] >= min_length - M * (1 - alpha[node1, node2]))
            elif sect_adjusted == 6:  # Downwards
                # Node2's y_pos should be at least min_length below Node1's y_pos
                model.sector_constraints.add(model.y_pos[node1] - model.y_pos[node2] >= min_length - M * (1 - alpha[node1, node2]))






        elif sect_adjusted == 1:         #upright diagonal /
            # dx = dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) - (model.x_pos[node2] - model.x_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # dx + dy >= min length of diagonal
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))
            
        elif sect_adjusted == 5:        # Diagonal downwards /
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M*(1 - alpha[node1, node2]))
            # -dx - dy >= min length
            # negative diagonal
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M*(1 - alpha[node1, node2]))

            


            
        ## Diagonal \
            
        elif sect_adjusted == 3:    # Up left diagonal \
            # -dx = dy
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dx is negative
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) <= 0)
            
            # -dx + dy >= min length (dx is negative value)
            model.sector_constraints.add(-(model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
            
            
            
        elif sect_adjusted == 7:    # Down right Diagonal \
            # dx = -dy
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) + (model.y_pos[node2] - model.y_pos[node1]) <= M * (1 - alpha[node1, node2]))
            
            # Ensure dy is negative
            model.sector_constraints.add((model.y_pos[node2] - model.y_pos[node1]) <= 0)
        
            # dx - dy >= min length (since dy is negative, we use -dy)
            model.sector_constraints.add((model.x_pos[node2] - model.x_pos[node1]) - (model.y_pos[node2] - model.y_pos[node1]) >= min_length - M * (1 - alpha[node1, node2]))
   




       



       
            # Fill in your constraints similar to above
    return Constraint.Skip 

# Initialize the constraint list on your model if not already done
model.sector_constraints = ConstraintList()

# Apply the rule to each edge
model.SectorConstraint = Constraint(model.Edges, rule=sector_constraints_rule)
# Out:
# Edge: (6194, 6199)
# sect_forward_pred: 2, sect_forward_orig: 3, sect_forward_succ: 4
# alpha_pred[6194, 6199]: None
# alpha_orig[6194, 6199]: None
# alpha_succ[6194, 6199]: None
# Edge: (6174, 6199)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6174, 6199]: None
# alpha_orig[6174, 6199]: None
# alpha_succ[6174, 6199]: None
# Edge: (6174, 6180)
# sect_forward_pred: 5, sect_forward_orig: 6, sect_forward_succ: 7
# alpha_pred[6174, 6180]: None
# alpha_orig[6174, 6180]: None
# alpha_succ[6174, 6180]: None
# Edge: (6174, 6192)
# sect_forward_pred: 0, sect_forward_orig: 1, sect_forward_succ: 2
# alpha_pred[6174, 6192]: None
# alpha_orig[6174, 6192]: None
# alpha_succ[6174, 6192]: None
# Edge: (6193, 6198)
# sect_forward_pred: 5, sect_forward_orig: 6, sect_forward_succ: 7
# alpha_pred[6193, 6198]: None
# alpha_orig[6193, 6198]: None
# alpha_succ[6193, 6198]: None
# Edge: (6193, 6398)
# sect_forward_pred: 1, sect_forward_orig: 2, sect_forward_succ: 3
# alpha_pred[6193, 6398]: None
# alpha_orig[6193, 6398]: None
# alpha_succ[6193, 6398]: None
# Edge: (6192, 6556)
# sect_forward_pred: 1, sect_forward_orig: 2, sect_forward_succ: 3
# alpha_pred[6192, 6556]: None
# alpha_orig[6192, 6556]: None
# alpha_succ[6192, 6556]: None
# Edge: (6192, 6193)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6192, 6193]: None
# alpha_orig[6192, 6193]: None
# alpha_succ[6192, 6193]: None
# Edge: (6188, 6198)
# sect_forward_pred: 1, sect_forward_orig: 2, sect_forward_succ: 3
# alpha_pred[6188, 6198]: None
# alpha_orig[6188, 6198]: None
# alpha_succ[6188, 6198]: None
# Edge: (6188, 6189)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6188, 6189]: None
# alpha_orig[6188, 6189]: None
# alpha_succ[6188, 6189]: None
# Edge: (6188, 6191)
# sect_forward_pred: 0, sect_forward_orig: 1, sect_forward_succ: 2
# alpha_pred[6188, 6191]: None
# alpha_orig[6188, 6191]: None
# alpha_succ[6188, 6191]: None
# Edge: (6175, 6177)
# sect_forward_pred: 4, sect_forward_orig: 5, sect_forward_succ: 6
# alpha_pred[6175, 6177]: None
# alpha_orig[6175, 6177]: None
# alpha_succ[6175, 6177]: None
# Edge: (6175, 6188)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6175, 6188]: None
# alpha_orig[6175, 6188]: None
# alpha_succ[6175, 6188]: None
# Edge: (6176, 6177)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6176, 6177]: None
# alpha_orig[6176, 6177]: None
# alpha_succ[6176, 6177]: None
# Edge: (6176, 6180)
# sect_forward_pred: 0, sect_forward_orig: 1, sect_forward_succ: 2
# alpha_pred[6176, 6180]: None
# alpha_orig[6176, 6180]: None
# alpha_succ[6176, 6180]: None
# Edge: (6178, 6180)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6178, 6180]: None
# alpha_orig[6178, 6180]: None
# alpha_succ[6178, 6180]: None
# Edge: (6178, 6186)
# sect_forward_pred: 7, sect_forward_orig: 0, sect_forward_succ: 1
# alpha_pred[6178, 6186]: None
# alpha_orig[6178, 6186]: None
# alpha_succ[6178, 6186]: None
# Edge: (6178, 6194)
# sect_forward_pred: 0, sect_forward_orig: 1, sect_forward_succ: 2
# alpha_pred[6178, 6194]: None
# alpha_orig[6178, 6194]: None
# alpha_succ[6178, 6194]: None
# Edge: (6182, 6186)
# sect_forward_pred: 0, sect_forward_orig: 1, sect_forward_succ: 2
# alpha_pred[6182, 6186]: None
# alpha_orig[6182, 6186]: None
# alpha_succ[6182, 6186]: None
# Edge: (6186, 6188)
# sect_forward_pred: 1, sect_forward_orig: 2, sect_forward_succ: 3
# alpha_pred[6186, 6188]: None
# alpha_orig[6186, 6188]: None
# alpha_succ[6186, 6188]: None
# Edge: (6181, 6186)
# sect_forward_pred: 2, sect_forward_orig: 3, sect_forward_succ: 4
# alpha_pred[6181, 6186]: None
# alpha_orig[6181, 6186]: None
# alpha_succ[6181, 6186]: None
# Edge: (6181, 6188)
# sect_forward_pred: 1, sect_forward_orig: 2, sect_forward_succ: 3
# alpha_pred[6181, 6188]: None
# alpha_orig[6181, 6188]: None
# alpha_succ[6181, 6188]: None
# Edge: (6185, 6194)
# sect_forward_pred: 3, sect_forward_orig: 4, sect_forward_succ: 5
# alpha_pred[6185, 6194]: None
# alpha_orig[6185, 6194]: None
# alpha_succ[6185, 6194]: None
# Edge: (6194, 6199)
# sect_backward_pred: 6, sect_backward_orig: 7, sect_backward_succ: 0
# alpha_pred[6194, 6199]: None
# alpha_orig[6194, 6199]: None
# alpha_succ[6194, 6199]: None
# Edge: (6174, 6199)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6174, 6199]: None
# alpha_orig[6174, 6199]: None
# alpha_succ[6174, 6199]: None
# Edge: (6174, 6180)
# sect_backward_pred: 1, sect_backward_orig: 2, sect_backward_succ: 3
# alpha_pred[6174, 6180]: None
# alpha_orig[6174, 6180]: None
# alpha_succ[6174, 6180]: None
# Edge: (6174, 6192)
# sect_backward_pred: 4, sect_backward_orig: 5, sect_backward_succ: 6
# alpha_pred[6174, 6192]: None
# alpha_orig[6174, 6192]: None
# alpha_succ[6174, 6192]: None
# Edge: (6193, 6198)
# sect_backward_pred: 1, sect_backward_orig: 2, sect_backward_succ: 3
# alpha_pred[6193, 6198]: None
# alpha_orig[6193, 6198]: None
# alpha_succ[6193, 6198]: None
# Edge: (6193, 6398)
# sect_backward_pred: 5, sect_backward_orig: 6, sect_backward_succ: 7
# alpha_pred[6193, 6398]: None
# alpha_orig[6193, 6398]: None
# alpha_succ[6193, 6398]: None
# Edge: (6192, 6556)
# sect_backward_pred: 5, sect_backward_orig: 6, sect_backward_succ: 7
# alpha_pred[6192, 6556]: None
# alpha_orig[6192, 6556]: None
# alpha_succ[6192, 6556]: None
# Edge: (6192, 6193)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6192, 6193]: None
# alpha_orig[6192, 6193]: None
# alpha_succ[6192, 6193]: None
# Edge: (6188, 6198)
# sect_backward_pred: 5, sect_backward_orig: 6, sect_backward_succ: 7
# alpha_pred[6188, 6198]: None
# alpha_orig[6188, 6198]: None
# alpha_succ[6188, 6198]: None
# Edge: (6188, 6189)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6188, 6189]: None
# alpha_orig[6188, 6189]: None
# alpha_succ[6188, 6189]: None
# Edge: (6188, 6191)
# sect_backward_pred: 4, sect_backward_orig: 5, sect_backward_succ: 6
# alpha_pred[6188, 6191]: None
# alpha_orig[6188, 6191]: None
# alpha_succ[6188, 6191]: None
# Edge: (6175, 6177)
# sect_backward_pred: 0, sect_backward_orig: 1, sect_backward_succ: 2
# alpha_pred[6175, 6177]: None
# alpha_orig[6175, 6177]: None
# alpha_succ[6175, 6177]: None
# Edge: (6175, 6188)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6175, 6188]: None
# alpha_orig[6175, 6188]: None
# alpha_succ[6175, 6188]: None
# Edge: (6176, 6177)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6176, 6177]: None
# alpha_orig[6176, 6177]: None
# alpha_succ[6176, 6177]: None
# Edge: (6176, 6180)
# sect_backward_pred: 4, sect_backward_orig: 5, sect_backward_succ: 6
# alpha_pred[6176, 6180]: None
# alpha_orig[6176, 6180]: None
# alpha_succ[6176, 6180]: None
# Edge: (6178, 6180)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6178, 6180]: None
# alpha_orig[6178, 6180]: None
# alpha_succ[6178, 6180]: None
# Edge: (6178, 6186)
# sect_backward_pred: 3, sect_backward_orig: 4, sect_backward_succ: 5
# alpha_pred[6178, 6186]: None
# alpha_orig[6178, 6186]: None
# alpha_succ[6178, 6186]: None
# Edge: (6178, 6194)
# sect_backward_pred: 4, sect_backward_orig: 5, sect_backward_succ: 6
# alpha_pred[6178, 6194]: None
# alpha_orig[6178, 6194]: None
# alpha_succ[6178, 6194]: None
# Edge: (6182, 6186)
# sect_backward_pred: 4, sect_backward_orig: 5, sect_backward_succ: 6
# alpha_pred[6182, 6186]: None
# alpha_orig[6182, 6186]: None
# alpha_succ[6182, 6186]: None
# Edge: (6186, 6188)
# sect_backward_pred: 5, sect_backward_orig: 6, sect_backward_succ: 7
# alpha_pred[6186, 6188]: None
# alpha_orig[6186, 6188]: None
# alpha_succ[6186, 6188]: None
# Edge: (6181, 6186)
# sect_backward_pred: 6, sect_backward_orig: 7, sect_backward_succ: 0
# alpha_pred[6181, 6186]: None
# alpha_orig[6181, 6186]: None
# alpha_succ[6181, 6186]: None
# Edge: (6181, 6188)
# sect_backward_pred: 5, sect_backward_orig: 6, sect_backward_succ: 7
# alpha_pred[6181, 6188]: None
# alpha_orig[6181, 6188]: None
# alpha_succ[6181, 6188]: None
# Edge: (6185, 6194)
# sect_backward_pred: 7, sect_backward_orig: 0, sect_backward_succ: 1
# alpha_pred[6185, 6194]: None
# alpha_orig[6185, 6194]: None
# alpha_succ[6185, 6194]: None

# %% [markdown]
# ## Circular Vertex Order
# The initial circular ordering of neighbour nodes (counterclockwise) should be the same after optimisation.
#
# For each node in the map, the sequence in which the neighbouring nodes are arranged around a particular node should match the order in which the neighbouring nodes are arranged in the final layout.

# %%
## Helper Function for the circular vertex order
## Determines if node with more than 2 neighbours is the source or destination node
## So the correct direction can be assigned to it

def directional_sector(model, node, neighbor):
    if (node, neighbor) in model.Edges:
        return model.dir_forward[node, neighbor]
    elif (neighbor, node) in model.Edges:
        return model.dir_backward[neighbor, node]
    else:
        return None  # This case should ideally never happen if the graph is well-defined

# %%
# Beta Binary Sum Constraint


def beta_sum_constraint_rule(model, node):
    # Ensure we use 0-based indexing to match the updated indexing in Beta
    # Note that RangeSet in Pyomo starts from 1, so we adjust the range accordingly
    return sum(model.Beta[node, index] for index in range(0, len(model.OrderedNeighbours[node]) )) == 1

model.BetaSumConstraint = Constraint(model.NodesWith2Neighbours, rule=beta_sum_constraint_rule)




# Define the ConstraintList in your Pyomo model
model.OrderMaintenanceConstraints = ConstraintList()


def add_order_maintenance_constraints(model):
    for node, neighbours in ordered_neighbours_dict.items():
        num_neighbours = len(neighbours)
        
        
        for index in range(num_neighbours):
            print(index)
            # Handle all neighbor pairs except the last pair (which wraps around)
            if index < num_neighbours - 1:
                next_index = index + 1
            else:
                next_index = 0      # wrap around case
                
                
            # Use the helper function to dynamically select dir_forward or dir_backward
            dir_sect = directional_sector(model, node, neighbours[index])
            next_dir_sect = directional_sector(model, node, neighbours[next_index])
            
            # Debugging prints before adding the constraint
            print(f"Node: {node}, Neighbour: {neighbours[index]}, Directional Sector: {dir_sect}")
            print(f"Node: {node}, Next Neighbour: {neighbours[next_index]}, Next Directional Sector: {next_dir_sect}")
            if index == num_neighbours - 1:  # For wrap-around case
                print(f"\nNode: {node}, Index: {index}, Beta: {model.Beta[node, index].value if model.Beta[node, index].value is not None else 'Not solved yet'}")

            
            
            if dir_sect is not None and next_dir_sect is not None:
                    model.OrderMaintenanceConstraints.add(dir_sect <= next_dir_sect - 1 + 8*model.Beta[node, index])

                

            
           
# Call the function to add the constraints to the ConstraintList
add_order_maintenance_constraints(model)
# Out:
# 0
# Node: 6194, Neighbour: 6185, Directional Sector: dir_backward[6185,6194]
# Node: 6194, Next Neighbour: 6199, Next Directional Sector: dir_forward[6194,6199]
# 1
# Node: 6194, Neighbour: 6199, Directional Sector: dir_forward[6194,6199]
# Node: 6194, Next Neighbour: 6178, Next Directional Sector: dir_backward[6178,6194]
# 2
# Node: 6194, Neighbour: 6178, Directional Sector: dir_backward[6178,6194]
# Node: 6194, Next Neighbour: 6185, Next Directional Sector: dir_backward[6185,6194]
#
# Node: 6194, Index: 2, Beta: Not solved yet
# 0
# Node: 6199, Neighbour: 6194, Directional Sector: dir_backward[6194,6199]
# Node: 6199, Next Neighbour: 6174, Next Directional Sector: dir_backward[6174,6199]
# 1
# Node: 6199, Neighbour: 6174, Directional Sector: dir_backward[6174,6199]
# Node: 6199, Next Neighbour: 6194, Next Directional Sector: dir_backward[6194,6199]
#
# Node: 6199, Index: 1, Beta: Not solved yet
# 0
# Node: 6174, Neighbour: 6199, Directional Sector: dir_forward[6174,6199]
# Node: 6174, Next Neighbour: 6192, Next Directional Sector: dir_forward[6174,6192]
# 1
# Node: 6174, Neighbour: 6192, Directional Sector: dir_forward[6174,6192]
# Node: 6174, Next Neighbour: 6180, Next Directional Sector: dir_forward[6174,6180]
# 2
# Node: 6174, Neighbour: 6180, Directional Sector: dir_forward[6174,6180]
# Node: 6174, Next Neighbour: 6199, Next Directional Sector: dir_forward[6174,6199]
#
# Node: 6174, Index: 2, Beta: Not solved yet
# 0
# Node: 6193, Neighbour: 6398, Directional Sector: dir_forward[6193,6398]
# Node: 6193, Next Neighbour: 6192, Next Directional Sector: dir_backward[6192,6193]
# 1
# Node: 6193, Neighbour: 6192, Directional Sector: dir_backward[6192,6193]
# Node: 6193, Next Neighbour: 6198, Next Directional Sector: dir_forward[6193,6198]
# 2
# Node: 6193, Neighbour: 6198, Directional Sector: dir_forward[6193,6198]
# Node: 6193, Next Neighbour: 6398, Next Directional Sector: dir_forward[6193,6398]
#
# Node: 6193, Index: 2, Beta: Not solved yet
# 0
# Node: 6198, Neighbour: 6193, Directional Sector: dir_backward[6193,6198]
# Node: 6198, Next Neighbour: 6188, Next Directional Sector: dir_backward[6188,6198]
# 1
# Node: 6198, Neighbour: 6188, Directional Sector: dir_backward[6188,6198]
# Node: 6198, Next Neighbour: 6193, Next Directional Sector: dir_backward[6193,6198]
#
# Node: 6198, Index: 1, Beta: Not solved yet
# 0
# Node: 6192, Neighbour: 6193, Directional Sector: dir_forward[6192,6193]
# Node: 6192, Next Neighbour: 6556, Next Directional Sector: dir_forward[6192,6556]
# 1
# Node: 6192, Neighbour: 6556, Directional Sector: dir_forward[6192,6556]
# Node: 6192, Next Neighbour: 6174, Next Directional Sector: dir_backward[6174,6192]
# 2
# Node: 6192, Neighbour: 6174, Directional Sector: dir_backward[6174,6192]
# Node: 6192, Next Neighbour: 6193, Next Directional Sector: dir_forward[6192,6193]
#
# Node: 6192, Index: 2, Beta: Not solved yet
# 0
# Node: 6188, Neighbour: 6189, Directional Sector: dir_forward[6188,6189]
# Node: 6188, Next Neighbour: 6191, Next Directional Sector: dir_forward[6188,6191]
# 1
# Node: 6188, Neighbour: 6191, Directional Sector: dir_forward[6188,6191]
# Node: 6188, Next Neighbour: 6198, Next Directional Sector: dir_forward[6188,6198]
# 2
# Node: 6188, Neighbour: 6198, Directional Sector: dir_forward[6188,6198]
# Node: 6188, Next Neighbour: 6175, Next Directional Sector: dir_backward[6175,6188]
# 3
# Node: 6188, Neighbour: 6175, Directional Sector: dir_backward[6175,6188]
# Node: 6188, Next Neighbour: 6186, Next Directional Sector: dir_backward[6186,6188]
# 4
# Node: 6188, Neighbour: 6186, Directional Sector: dir_backward[6186,6188]
# Node: 6188, Next Neighbour: 6181, Next Directional Sector: dir_backward[6181,6188]
# 5
# Node: 6188, Neighbour: 6181, Directional Sector: dir_backward[6181,6188]
# Node: 6188, Next Neighbour: 6189, Next Directional Sector: dir_forward[6188,6189]
#
# Node: 6188, Index: 5, Beta: Not solved yet
# 0
# Node: 6175, Neighbour: 6188, Directional Sector: dir_forward[6175,6188]
# Node: 6175, Next Neighbour: 6177, Next Directional Sector: dir_forward[6175,6177]
# 1
# Node: 6175, Neighbour: 6177, Directional Sector: dir_forward[6175,6177]
# Node: 6175, Next Neighbour: 6188, Next Directional Sector: dir_forward[6175,6188]
#
# Node: 6175, Index: 1, Beta: Not solved yet
# 0
# Node: 6177, Neighbour: 6175, Directional Sector: dir_backward[6175,6177]
# Node: 6177, Next Neighbour: 6176, Next Directional Sector: dir_backward[6176,6177]
# 1
# Node: 6177, Neighbour: 6176, Directional Sector: dir_backward[6176,6177]
# Node: 6177, Next Neighbour: 6175, Next Directional Sector: dir_backward[6175,6177]
#
# Node: 6177, Index: 1, Beta: Not solved yet
# 0
# Node: 6176, Neighbour: 6177, Directional Sector: dir_forward[6176,6177]
# Node: 6176, Next Neighbour: 6180, Next Directional Sector: dir_forward[6176,6180]
# 1
# Node: 6176, Neighbour: 6180, Directional Sector: dir_forward[6176,6180]
# Node: 6176, Next Neighbour: 6177, Next Directional Sector: dir_forward[6176,6177]
#
# Node: 6176, Index: 1, Beta: Not solved yet
# 0
# Node: 6178, Neighbour: 6180, Directional Sector: dir_forward[6178,6180]
# Node: 6178, Next Neighbour: 6186, Next Directional Sector: dir_forward[6178,6186]
# 1
# Node: 6178, Neighbour: 6186, Directional Sector: dir_forward[6178,6186]
# Node: 6178, Next Neighbour: 6194, Next Directional Sector: dir_forward[6178,6194]
# 2
# Node: 6178, Neighbour: 6194, Directional Sector: dir_forward[6178,6194]
# Node: 6178, Next Neighbour: 6180, Next Directional Sector: dir_forward[6178,6180]
#
# Node: 6178, Index: 2, Beta: Not solved yet
# 0
# Node: 6180, Neighbour: 6174, Directional Sector: dir_backward[6174,6180]
# Node: 6180, Next Neighbour: 6178, Next Directional Sector: dir_backward[6178,6180]
# 1
# Node: 6180, Neighbour: 6178, Directional Sector: dir_backward[6178,6180]
# Node: 6180, Next Neighbour: 6176, Next Directional Sector: dir_backward[6176,6180]
# 2
# Node: 6180, Neighbour: 6176, Directional Sector: dir_backward[6176,6180]
# Node: 6180, Next Neighbour: 6174, Next Directional Sector: dir_backward[6174,6180]
#
# Node: 6180, Index: 2, Beta: Not solved yet
# 0
# Node: 6186, Neighbour: 6181, Directional Sector: dir_backward[6181,6186]
# Node: 6186, Next Neighbour: 6188, Next Directional Sector: dir_forward[6186,6188]
# 1
# Node: 6186, Neighbour: 6188, Directional Sector: dir_forward[6186,6188]
# Node: 6186, Next Neighbour: 6178, Next Directional Sector: dir_backward[6178,6186]
# 2
# Node: 6186, Neighbour: 6178, Directional Sector: dir_backward[6178,6186]
# Node: 6186, Next Neighbour: 6182, Next Directional Sector: dir_backward[6182,6186]
# 3
# Node: 6186, Neighbour: 6182, Directional Sector: dir_backward[6182,6186]
# Node: 6186, Next Neighbour: 6181, Next Directional Sector: dir_backward[6181,6186]
#
# Node: 6186, Index: 3, Beta: Not solved yet
# 0
# Node: 6181, Neighbour: 6188, Directional Sector: dir_forward[6181,6188]
# Node: 6181, Next Neighbour: 6186, Next Directional Sector: dir_forward[6181,6186]
# 1
# Node: 6181, Neighbour: 6186, Directional Sector: dir_forward[6181,6186]
# Node: 6181, Next Neighbour: 6188, Next Directional Sector: dir_forward[6181,6188]
#
# Node: 6181, Index: 1, Beta: Not solved yet

# %% [markdown]
# ## Edge Spacing
# Each edge must have a distance of at least dmin > 0 from each non incident edge.
#
# - Prevents edge crossings
# - maintains planarity (edges have minimum separation in at least 1 octilinear direction)
# - enhances visualisation
# - preserves topology structure

# %%
def non_incident_edge_direction_constraint_rule(model, u1, v1, u2, v2):
    
    e1 = (u1, v1)
    e2 = (u2, v2)
        
    return (model.is_N[e1, e2] + model.is_S[e1, e2] + model.is_E[e1, e2] + model.is_W[e1, e2] +
            model.is_NE[e1, e2] + model.is_NW[e1, e2] + model.is_SE[e1, e2] + model.is_SW[e1, e2] >= 1)
    
#model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)
model.NonIncidentEdgeDirectionConstraint = Constraint(model.NonIntersecting_NonIncidentEdges, rule=non_incident_edge_direction_constraint_rule)

# Initialize ConstraintList outside of function
# Adds new constraints to list in model without reinitializing it
model.edgeSpacingConstraints = ConstraintList()

def edge_spacing_constraint(model, u1, v1, u2, v2):
    dmin = 500
    
    ## infeasibility coming from too small M value due to large distances between
    M = 30000
    
    
    e1 = (u1, v1)
    e2 = (u2, v2)
    
    # is_N[e1, e2] means that e1 is north of e1
    
    ## North Constraint
    c1 = model.y_pos[u2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c2 = model.y_pos[v2] - model.y_pos[u1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c3 = model.y_pos[u2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin
    c4 = model.y_pos[v2] - model.y_pos[v1] <= M * (1 - model.is_N[e1, e2]) - dmin

    
    # South
    c5 = model.y_pos[u1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c6 = model.y_pos[v1] - model.y_pos[u2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c7 = model.y_pos[u1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin
    c8 = model.y_pos[v1] - model.y_pos[v2] <= M * (1 - model.is_S[e1, e2]) - dmin

    
    # is_E[e1, e2] = 1 means that e1 is East of e2
    ## East
    c9 = model.x_pos[u2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c10 = model.x_pos[v2] - model.x_pos[u1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c11 = model.x_pos[u2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin
    c12 = model.x_pos[v2] - model.x_pos[v1] <= M * (1 - model.is_E[e1, e2]) - dmin

    
    
    
    ## West
    c13 = model.x_pos[u1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c14 = model.x_pos[v1] - model.x_pos[u2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c15 = model.x_pos[u1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin
    c16 = model.x_pos[v1] - model.x_pos[v2] <= M * (1 - model.is_W[e1, e2]) - dmin

    
    
    ## NE
    c17 = model.z1_pos[u2] - model.z1_pos[u1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c18 = model.z1_pos[v2] - model.z1_pos[u1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c19 = model.z1_pos[u2] - model.z1_pos[v1] <= M * (1 - model.is_NE[e1, e2]) - dmin
    c20 = model.z1_pos[v2] - model.z1_pos[v1] <= M * (1 - model.is_NE[e1, e2]) - dmin

    
    
    ## NW
    c21 = model.z2_pos[u1] - model.z2_pos[u2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c22 = model.z2_pos[u1] - model.z2_pos[v2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c23 = model.z2_pos[v1] - model.z2_pos[u2] <= M * (1 - model.is_NW[e1, e2]) - dmin
    c24 = model.z2_pos[v1] - model.z2_pos[v2] <= M * (1 - model.is_NW[e1, e2]) - dmin

    
    
    # SE
    c25 = model.z2_pos[u2] - model.z2_pos[u1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c26 = model.z2_pos[v2] - model.z2_pos[u1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c27 = model.z2_pos[u2] - model.z2_pos[v1] <= M * (1 - model.is_SE[e1, e2]) - dmin
    c28 = model.z2_pos[v2] - model.z2_pos[v1] <= M * (1 - model.is_SE[e1, e2]) - dmin

    
    
    
    
    ## SW
    c29 = model.z1_pos[u1] - model.z1_pos[u2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c30 = model.z1_pos[u1] - model.z1_pos[v2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c31 = model.z1_pos[v1] - model.z1_pos[u2] <= M * (1 - model.is_SW[e1, e2]) - dmin
    c32 = model.z1_pos[v1] - model.z1_pos[v2] <= M * (1 - model.is_SW[e1, e2]) - dmin

    
    constraint_list = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32]

    # Add all constraints to the constraint list
    for constraint in constraint_list:
        model.edgeSpacingConstraints.add(constraint)
 
 
 
        
# Call edge_spacing_constraint for each non-incident edge pair
for u1, v1, u2, v2 in model.NonIncidentEdges:
    edge_spacing_constraint(model, u1, v1, u2, v2)

# %% [markdown]
# # Relative Position Constraint and Objective Function

# %%
# Updated constraint without Big M
def rpos_constraint_upper(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= model.dir_forward[u, v] - model.sect_forward[u, v]

model.RposConstraintUpper = Constraint(model.Edges, rule=rpos_constraint_upper)

# Updated constraint without Big M
def rpos_constraint_lower(model, u, v):
    # Directly express the deviation without a multiplier
    return model.rpos[u, v] >= -model.dir_forward[u, v] + model.sect_forward[u, v]

model.RposConstraintLower = Constraint(model.Edges, rule=rpos_constraint_lower)

# Objective function to minimize the sum of the deviations
def relative_position_cost(model):
    OF = sum(model.rpos[edge] for edge in model.Edges)
    print(f"cost is: {OF}")
    return OF

model.RelativePositionObjective = Objective(rule=relative_position_cost, sense=minimize)
""" 

def rpos_constraint_upper(model, u, v):
    expr = model.dir_forward[u, v] - model.sect_forward[u, v] <= M * model.rpos[u, v]
    print(f"Upper Constraint ({u}, {v}): {expr}")
    return expr

def rpos_constraint_lower(model, u, v):
    expr = -model.dir_forward[u, v] + model.sect_forward[u, v] <= M * model.rpos[u, v]
    print(f"Lower Constraint ({u}, {v}): {expr}")
    return expr

model.RposConstraintUpper = Constraint(model.Edges, rule=rpos_constraint_upper)
model.RposConstraintLower = Constraint(model.Edges, rule=rpos_constraint_lower)

def relative_position_cost(model):
    cost_expr = sum(model.rpos[edge] for edge in model.Edges)
    print(f"Relative Position Cost: {cost_expr}")
    return cost_expr

model.RelativePositionObjective = Objective(rule=relative_position_cost, sense=minimize)
"""
# Out:
# cost is: rpos[6194,6199] + rpos[6174,6199] + rpos[6174,6180] + rpos[6174,6192] + rpos[6193,6198] + rpos[6193,6398] + rpos[6192,6556] + rpos[6192,6193] + rpos[6188,6198] + rpos[6188,6189] + rpos[6188,6191] + rpos[6175,6177] + rpos[6175,6188] + rpos[6176,6177] + rpos[6176,6180] + rpos[6178,6180] + rpos[6178,6186] + rpos[6178,6194] + rpos[6182,6186] + rpos[6186,6188] + rpos[6181,6186] + rpos[6181,6188] + rpos[6185,6194]
# ' \n\ndef rpos_constraint_upper(model, u, v):\n    expr = model.dir_forward[u, v] - model.sect_forward[u, v] <= M * model.rpos[u, v]\n    print(f"Upper Constraint ({u}, {v}): {expr}")\n    return expr\n\ndef rpos_constraint_lower(model, u, v):\n    expr = -model.dir_forward[u, v] + model.sect_forward[u, v] <= M * model.rpos[u, v]\n    print(f"Lower Constraint ({u}, {v}): {expr}")\n    return expr\n\nmodel.RposConstraintUpper = Constraint(model.Edges, rule=rpos_constraint_upper)\nmodel.RposConstraintLower = Constraint(model.Edges, rule=rpos_constraint_lower)\n\ndef relative_position_cost(model):\n    cost_expr = sum(model.rpos[edge] for edge in model.Edges)\n    print(f"Relative Position Cost: {cost_expr}")\n    return cost_expr\n\nmodel.RelativePositionObjective = Objective(rule=relative_position_cost, sense=minimize)\n'

# %% [markdown]
# # Solver

# %%
#solver.solve(model, tee=True)  # 'tee=True' enables solver output
#Solve the model
solver = SolverFactory('gurobi')
results = solver.solve(model, tee = True)

# Assuming 'results' contains the solver results
print(results.solver.status)
print(results.solver.termination_condition)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmpl4po4s9t.pyomo.lp
# Reading time = 0.41 seconds
# x1: 7234 rows, 1882 columns, 29527 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7234 rows, 1882 columns and 29527 nonzeros
# Model fingerprint: 0xd1246c01
# Variable types: 63 continuous, 1819 integer (1773 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 271 rows and 178 columns
# Presolve time: 0.18s
# Presolved: 6963 rows, 1704 columns, 26635 nonzeros
# Variable types: 38 continuous, 1666 integer (1650 binary)
#
# Root relaxation: objective 3.002249e+00, 1343 iterations, 0.08 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.00225    0   20          -    3.00225      -     -    0s
#      0     0    3.00225    0   18          -    3.00225      -     -    0s
#      0     0    7.06422    0   93          -    7.06422      -     -    0s
#      0     0   10.02156    0   10          -   10.02156      -     -    0s
#      0     0   10.02156    0   12          -   10.02156      -     -    0s
#      0     0   10.04222    0   12          -   10.04222      -     -    0s
#      0     0   10.04222    0   32          -   10.04222      -     -    1s
#      0     0   10.04222    0   29          -   10.04222      -     -    1s
#      0     0   10.04222    0   26          -   10.04222      -     -    1s
#      0     0   10.04222    0   28          -   10.04222      -     -    1s
#      0     0   10.04222    0   14          -   10.04222      -     -    1s
#      0     0   10.04222    0   16          -   10.04222      -     -    1s
# H    0     0                      34.0000000   10.04222  70.5%     -    1s
#      0     0   10.04222    0   16   34.00000   10.04222  70.5%     -    1s
# H    0     0                      27.0000000   10.04222  62.8%     -    1s
#      0     0   10.04959    0    6   27.00000   10.04959  62.8%     -    2s
#      0     0   10.04959    0    6   27.00000   10.04959  62.8%     -    2s
# H    0     0                      26.0000000   10.04959  61.3%     -    2s
#      0     0   10.14337    0   22   26.00000   10.14337  61.0%     -    2s
#      0     0   11.00000    0    8   26.00000   11.00000  57.7%     -    2s
#      0     0   11.00000    0    8   26.00000   11.00000  57.7%     -    2s
#      0     0   11.00000    0   13   26.00000   11.00000  57.7%     -    2s
#      0     0   11.13314    0   15   26.00000   11.13314  57.2%     -    2s
#      0     0   11.13314    0   23   26.00000   11.13314  57.2%     -    2s
#      0     0   11.13314    0   22   26.00000   11.13314  57.2%     -    2s
#      0     0   11.13314    0   12   26.00000   11.13314  57.2%     -    2s
#      0     0   11.13314    0   12   26.00000   11.13314  57.2%     -    2s
#      0     0   11.13314    0   18   26.00000   11.13314  57.2%     -    2s
#      0     0   11.13314    0    6   26.00000   11.13314  57.2%     -    2s
# H    0     0                      20.0000000   11.13314  44.3%     -    2s
# H    0     0                      13.0000000   11.13314  14.4%     -    2s
#      0     0   11.13314    0    6   13.00000   11.13314  14.4%     -    2s
#
# Cutting planes:
#   Learned: 4
#   Gomory: 2
#   Implied bound: 2
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (5409 simplex iterations) in 2.87 seconds (1.63 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 13 20 26 ... 34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# ok
# optimal

# %%
# Solver Status
solver_status = results.solver.status
termination_condition = results.solver.termination_condition
# Solver Statistics
solve_time = results.solver.time
##iterations = results.solver.iterations
num_constraints = results.problem.number_of_constraints
num_variables = results.problem.number_of_variables
num_nonzeros = results.problem.number_of_nonzeros

print(f"Solver Status: {solver_status}")
print(f"Termination Condition: {termination_condition}")


print(f"Solve Time: {solve_time} seconds")
#print(f"Iterations: {iterations}")
print(f"Number of Constraints: {num_constraints}")
print(f"Number of Variables: {num_variables}")
print(f"Number of Nonzeros: {num_nonzeros}")
# Out:
# Solver Status: ok
# Termination Condition: optimal
# Solve Time: 3.6748788356781006 seconds
# Number of Constraints: 7234
# Number of Variables: 1882
# Number of Nonzeros: 29527

# %%
""" # Assuming model is your Pyomo ConcreteModel

# Count alpha direction constraints
alpha_direction_constraints_count = sum(1 for _ in model.alpha_direction_constraint)

# Count forward direction constraints
dir_forward_constraints_count = sum(1 for _ in model.DirForwardConstraint)

# Count backward direction constraints
dir_backward_constraints_count = sum(1 for _ in model.DirBackwardConstraint)

# Count sector constraints (if ConstraintList)
sector_constraints_count = sum(1 for _ in model.sector_constraints)

# Count beta sum constraints
beta_sum_constraints_count = sum(1 for _ in model.BetaSumConstraint)

# Count order maintenance constraints (if ConstraintList)
order_maintenance_constraints_count = sum(1 for _ in model.OrderMaintenanceConstraints)

# Count non-incident edge direction constraints
non_incident_edge_direction_constraints_count = sum(1 for _ in model.NonIncidentEdgeDirectionConstraint)

# Count edge spacing constraints (if ConstraintList)
edge_spacing_constraints_count = sum(1 for _ in model.edgeSpacingConstraints)

# Count relative position constraints (upper and lower bounds)
relative_position_constraints_count = sum(1 for _ in model.RposConstraintUpper) + sum(1 for _ in model.RposConstraintLower)


# Print the counts
print("Counts of specific constraints:")
print(f"Alpha Direction Constraints: {alpha_direction_constraints_count}")
print(f"Forward Direction Constraints: {dir_forward_constraints_count}")
print(f"Backward Direction Constraints: {dir_backward_constraints_count}")
print(f"Sector Constraints: {sector_constraints_count}")
print(f"Beta Sum Constraints: {beta_sum_constraints_count}")
print(f"Order Maintenance Constraints: {order_maintenance_constraints_count}")
print(f"Non-Incident Edge Direction Constraints: {non_incident_edge_direction_constraints_count}")
print(f"Edge Spacing Constraints: {edge_spacing_constraints_count}")
print(f"Relative Position Constraints: {relative_position_constraints_count}")  # Added line



solver_summary = results.Solver[0]
print("Solver Summary:")
print(f"Status: {solver_summary.status}")
print(f"Termination condition: {solver_summary.termination_condition}")
print(f"Runtime: {solver_summary.user_time} seconds") """
# Out:
# ' # Assuming model is your Pyomo ConcreteModel\n\n# Count alpha direction constraints\nalpha_direction_constraints_count = sum(1 for _ in model.alpha_direction_constraint)\n\n# Count forward direction constraints\ndir_forward_constraints_count = sum(1 for _ in model.DirForwardConstraint)\n\n# Count backward direction constraints\ndir_backward_constraints_count = sum(1 for _ in model.DirBackwardConstraint)\n\n# Count sector constraints (if ConstraintList)\nsector_constraints_count = sum(1 for _ in model.sector_constraints)\n\n# Count beta sum constraints\nbeta_sum_constraints_count = sum(1 for _ in model.BetaSumConstraint)\n\n# Count order maintenance constraints (if ConstraintList)\norder_maintenance_constraints_count = sum(1 for _ in model.OrderMaintenanceConstraints)\n\n# Count non-incident edge direction constraints\nnon_incident_edge_direction_constraints_count = sum(1 for _ in model.NonIncidentEdgeDirectionConstraint)\n\n# Count edge spacing constraints (if ConstraintList)\nedge_spacing_constraints_count = sum(1 for _ in model.edgeSpacingConstraints)\n\n# Count relative position constraints (upper and lower bounds)\nrelative_position_constraints_count = sum(1 for _ in model.RposConstraintUpper) + sum(1 for _ in model.RposConstraintLower)\n\n\n# Print the counts\nprint("Counts of specific constraints:")\nprint(f"Alpha Direction Constraints: {alpha_direction_constraints_count}")\nprint(f"Forward Direction Constraints: {dir_forward_constraints_count}")\nprint(f"Backward Direction Constraints: {dir_backward_constraints_count}")\nprint(f"Sector Constraints: {sector_constraints_count}")\nprint(f"Beta Sum Constraints: {beta_sum_constraints_count}")\nprint(f"Order Maintenance Constraints: {order_maintenance_constraints_count}")\nprint(f"Non-Incident Edge Direction Constraints: {non_incident_edge_direction_constraints_count}")\nprint(f"Edge Spacing Constraints: {edge_spacing_constraints_count}")\nprint(f"Relative Position Constraints: {relative_position_constraints_count}")  # Added line\n\n\n\nsolver_summary = results.Solver[0]\nprint("Solver Summary:")\nprint(f"Status: {solver_summary.status}")\nprint(f"Termination condition: {solver_summary.termination_condition}")\nprint(f"Runtime: {solver_summary.user_time} seconds") '

# %%
from pyomo.core.expr.visitor import identify_variables

# Function to count the variables in each constraint
def count_variables_in_constraints(model):
    for constraint_object in model.component_objects(ctype=pyomo.environ.Constraint, active=True):
        for index in constraint_object:
            expr = constraint_object[index].body
            # Use identify_variables to get a generator of variables in the expression
            variables = list(identify_variables(expr))
            num_variables = len(variables)
            print(f"{constraint_object.name}[{index}] involves {num_variables} variables.")

# Call the function to count variables in constraints
count_variables_in_constraints(model)
# Out:
# alpha_direction_constraint[(6194, 6199)] involves 3 variables.
# alpha_direction_constraint[(6174, 6199)] involves 3 variables.
# alpha_direction_constraint[(6174, 6180)] involves 3 variables.
# alpha_direction_constraint[(6174, 6192)] involves 3 variables.
# alpha_direction_constraint[(6193, 6198)] involves 3 variables.
# alpha_direction_constraint[(6193, 6398)] involves 3 variables.
# alpha_direction_constraint[(6192, 6556)] involves 3 variables.
# alpha_direction_constraint[(6192, 6193)] involves 3 variables.
# alpha_direction_constraint[(6188, 6198)] involves 3 variables.
# alpha_direction_constraint[(6188, 6189)] involves 3 variables.
# alpha_direction_constraint[(6188, 6191)] involves 3 variables.
# alpha_direction_constraint[(6175, 6177)] involves 3 variables.
# alpha_direction_constraint[(6175, 6188)] involves 3 variables.
# alpha_direction_constraint[(6176, 6177)] involves 3 variables.
# alpha_direction_constraint[(6176, 6180)] involves 3 variables.
# alpha_direction_constraint[(6178, 6180)] involves 3 variables.
# alpha_direction_constraint[(6178, 6186)] involves 3 variables.
# alpha_direction_constraint[(6178, 6194)] involves 3 variables.
# alpha_direction_constraint[(6182, 6186)] involves 3 variables.
# alpha_direction_constraint[(6186, 6188)] involves 3 variables.
# alpha_direction_constraint[(6181, 6186)] involves 3 variables.
# alpha_direction_constraint[(6181, 6188)] involves 3 variables.
# alpha_direction_constraint[(6185, 6194)] involves 3 variables.
# DirForwardConstraint[(6194, 6199)] involves 4 variables.
# DirForwardConstraint[(6174, 6199)] involves 4 variables.
# DirForwardConstraint[(6174, 6180)] involves 4 variables.
# DirForwardConstraint[(6174, 6192)] involves 4 variables.
# DirForwardConstraint[(6193, 6198)] involves 4 variables.
# DirForwardConstraint[(6193, 6398)] involves 4 variables.
# DirForwardConstraint[(6192, 6556)] involves 4 variables.
# DirForwardConstraint[(6192, 6193)] involves 4 variables.
# DirForwardConstraint[(6188, 6198)] involves 4 variables.
# DirForwardConstraint[(6188, 6189)] involves 4 variables.
# DirForwardConstraint[(6188, 6191)] involves 4 variables.
# DirForwardConstraint[(6175, 6177)] involves 4 variables.
# DirForwardConstraint[(6175, 6188)] involves 4 variables.
# DirForwardConstraint[(6176, 6177)] involves 4 variables.
# DirForwardConstraint[(6176, 6180)] involves 4 variables.
# DirForwardConstraint[(6178, 6180)] involves 4 variables.
# DirForwardConstraint[(6178, 6186)] involves 4 variables.
# DirForwardConstraint[(6178, 6194)] involves 4 variables.
# DirForwardConstraint[(6182, 6186)] involves 4 variables.
# DirForwardConstraint[(6186, 6188)] involves 4 variables.
# DirForwardConstraint[(6181, 6186)] involves 4 variables.
# DirForwardConstraint[(6181, 6188)] involves 4 variables.
# DirForwardConstraint[(6185, 6194)] involves 4 variables.
# DirBackwardConstraint[(6194, 6199)] involves 4 variables.
# DirBackwardConstraint[(6174, 6199)] involves 4 variables.
# DirBackwardConstraint[(6174, 6180)] involves 4 variables.
# DirBackwardConstraint[(6174, 6192)] involves 4 variables.
# DirBackwardConstraint[(6193, 6198)] involves 4 variables.
# DirBackwardConstraint[(6193, 6398)] involves 4 variables.
# DirBackwardConstraint[(6192, 6556)] involves 4 variables.
# DirBackwardConstraint[(6192, 6193)] involves 4 variables.
# DirBackwardConstraint[(6188, 6198)] involves 4 variables.
# DirBackwardConstraint[(6188, 6189)] involves 4 variables.
# DirBackwardConstraint[(6188, 6191)] involves 4 variables.
# DirBackwardConstraint[(6175, 6177)] involves 4 variables.
# DirBackwardConstraint[(6175, 6188)] involves 4 variables.
# DirBackwardConstraint[(6176, 6177)] involves 4 variables.
# DirBackwardConstraint[(6176, 6180)] involves 4 variables.
# DirBackwardConstraint[(6178, 6180)] involves 4 variables.
# DirBackwardConstraint[(6178, 6186)] involves 4 variables.
# DirBackwardConstraint[(6178, 6194)] involves 4 variables.
# DirBackwardConstraint[(6182, 6186)] involves 4 variables.
# DirBackwardConstraint[(6186, 6188)] involves 4 variables.
# DirBackwardConstraint[(6181, 6186)] involves 4 variables.
# DirBackwardConstraint[(6181, 6188)] involves 4 variables.
# DirBackwardConstraint[(6185, 6194)] involves 4 variables.
# sector_constraints[1] involves 3 variables.
# sector_constraints[2] involves 3 variables.
# sector_constraints[3] involves 3 variables.
# sector_constraints[4] involves 5 variables.
# sector_constraints[5] involves 2 variables.
# sector_constraints[6] involves 5 variables.
# sector_constraints[7] involves 3 variables.
# sector_constraints[8] involves 3 variables.
# sector_constraints[9] involves 3 variables.
# sector_constraints[10] involves 5 variables.
# sector_constraints[11] involves 2 variables.
# sector_constraints[12] involves 5 variables.
# sector_constraints[13] involves 3 variables.
# sector_constraints[14] involves 3 variables.
# sector_constraints[15] involves 3 variables.
# sector_constraints[16] involves 5 variables.
# sector_constraints[17] involves 5 variables.
# sector_constraints[18] involves 5 variables.
# sector_constraints[19] involves 5 variables.
# sector_constraints[20] involves 5 variables.
# sector_constraints[21] involves 5 variables.
# sector_constraints[22] involves 3 variables.
# sector_constraints[23] involves 3 variables.
# sector_constraints[24] involves 3 variables.
# sector_constraints[25] involves 5 variables.
# sector_constraints[26] involves 2 variables.
# sector_constraints[27] involves 5 variables.
# sector_constraints[28] involves 3 variables.
# sector_constraints[29] involves 3 variables.
# sector_constraints[30] involves 3 variables.
# sector_constraints[31] involves 5 variables.
# sector_constraints[32] involves 5 variables.
# sector_constraints[33] involves 5 variables.
# sector_constraints[34] involves 3 variables.
# sector_constraints[35] involves 3 variables.
# sector_constraints[36] involves 3 variables.
# sector_constraints[37] involves 5 variables.
# sector_constraints[38] involves 5 variables.
# sector_constraints[39] involves 5 variables.
# sector_constraints[40] involves 3 variables.
# sector_constraints[41] involves 3 variables.
# sector_constraints[42] involves 3 variables.
# sector_constraints[43] involves 5 variables.
# sector_constraints[44] involves 2 variables.
# sector_constraints[45] involves 5 variables.
# sector_constraints[46] involves 5 variables.
# sector_constraints[47] involves 5 variables.
# sector_constraints[48] involves 5 variables.
# sector_constraints[49] involves 3 variables.
# sector_constraints[50] involves 3 variables.
# sector_constraints[51] involves 3 variables.
# sector_constraints[52] involves 5 variables.
# sector_constraints[53] involves 2 variables.
# sector_constraints[54] involves 5 variables.
# sector_constraints[55] involves 5 variables.
# sector_constraints[56] involves 5 variables.
# sector_constraints[57] involves 5 variables.
# sector_constraints[58] involves 3 variables.
# sector_constraints[59] involves 3 variables.
# sector_constraints[60] involves 3 variables.
# sector_constraints[61] involves 5 variables.
# sector_constraints[62] involves 2 variables.
# sector_constraints[63] involves 5 variables.
# sector_constraints[64] involves 5 variables.
# sector_constraints[65] involves 2 variables.
# sector_constraints[66] involves 5 variables.
# sector_constraints[67] involves 3 variables.
# sector_constraints[68] involves 3 variables.
# sector_constraints[69] involves 3 variables.
# sector_constraints[70] involves 5 variables.
# sector_constraints[71] involves 5 variables.
# sector_constraints[72] involves 5 variables.
# sector_constraints[73] involves 5 variables.
# sector_constraints[74] involves 5 variables.
# sector_constraints[75] involves 5 variables.
# sector_constraints[76] involves 3 variables.
# sector_constraints[77] involves 3 variables.
# sector_constraints[78] involves 3 variables.
# sector_constraints[79] involves 5 variables.
# sector_constraints[80] involves 2 variables.
# sector_constraints[81] involves 5 variables.
# sector_constraints[82] involves 5 variables.
# sector_constraints[83] involves 2 variables.
# sector_constraints[84] involves 5 variables.
# sector_constraints[85] involves 3 variables.
# sector_constraints[86] involves 3 variables.
# sector_constraints[87] involves 3 variables.
# sector_constraints[88] involves 5 variables.
# sector_constraints[89] involves 5 variables.
# sector_constraints[90] involves 5 variables.
# sector_constraints[91] involves 3 variables.
# sector_constraints[92] involves 3 variables.
# sector_constraints[93] involves 3 variables.
# sector_constraints[94] involves 5 variables.
# sector_constraints[95] involves 5 variables.
# sector_constraints[96] involves 5 variables.
# sector_constraints[97] involves 3 variables.
# sector_constraints[98] involves 3 variables.
# sector_constraints[99] involves 3 variables.
# sector_constraints[100] involves 3 variables.
# sector_constraints[101] involves 3 variables.
# sector_constraints[102] involves 3 variables.
# sector_constraints[103] involves 5 variables.
# sector_constraints[104] involves 5 variables.
# sector_constraints[105] involves 5 variables.
# sector_constraints[106] involves 3 variables.
# sector_constraints[107] involves 3 variables.
# sector_constraints[108] involves 3 variables.
# sector_constraints[109] involves 5 variables.
# sector_constraints[110] involves 2 variables.
# sector_constraints[111] involves 5 variables.
# sector_constraints[112] involves 3 variables.
# sector_constraints[113] involves 3 variables.
# sector_constraints[114] involves 3 variables.
# sector_constraints[115] involves 5 variables.
# sector_constraints[116] involves 5 variables.
# sector_constraints[117] involves 5 variables.
# sector_constraints[118] involves 5 variables.
# sector_constraints[119] involves 2 variables.
# sector_constraints[120] involves 5 variables.
# sector_constraints[121] involves 3 variables.
# sector_constraints[122] involves 3 variables.
# sector_constraints[123] involves 3 variables.
# sector_constraints[124] involves 5 variables.
# sector_constraints[125] involves 5 variables.
# sector_constraints[126] involves 5 variables.
# sector_constraints[127] involves 3 variables.
# sector_constraints[128] involves 3 variables.
# sector_constraints[129] involves 3 variables.
# sector_constraints[130] involves 5 variables.
# sector_constraints[131] involves 5 variables.
# sector_constraints[132] involves 5 variables.
# sector_constraints[133] involves 3 variables.
# sector_constraints[134] involves 3 variables.
# sector_constraints[135] involves 3 variables.
# sector_constraints[136] involves 5 variables.
# sector_constraints[137] involves 2 variables.
# sector_constraints[138] involves 5 variables.
# sector_constraints[139] involves 3 variables.
# sector_constraints[140] involves 3 variables.
# sector_constraints[141] involves 3 variables.
# sector_constraints[142] involves 5 variables.
# sector_constraints[143] involves 5 variables.
# sector_constraints[144] involves 5 variables.
# sector_constraints[145] involves 5 variables.
# sector_constraints[146] involves 2 variables.
# sector_constraints[147] involves 5 variables.
# sector_constraints[148] involves 3 variables.
# sector_constraints[149] involves 3 variables.
# sector_constraints[150] involves 3 variables.
# sector_constraints[151] involves 5 variables.
# sector_constraints[152] involves 5 variables.
# sector_constraints[153] involves 5 variables.
# sector_constraints[154] involves 3 variables.
# sector_constraints[155] involves 3 variables.
# sector_constraints[156] involves 3 variables.
# sector_constraints[157] involves 5 variables.
# sector_constraints[158] involves 5 variables.
# sector_constraints[159] involves 5 variables.
# sector_constraints[160] involves 3 variables.
# sector_constraints[161] involves 3 variables.
# sector_constraints[162] involves 3 variables.
# sector_constraints[163] involves 3 variables.
# sector_constraints[164] involves 3 variables.
# sector_constraints[165] involves 3 variables.
# sector_constraints[166] involves 5 variables.
# sector_constraints[167] involves 5 variables.
# sector_constraints[168] involves 5 variables.
# sector_constraints[169] involves 3 variables.
# sector_constraints[170] involves 3 variables.
# sector_constraints[171] involves 3 variables.
# sector_constraints[172] involves 5 variables.
# sector_constraints[173] involves 5 variables.
# sector_constraints[174] involves 5 variables.
# sector_constraints[175] involves 3 variables.
# sector_constraints[176] involves 3 variables.
# sector_constraints[177] involves 3 variables.
# sector_constraints[178] involves 5 variables.
# sector_constraints[179] involves 2 variables.
# sector_constraints[180] involves 5 variables.
# sector_constraints[181] involves 3 variables.
# sector_constraints[182] involves 3 variables.
# sector_constraints[183] involves 3 variables.
# sector_constraints[184] involves 5 variables.
# sector_constraints[185] involves 2 variables.
# sector_constraints[186] involves 5 variables.
# sector_constraints[187] involves 3 variables.
# sector_constraints[188] involves 3 variables.
# sector_constraints[189] involves 3 variables.
# sector_constraints[190] involves 5 variables.
# sector_constraints[191] involves 5 variables.
# sector_constraints[192] involves 5 variables.
# sector_constraints[193] involves 3 variables.
# sector_constraints[194] involves 3 variables.
# sector_constraints[195] involves 3 variables.
# sector_constraints[196] involves 5 variables.
# sector_constraints[197] involves 2 variables.
# sector_constraints[198] involves 5 variables.
# sector_constraints[199] involves 5 variables.
# sector_constraints[200] involves 2 variables.
# sector_constraints[201] involves 5 variables.
# sector_constraints[202] involves 3 variables.
# sector_constraints[203] involves 3 variables.
# sector_constraints[204] involves 3 variables.
# sector_constraints[205] involves 5 variables.
# sector_constraints[206] involves 5 variables.
# sector_constraints[207] involves 5 variables.
# BetaSumConstraint[6194] involves 3 variables.
# BetaSumConstraint[6199] involves 2 variables.
# BetaSumConstraint[6174] involves 3 variables.
# BetaSumConstraint[6193] involves 3 variables.
# BetaSumConstraint[6198] involves 2 variables.
# BetaSumConstraint[6192] involves 3 variables.
# BetaSumConstraint[6188] involves 6 variables.
# BetaSumConstraint[6175] involves 2 variables.
# BetaSumConstraint[6177] involves 2 variables.
# BetaSumConstraint[6176] involves 2 variables.
# BetaSumConstraint[6178] involves 3 variables.
# BetaSumConstraint[6180] involves 3 variables.
# BetaSumConstraint[6186] involves 4 variables.
# BetaSumConstraint[6181] involves 2 variables.
# OrderMaintenanceConstraints[1] involves 3 variables.
# OrderMaintenanceConstraints[2] involves 3 variables.
# OrderMaintenanceConstraints[3] involves 3 variables.
# OrderMaintenanceConstraints[4] involves 3 variables.
# OrderMaintenanceConstraints[5] involves 3 variables.
# OrderMaintenanceConstraints[6] involves 3 variables.
# OrderMaintenanceConstraints[7] involves 3 variables.
# OrderMaintenanceConstraints[8] involves 3 variables.
# OrderMaintenanceConstraints[9] involves 3 variables.
# OrderMaintenanceConstraints[10] involves 3 variables.
# OrderMaintenanceConstraints[11] involves 3 variables.
# OrderMaintenanceConstraints[12] involves 3 variables.
# OrderMaintenanceConstraints[13] involves 3 variables.
# OrderMaintenanceConstraints[14] involves 3 variables.
# OrderMaintenanceConstraints[15] involves 3 variables.
# OrderMaintenanceConstraints[16] involves 3 variables.
# OrderMaintenanceConstraints[17] involves 3 variables.
# OrderMaintenanceConstraints[18] involves 3 variables.
# OrderMaintenanceConstraints[19] involves 3 variables.
# OrderMaintenanceConstraints[20] involves 3 variables.
# OrderMaintenanceConstraints[21] involves 3 variables.
# OrderMaintenanceConstraints[22] involves 3 variables.
# OrderMaintenanceConstraints[23] involves 3 variables.
# OrderMaintenanceConstraints[24] involves 3 variables.
# OrderMaintenanceConstraints[25] involves 3 variables.
# OrderMaintenanceConstraints[26] involves 3 variables.
# OrderMaintenanceConstraints[27] involves 3 variables.
# OrderMaintenanceConstraints[28] involves 3 variables.
# OrderMaintenanceConstraints[29] involves 3 variables.
# OrderMaintenanceConstraints[30] involves 3 variables.
# OrderMaintenanceConstraints[31] involves 3 variables.
# OrderMaintenanceConstraints[32] involves 3 variables.
# OrderMaintenanceConstraints[33] involves 3 variables.
# OrderMaintenanceConstraints[34] involves 3 variables.
# OrderMaintenanceConstraints[35] involves 3 variables.
# OrderMaintenanceConstraints[36] involves 3 variables.
# OrderMaintenanceConstraints[37] involves 3 variables.
# OrderMaintenanceConstraints[38] involves 3 variables.
# OrderMaintenanceConstraints[39] involves 3 variables.
# OrderMaintenanceConstraints[40] involves 3 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6174, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6174, 6192)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6193, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6193, 6398)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6192, 6556)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6192, 6193)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6194, 6199, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6193, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6193, 6398)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6192, 6556)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6192, 6193)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6199, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6193, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6193, 6398)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6192, 6556)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6192, 6193)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6180, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6193, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6193, 6398)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6174, 6192, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6192, 6556)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6198, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6192, 6556)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6193, 6398, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6556, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6188, 6198)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6188, 6189)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6188, 6191)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6175, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6192, 6193, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6198, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6189, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6175, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6188, 6191, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6177, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6176, 6177)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6176, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6175, 6188, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6178, 6180)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6177, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6178, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6178, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6176, 6180, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6180, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6180, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6180, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6180, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6180, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6186, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6186, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6194, 6182, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6194, 6186, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6194, 6181, 6186)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6178, 6194, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6182, 6186, 6181, 6188)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6182, 6186, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6186, 6188, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6181, 6186, 6185, 6194)] involves 8 variables.
# NonIncidentEdgeDirectionConstraint[(6181, 6188, 6185, 6194)] involves 8 variables.
# edgeSpacingConstraints[1] involves 3 variables.
# edgeSpacingConstraints[2] involves 3 variables.
# edgeSpacingConstraints[3] involves 3 variables.
# edgeSpacingConstraints[4] involves 3 variables.
# edgeSpacingConstraints[5] involves 3 variables.
# edgeSpacingConstraints[6] involves 3 variables.
# edgeSpacingConstraints[7] involves 3 variables.
# edgeSpacingConstraints[8] involves 3 variables.
# edgeSpacingConstraints[9] involves 3 variables.
# edgeSpacingConstraints[10] involves 3 variables.
# edgeSpacingConstraints[11] involves 3 variables.
# edgeSpacingConstraints[12] involves 3 variables.
# edgeSpacingConstraints[13] involves 3 variables.
# edgeSpacingConstraints[14] involves 3 variables.
# edgeSpacingConstraints[15] involves 3 variables.
# edgeSpacingConstraints[16] involves 3 variables.
# edgeSpacingConstraints[17] involves 5 variables.
# edgeSpacingConstraints[18] involves 5 variables.
# edgeSpacingConstraints[19] involves 5 variables.
# edgeSpacingConstraints[20] involves 5 variables.
# edgeSpacingConstraints[21] involves 5 variables.
# edgeSpacingConstraints[22] involves 5 variables.
# edgeSpacingConstraints[23] involves 5 variables.
# edgeSpacingConstraints[24] involves 5 variables.
# edgeSpacingConstraints[25] involves 5 variables.
# edgeSpacingConstraints[26] involves 5 variables.
# edgeSpacingConstraints[27] involves 5 variables.
# edgeSpacingConstraints[28] involves 5 variables.
# edgeSpacingConstraints[29] involves 5 variables.
# edgeSpacingConstraints[30] involves 5 variables.
# edgeSpacingConstraints[31] involves 5 variables.
# edgeSpacingConstraints[32] involves 5 variables.
# edgeSpacingConstraints[33] involves 3 variables.
# edgeSpacingConstraints[34] involves 3 variables.
# edgeSpacingConstraints[35] involves 3 variables.
# edgeSpacingConstraints[36] involves 3 variables.
# edgeSpacingConstraints[37] involves 3 variables.
# edgeSpacingConstraints[38] involves 3 variables.
# edgeSpacingConstraints[39] involves 3 variables.
# edgeSpacingConstraints[40] involves 3 variables.
# edgeSpacingConstraints[41] involves 3 variables.
# edgeSpacingConstraints[42] involves 3 variables.
# edgeSpacingConstraints[43] involves 3 variables.
# edgeSpacingConstraints[44] involves 3 variables.
# edgeSpacingConstraints[45] involves 3 variables.
# edgeSpacingConstraints[46] involves 3 variables.
# edgeSpacingConstraints[47] involves 3 variables.
# edgeSpacingConstraints[48] involves 3 variables.
# edgeSpacingConstraints[49] involves 5 variables.
# edgeSpacingConstraints[50] involves 5 variables.
# edgeSpacingConstraints[51] involves 5 variables.
# edgeSpacingConstraints[52] involves 5 variables.
# edgeSpacingConstraints[53] involves 5 variables.
# edgeSpacingConstraints[54] involves 5 variables.
# edgeSpacingConstraints[55] involves 5 variables.
# edgeSpacingConstraints[56] involves 5 variables.
# edgeSpacingConstraints[57] involves 5 variables.
# edgeSpacingConstraints[58] involves 5 variables.
# edgeSpacingConstraints[59] involves 5 variables.
# edgeSpacingConstraints[60] involves 5 variables.
# edgeSpacingConstraints[61] involves 5 variables.
# edgeSpacingConstraints[62] involves 5 variables.
# edgeSpacingConstraints[63] involves 5 variables.
# edgeSpacingConstraints[64] involves 5 variables.
# edgeSpacingConstraints[65] involves 3 variables.
# edgeSpacingConstraints[66] involves 3 variables.
# edgeSpacingConstraints[67] involves 3 variables.
# edgeSpacingConstraints[68] involves 3 variables.
# edgeSpacingConstraints[69] involves 3 variables.
# edgeSpacingConstraints[70] involves 3 variables.
# edgeSpacingConstraints[71] involves 3 variables.
# edgeSpacingConstraints[72] involves 3 variables.
# edgeSpacingConstraints[73] involves 3 variables.
# edgeSpacingConstraints[74] involves 3 variables.
# edgeSpacingConstraints[75] involves 3 variables.
# edgeSpacingConstraints[76] involves 3 variables.
# edgeSpacingConstraints[77] involves 3 variables.
# edgeSpacingConstraints[78] involves 3 variables.
# edgeSpacingConstraints[79] involves 3 variables.
# edgeSpacingConstraints[80] involves 3 variables.
# edgeSpacingConstraints[81] involves 5 variables.
# edgeSpacingConstraints[82] involves 5 variables.
# edgeSpacingConstraints[83] involves 5 variables.
# edgeSpacingConstraints[84] involves 5 variables.
# edgeSpacingConstraints[85] involves 5 variables.
# edgeSpacingConstraints[86] involves 5 variables.
# edgeSpacingConstraints[87] involves 5 variables.
# edgeSpacingConstraints[88] involves 5 variables.
# edgeSpacingConstraints[89] involves 5 variables.
# edgeSpacingConstraints[90] involves 5 variables.
# edgeSpacingConstraints[91] involves 5 variables.
# edgeSpacingConstraints[92] involves 5 variables.
# edgeSpacingConstraints[93] involves 5 variables.
# edgeSpacingConstraints[94] involves 5 variables.
# edgeSpacingConstraints[95] involves 5 variables.
# edgeSpacingConstraints[96] involves 5 variables.
# edgeSpacingConstraints[97] involves 3 variables.
# edgeSpacingConstraints[98] involves 3 variables.
# edgeSpacingConstraints[99] involves 3 variables.
# edgeSpacingConstraints[100] involves 3 variables.
# edgeSpacingConstraints[101] involves 3 variables.
# edgeSpacingConstraints[102] involves 3 variables.
# edgeSpacingConstraints[103] involves 3 variables.
# edgeSpacingConstraints[104] involves 3 variables.
# edgeSpacingConstraints[105] involves 3 variables.
# edgeSpacingConstraints[106] involves 3 variables.
# edgeSpacingConstraints[107] involves 3 variables.
# edgeSpacingConstraints[108] involves 3 variables.
# edgeSpacingConstraints[109] involves 3 variables.
# edgeSpacingConstraints[110] involves 3 variables.
# edgeSpacingConstraints[111] involves 3 variables.
# edgeSpacingConstraints[112] involves 3 variables.
# edgeSpacingConstraints[113] involves 5 variables.
# edgeSpacingConstraints[114] involves 5 variables.
# edgeSpacingConstraints[115] involves 5 variables.
# edgeSpacingConstraints[116] involves 5 variables.
# edgeSpacingConstraints[117] involves 5 variables.
# edgeSpacingConstraints[118] involves 5 variables.
# edgeSpacingConstraints[119] involves 5 variables.
# edgeSpacingConstraints[120] involves 5 variables.
# edgeSpacingConstraints[121] involves 5 variables.
# edgeSpacingConstraints[122] involves 5 variables.
# edgeSpacingConstraints[123] involves 5 variables.
# edgeSpacingConstraints[124] involves 5 variables.
# edgeSpacingConstraints[125] involves 5 variables.
# edgeSpacingConstraints[126] involves 5 variables.
# edgeSpacingConstraints[127] involves 5 variables.
# edgeSpacingConstraints[128] involves 5 variables.
# edgeSpacingConstraints[129] involves 3 variables.
# edgeSpacingConstraints[130] involves 3 variables.
# edgeSpacingConstraints[131] involves 3 variables.
# edgeSpacingConstraints[132] involves 3 variables.
# edgeSpacingConstraints[133] involves 3 variables.
# edgeSpacingConstraints[134] involves 3 variables.
# edgeSpacingConstraints[135] involves 3 variables.
# edgeSpacingConstraints[136] involves 3 variables.
# edgeSpacingConstraints[137] involves 3 variables.
# edgeSpacingConstraints[138] involves 3 variables.
# edgeSpacingConstraints[139] involves 3 variables.
# edgeSpacingConstraints[140] involves 3 variables.
# edgeSpacingConstraints[141] involves 3 variables.
# edgeSpacingConstraints[142] involves 3 variables.
# edgeSpacingConstraints[143] involves 3 variables.
# edgeSpacingConstraints[144] involves 3 variables.
# edgeSpacingConstraints[145] involves 5 variables.
# edgeSpacingConstraints[146] involves 5 variables.
# edgeSpacingConstraints[147] involves 5 variables.
# edgeSpacingConstraints[148] involves 5 variables.
# edgeSpacingConstraints[149] involves 5 variables.
# edgeSpacingConstraints[150] involves 5 variables.
# edgeSpacingConstraints[151] involves 5 variables.
# edgeSpacingConstraints[152] involves 5 variables.
# edgeSpacingConstraints[153] involves 5 variables.
# edgeSpacingConstraints[154] involves 5 variables.
# edgeSpacingConstraints[155] involves 5 variables.
# edgeSpacingConstraints[156] involves 5 variables.
# edgeSpacingConstraints[157] involves 5 variables.
# edgeSpacingConstraints[158] involves 5 variables.
# edgeSpacingConstraints[159] involves 5 variables.
# edgeSpacingConstraints[160] involves 5 variables.
# edgeSpacingConstraints[161] involves 3 variables.
# edgeSpacingConstraints[162] involves 3 variables.
# edgeSpacingConstraints[163] involves 3 variables.
# edgeSpacingConstraints[164] involves 3 variables.
# edgeSpacingConstraints[165] involves 3 variables.
# edgeSpacingConstraints[166] involves 3 variables.
# edgeSpacingConstraints[167] involves 3 variables.
# edgeSpacingConstraints[168] involves 3 variables.
# edgeSpacingConstraints[169] involves 3 variables.
# edgeSpacingConstraints[170] involves 3 variables.
# edgeSpacingConstraints[171] involves 3 variables.
# edgeSpacingConstraints[172] involves 3 variables.
# edgeSpacingConstraints[173] involves 3 variables.
# edgeSpacingConstraints[174] involves 3 variables.
# edgeSpacingConstraints[175] involves 3 variables.
# edgeSpacingConstraints[176] involves 3 variables.
# edgeSpacingConstraints[177] involves 5 variables.
# edgeSpacingConstraints[178] involves 5 variables.
# edgeSpacingConstraints[179] involves 5 variables.
# edgeSpacingConstraints[180] involves 5 variables.
# edgeSpacingConstraints[181] involves 5 variables.
# edgeSpacingConstraints[182] involves 5 variables.
# edgeSpacingConstraints[183] involves 5 variables.
# edgeSpacingConstraints[184] involves 5 variables.
# edgeSpacingConstraints[185] involves 5 variables.
# edgeSpacingConstraints[186] involves 5 variables.
# edgeSpacingConstraints[187] involves 5 variables.
# edgeSpacingConstraints[188] involves 5 variables.
# edgeSpacingConstraints[189] involves 5 variables.
# edgeSpacingConstraints[190] involves 5 variables.
# edgeSpacingConstraints[191] involves 5 variables.
# edgeSpacingConstraints[192] involves 5 variables.
# edgeSpacingConstraints[193] involves 3 variables.
# edgeSpacingConstraints[194] involves 3 variables.
# edgeSpacingConstraints[195] involves 3 variables.
# edgeSpacingConstraints[196] involves 3 variables.
# edgeSpacingConstraints[197] involves 3 variables.
# edgeSpacingConstraints[198] involves 3 variables.
# edgeSpacingConstraints[199] involves 3 variables.
# edgeSpacingConstraints[200] involves 3 variables.
# edgeSpacingConstraints[201] involves 3 variables.
# edgeSpacingConstraints[202] involves 3 variables.
# edgeSpacingConstraints[203] involves 3 variables.
# edgeSpacingConstraints[204] involves 3 variables.
# edgeSpacingConstraints[205] involves 3 variables.
# edgeSpacingConstraints[206] involves 3 variables.
# edgeSpacingConstraints[207] involves 3 variables.
# edgeSpacingConstraints[208] involves 3 variables.
# edgeSpacingConstraints[209] involves 5 variables.
# edgeSpacingConstraints[210] involves 5 variables.
# edgeSpacingConstraints[211] involves 5 variables.
# edgeSpacingConstraints[212] involves 5 variables.
# edgeSpacingConstraints[213] involves 5 variables.
# edgeSpacingConstraints[214] involves 5 variables.
# edgeSpacingConstraints[215] involves 5 variables.
# edgeSpacingConstraints[216] involves 5 variables.
# edgeSpacingConstraints[217] involves 5 variables.
# edgeSpacingConstraints[218] involves 5 variables.
# edgeSpacingConstraints[219] involves 5 variables.
# edgeSpacingConstraints[220] involves 5 variables.
# edgeSpacingConstraints[221] involves 5 variables.
# edgeSpacingConstraints[222] involves 5 variables.
# edgeSpacingConstraints[223] involves 5 variables.
# edgeSpacingConstraints[224] involves 5 variables.
# edgeSpacingConstraints[225] involves 3 variables.
# edgeSpacingConstraints[226] involves 3 variables.
# edgeSpacingConstraints[227] involves 3 variables.
# edgeSpacingConstraints[228] involves 3 variables.
# edgeSpacingConstraints[229] involves 3 variables.
# edgeSpacingConstraints[230] involves 3 variables.
# edgeSpacingConstraints[231] involves 3 variables.
# edgeSpacingConstraints[232] involves 3 variables.
# edgeSpacingConstraints[233] involves 3 variables.
# edgeSpacingConstraints[234] involves 3 variables.
# edgeSpacingConstraints[235] involves 3 variables.
# edgeSpacingConstraints[236] involves 3 variables.
# edgeSpacingConstraints[237] involves 3 variables.
# edgeSpacingConstraints[238] involves 3 variables.
# edgeSpacingConstraints[239] involves 3 variables.
# edgeSpacingConstraints[240] involves 3 variables.
# edgeSpacingConstraints[241] involves 5 variables.
# edgeSpacingConstraints[242] involves 5 variables.
# edgeSpacingConstraints[243] involves 5 variables.
# edgeSpacingConstraints[244] involves 5 variables.
# edgeSpacingConstraints[245] involves 5 variables.
# edgeSpacingConstraints[246] involves 5 variables.
# edgeSpacingConstraints[247] involves 5 variables.
# edgeSpacingConstraints[248] involves 5 variables.
# edgeSpacingConstraints[249] involves 5 variables.
# edgeSpacingConstraints[250] involves 5 variables.
# edgeSpacingConstraints[251] involves 5 variables.
# edgeSpacingConstraints[252] involves 5 variables.
# edgeSpacingConstraints[253] involves 5 variables.
# edgeSpacingConstraints[254] involves 5 variables.
# edgeSpacingConstraints[255] involves 5 variables.
# edgeSpacingConstraints[256] involves 5 variables.
# edgeSpacingConstraints[257] involves 3 variables.
# edgeSpacingConstraints[258] involves 3 variables.
# edgeSpacingConstraints[259] involves 3 variables.
# edgeSpacingConstraints[260] involves 3 variables.
# edgeSpacingConstraints[261] involves 3 variables.
# edgeSpacingConstraints[262] involves 3 variables.
# edgeSpacingConstraints[263] involves 3 variables.
# edgeSpacingConstraints[264] involves 3 variables.
# edgeSpacingConstraints[265] involves 3 variables.
# edgeSpacingConstraints[266] involves 3 variables.
# edgeSpacingConstraints[267] involves 3 variables.
# edgeSpacingConstraints[268] involves 3 variables.
# edgeSpacingConstraints[269] involves 3 variables.
# edgeSpacingConstraints[270] involves 3 variables.
# edgeSpacingConstraints[271] involves 3 variables.
# edgeSpacingConstraints[272] involves 3 variables.
# edgeSpacingConstraints[273] involves 5 variables.
# edgeSpacingConstraints[274] involves 5 variables.
# edgeSpacingConstraints[275] involves 5 variables.
# edgeSpacingConstraints[276] involves 5 variables.
# edgeSpacingConstraints[277] involves 5 variables.
# edgeSpacingConstraints[278] involves 5 variables.
# edgeSpacingConstraints[279] involves 5 variables.
# edgeSpacingConstraints[280] involves 5 variables.
# edgeSpacingConstraints[281] involves 5 variables.
# edgeSpacingConstraints[282] involves 5 variables.
# edgeSpacingConstraints[283] involves 5 variables.
# edgeSpacingConstraints[284] involves 5 variables.
# edgeSpacingConstraints[285] involves 5 variables.
# edgeSpacingConstraints[286] involves 5 variables.
# edgeSpacingConstraints[287] involves 5 variables.
# edgeSpacingConstraints[288] involves 5 variables.
# edgeSpacingConstraints[289] involves 3 variables.
# edgeSpacingConstraints[290] involves 3 variables.
# edgeSpacingConstraints[291] involves 3 variables.
# edgeSpacingConstraints[292] involves 3 variables.
# edgeSpacingConstraints[293] involves 3 variables.
# edgeSpacingConstraints[294] involves 3 variables.
# edgeSpacingConstraints[295] involves 3 variables.
# edgeSpacingConstraints[296] involves 3 variables.
# edgeSpacingConstraints[297] involves 3 variables.
# edgeSpacingConstraints[298] involves 3 variables.
# edgeSpacingConstraints[299] involves 3 variables.
# edgeSpacingConstraints[300] involves 3 variables.
# ...
# edgeSpacingConstraints[6394] involves 5 variables.
# edgeSpacingConstraints[6395] involves 5 variables.
# edgeSpacingConstraints[6396] involves 5 variables.
# edgeSpacingConstraints[6397] involves 5 variables.
# edgeSpacingConstraints[6398] involves 5 variables.
# edgeSpacingConstraints[6399] involves 5 variables.
# edgeSpacingConstraints[6400] involves 5 variables.
# edgeSpacingConstraints[6401] involves 3 variables.
# edgeSpacingConstraints[6402] involves 3 variables.
# edgeSpacingConstraints[6403] involves 3 variables.
# edgeSpacingConstraints[6404] involves 3 variables.
# edgeSpacingConstraints[6405] involves 3 variables.
# edgeSpacingConstraints[6406] involves 3 variables.
# edgeSpacingConstraints[6407] involves 3 variables.
# edgeSpacingConstraints[6408] involves 3 variables.
# edgeSpacingConstraints[6409] involves 3 variables.
# edgeSpacingConstraints[6410] involves 3 variables.
# edgeSpacingConstraints[6411] involves 3 variables.
# edgeSpacingConstraints[6412] involves 3 variables.
# edgeSpacingConstraints[6413] involves 3 variables.
# edgeSpacingConstraints[6414] involves 3 variables.
# edgeSpacingConstraints[6415] involves 3 variables.
# edgeSpacingConstraints[6416] involves 3 variables.
# edgeSpacingConstraints[6417] involves 5 variables.
# edgeSpacingConstraints[6418] involves 5 variables.
# edgeSpacingConstraints[6419] involves 5 variables.
# edgeSpacingConstraints[6420] involves 5 variables.
# edgeSpacingConstraints[6421] involves 5 variables.
# edgeSpacingConstraints[6422] involves 5 variables.
# edgeSpacingConstraints[6423] involves 5 variables.
# edgeSpacingConstraints[6424] involves 5 variables.
# edgeSpacingConstraints[6425] involves 5 variables.
# edgeSpacingConstraints[6426] involves 5 variables.
# edgeSpacingConstraints[6427] involves 5 variables.
# edgeSpacingConstraints[6428] involves 5 variables.
# edgeSpacingConstraints[6429] involves 5 variables.
# edgeSpacingConstraints[6430] involves 5 variables.
# edgeSpacingConstraints[6431] involves 5 variables.
# edgeSpacingConstraints[6432] involves 5 variables.
# edgeSpacingConstraints[6433] involves 3 variables.
# edgeSpacingConstraints[6434] involves 3 variables.
# edgeSpacingConstraints[6435] involves 3 variables.
# edgeSpacingConstraints[6436] involves 3 variables.
# edgeSpacingConstraints[6437] involves 3 variables.
# edgeSpacingConstraints[6438] involves 3 variables.
# edgeSpacingConstraints[6439] involves 3 variables.
# edgeSpacingConstraints[6440] involves 3 variables.
# edgeSpacingConstraints[6441] involves 3 variables.
# edgeSpacingConstraints[6442] involves 3 variables.
# edgeSpacingConstraints[6443] involves 3 variables.
# edgeSpacingConstraints[6444] involves 3 variables.
# edgeSpacingConstraints[6445] involves 3 variables.
# edgeSpacingConstraints[6446] involves 3 variables.
# edgeSpacingConstraints[6447] involves 3 variables.
# edgeSpacingConstraints[6448] involves 3 variables.
# edgeSpacingConstraints[6449] involves 5 variables.
# edgeSpacingConstraints[6450] involves 5 variables.
# edgeSpacingConstraints[6451] involves 5 variables.
# edgeSpacingConstraints[6452] involves 5 variables.
# edgeSpacingConstraints[6453] involves 5 variables.
# edgeSpacingConstraints[6454] involves 5 variables.
# edgeSpacingConstraints[6455] involves 5 variables.
# edgeSpacingConstraints[6456] involves 5 variables.
# edgeSpacingConstraints[6457] involves 5 variables.
# edgeSpacingConstraints[6458] involves 5 variables.
# edgeSpacingConstraints[6459] involves 5 variables.
# edgeSpacingConstraints[6460] involves 5 variables.
# edgeSpacingConstraints[6461] involves 5 variables.
# edgeSpacingConstraints[6462] involves 5 variables.
# edgeSpacingConstraints[6463] involves 5 variables.
# edgeSpacingConstraints[6464] involves 5 variables.
# edgeSpacingConstraints[6465] involves 3 variables.
# edgeSpacingConstraints[6466] involves 3 variables.
# edgeSpacingConstraints[6467] involves 3 variables.
# edgeSpacingConstraints[6468] involves 3 variables.
# edgeSpacingConstraints[6469] involves 3 variables.
# edgeSpacingConstraints[6470] involves 3 variables.
# edgeSpacingConstraints[6471] involves 3 variables.
# edgeSpacingConstraints[6472] involves 3 variables.
# edgeSpacingConstraints[6473] involves 3 variables.
# edgeSpacingConstraints[6474] involves 3 variables.
# edgeSpacingConstraints[6475] involves 3 variables.
# edgeSpacingConstraints[6476] involves 3 variables.
# edgeSpacingConstraints[6477] involves 3 variables.
# edgeSpacingConstraints[6478] involves 3 variables.
# edgeSpacingConstraints[6479] involves 3 variables.
# edgeSpacingConstraints[6480] involves 3 variables.
# edgeSpacingConstraints[6481] involves 5 variables.
# edgeSpacingConstraints[6482] involves 5 variables.
# edgeSpacingConstraints[6483] involves 5 variables.
# edgeSpacingConstraints[6484] involves 5 variables.
# edgeSpacingConstraints[6485] involves 5 variables.
# edgeSpacingConstraints[6486] involves 5 variables.
# edgeSpacingConstraints[6487] involves 5 variables.
# edgeSpacingConstraints[6488] involves 5 variables.
# edgeSpacingConstraints[6489] involves 5 variables.
# edgeSpacingConstraints[6490] involves 5 variables.
# edgeSpacingConstraints[6491] involves 5 variables.
# edgeSpacingConstraints[6492] involves 5 variables.
# edgeSpacingConstraints[6493] involves 5 variables.
# edgeSpacingConstraints[6494] involves 5 variables.
# edgeSpacingConstraints[6495] involves 5 variables.
# edgeSpacingConstraints[6496] involves 5 variables.
# edgeSpacingConstraints[6497] involves 3 variables.
# edgeSpacingConstraints[6498] involves 3 variables.
# edgeSpacingConstraints[6499] involves 3 variables.
# edgeSpacingConstraints[6500] involves 3 variables.
# edgeSpacingConstraints[6501] involves 3 variables.
# edgeSpacingConstraints[6502] involves 3 variables.
# edgeSpacingConstraints[6503] involves 3 variables.
# edgeSpacingConstraints[6504] involves 3 variables.
# edgeSpacingConstraints[6505] involves 3 variables.
# edgeSpacingConstraints[6506] involves 3 variables.
# edgeSpacingConstraints[6507] involves 3 variables.
# edgeSpacingConstraints[6508] involves 3 variables.
# edgeSpacingConstraints[6509] involves 3 variables.
# edgeSpacingConstraints[6510] involves 3 variables.
# edgeSpacingConstraints[6511] involves 3 variables.
# edgeSpacingConstraints[6512] involves 3 variables.
# edgeSpacingConstraints[6513] involves 5 variables.
# edgeSpacingConstraints[6514] involves 5 variables.
# edgeSpacingConstraints[6515] involves 5 variables.
# edgeSpacingConstraints[6516] involves 5 variables.
# edgeSpacingConstraints[6517] involves 5 variables.
# edgeSpacingConstraints[6518] involves 5 variables.
# edgeSpacingConstraints[6519] involves 5 variables.
# edgeSpacingConstraints[6520] involves 5 variables.
# edgeSpacingConstraints[6521] involves 5 variables.
# edgeSpacingConstraints[6522] involves 5 variables.
# edgeSpacingConstraints[6523] involves 5 variables.
# edgeSpacingConstraints[6524] involves 5 variables.
# edgeSpacingConstraints[6525] involves 5 variables.
# edgeSpacingConstraints[6526] involves 5 variables.
# edgeSpacingConstraints[6527] involves 5 variables.
# edgeSpacingConstraints[6528] involves 5 variables.
# edgeSpacingConstraints[6529] involves 3 variables.
# edgeSpacingConstraints[6530] involves 3 variables.
# edgeSpacingConstraints[6531] involves 3 variables.
# edgeSpacingConstraints[6532] involves 3 variables.
# edgeSpacingConstraints[6533] involves 3 variables.
# edgeSpacingConstraints[6534] involves 3 variables.
# edgeSpacingConstraints[6535] involves 3 variables.
# edgeSpacingConstraints[6536] involves 3 variables.
# edgeSpacingConstraints[6537] involves 3 variables.
# edgeSpacingConstraints[6538] involves 3 variables.
# edgeSpacingConstraints[6539] involves 3 variables.
# edgeSpacingConstraints[6540] involves 3 variables.
# edgeSpacingConstraints[6541] involves 3 variables.
# edgeSpacingConstraints[6542] involves 3 variables.
# edgeSpacingConstraints[6543] involves 3 variables.
# edgeSpacingConstraints[6544] involves 3 variables.
# edgeSpacingConstraints[6545] involves 5 variables.
# edgeSpacingConstraints[6546] involves 5 variables.
# edgeSpacingConstraints[6547] involves 5 variables.
# edgeSpacingConstraints[6548] involves 5 variables.
# edgeSpacingConstraints[6549] involves 5 variables.
# edgeSpacingConstraints[6550] involves 5 variables.
# edgeSpacingConstraints[6551] involves 5 variables.
# edgeSpacingConstraints[6552] involves 5 variables.
# edgeSpacingConstraints[6553] involves 5 variables.
# edgeSpacingConstraints[6554] involves 5 variables.
# edgeSpacingConstraints[6555] involves 5 variables.
# edgeSpacingConstraints[6556] involves 5 variables.
# edgeSpacingConstraints[6557] involves 5 variables.
# edgeSpacingConstraints[6558] involves 5 variables.
# edgeSpacingConstraints[6559] involves 5 variables.
# edgeSpacingConstraints[6560] involves 5 variables.
# edgeSpacingConstraints[6561] involves 3 variables.
# edgeSpacingConstraints[6562] involves 3 variables.
# edgeSpacingConstraints[6563] involves 3 variables.
# edgeSpacingConstraints[6564] involves 3 variables.
# edgeSpacingConstraints[6565] involves 3 variables.
# edgeSpacingConstraints[6566] involves 3 variables.
# edgeSpacingConstraints[6567] involves 3 variables.
# edgeSpacingConstraints[6568] involves 3 variables.
# edgeSpacingConstraints[6569] involves 3 variables.
# edgeSpacingConstraints[6570] involves 3 variables.
# edgeSpacingConstraints[6571] involves 3 variables.
# edgeSpacingConstraints[6572] involves 3 variables.
# edgeSpacingConstraints[6573] involves 3 variables.
# edgeSpacingConstraints[6574] involves 3 variables.
# edgeSpacingConstraints[6575] involves 3 variables.
# edgeSpacingConstraints[6576] involves 3 variables.
# edgeSpacingConstraints[6577] involves 5 variables.
# edgeSpacingConstraints[6578] involves 5 variables.
# edgeSpacingConstraints[6579] involves 5 variables.
# edgeSpacingConstraints[6580] involves 5 variables.
# edgeSpacingConstraints[6581] involves 5 variables.
# edgeSpacingConstraints[6582] involves 5 variables.
# edgeSpacingConstraints[6583] involves 5 variables.
# edgeSpacingConstraints[6584] involves 5 variables.
# edgeSpacingConstraints[6585] involves 5 variables.
# edgeSpacingConstraints[6586] involves 5 variables.
# edgeSpacingConstraints[6587] involves 5 variables.
# edgeSpacingConstraints[6588] involves 5 variables.
# edgeSpacingConstraints[6589] involves 5 variables.
# edgeSpacingConstraints[6590] involves 5 variables.
# edgeSpacingConstraints[6591] involves 5 variables.
# edgeSpacingConstraints[6592] involves 5 variables.
# edgeSpacingConstraints[6593] involves 3 variables.
# edgeSpacingConstraints[6594] involves 3 variables.
# edgeSpacingConstraints[6595] involves 3 variables.
# edgeSpacingConstraints[6596] involves 3 variables.
# edgeSpacingConstraints[6597] involves 3 variables.
# edgeSpacingConstraints[6598] involves 3 variables.
# edgeSpacingConstraints[6599] involves 3 variables.
# edgeSpacingConstraints[6600] involves 3 variables.
# edgeSpacingConstraints[6601] involves 3 variables.
# edgeSpacingConstraints[6602] involves 3 variables.
# edgeSpacingConstraints[6603] involves 3 variables.
# edgeSpacingConstraints[6604] involves 3 variables.
# edgeSpacingConstraints[6605] involves 3 variables.
# edgeSpacingConstraints[6606] involves 3 variables.
# edgeSpacingConstraints[6607] involves 3 variables.
# edgeSpacingConstraints[6608] involves 3 variables.
# edgeSpacingConstraints[6609] involves 5 variables.
# edgeSpacingConstraints[6610] involves 5 variables.
# edgeSpacingConstraints[6611] involves 5 variables.
# edgeSpacingConstraints[6612] involves 5 variables.
# edgeSpacingConstraints[6613] involves 5 variables.
# edgeSpacingConstraints[6614] involves 5 variables.
# edgeSpacingConstraints[6615] involves 5 variables.
# edgeSpacingConstraints[6616] involves 5 variables.
# edgeSpacingConstraints[6617] involves 5 variables.
# edgeSpacingConstraints[6618] involves 5 variables.
# edgeSpacingConstraints[6619] involves 5 variables.
# edgeSpacingConstraints[6620] involves 5 variables.
# edgeSpacingConstraints[6621] involves 5 variables.
# edgeSpacingConstraints[6622] involves 5 variables.
# edgeSpacingConstraints[6623] involves 5 variables.
# edgeSpacingConstraints[6624] involves 5 variables.
# edgeSpacingConstraints[6625] involves 3 variables.
# edgeSpacingConstraints[6626] involves 3 variables.
# edgeSpacingConstraints[6627] involves 3 variables.
# edgeSpacingConstraints[6628] involves 3 variables.
# edgeSpacingConstraints[6629] involves 3 variables.
# edgeSpacingConstraints[6630] involves 3 variables.
# edgeSpacingConstraints[6631] involves 3 variables.
# edgeSpacingConstraints[6632] involves 3 variables.
# edgeSpacingConstraints[6633] involves 3 variables.
# edgeSpacingConstraints[6634] involves 3 variables.
# edgeSpacingConstraints[6635] involves 3 variables.
# edgeSpacingConstraints[6636] involves 3 variables.
# edgeSpacingConstraints[6637] involves 3 variables.
# edgeSpacingConstraints[6638] involves 3 variables.
# edgeSpacingConstraints[6639] involves 3 variables.
# edgeSpacingConstraints[6640] involves 3 variables.
# edgeSpacingConstraints[6641] involves 5 variables.
# edgeSpacingConstraints[6642] involves 5 variables.
# edgeSpacingConstraints[6643] involves 5 variables.
# edgeSpacingConstraints[6644] involves 5 variables.
# edgeSpacingConstraints[6645] involves 5 variables.
# edgeSpacingConstraints[6646] involves 5 variables.
# edgeSpacingConstraints[6647] involves 5 variables.
# edgeSpacingConstraints[6648] involves 5 variables.
# edgeSpacingConstraints[6649] involves 5 variables.
# edgeSpacingConstraints[6650] involves 5 variables.
# edgeSpacingConstraints[6651] involves 5 variables.
# edgeSpacingConstraints[6652] involves 5 variables.
# edgeSpacingConstraints[6653] involves 5 variables.
# edgeSpacingConstraints[6654] involves 5 variables.
# edgeSpacingConstraints[6655] involves 5 variables.
# edgeSpacingConstraints[6656] involves 5 variables.
# RposConstraintUpper[(6194, 6199)] involves 2 variables.
# RposConstraintUpper[(6174, 6199)] involves 2 variables.
# RposConstraintUpper[(6174, 6180)] involves 2 variables.
# RposConstraintUpper[(6174, 6192)] involves 2 variables.
# RposConstraintUpper[(6193, 6198)] involves 2 variables.
# RposConstraintUpper[(6193, 6398)] involves 2 variables.
# RposConstraintUpper[(6192, 6556)] involves 2 variables.
# RposConstraintUpper[(6192, 6193)] involves 2 variables.
# RposConstraintUpper[(6188, 6198)] involves 2 variables.
# RposConstraintUpper[(6188, 6189)] involves 2 variables.
# RposConstraintUpper[(6188, 6191)] involves 2 variables.
# RposConstraintUpper[(6175, 6177)] involves 2 variables.
# RposConstraintUpper[(6175, 6188)] involves 2 variables.
# RposConstraintUpper[(6176, 6177)] involves 2 variables.
# RposConstraintUpper[(6176, 6180)] involves 2 variables.
# RposConstraintUpper[(6178, 6180)] involves 2 variables.
# RposConstraintUpper[(6178, 6186)] involves 2 variables.
# RposConstraintUpper[(6178, 6194)] involves 2 variables.
# RposConstraintUpper[(6182, 6186)] involves 2 variables.
# RposConstraintUpper[(6186, 6188)] involves 2 variables.
# RposConstraintUpper[(6181, 6186)] involves 2 variables.
# RposConstraintUpper[(6181, 6188)] involves 2 variables.
# RposConstraintUpper[(6185, 6194)] involves 2 variables.
# RposConstraintLower[(6194, 6199)] involves 2 variables.
# RposConstraintLower[(6174, 6199)] involves 2 variables.
# RposConstraintLower[(6174, 6180)] involves 2 variables.
# RposConstraintLower[(6174, 6192)] involves 2 variables.
# RposConstraintLower[(6193, 6198)] involves 2 variables.
# RposConstraintLower[(6193, 6398)] involves 2 variables.
# RposConstraintLower[(6192, 6556)] involves 2 variables.
# RposConstraintLower[(6192, 6193)] involves 2 variables.
# RposConstraintLower[(6188, 6198)] involves 2 variables.
# RposConstraintLower[(6188, 6189)] involves 2 variables.
# RposConstraintLower[(6188, 6191)] involves 2 variables.
# RposConstraintLower[(6175, 6177)] involves 2 variables.
# RposConstraintLower[(6175, 6188)] involves 2 variables.
# RposConstraintLower[(6176, 6177)] involves 2 variables.
# RposConstraintLower[(6176, 6180)] involves 2 variables.
# RposConstraintLower[(6178, 6180)] involves 2 variables.
# RposConstraintLower[(6178, 6186)] involves 2 variables.
# RposConstraintLower[(6178, 6194)] involves 2 variables.
# RposConstraintLower[(6182, 6186)] involves 2 variables.
# RposConstraintLower[(6186, 6188)] involves 2 variables.
# RposConstraintLower[(6181, 6186)] involves 2 variables.
# RposConstraintLower[(6181, 6188)] involves 2 variables.
# RposConstraintLower[(6185, 6194)] involves 2 variables.

# %%
from collections import defaultdict

def count_variables_in_constraints(model):
    # Dictionary to hold the sum of variables for each constraint type
    sum_variables_by_constraint = defaultdict(int)

    for constraint_object in model.component_objects(ctype=pyomo.environ.Constraint, active=True):
        for index in constraint_object:
            expr = constraint_object[index].body
            # Use identify_variables to get a generator of variables in the expression
            variables = list(identify_variables(expr))
            num_variables = len(variables)
            # Add the number of variables to the total for this type of constraint
            sum_variables_by_constraint[constraint_object.name] += num_variables

    # Print the total number of variables for each type of constraint
    for constraint_name, total_variables in sum_variables_by_constraint.items():
        print(f"{constraint_name} involves a total of {total_variables} variables.")

# Call the function to count variables in constraints
count_variables_in_constraints(model)
# Out:
# alpha_direction_constraint involves a total of 69 variables.
# DirForwardConstraint involves a total of 92 variables.
# DirBackwardConstraint involves a total of 92 variables.
# sector_constraints involves a total of 798 variables.
# BetaSumConstraint involves a total of 40 variables.
# OrderMaintenanceConstraints involves a total of 120 variables.
# NonIncidentEdgeDirectionConstraint involves a total of 1616 variables.
# edgeSpacingConstraints involves a total of 26624 variables.
# RposConstraintUpper involves a total of 46 variables.
# RposConstraintLower involves a total of 46 variables.

# %%
# Check if the solver found an optimal solution
if (results.solver.status == SolverStatus.ok) and (results.solver.termination_condition == TerminationCondition.optimal):
    # Print the value of the cost expression after solving
    optimized_cost = value(model.RelativePositionObjective.expr)
    print(f"Optimized Relative Position Cost: {optimized_cost}")
else:
    print("Solver did not find an optimal solution.")
# Out:
# Optimized Relative Position Cost: 13.0

# %% [markdown]
# ## DEBUGGING

# %%
""" # After solving the model
for node in model.NodesWith2Neighbours:
    beta_values = [model.Beta[node, index].value for index in range(len(model.OrderedNeighbours[node]))]
    beta_sum = sum(value for value in beta_values if value is not None)
    print(f"Node: {node}, Beta Values: {beta_values}, Sum of Beta values: {beta_sum}")

    # If all Beta values are available (None of them is None), proceed with additional checks
    if None not in beta_values:
        # For the last neighbor pair, check the wrap-around constraint
        last_index = len(model.OrderedNeighbours[node]) - 1
        # Check if the Beta variable for the wrap-around case is 1 (active)
        if model.Beta[node, last_index].value == 1:
            # Print details for the wrap-around case
            print(f"Node {node} uses wrap-around with Beta[{node}, {last_index}] active.")
            
            
# Iterate through each node in the set of nodes with 2 or more neighbours
for node in model.NodesWith2Neighbours:
    # Access the ordered list of neighbours for the current node from the model parameter
    ordered_neighbours = model.OrderedNeighbours[node]
    
    # Print the current node, its ordered neighbours, and the count of neighbours
    print(f"Node: {node}")
    print(f"Ordered Neighbours: {ordered_neighbours}")
    print(f"Number of Neighbours: {len(ordered_neighbours)}")
    print("-------")  # Just a separator for clarity
 

# After solving the model
for (node, index) in model.Beta:
    beta_value = model.Beta[node, index].value
    print(f"Beta[{node}, {index}]: {beta_value}")


# After solving the model
for node in model.NodesWith2Neighbours:
    beta_sum = sum(model.Beta[node, index].value for index in range(0, len(model.OrderedNeighbours[node])))
    print(f"Sum of Beta values for Node {node}: {beta_sum}")           




# Debugging for binary direction constraint incident edges
# After solving the model
for (u1, v1, u2, v2) in model.NonIncidentEdges:
    e1 = (u1, v1)
    e2 = (u2, v2)
    print(f"Edge pair: {e1}, {e2}")
    print(f"  is_N: {model.is_N[e1, e2].value}")
    print(f"  is_S: {model.is_S[e1, e2].value}")
    print(f"  is_E: {model.is_E[e1, e2].value}")
    print(f"  is_W: {model.is_W[e1, e2].value}")
    print(f"  is_NE: {model.is_NE[e1, e2].value}")
    print(f"  is_NW: {model.is_NW[e1, e2].value}")
    print(f"  is_SE: {model.is_SE[e1, e2].value}")
    print(f"  is_SW: {model.is_SW[e1, e2].value}") """
# Out:
# ' # After solving the model\nfor node in model.NodesWith2Neighbours:\n    beta_values = [model.Beta[node, index].value for index in range(len(model.OrderedNeighbours[node]))]\n    beta_sum = sum(value for value in beta_values if value is not None)\n    print(f"Node: {node}, Beta Values: {beta_values}, Sum of Beta values: {beta_sum}")\n\n    # If all Beta values are available (None of them is None), proceed with additional checks\n    if None not in beta_values:\n        # For the last neighbor pair, check the wrap-around constraint\n        last_index = len(model.OrderedNeighbours[node]) - 1\n        # Check if the Beta variable for the wrap-around case is 1 (active)\n        if model.Beta[node, last_index].value == 1:\n            # Print details for the wrap-around case\n            print(f"Node {node} uses wrap-around with Beta[{node}, {last_index}] active.")\n            \n            \n# Iterate through each node in the set of nodes with 2 or more neighbours\nfor node in model.NodesWith2Neighbours:\n    # Access the ordered list of neighbours for the current node from the model parameter\n    ordered_neighbours = model.OrderedNeighbours[node]\n    \n    # Print the current node, its ordered neighbours, and the count of neighbours\n    print(f"Node: {node}")\n    print(f"Ordered Neighbours: {ordered_neighbours}")\n    print(f"Number of Neighbours: {len(ordered_neighbours)}")\n    print("-------")  # Just a separator for clarity\n \n\n# After solving the model\nfor (node, index) in model.Beta:\n    beta_value = model.Beta[node, index].value\n    print(f"Beta[{node}, {index}]: {beta_value}")\n\n\n# After solving the model\nfor node in model.NodesWith2Neighbours:\n    beta_sum = sum(model.Beta[node, index].value for index in range(0, len(model.OrderedNeighbours[node])))\n    print(f"Sum of Beta values for Node {node}: {beta_sum}")           \n\n\n\n\n# Debugging for binary direction constraint incident edges\n# After solving the model\nfor (u1, v1, u2, v2) in model.NonIncidentEdges:\n    e1 = (u1, v1)\n    e2 = (u2, v2)\n    print(f"Edge pair: {e1}, {e2}")\n    print(f"  is_N: {model.is_N[e1, e2].value}")\n    print(f"  is_S: {model.is_S[e1, e2].value}")\n    print(f"  is_E: {model.is_E[e1, e2].value}")\n    print(f"  is_W: {model.is_W[e1, e2].value}")\n    print(f"  is_NE: {model.is_NE[e1, e2].value}")\n    print(f"  is_NW: {model.is_NW[e1, e2].value}")\n    print(f"  is_SE: {model.is_SE[e1, e2].value}")\n    print(f"  is_SW: {model.is_SW[e1, e2].value}") '

# %%
"""  # Debugging for dir forward constraint
for edge in model.Edges:
    node1, node2 = edge
    print(f"\nEdge: {(node1, node2)}")
    
    forward = edge_details[edge].get('forward_sector')
    print(f"sec-for original = {forward}")
    print(f"dir_forward[{node1}, {node2}]: {model.dir_forward[node1, node2].value}")
     
print("\n\n")
 # debugging for dir backward constraint
for edge in model.Edges:
    node1, node2 = edge
    print(f"\nEdge: {(node1, node2)}")
    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")
    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")
    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}")
    print(f"dir_backward[{node1}, {node2}]: {model.dir_backward[node1, node2].value}")  """
# Out:
# '  # Debugging for dir forward constraint\nfor edge in model.Edges:\n    node1, node2 = edge\n    print(f"\nEdge: {(node1, node2)}")\n    \n    forward = edge_details[edge].get(\'forward_sector\')\n    print(f"sec-for original = {forward}")\n    print(f"dir_forward[{node1}, {node2}]: {model.dir_forward[node1, node2].value}")\n     \nprint("\n\n")\n # debugging for dir backward constraint\nfor edge in model.Edges:\n    node1, node2 = edge\n    print(f"\nEdge: {(node1, node2)}")\n    print(f"alpha_pred[{node1}, {node2}]: {model.alpha_pred[node1, node2].value}")\n    print(f"alpha_orig[{node1}, {node2}]: {model.alpha_orig[node1, node2].value}")\n    print(f"alpha_succ[{node1}, {node2}]: {model.alpha_succ[node1, node2].value}")\n    print(f"dir_backward[{node1}, {node2}]: {model.dir_backward[node1, node2].value}")  '

# %%
# Print initial positions
print("Initial Positions:")
for node in model.Nodes:
    print(f"Node {node}: x = {model.x_init[node]}, y = {model.y_init[node]}")

# After solving the model

# Print final positions
print("\nFinal Positions:")
for node in model.Nodes:
    print(f"Node {node}: x = {value(model.x_pos[node])}, y = {value(model.y_pos[node])}")
# Out:
# Initial Positions:
# Node 6194: x = -933143.2012999885, y = 7005300.7157662185
# Node 6199: x = -956380.1431276693, y = 7021199.753507257
# Node 6174: x = -994292.8900240782, y = 7033429.505480125
# Node 6193: x = -736241.5086238278, y = 7169181.763432151
# Node 6198: x = -743579.4668179399, y = 7114147.184426849
# Node 6192: x = -928251.266277078, y = 7155728.851095909
# Node 6556: x = -936812.1803970463, y = 7209540.485041131
# Node 6398: x = -717896.6131385515, y = 7231554.344659001
# Node 6188: x = -737464.4645496837, y = 7037098.559885431
# Node 6175: x = -895230.4544035797, y = 7032206.615032485
# Node 6177: x = -955157.0758823229, y = 6905015.398618673
# Node 6176: x = -1050550.532405767, y = 6898900.412749045
# Node 6178: x = -1048104.5092345652, y = 6919691.307246547
# Node 6180: x = -1027313.7018975778, y = 6919691.307246547
# Node 6182: x = -786384.1487372603, y = 6933144.195593818
# Node 6186: x = -747248.3345955035, y = 7005300.7157662185
# Node 6181: x = -716673.5458932046, y = 6984509.847294063
# Node 6189: x = -713004.5667961502, y = 7033429.505480125
# Node 6191: x = -716673.5458932046, y = 7055443.505209369
# Node 6185: x = -736241.5086238278, y = 7065227.487227938
#
# Final Positions:
# Node 6194: x = 5328.035630743778, y = -1539.3409223665149
# Node 6199: x = 4335.552574126583, y = -546.8578657493199
# Node 6174: x = 846.8234464138568, y = -546.8578657493199
# Node 6193: x = 15726.05806048554, y = 4708.3536960346355
# Node 6198: x = 15726.05806048554, y = 1932.2725927753308
# Node 6192: x = 6102.035008197787, y = 4708.353696034614
# Node 6556: x = 6102.035008197787, y = 7432.771614794528
# Node 6398: x = 14100.697700583445, y = 6333.714055936725
# Node 6188: x = 17658.330653260877, y = 0.0
# Node 6175: x = 9766.239884804163, y = 0.0
# Node 6177: x = 9766.239884804163, y = -9912.411689893685
# Node 6176: x = 846.8234464138559, y = -9912.411689893685
# Node 6178: x = 0.0, y = -6867.376553110293
# Node 6180: x = 846.8234464138568, y = -7714.1999995241495
# Node 6182: x = 14764.785421070746, y = -9760.921785300421
# Node 6186: x = 17658.330653260877, y = -6867.376553110293
# Node 6181: x = 20264.998835458584, y = -6867.376553110293
# Node 6189: x = 18895.008216676677, y = 0.0
# Node 6191: x = 18635.715532402246, y = 977.3848791413711
# Node 6185: x = 15618.98973089436, y = -1539.3409223665149

# %%
def print_edge_constraints(model, edge):
    node1, node2 = edge
    constraints = []
    M = 10000  # This should be the same M used in your constraints
    
    # Retrieve original sector and minimum edge length directly
    sect_orig = model.sect_forward[edge]
    min_length = model.distance[edge]
    
    print(f'Forward sector: {sect_orig}')
    
    for alpha in [model.alpha_pred, model.alpha_orig, model.alpha_succ]:
        # Get the value of the alpha variable for this edge
        alpha_value = alpha[edge].value
        # Adjusted sector based on alpha variable
        sect_adjusted = (sect_orig + (-1 if alpha is model.alpha_pred else 0 if alpha is model.alpha_orig else 1)) % 8
        if sect_adjusted in [0, 4]:  # Horizontal
            constraints.append((node1, node2, 'Horizontal', sect_adjusted, alpha_value))
        elif sect_adjusted in [1, 5]:  # Diagonal /
            constraints.append((node1, node2, 'Diagonal /', sect_adjusted, alpha_value))
        elif sect_adjusted in [2, 6]:  # Vertical
            constraints.append((node1, node2, 'Vertical', sect_adjusted, alpha_value))
        elif sect_adjusted in [3, 7]:  # Diagonal \
            constraints.append((node1, node2, 'Diagonal \\', sect_adjusted, alpha_value))
    
    for c in constraints:
        print(f'Edge: {c[0]} -> {c[1]}, Type: {c[2]}, Adjusted Sector: {c[3]}, Alpha Value: {c[4]}')

# Call this function with the model and the specific edge you're interested in after solving the model
#print_edge_constraints(model, (6185, 6195))

for edge in list(G.edges()):
    print_edge_constraints(model, edge)
    print("\n----------\n")
# Out:
# Forward sector: 3
# Edge: 6194 -> 6199, Type: Vertical, Adjusted Sector: 2, Alpha Value: -0.0
# Edge: 6194 -> 6199, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: 1.0
# Edge: 6194 -> 6199, Type: Horizontal, Adjusted Sector: 4, Alpha Value: -0.0
#
# ----------
#
# Forward sector: 0
# Edge: 6174 -> 6199, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: -0.0
# Edge: 6174 -> 6199, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 1.0
# Edge: 6174 -> 6199, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: -0.0
#
# ----------
#
# Forward sector: 6
# Edge: 6174 -> 6180, Type: Diagonal /, Adjusted Sector: 5, Alpha Value: 0.0
# Edge: 6174 -> 6180, Type: Vertical, Adjusted Sector: 6, Alpha Value: 1.0
# Edge: 6174 -> 6180, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 1
# Edge: 6174 -> 6192, Type: Horizontal, Adjusted Sector: 0, Alpha Value: -0.0
# Edge: 6174 -> 6192, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 1.0
# Edge: 6174 -> 6192, Type: Vertical, Adjusted Sector: 2, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 6
# Edge: 6193 -> 6198, Type: Diagonal /, Adjusted Sector: 5, Alpha Value: 0.0
# Edge: 6193 -> 6198, Type: Vertical, Adjusted Sector: 6, Alpha Value: 1.0
# Edge: 6193 -> 6198, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 2
# Edge: 6193 -> 6398, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: -0.0
# Edge: 6193 -> 6398, Type: Vertical, Adjusted Sector: 2, Alpha Value: -0.0
# Edge: 6193 -> 6398, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: 1.0
#
# ----------
#
# Forward sector: 2
# Edge: 6192 -> 6556, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: -0.0
# Edge: 6192 -> 6556, Type: Vertical, Adjusted Sector: 2, Alpha Value: 1.0
# Edge: 6192 -> 6556, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: -0.0
#
# ----------
#
# Forward sector: 0
# Edge: 6192 -> 6193, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: -0.0
# Edge: 6192 -> 6193, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 1.0
# Edge: 6192 -> 6193, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: -0.0
#
# ----------
#
# Forward sector: 2
# Edge: 6188 -> 6198, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
# Edge: 6188 -> 6198, Type: Vertical, Adjusted Sector: 2, Alpha Value: -0.0
# Edge: 6188 -> 6198, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: 1.0
#
# ----------
#
# Forward sector: 0
# Edge: 6188 -> 6189, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: 0.0
# Edge: 6188 -> 6189, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 1.0
# Edge: 6188 -> 6189, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 1
# Edge: 6188 -> 6191, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 0.0
# Edge: 6188 -> 6191, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 1.0
# Edge: 6188 -> 6191, Type: Vertical, Adjusted Sector: 2, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 5
# Edge: 6175 -> 6177, Type: Horizontal, Adjusted Sector: 4, Alpha Value: 0.0
# Edge: 6175 -> 6177, Type: Diagonal /, Adjusted Sector: 5, Alpha Value: 0.0
# Edge: 6175 -> 6177, Type: Vertical, Adjusted Sector: 6, Alpha Value: 1.0
#
# ----------
#
# Forward sector: 0
# Edge: 6175 -> 6188, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: 0.0
# Edge: 6175 -> 6188, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 1.0
# Edge: 6175 -> 6188, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 0
# Edge: 6176 -> 6177, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: -0.0
# Edge: 6176 -> 6177, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 1.0
# Edge: 6176 -> 6177, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 1
# Edge: 6176 -> 6180, Type: Horizontal, Adjusted Sector: 0, Alpha Value: -0.0
# Edge: 6176 -> 6180, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: -0.0
# Edge: 6176 -> 6180, Type: Vertical, Adjusted Sector: 2, Alpha Value: 1.0
#
# ----------
#
# Forward sector: 0
# Edge: 6178 -> 6180, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: 1.0
# Edge: 6178 -> 6180, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 0.0
# Edge: 6178 -> 6180, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 0
# Edge: 6178 -> 6186, Type: Diagonal \, Adjusted Sector: 7, Alpha Value: 0.0
# Edge: 6178 -> 6186, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 1.0
# Edge: 6178 -> 6186, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 1
# Edge: 6178 -> 6194, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 0.0
# Edge: 6178 -> 6194, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 1.0
# Edge: 6178 -> 6194, Type: Vertical, Adjusted Sector: 2, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 1
# Edge: 6182 -> 6186, Type: Horizontal, Adjusted Sector: 0, Alpha Value: 0.0
# Edge: 6182 -> 6186, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 1.0
# Edge: 6182 -> 6186, Type: Vertical, Adjusted Sector: 2, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 2
# Edge: 6186 -> 6188, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
# Edge: 6186 -> 6188, Type: Vertical, Adjusted Sector: 2, Alpha Value: 1.0
# Edge: 6186 -> 6188, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: 0.0
#
# ----------
#
# Forward sector: 3
# Edge: 6181 -> 6186, Type: Vertical, Adjusted Sector: 2, Alpha Value: 0.0
# Edge: 6181 -> 6186, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: 0.0
# Edge: 6181 -> 6186, Type: Horizontal, Adjusted Sector: 4, Alpha Value: 1.0
#
# ----------
#
# Forward sector: 2
# Edge: 6181 -> 6188, Type: Diagonal /, Adjusted Sector: 1, Alpha Value: 0.0
# Edge: 6181 -> 6188, Type: Vertical, Adjusted Sector: 2, Alpha Value: 0.0
# Edge: 6181 -> 6188, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: 1.0
#
# ----------
#
# Forward sector: 4
# Edge: 6185 -> 6194, Type: Diagonal \, Adjusted Sector: 3, Alpha Value: -0.0
# Edge: 6185 -> 6194, Type: Horizontal, Adjusted Sector: 4, Alpha Value: 1.0
# Edge: 6185 -> 6194, Type: Diagonal /, Adjusted Sector: 5, Alpha Value: 0.0
#
# ----------

# %% [markdown]
# # NetworkX Graph

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines


# First, ensure that you have defined 'value' function to extract values from the model
# Assuming value function is like this:
# def value(model_attribute):
#     return model_attribute()  # Adjust depending on how your model returns values

# Update positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}

# Increase the figure size
plt.figure(figsize=(15, 15))

# Draw nodes with updated positions
nx.draw_networkx_nodes(G, updated_pos, node_color='skyblue', node_size=500)


# Create custom lines for the legend
red_line = mlines.Line2D([], [], color='red', markersize=20, label='380 kV', linewidth = 3)
green_line = mlines.Line2D([], [], color='green', markersize=20, label='220 kV', linewidth = 3)




# Draw the graph edges with different colors based on the voltage using updated positions
for (u, v, d) in G.edges(data=True):
    edge_color = 'r' if d['voltage'] == 380.0 else 'g' if d['voltage'] == 220.0 else 'k'
    nx.draw_networkx_edges(G, updated_pos, edgelist=[(u, v)], edge_color=edge_color, width=3, arrows = False)

# Draw the node labels with updated positions
nx.draw_networkx_labels(G, updated_pos, font_size=10)

# Get the edge labels for the link_ids
edge_labels = nx.get_edge_attributes(G, 'link_id')

# Draw the edge labels with updated positions
nx.draw_networkx_edge_labels(G, updated_pos, edge_labels=edge_labels, label_pos=0.5, font_size=7)

# Optionally, if you want to make the plot title and axes invisible
#plt.title("Optimized Graph")
plt.axis('equal')  # Turn off the axis

# Add the legend to the plot
plt.legend(handles=[red_line, green_line], loc='lower right', fontsize = 20)
plt.grid(True)

# Show the plot with the optimized graph
plt.show()
# Out:
# C:\Users\katec\AppData\Local\Temp\ipykernel_8712\1494253743.py:30: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(G, updated_pos, edgelist=[(u, v)], edge_color=edge_color, width=3, arrows = False)

# %%
# Assuming 'G' is your graph and 'model' is your Pyomo model
# Updated positions based on optimized x and y coordinates
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}

# Initialize a list to store edge information along with the calculated angles
opt_edges_info = []

# Iterate through each edge in your graph
for edge in G.edges():
    node1, node2 = edge

    # Retrieve the updated positions for source and destination nodes
    src_x, src_y = updated_pos[node1]
    dst_x, dst_y = updated_pos[node2]

    # Calculate the angle using the updated positions
    angle = calculate_angle(src_x, src_y, dst_x, dst_y)

    formatted_angle = round(angle, 2)

    # Append the edge information and formatted angle to the list
    opt_edges_info.append({
        'Edge': edge,
        'Source': node1,
        'Destination': node2,
        'Angle (degrees)': formatted_angle  # Use the formatted angle
    })

# Convert the list of dictionaries to a pandas DataFrame for easy tabular display
opt_edges_info_df = pd.DataFrame(opt_edges_info)

# Print the DataFrame
#print(edges_info_df)
display(opt_edges_info_df)
# Out:
#             Edge  Source  Destination  Angle (degrees)
# 0   (6194, 6199)    6194         6199           135.00
# 1   (6174, 6199)    6174         6199             0.00
# 2   (6174, 6180)    6174         6180           270.00
# 3   (6174, 6192)    6174         6192            45.00
# 4   (6193, 6198)    6193         6198           270.00
# 5   (6193, 6398)    6193         6398           135.00
# 6   (6192, 6556)    6192         6556            90.00
# 7   (6192, 6193)    6192         6193             0.00
# 8   (6188, 6198)    6188         6198           135.00
# 9   (6188, 6189)    6188         6189             0.00
# 10  (6188, 6191)    6188         6191            45.00
# 11  (6175, 6177)    6175         6177           270.00
# 12  (6175, 6188)    6175         6188             0.00
# 13  (6176, 6177)    6176         6177             0.00
# 14  (6176, 6180)    6176         6180            90.00
# 15  (6178, 6180)    6178         6180           315.00
# 16  (6178, 6186)    6178         6186             0.00
# 17  (6178, 6194)    6178         6194            45.00
# 18  (6182, 6186)    6182         6186            45.00
# 19  (6186, 6188)    6186         6188            90.00
# 20  (6181, 6186)    6181         6186           180.00
# 21  (6181, 6188)    6181         6188           110.79
# 22  (6185, 6194)    6185         6194           180.00

# %%
def count_octilinearity_violations(opt_edges_info):
    violations = 0
    for edge_info in opt_edges_info:
        angle = edge_info['Angle (degrees)']
        # Check if the angle is not an exact multiple of 45 (including 0)
        if angle % 45 != 0:
            violations += 1
    return violations

# Count the number of octilinearity violations using the updated edge information
octilinearity_violations = count_octilinearity_violations(opt_edges_info)

# Print the number of octilinearity violations
print(f"Number of Octilinearity Violations: {octilinearity_violations}")
# Out:
# Number of Octilinearity Violations: 1

# %%
def lines_intersect(line1, line2):
    """Check if two lines (each defined by two points) intersect."""
    def ccw(A, B, C):
        return (C[1] - A[1]) * (B[0] - A[0]) > (B[1] - A[1]) * (C[0] - A[0])

    A, B = line1
    C, D = line2

    return ccw(A, C, D) != ccw(B, C, D) and ccw(A, B, C) != ccw(A, B, D)

def count_edge_crossings(G, pos):
    crossings = 0
    edges = list(G.edges())
    for i in range(len(edges)):
        for j in range(i + 1, len(edges)):
            edge1, edge2 = edges[i], edges[j]
            if not set(edge1) & set(edge2):  # Ensure edges are not incident
                line1 = (pos[edge1[0]], pos[edge1[1]])
                line2 = (pos[edge2[0]], pos[edge2[1]])
                if lines_intersect(line1, line2):
                    crossings += 1
    return crossings

# %%
import pandas as pd
import networkx as nx
from pyomo.environ import value, SolverFactory
from pyomo.core import ConstraintList

def solve_model(model):
    solver = SolverFactory('gurobi')
    results = solver.solve(model, tee=True)
    return results

def extract_solver_stats(results):
    stats = {
        'Solver Status': str(results.solver.status),
        'Termination Condition': str(results.solver.termination_condition),
        'Solve Time (s)': results.solver.time,
        'Number of Constraints': results.problem.number_of_constraints,
        'Number of Variables': results.problem.number_of_variables,
        'Number of Nonzeros': results.problem.number_of_nonzeros
    }
    if results.solver.status == 'ok' and results.solver.termination_condition == 'optimal':
        stats['Objective Value'] = int(value(model.RelativePositionObjective.expr))
    else:
        stats['Objective Value'] = 'N/A'
    return stats

def count_edge_crossings(G, pos):
    crossings = 0
    edges = list(G.edges())
    for i in range(len(edges)):
        for j in range(i + 1, len(edges)):
            edge1, edge2 = edges[i], edges[j]
            if not set(edge1) & set(edge2):  # Ensure edges are not incident
                line1 = (pos[edge1[0]], pos[edge1[1]])
                line2 = (pos[edge2[0]], pos[edge2[1]])
                if lines_intersect(line1, line2):
                    crossings += 1
    return crossings

def calculate_edge_statistics(G, pos):
    # Use your custom euclidean_distance function to calculate lengths
    lengths = [euclidean_distance(pos[u][0], pos[u][1], pos[v][0], pos[v][1]) for u, v in G.edges()]
    avg_length = sum(lengths) / len(lengths) if lengths else 0
    std_dev_length = pd.Series(lengths).std() if lengths else 0
    min_length = min(lengths) if lengths else 0
    max_length = max(lengths) if lengths else 0
    return avg_length, std_dev_length, (min_length, max_length)


def calculate_node_displacement(initial_pos, updated_pos):
    displacements = [euclidean_distance(initial_pos[node][0], initial_pos[node][1], updated_pos[node][0], updated_pos[node][1]) for node in initial_pos]
    total_displacement = sum(displacements)
    return total_displacement



def display_results(stats, num_crossings, avg_length, std_dev_length, length_range, displacement, octilinearity_violations):
    
    

    # Round the other values to 2 decimal places
    avg_length = round(avg_length, 2)
    std_dev_length = round(std_dev_length, 2)
    length_range = (round(length_range[0], 2), round(length_range[1], 2))
    displacement = round(displacement, 2)
    
    results_df = pd.DataFrame([
        ['Solver Status', stats['Solver Status']],
        ['Objective Function Value', stats.get('Objective Value', 'N/A')],
        ['Computation Time (s)', stats['Solve Time (s)']],
        ['Number of Iterations', stats.get('Iterations', 'N/A')],
        
        ['Number of Constraints', stats['Number of Constraints']],
        ['Number of Variables', stats['Number of Variables']],
        
        ['Number of Edge Crossings', num_crossings],
        ['Octilinearity Violations', octilinearity_violations],  

        ['Edge Length Average', avg_length],
        ['Edge Length Standard Deviation', std_dev_length],
        ['Edge Length Range', f"{length_range[0]} to {length_range[1]}"],
        ['Total Node Displacement', displacement]
    ], columns=['Metric', 'Value'])
    
    display(results_df)
    #print(results_df.to_string(index=False))



# Example usage
results = solve_model(model)
stats = extract_solver_stats(results)

# Check for the number of iterations and add it to stats
if hasattr(results.solver, 'iterations'):
    stats['Number of Iterations'] = results.solver.iterations
else:
    stats['Number of Iterations'] = 'Not provided by solver'

initial_pos = nx.get_node_attributes(G, 'pos')  # Assuming initial positions are stored as node attributes
updated_pos = {node: (value(model.x_pos[node]), value(model.y_pos[node])) for node in G.nodes()}
num_crossings = count_edge_crossings(G, updated_pos)
avg_length, std_dev_length, length_range = calculate_edge_statistics(G, updated_pos)
displacement = calculate_node_displacement(initial_pos, updated_pos)
# Example usage
display_results(stats, num_crossings, avg_length, std_dev_length, length_range, displacement, octilinearity_violations)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-30
# Read LP format model from file C:\Users\katec\AppData\Local\Temp\tmp4fdqzci4.pyomo.lp
# Reading time = 0.22 seconds
# x1: 7234 rows, 1882 columns, 29527 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: AMD Ryzen 7 4700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7234 rows, 1882 columns and 29527 nonzeros
# Model fingerprint: 0xd1246c01
# Variable types: 63 continuous, 1819 integer (1773 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 271 rows and 178 columns
# Presolve time: 0.12s
# Presolved: 6963 rows, 1704 columns, 26635 nonzeros
# Variable types: 38 continuous, 1666 integer (1650 binary)
#
# Root relaxation: objective 3.002249e+00, 1343 iterations, 0.05 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.00225    0   20          -    3.00225      -     -    0s
#      0     0    3.00225    0   18          -    3.00225      -     -    0s
#      0     0    7.06422    0   93          -    7.06422      -     -    0s
#      0     0   10.02156    0   10          -   10.02156      -     -    0s
#      0     0   10.02156    0   12          -   10.02156      -     -    0s
#      0     0   10.04222    0   12          -   10.04222      -     -    0s
#      0     0   10.04222    0   32          -   10.04222      -     -    0s
#      0     0   10.04222    0   29          -   10.04222      -     -    0s
#      0     0   10.04222    0   26          -   10.04222      -     -    0s
#      0     0   10.04222    0   28          -   10.04222      -     -    0s
#      0     0   10.04222    0   14          -   10.04222      -     -    0s
#      0     0   10.04222    0   16          -   10.04222      -     -    1s
# H    0     0                      34.0000000   10.04222  70.5%     -    1s
#      0     0   10.04222    0   16   34.00000   10.04222  70.5%     -    1s
# H    0     0                      27.0000000   10.04222  62.8%     -    1s
#      0     0   10.04959    0    6   27.00000   10.04959  62.8%     -    1s
#      0     0   10.04959    0    6   27.00000   10.04959  62.8%     -    1s
# H    0     0                      26.0000000   10.04959  61.3%     -    1s
#      0     0   10.14337    0   22   26.00000   10.14337  61.0%     -    1s
#      0     0   11.00000    0    8   26.00000   11.00000  57.7%     -    1s
#      0     0   11.00000    0    8   26.00000   11.00000  57.7%     -    1s
#      0     0   11.00000    0   13   26.00000   11.00000  57.7%     -    1s
#      0     0   11.13314    0   15   26.00000   11.13314  57.2%     -    1s
#      0     0   11.13314    0   23   26.00000   11.13314  57.2%     -    1s
#      0     0   11.13314    0   22   26.00000   11.13314  57.2%     -    1s
#      0     0   11.13314    0   12   26.00000   11.13314  57.2%     -    1s
#      0     0   11.13314    0   12   26.00000   11.13314  57.2%     -    1s
#      0     0   11.13314    0   18   26.00000   11.13314  57.2%     -    1s
#      0     0   11.13314    0    6   26.00000   11.13314  57.2%     -    2s
# H    0     0                      20.0000000   11.13314  44.3%     -    2s
# H    0     0                      13.0000000   11.13314  14.4%     -    2s
#      0     0   11.13314    0    6   13.00000   11.13314  14.4%     -    2s
#
# Cutting planes:
#   Learned: 4
#   Gomory: 2
#   Implied bound: 2
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (5409 simplex iterations) in 2.16 seconds (1.63 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 13 20 26 ... 34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#                             Metric                Value
# 0                    Solver Status                   ok
# 1         Objective Function Value                   13
# 2             Computation Time (s)             2.664728
# 3             Number of Iterations                  N/A
# 4            Number of Constraints                 7234
# 5              Number of Variables                 1882
# 6         Number of Edge Crossings                    4
# 7         Octilinearity Violations                    1
# 8              Edge Length Average              5599.21
# 9   Edge Length Standard Deviation              4096.16
# 10               Edge Length Range  1197.59 to 17658.33
# 11         Total Node Displacement         141844903.42
